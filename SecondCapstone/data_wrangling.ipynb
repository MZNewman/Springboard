# %% [markdown]
# ## Table of Contents
# - [pokemon_df](#pokemon_df)
# - [pokemon_types_df](#pokemon_types_df)
# - [pokemon_abilities_df](#pokemon_abilities_df)
# - [moves_df](#moves_df)
# - [strategydex_df](#strategydex_df)
# - [pokemon_learnsets_df](#pokemon_learnsets_df)
# - [strategies_dict](#strategies_dict)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import json
import pandas_profiling

# %% [markdown]
# <a id='pokemon_df'></a>
# ### pokemon_df

# %% [markdown]
# First, we need load the dictionary of pokemon data from Smogon.com, contained in smogonpokemondata2021/smogonpokemondata2021/scraped_data/pokedex_dict.json (as a relative path from this file).
#
# If you are interested in examining this json in more detail to see more about its structure and the content it contains, all with a convenient graphical user interface, I recommend copying the text and pasting it into http://jsonviewer.stack.hu/

# %%
with open("smogonpokemondata2021/smogonpokemondata2021/scraped_data/pokedex_dict.json") as infile:
    pokedex_dict = json.load(infile)

# %% [markdown]
# Once loaded, we need to turn that JSON object into a Pandas Dataframe.  The part of the JSON we are accessing can be best observed by checking the JSON in the jsonviewer I mentioned before.  This is the data about the pokemon, which are the central feature of our project.  It contains many useful things like the names, the stats, the types, the abilities, as well as the target variable "formats" (which is the competitive format we ultimately aim to be able to predict).

# %%
pokemon_df = pd.DataFrame(pokedex_dict['injectRpcs'][1][1]['pokemon'])
pokemon_df
# Out:
#                  name   hp  atk  def  spa  spd  spe  weight  height  \
# 0           Bulbasaur   45   49   49   65   65   45     6.9     0.7
# 1             Ivysaur   60   62   63   80   80   60    13.0     1.0
# 2            Venusaur   80   82   83  100  100   80   100.0     2.0
# 3          Charmander   39   52   43   60   50   65     8.5     0.6
# 4          Charmeleon   58   64   58   80   65   80    19.0     1.1
# ...               ...  ...  ...  ...  ...  ...  ...     ...     ...
# 1201      Scizor-Mega   70  150  140   65  100   75   125.0     2.0
# 1202   Blastoise-Gmax   79   83  100   85  105   78     0.0     1.6
# 1203  Crucibelle-Mega  106  135   75   91  125  108    22.5     1.4
# 1204      Meowth-Gmax   40   45   35   40   40   90     0.0    33.0
# 1205       Eevee-Gmax   55   55   50   45   65   55     0.0    18.0
#
#                 types                               abilities         formats  \
# 0     [Grass, Poison]                 [Chlorophyll, Overgrow]            [LC]
# 1     [Grass, Poison]                 [Chlorophyll, Overgrow]           [NFE]
# 2     [Grass, Poison]                 [Chlorophyll, Overgrow]          [RUBL]
# 3              [Fire]                    [Blaze, Solar Power]            [LC]
# 4              [Fire]                    [Blaze, Solar Power]           [NFE]
# ...               ...                                     ...             ...
# 1201     [Bug, Steel]                            [Technician]  [National Dex]
# 1202          [Water]                    [Rain Dish, Torrent]            [AG]
# 1203   [Rock, Poison]                           [Magic Guard]           [CAP]
# 1204         [Normal]           [Pickup, Technician, Unnerve]            [AG]
# 1205         [Normal]  [Adaptability, Anticipation, Run Away]            [AG]
#
#      isNonstandard                                                oob
# 0         Standard  {'dex_number': 1, 'evos': ['Ivysaur'], 'alts':...
# 1         Standard  {'dex_number': 2, 'evos': ['Venusaur'], 'alts'...
# 2         Standard  {'dex_number': 3, 'evos': [], 'alts': ['Venusa...
# 3         Standard  {'dex_number': 4, 'evos': ['Charmeleon'], 'alt...
# 4         Standard  {'dex_number': 5, 'evos': ['Charizard'], 'alts...
# ...            ...                                                ...
# 1201        NatDex                                               None
# 1202      Standard                                               None
# 1203           CAP                                               None
# 1204      Standard                                               None
# 1205      Standard                                               None
#
# [1206 rows x 14 columns]

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1206 non-null   object
#  1   hp             1206 non-null   int64
#  2   atk            1206 non-null   int64
#  3   def            1206 non-null   int64
#  4   spa            1206 non-null   int64
#  5   spd            1206 non-null   int64
#  6   spe            1206 non-null   int64
#  7   weight         1206 non-null   float64
#  8   height         1206 non-null   float64
#  9   types          1206 non-null   object
#  10  abilities      1206 non-null   object
#  11  formats        1206 non-null   object
#  12  isNonstandard  1206 non-null   object
#  13  oob            1102 non-null   object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 132.0+ KB

# %% [markdown]
# From the info, we can see that our dataframe is mostly full, which is great, but we have some null values in the oob column which is a good first thing to check out.

# %%
pokemon_df.loc[pokemon_df.loc[:, 'oob'].isnull()]
# Out:
#                       name   hp  atk  def  spa  spd  spe  weight  height  \
# 1102  Darmanitan-Galar-Zen  105  160   55   30   55  135   120.0     1.7
# 1103         Houndoom-Mega   75   90   90  140   90  115    49.5     1.9
# 1104        Blastoise-Mega   79  103  120  135  115   78   101.1     1.6
# 1105         Alcremie-Gmax   65   60   75  110  121   64     0.0    30.0
# 1106  Mimikyu-Busted-Totem   55   90   80   50  105   96     2.8     0.4
# ...                    ...  ...  ...  ...  ...  ...  ...     ...     ...
# 1201           Scizor-Mega   70  150  140   65  100   75   125.0     2.0
# 1202        Blastoise-Gmax   79   83  100   85  105   78     0.0     1.6
# 1203       Crucibelle-Mega  106  135   75   91  125  108    22.5     1.4
# 1204           Meowth-Gmax   40   45   35   40   40   90     0.0    33.0
# 1205            Eevee-Gmax   55   55   50   45   65   55     0.0    18.0
#
#                types                               abilities         formats  \
# 1102     [Ice, Fire]                              [Zen Mode]          [Uber]
# 1103    [Dark, Fire]                           [Solar Power]  [National Dex]
# 1104         [Water]                         [Mega Launcher]  [National Dex]
# 1105         [Fairy]                [Aroma Veil, Sweet Veil]            [AG]
# 1106  [Ghost, Fairy]                              [Disguise]  [National Dex]
# ...              ...                                     ...             ...
# 1201    [Bug, Steel]                            [Technician]  [National Dex]
# 1202         [Water]                    [Rain Dish, Torrent]            [AG]
# 1203  [Rock, Poison]                           [Magic Guard]           [CAP]
# 1204        [Normal]           [Pickup, Technician, Unnerve]            [AG]
# 1205        [Normal]  [Adaptability, Anticipation, Run Away]            [AG]
#
#      isNonstandard   oob
# 1102      Standard  None
# 1103        NatDex  None
# 1104        NatDex  None
# 1105      Standard  None
# 1106        NatDex  None
# ...            ...   ...
# 1201        NatDex  None
# 1202      Standard  None
# 1203           CAP  None
# 1204      Standard  None
# 1205      Standard  None
#
# [104 rows x 14 columns]

# %% [markdown]
# These are a lot of alternative forms of pokemon, such as Mega, Gmax and Totem, which we are not going to include in our project for the following reasons:
#
# 1. They are difficult to represent in the context of the machine learning model we wish to train.
#
# 2. They are outside of the standard Smogon 6v6 pokemon battle rulesets, which give a fair and consistent context to the ranking of pokemon that we are trying to predict.
#
# Therefore, all of these pokemon and their rows will simply be removed.
#
# To have a record of pokemon that we are removing, they will be stored in another dataframe called pokemon_removed_df.  This is useful for records and also in the case that we decide to use the removed pokemon in another way in the future of this project.

# %%
pokemon_removed_df = pokemon_df.loc[pokemon_df.loc[:, 'oob'].isnull()].copy()
pokemon_df = pokemon_df.loc[~pokemon_df.loc[:, 'oob'].isnull()].copy()

# %% [markdown]
# With that obvious step out of the way, let's make a pandas profiling report to see if there are any less obvious things in pokemon_df that we should be examining or cleaning.

# %%
profile_report = pokemon_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/28 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# We gained two key insights from this report:
#
# 1. Several columns (types, abilities, formats, and oob) have unsupported types, which prevents us from gaining much further insight about them.  This is a problem that we will have to solve. Types and abilities will have their own separate dataframes, so we will deal with those later.  Formats only contains a list with a single value though, so it's easier to solve now.
#
# 2. If you examine the extreme values for a numerical column like "weight", you can see that the amount of pokemon with said weights don't correspond to the number of such pokemon listed on pokemon reference websites (such as Bulbapedia).  Let's examine this now:

# %%
pokemon_df.loc[pokemon_df['weight'] == 0.2]
# Out:
#                   name  hp  atk  def  spa  spd  spe  weight  height  \
# 875           Cutiefly  40   45   40   55   40   84     0.2     0.1
# 1043          Sinistea  40   45   45   74   54   50     0.2     0.1
# 1044  Sinistea-Antique  40   45   45   74   54   50     0.2     0.1
#
#              types                                abilities formats  \
# 875   [Bug, Fairy]  [Honey Gather, Shield Dust, Sweet Veil]   [NFE]
# 1043       [Ghost]                [Cursed Body, Weak Armor]    [LC]
# 1044       [Ghost]                [Cursed Body, Weak Armor]    [LC]
#
#      isNonstandard                                                oob
# 875       Standard  {'dex_number': 742, 'evos': ['Ribombee'], 'alt...
# 1043      Standard  {'dex_number': 854, 'evos': ['Polteageist'], '...
# 1044      Standard  {'dex_number': 854, 'evos': ['Polteageist-Anti...

# %%
pokemon_df.loc[pokemon_df['weight'] == 0.3]
# Out:
#              name  hp  atk  def  spa  spd  spe  weight  height  \
# 389    Rotom-Heat  50   65  107  105  107   86     0.3     0.3
# 390    Rotom-Wash  50   65  107  105  107   86     0.3     0.3
# 391   Rotom-Frost  50   65  107  105  107   86     0.3     0.3
# 392     Rotom-Fan  50   65  107  105  107   86     0.3     0.3
# 393     Rotom-Mow  50   65  107  105  107   86     0.3     0.3
# 517         Rotom  50   50   77   95   77   91     0.3     0.3
# 518          Uxie  75   75  130   75  130   95     0.3     0.3
# 519       Mesprit  80  105  105  105  105   80     0.3     0.3
# 520         Azelf  75  125   70  125   70  115     0.3     0.3
# 661        Tynamo  35   55   40   45   40   60     0.3     0.2
# 880    Wishiwashi  45   20   20   25   25   40     0.3     0.2
# 901        Comfey  51   52   90   82  110  100     0.3     0.1
# 928        Minior  60  100   60  100   60  120     0.3     0.3
# 1059      Milcery  45   40   40   50   61   34     0.3     0.2
#
#                    types                            abilities         formats  \
# 389     [Electric, Fire]                           [Levitate]            [UU]
# 390    [Electric, Water]                           [Levitate]            [UU]
# 391      [Electric, Ice]                           [Levitate]      [Untiered]
# 392   [Electric, Flying]                           [Levitate]      [Untiered]
# 393    [Electric, Grass]                           [Levitate]            [NU]
# 517    [Electric, Ghost]                           [Levitate]      [Untiered]
# 518            [Psychic]                           [Levitate]      [Untiered]
# 519            [Psychic]                           [Levitate]            [PU]
# 520            [Psychic]                           [Levitate]            [UU]
# 661           [Electric]                           [Levitate]  [National Dex]
# 880              [Water]                          [Schooling]      [Untiered]
# 901              [Fairy]  [Flower Veil, Natural Cure, Triage]            [NU]
# 928       [Rock, Flying]                       [Shields Down]  [National Dex]
# 1059             [Fairy]             [Aroma Veil, Sweet Veil]            [LC]
#
#      isNonstandard                                                oob
# 389       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 390       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 391       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 392       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 393       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 517       Standard  {'dex_number': 479, 'evos': [], 'alts': [], 'g...
# 518       Standard  {'dex_number': 480, 'evos': [], 'alts': [], 'g...
# 519       Standard  {'dex_number': 481, 'evos': [], 'alts': [], 'g...
# 520       Standard  {'dex_number': 482, 'evos': [], 'alts': [], 'g...
# 661         NatDex  {'dex_number': 602, 'evos': ['Eelektrik'], 'al...
# 880       Standard  {'dex_number': 746, 'evos': [], 'alts': ['Wish...
# 901       Standard  {'dex_number': 764, 'evos': [], 'alts': [], 'g...
# 928         NatDex  {'dex_number': 774, 'evos': [], 'alts': ['Mini...
# 1059      Standard  {'dex_number': 868, 'evos': ['Alcremie'], 'alt...

# %% [markdown]
# Here we can see what the problem is: there are other alternative forms of pokemon besides the one's we deleted before.  Some examples are the "antique" form (Sinistea has it), and the alternative forms of Rotom.  We need a strategy to find and decide what to do with all of these alternative forms, which is probably the most difficult task in cleaning pokemon_df.
#
# So far, it seems like the best strategy to find all of the alternative forms is to look for each pokemon name which contains the "-" character, since it's been attached to every alternative form so far (though it may not be the case that every instance of "-" corresponds to an alternative form.
#
# We'll have to convert the slice of the dataframe we're looking for to a string, because we need to see all of it and that's one of the easiest ways to display it.

# %%
print(pokemon_df.loc[pokemon_df['name'].str.contains("-")].to_string())
# Out:
#                        name   hp  atk  def  spa  spd  spe  weight  height                types                                   abilities         formats isNonstandard                                                                                                                  oob
# 28                Nidoran-F   55   47   52   40   40   41     7.0     0.4             [Poison]             [Hustle, Poison Point, Rivalry]            [LC]      Standard  {'dex_number': 29, 'evos': ['Nidorina'], 'alts': [], 'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 31                Nidoran-M   46   57   40   40   40   50     9.0     0.5             [Poison]             [Hustle, Poison Point, Rivalry]            [LC]      Standard  {'dex_number': 32, 'evos': ['Nidorino'], 'alts': [], 'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 249                   Ho-Oh  106  130   90  110  154   90   199.0     3.8       [Fire, Flying]                     [Pressure, Regenerator]          [Uber]      Standard                 {'dex_number': 250, 'evos': [], 'alts': [], 'genfamily': ['GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 386           Deoxys-Attack   50  180   20  180   20  150    60.8     1.7            [Psychic]                                  [Pressure]  [National Dex]        NatDex                       {'dex_number': 386, 'evos': [], 'alts': [], 'genfamily': ['RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 387          Deoxys-Defense   50   70  160   70  160   90    60.8     1.7            [Psychic]                                  [Pressure]  [National Dex]        NatDex                       {'dex_number': 386, 'evos': [], 'alts': [], 'genfamily': ['RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 388            Deoxys-Speed   50   95   90   95   90  180    60.8     1.7            [Psychic]                                  [Pressure]  [National Dex]        NatDex                       {'dex_number': 386, 'evos': [], 'alts': [], 'genfamily': ['RS', 'DP', 'BW', 'XY', 'SM', 'SS']}
# 389              Rotom-Heat   50   65  107  105  107   86     0.3     0.3     [Electric, Fire]                                  [Levitate]            [UU]      Standard                             {'dex_number': 479, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 390              Rotom-Wash   50   65  107  105  107   86     0.3     0.3    [Electric, Water]                                  [Levitate]            [UU]      Standard                             {'dex_number': 479, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 391             Rotom-Frost   50   65  107  105  107   86     0.3     0.3      [Electric, Ice]                                  [Levitate]      [Untiered]      Standard                             {'dex_number': 479, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 392               Rotom-Fan   50   65  107  105  107   86     0.3     0.3   [Electric, Flying]                                  [Levitate]      [Untiered]      Standard                             {'dex_number': 479, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 393               Rotom-Mow   50   65  107  105  107   86     0.3     0.3    [Electric, Grass]                                  [Levitate]            [NU]      Standard                             {'dex_number': 479, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 411          Wormadam-Sandy   60   79  105   59   85   36     6.5     0.5        [Bug, Ground]                    [Anticipation, Overcoat]  [National Dex]        NatDex                             {'dex_number': 413, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 412          Wormadam-Trash   60   69   95   69   95   36     6.5     0.5         [Bug, Steel]                    [Anticipation, Overcoat]  [National Dex]        NatDex                             {'dex_number': 413, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 415              Arceus-Bug  120  120  120  120  120  120   320.0     3.2                [Bug]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 416             Arceus-Dark  120  120  120  120  120  120   320.0     3.2               [Dark]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 417           Arceus-Dragon  120  120  120  120  120  120   320.0     3.2             [Dragon]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 418         Arceus-Electric  120  120  120  120  120  120   320.0     3.2           [Electric]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 419         Arceus-Fighting  120  120  120  120  120  120   320.0     3.2           [Fighting]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 420             Arceus-Fire  120  120  120  120  120  120   320.0     3.2               [Fire]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 421           Arceus-Flying  120  120  120  120  120  120   320.0     3.2             [Flying]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 422            Arceus-Ghost  120  120  120  120  120  120   320.0     3.2              [Ghost]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 423            Arceus-Grass  120  120  120  120  120  120   320.0     3.2              [Grass]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 424           Arceus-Ground  120  120  120  120  120  120   320.0     3.2             [Ground]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 425              Arceus-Ice  120  120  120  120  120  120   320.0     3.2                [Ice]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 426           Arceus-Poison  120  120  120  120  120  120   320.0     3.2             [Poison]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 427          Arceus-Psychic  120  120  120  120  120  120   320.0     3.2            [Psychic]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 428             Arceus-Rock  120  120  120  120  120  120   320.0     3.2               [Rock]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 429            Arceus-Steel  120  120  120  120  120  120   320.0     3.2              [Steel]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 430            Arceus-Water  120  120  120  120  120  120   320.0     3.2              [Water]                                 [Multitype]  [National Dex]        NatDex                             {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 514               Porygon-Z   85   80   70  135   75   90    34.0     0.9             [Normal]          [Adaptability, Analytic, Download]          [NUBL]      Standard                             {'dex_number': 474, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 525         Giratina-Origin  150  120  100  120  100   90   650.0     6.9      [Ghost, Dragon]                                  [Levitate]          [Uber]      Standard                             {'dex_number': 487, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 531             Shaymin-Sky  100  103   75  120   75  127     5.2     0.4      [Grass, Flying]                              [Serene Grace]  [National Dex]        NatDex                             {'dex_number': 492, 'evos': [], 'alts': [], 'genfamily': ['DP', 'BW', 'XY', 'SM', 'SS']}
# 620   Basculin-Blue-Striped   70   92   65   80   55   98    18.0     1.0              [Water]     [Adaptability, Mold Breaker, Rock Head]      [Untiered]      Standard                                   {'dex_number': 550, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 692        Tornadus-Therian   79  100   80  110   90  121    63.0     1.4             [Flying]                               [Regenerator]            [OU]      Standard                                   {'dex_number': 641, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 694       Thundurus-Therian   79  105   70  145   80  101    61.0     3.0   [Electric, Flying]                               [Volt Absorb]            [UU]      Standard                                   {'dex_number': 642, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 698        Landorus-Therian   89  145   90  105   80   91    68.0     1.3     [Ground, Flying]                                [Intimidate]            [OU]      Standard                                   {'dex_number': 645, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 700            Kyurem-Black  125  170  100  120   90   95   325.0     3.3        [Dragon, Ice]                                  [Teravolt]          [Uber]      Standard                                   {'dex_number': 646, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 701            Kyurem-White  125  120   90  170  100   95   325.0     3.6        [Dragon, Ice]                                [Turboblaze]          [Uber]      Standard                                   {'dex_number': 646, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 703         Keldeo-Resolute   91   72   90  129   90  108    48.5     1.4    [Water, Fighting]                                 [Justified]            [UU]      Standard                                   {'dex_number': 647, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 706          Genesect-Douse   71  120   95  120   95   99    82.5     1.5         [Bug, Steel]                                  [Download]          [Uber]      Standard                                   {'dex_number': 649, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 707          Genesect-Shock   71  120   95  120   95   99    82.5     1.5         [Bug, Steel]                                  [Download]          [Uber]      Standard                                   {'dex_number': 649, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 708           Genesect-Burn   71  120   95  120   95   99    82.5     1.5         [Bug, Steel]                                  [Download]          [Uber]      Standard                                   {'dex_number': 649, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 709          Genesect-Chill   71  120   95  120   95   99    82.5     1.5         [Bug, Steel]                                  [Download]          [Uber]      Standard                                   {'dex_number': 649, 'evos': [], 'alts': [], 'genfamily': ['BW', 'XY', 'SM', 'SS']}
# 719            Arceus-Fairy  120  120  120  120  120  120   320.0     3.2              [Fairy]                                 [Multitype]  [National Dex]        NatDex                                         {'dex_number': 493, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 722              Meowstic-M   74   48   76   83   81  104     8.5     0.6            [Psychic]          [Infiltrator, Keen Eye, Prankster]      [Untiered]      Standard                                         {'dex_number': 678, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 726         Pumpkaboo-Small   44   66   70   44   55   56     3.5     0.3       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]            [LC]      Standard                        {'dex_number': 710, 'evos': ['Gourgeist-Small'], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 727         Pumpkaboo-Large   54   66   70   44   55   46     7.5     0.5       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]            [LC]      Standard                        {'dex_number': 710, 'evos': ['Gourgeist-Large'], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 728         Gourgeist-Small   55   85  122   58   75   99     9.5     0.7       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]      [Untiered]      Standard                                         {'dex_number': 711, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 729         Gourgeist-Large   75   95  122   58   75   69    14.0     1.1       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]      [Untiered]      Standard                                         {'dex_number': 711, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 750          Vivillon-Fancy   80   52   50   90   50   89    17.0     1.2        [Bug, Flying]                [Compound Eyes, Shield Dust]  [National Dex]        NatDex                                         {'dex_number': 666, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 751       Vivillon-Pokeball   80   52   50   90   50   89    17.0     1.2        [Bug, Flying]                [Compound Eyes, Shield Dust]  [National Dex]        NatDex                                         {'dex_number': 666, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 763              Meowstic-F   74   48   76   83   81  104     8.5     0.6            [Psychic]        [Competitive, Infiltrator, Keen Eye]      [Untiered]      Standard                                         {'dex_number': 678, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 794         Pumpkaboo-Super   59   66   70   44   55   41    15.0     0.8       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]            [LC]      Standard                        {'dex_number': 710, 'evos': ['Gourgeist-Super'], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 796         Gourgeist-Super   85  100  122   58   75   54    39.0     1.7       [Ghost, Grass]                   [Frisk, Insomnia, Pickup]      [Untiered]      Standard                                         {'dex_number': 711, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 801           Hoopa-Unbound   80  160   60  170  130   80   490.0     6.5      [Psychic, Dark]                                  [Magician]  [National Dex]        NatDex                                         {'dex_number': 720, 'evos': [], 'alts': [], 'genfamily': ['XY', 'SM', 'SS']}
# 812        Pikachu-Original   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 813           Pikachu-Hoenn   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 814          Pikachu-Sinnoh   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 815           Pikachu-Unova   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 816           Pikachu-Kalos   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 817           Pikachu-Alola   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 818         Pikachu-Partner   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 821       Lycanroc-Midnight   85  115   75   55   75   82    25.0     1.1               [Rock]          [Keen Eye, No Guard, Vital Spirit]      [Untiered]      Standard                                               {'dex_number': 745, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 828           Rattata-Alola   30   56   35   25   35   72     3.8     0.3       [Dark, Normal]               [Gluttony, Hustle, Thick Fat]  [National Dex]        NatDex                                {'dex_number': 19, 'evos': ['Raticate-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 829          Raticate-Alola   75   71   70   40   80   77    25.5     0.7       [Dark, Normal]               [Gluttony, Hustle, Thick Fat]  [National Dex]        NatDex                                                {'dex_number': 20, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 830    Raticate-Alola-Totem   75   71   70   40   80   77   105.0     1.4       [Dark, Normal]                                 [Thick Fat]  [National Dex]        NatDex                                                {'dex_number': 20, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 831         Pikachu-Starter   45   80   50   75   60  120     6.0     0.4           [Electric]                     [Lightning Rod, Static]  [National Dex]        NatDex                                                {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 832            Raichu-Alola   60   85   50   95   85  110    21.0     0.7  [Electric, Psychic]                              [Surge Surfer]          [PUBL]      Standard                                                {'dex_number': 26, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 833         Sandshrew-Alola   50   75   90   10   35   40    40.0     0.7         [Ice, Steel]                    [Slush Rush, Snow Cloak]            [LC]      Standard                               {'dex_number': 27, 'evos': ['Sandslash-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 834         Sandslash-Alola   75  100  120   25   65   65    55.0     1.2         [Ice, Steel]                    [Slush Rush, Snow Cloak]            [PU]      Standard                                                {'dex_number': 28, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 835            Vulpix-Alola   38   41   40   50   65   65     9.9     0.6                [Ice]                  [Snow Cloak, Snow Warning]           [NFE]      Standard                               {'dex_number': 37, 'evos': ['Ninetales-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 836         Ninetales-Alola   73   67   75   81  100  109    19.9     1.1         [Ice, Fairy]                  [Snow Cloak, Snow Warning]            [UU]      Standard                                                {'dex_number': 38, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 837           Diglett-Alola   10   55   30   35   45   90     1.0     0.2      [Ground, Steel]      [Sand Force, Sand Veil, Tangling Hair]            [LC]      Standard                                 {'dex_number': 50, 'evos': ['Dugtrio-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 838           Dugtrio-Alola   35  100   60   50   70  110    66.6     0.7      [Ground, Steel]      [Sand Force, Sand Veil, Tangling Hair]      [Untiered]      Standard                                                {'dex_number': 51, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 839            Meowth-Alola   40   35   35   50   40   90     4.2     0.4               [Dark]               [Pickup, Rattled, Technician]            [LC]      Standard                                 {'dex_number': 52, 'evos': ['Persian-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 840           Persian-Alola   65   60   60   75   65  115    33.0     1.1               [Dark]             [Fur Coat, Rattled, Technician]      [Untiered]      Standard                                                {'dex_number': 53, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 841           Geodude-Alola   40   80  100   30   30   20    20.3     0.4     [Rock, Electric]            [Galvanize, Magnet Pull, Sturdy]  [National Dex]        NatDex                                {'dex_number': 74, 'evos': ['Graveler-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 842          Graveler-Alola   55   95  115   45   45   35   110.0     1.0     [Rock, Electric]            [Galvanize, Magnet Pull, Sturdy]  [National Dex]        NatDex                                   {'dex_number': 75, 'evos': ['Golem-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 843             Golem-Alola   80  120  130   55   65   45   316.0     1.7     [Rock, Electric]            [Galvanize, Magnet Pull, Sturdy]  [National Dex]        NatDex                                                {'dex_number': 76, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 844            Grimer-Alola   80   80   50   40   50   25    42.0     0.7       [Poison, Dark]  [Gluttony, Poison Touch, Power of Alchemy]  [National Dex]        NatDex                                     {'dex_number': 88, 'evos': ['Muk-Alola'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 845               Muk-Alola  105  105   75   65  100   50    52.0     1.0       [Poison, Dark]  [Gluttony, Poison Touch, Power of Alchemy]  [National Dex]        NatDex                                                {'dex_number': 89, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 846         Exeggutor-Alola   95  105   85  125   75   45   415.6    10.9      [Grass, Dragon]                            [Frisk, Harvest]      [Untiered]      Standard                                               {'dex_number': 103, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 847           Marowak-Alola   60   80  110   50   80   45    34.0     1.0        [Fire, Ghost]     [Cursed Body, Lightning Rod, Rock Head]            [RU]      Standard                                               {'dex_number': 105, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 848     Marowak-Alola-Totem   60   80  110   50   80   45    98.0     1.7        [Fire, Ghost]                                 [Rock Head]  [National Dex]        NatDex                                               {'dex_number': 105, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 849           Eevee-Starter   65   75   70   65   85   75     6.5     0.3             [Normal]      [Adaptability, Anticipation, Run Away]  [National Dex]        NatDex                                               {'dex_number': 133, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 850             Zygarde-10%   54  100   71   61   85  115    33.5     1.2     [Dragon, Ground]               [Aura Break, Power Construct]          [RUBL]      Standard                             {'dex_number': 718, 'evos': [], 'alts': ['Zygarde-Complete'], 'genfamily': ['SM', 'SS']}
# 865          Gumshoos-Totem   88  110   60   55   60   45    60.0     1.4             [Normal]                              [Adaptability]  [National Dex]        NatDex                                               {'dex_number': 735, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 868          Vikavolt-Totem   77   70   90  145   75   43   147.5     2.6      [Bug, Electric]                                  [Levitate]  [National Dex]        NatDex                                               {'dex_number': 738, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 872        Oricorio-Pom-Pom   75   70   70   98   70   93     3.4     0.6   [Electric, Flying]                                    [Dancer]  [National Dex]        NatDex                                               {'dex_number': 741, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 873           Oricorio-Pa'u   75   70   70   98   70   93     3.4     0.6    [Psychic, Flying]                                    [Dancer]  [National Dex]        NatDex                                               {'dex_number': 741, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 874          Oricorio-Sensu   75   70   70   98   70   93     3.4     0.6      [Ghost, Flying]                                    [Dancer]  [National Dex]        NatDex                                               {'dex_number': 741, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 877          Ribombee-Totem   60   55   60   95   70  124     2.0     0.4         [Bug, Fairy]                                [Sweet Veil]  [National Dex]        NatDex                                               {'dex_number': 743, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 879           Lycanroc-Dusk   75  117   65   55   65  110    25.0     0.8               [Rock]                               [Tough Claws]            [UU]      Standard                                               {'dex_number': 745, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 887         Araquanid-Totem   68   70   92   50  132   42   217.5     3.1         [Water, Bug]                              [Water Bubble]  [National Dex]        NatDex                                               {'dex_number': 752, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 890          Lurantis-Totem   70  105   90   80   90   45    58.0     1.5              [Grass]                                [Leaf Guard]  [National Dex]        NatDex                                               {'dex_number': 754, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 895          Salazzle-Totem   68   64   60  111   60  117    81.0     2.1       [Poison, Fire]                                 [Corrosion]  [National Dex]        NatDex                                               {'dex_number': 758, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 911            Silvally-Bug   95   95   95   95   95   95   100.5     2.3                [Bug]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 912           Silvally-Dark   95   95   95   95   95   95   100.5     2.3               [Dark]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 913         Silvally-Dragon   95   95   95   95   95   95   100.5     2.3             [Dragon]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 914       Silvally-Electric   95   95   95   95   95   95   100.5     2.3           [Electric]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 915          Silvally-Fairy   95   95   95   95   95   95   100.5     2.3              [Fairy]                                [RKS System]            [PU]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 916       Silvally-Fighting   95   95   95   95   95   95   100.5     2.3           [Fighting]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 917           Silvally-Fire   95   95   95   95   95   95   100.5     2.3               [Fire]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 918         Silvally-Flying   95   95   95   95   95   95   100.5     2.3             [Flying]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 919          Silvally-Ghost   95   95   95   95   95   95   100.5     2.3              [Ghost]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 920          Silvally-Grass   95   95   95   95   95   95   100.5     2.3              [Grass]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 921         Silvally-Ground   95   95   95   95   95   95   100.5     2.3             [Ground]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 922            Silvally-Ice   95   95   95   95   95   95   100.5     2.3                [Ice]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 923         Silvally-Poison   95   95   95   95   95   95   100.5     2.3             [Poison]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 924        Silvally-Psychic   95   95   95   95   95   95   100.5     2.3            [Psychic]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 925           Silvally-Rock   95   95   95   95   95   95   100.5     2.3               [Rock]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 926          Silvally-Steel   95   95   95   95   95   95   100.5     2.3              [Steel]                                [RKS System]            [PU]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 927          Silvally-Water   95   95   95   95   95   95   100.5     2.3              [Water]                                [RKS System]      [Untiered]      Standard                                               {'dex_number': 773, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 932        Togedemaru-Totem   65   98   63   40   73   96    13.0     0.6    [Electric, Steel]                                    [Sturdy]  [National Dex]        NatDex                                               {'dex_number': 777, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 934           Mimikyu-Totem   55   90   80   50  105   96     2.8     0.4       [Ghost, Fairy]                                  [Disguise]  [National Dex]        NatDex                         {'dex_number': 778, 'evos': [], 'alts': ['Mimikyu-Busted-Totem'], 'genfamily': ['SM', 'SS']}
# 938                Jangmo-o   45   55   65   45   45   45    29.7     0.6             [Dragon]         [Bulletproof, Overcoat, Soundproof]            [LC]      Standard                                     {'dex_number': 782, 'evos': ['Hakamo-o'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 939                Hakamo-o   55   75   90   65   70   65    47.0     1.2   [Dragon, Fighting]         [Bulletproof, Overcoat, Soundproof]           [NFE]      Standard                                      {'dex_number': 783, 'evos': ['Kommo-o'], 'alts': [], 'genfamily': ['SM', 'SS']}
# 940                 Kommo-o   75  110  125  100  105   85    78.2     1.6   [Dragon, Fighting]         [Bulletproof, Overcoat, Soundproof]            [UU]      Standard                                               {'dex_number': 784, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 941           Kommo-o-Totem   75  110  125  100  105   85   207.5     2.4   [Dragon, Fighting]                                  [Overcoat]  [National Dex]        NatDex                                               {'dex_number': 784, 'evos': [], 'alts': [], 'genfamily': ['SM', 'SS']}
# 954      Necrozma-Dusk Mane   97  157  127  113  109   77   460.0     3.8     [Psychic, Steel]                               [Prism Armor]          [Uber]      Standard                               {'dex_number': 800, 'evos': [], 'alts': ['Necrozma-Ultra'], 'genfamily': ['SM', 'SS']}
# 955     Necrozma-Dawn Wings   97  113  109  157  127   77   350.0     4.2     [Psychic, Ghost]                               [Prism Armor]          [Uber]      Standard                               {'dex_number': 800, 'evos': [], 'alts': ['Necrozma-Ultra'], 'genfamily': ['SM', 'SS']}
# 977           Pikachu-World   35   55   40   50   50   90     6.0     0.4           [Electric]                     [Lightning Rod, Static]      [Untiered]      Standard                                                      {'dex_number': 25, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 978            Meowth-Galar   50   65   55   40   40   40     7.5     0.4              [Steel]              [Pickup, Tough Claws, Unnerve]            [LC]      Standard                                          {'dex_number': 52, 'evos': ['Perrserker'], 'alts': [], 'genfamily': ['SS']}
# 979            Ponyta-Galar   50   85   55   65   65   90    24.0     0.8            [Psychic]       [Anticipation, Pastel Veil, Run Away]            [LC]      Standard                                      {'dex_number': 77, 'evos': ['Rapidash-Galar'], 'alts': [], 'genfamily': ['SS']}
# 980          Rapidash-Galar   65  100   70   80   80  105    80.0     1.7     [Psychic, Fairy]       [Anticipation, Pastel Veil, Run Away]      [Untiered]      Standard                                                      {'dex_number': 78, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 981          Slowpoke-Galar   90   65   65   40   40   15    36.0     1.2            [Psychic]          [Gluttony, Own Tempo, Regenerator]            [LC]      Standard                     {'dex_number': 79, 'evos': ['Slowbro-Galar', 'Slowking-Galar'], 'alts': [], 'genfamily': ['SS']}
# 982           Slowbro-Galar   95  100   95  100   70   30    70.5     1.6    [Poison, Psychic]        [Own Tempo, Quick Draw, Regenerator]          [RUBL]      Standard                                                      {'dex_number': 80, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 983        Farfetch'd-Galar   52   95   55   58   62   55    15.0     0.8           [Fighting]                        [Scrappy, Steadfast]            [LC]      Standard                                          {'dex_number': 83, 'evos': ['Sirfetch'd'], 'alts': [], 'genfamily': ['SS']}
# 984           Weezing-Galar   65   90  120   85   70   60    16.0     3.0      [Poison, Fairy]   [Levitate, Misty Surge, Neutralizing Gas]            [RU]      Standard                                                     {'dex_number': 110, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 985          Mr. Mime-Galar   50   65   65   90   90  100    56.8     1.4       [Ice, Psychic]    [Ice Body, Screen Cleaner, Vital Spirit]           [NFE]      Standard                                           {'dex_number': 122, 'evos': ['Mr. Rime'], 'alts': [], 'genfamily': ['SS']}
# 986          Articuno-Galar   90   85   85  125  100   95    50.9     1.7    [Psychic, Flying]                               [Competitive]            [NU]      Standard                                                     {'dex_number': 144, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 987            Zapdos-Galar   90  125   90   85   90  100    58.2     1.6   [Fighting, Flying]                                   [Defiant]          [UUBL]      Standard                                                     {'dex_number': 145, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 988           Moltres-Galar   90   85   90  100  125   90    66.0     2.0       [Dark, Flying]                                   [Berserk]            [UU]      Standard                                                     {'dex_number': 146, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 989          Slowking-Galar   95   65   80  110  110   30    79.5     1.8    [Poison, Psychic]  [Curious Medicine, Own Tempo, Regenerator]            [OU]      Standard                                                     {'dex_number': 199, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 990           Corsola-Galar   60   55  100   65  100   30     0.5     0.6              [Ghost]                   [Cursed Body, Weak Armor]           [NFE]      Standard                                            {'dex_number': 222, 'evos': ['Cursola'], 'alts': [], 'genfamily': ['SS']}
# 991         Zigzagoon-Galar   38   30   41   30   41   60    17.5     0.4       [Dark, Normal]              [Gluttony, Pickup, Quick Feet]            [LC]      Standard                                      {'dex_number': 263, 'evos': ['Linoone-Galar'], 'alts': [], 'genfamily': ['SS']}
# 992           Linoone-Galar   78   70   61   50   61  100    32.5     0.5       [Dark, Normal]              [Gluttony, Pickup, Quick Feet]           [NFE]      Standard                                          {'dex_number': 264, 'evos': ['Obstagoon'], 'alts': [], 'genfamily': ['SS']}
# 993          Darumaka-Galar   70   90   45   15   45   50    40.0     0.7                [Ice]                       [Hustle, Inner Focus]            [LC]      Standard                                   {'dex_number': 554, 'evos': ['Darmanitan-Galar'], 'alts': [], 'genfamily': ['SS']}
# 994        Darmanitan-Galar  105  140   55   30   55   95   120.0     1.7                [Ice]                 [Gorilla Tactics, Zen Mode]          [Uber]      Standard                               {'dex_number': 555, 'evos': [], 'alts': ['Darmanitan-Galar-Zen'], 'genfamily': ['SS']}
# 995            Yamask-Galar   38   55   85   30   65   30     1.5     0.5      [Ground, Ghost]                          [Wandering Spirit]            [LC]      Standard                                          {'dex_number': 562, 'evos': ['Runerigus'], 'alts': [], 'genfamily': ['SS']}
# 996          Stunfisk-Galar  109   81   99   66   84   32    20.5     0.7      [Ground, Steel]                                   [Mimicry]      [Untiered]      Standard                                                     {'dex_number': 618, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 997       Magearna-Original   80   95  115  130  115   65    80.5     1.0       [Steel, Fairy]                                [Soul-Heart]          [Uber]      Standard                                                     {'dex_number': 801, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1038     Toxtricity-Low-Key   75   98   70  114   70   75    40.0     1.6   [Electric, Poison]              [Minus, Punk Rock, Technician]            [RU]      Standard                            {'dex_number': 849, 'evos': [], 'alts': ['Toxtricity-Low-Key-Gmax'], 'genfamily': ['SS']}
# 1044       Sinistea-Antique   40   45   45   74   54   50     0.2     0.1              [Ghost]                   [Cursed Body, Weak Armor]            [LC]      Standard                                {'dex_number': 854, 'evos': ['Polteageist-Antique'], 'alts': [], 'genfamily': ['SS']}
# 1046    Polteageist-Antique   60   65   65  134  114   70     0.4     0.2              [Ghost]                   [Cursed Body, Weak Armor]          [NUBL]      Standard                                                     {'dex_number': 855, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1068             Indeedee-F   70   55   65   95  105   85    28.0     0.9    [Psychic, Normal]     [Own Tempo, Psychic Surge, Synchronize]          [PUBL]      Standard                                                     {'dex_number': 876, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1081         Zacian-Crowned   92  170  115   80  115  148   355.0     2.8       [Fairy, Steel]                            [Intrepid Sword]            [AG]      Standard                                                     {'dex_number': 888, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1083      Zamazenta-Crowned   92  130  145   80  145  128   785.0     2.9    [Fighting, Steel]                          [Dauntless Shield]          [Uber]      Standard                                                     {'dex_number': 889, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1087   Urshifu-Rapid-Strike  100  130  100   63   60   97   105.0     1.9    [Fighting, Water]                               [Unseen Fist]            [OU]      Standard                          {'dex_number': 892, 'evos': [], 'alts': ['Urshifu-Rapid-Strike-Gmax'], 'genfamily': ['SS']}
# 1089            Zarude-Dada  105  120  105   70   95  105    70.0     1.8        [Dark, Grass]                                [Leaf Guard]            [RU]      Standard                                                     {'dex_number': 893, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1095            Calyrex-Ice  100  165  150   85  130   50   809.1     2.4       [Psychic, Ice]                        [As One (Glastrier)]          [Uber]      Standard                                                     {'dex_number': 898, 'evos': [], 'alts': [], 'genfamily': ['SS']}
# 1096         Calyrex-Shadow  100   85   80  165  100  150    53.6     2.4     [Psychic, Ghost]                        [As One (Spectrier)]          [Uber]      Standard                                                     {'dex_number': 898, 'evos': [], 'alts': [], 'genfamily': ['SS']}

# %% [markdown]
# Which alternative forms of pokemon are fair and can remain in the dataframe as legitimately separate forms for competitive purposes?:
# - The different forms of Rotom, because they have completely different types and moveset strategies on Smogon.com
# - The Nidorans, because the M and F versions correspond to different genders which are completely different pokemon
# - Ho-Oh because it's name simply contains a "-"
# - Porygon-Z because it's name simply contains a "-"
# - Giratina-Origin, because it's a different form of Giratina with a totally different set of stats, and thus is quite different competitively
# - Therian forms of the Forces of Nature because they have different stats as with Giratina
# - Kyurem-White and Kyurem-Black are stat changes similar to Origin form or Therian forms
# - Meowstic genders, which have different abilities and strategies
# - Pumpakaboo and Gourgeist alternate size forms, which have different stats and strategies
# - Lycanroc forms, which have different stats and strategies
# - Alola forms of Raichu, Sandslash, Ninetails, Dugtrio, Persian, Exeggutor, Marowak, and all other Alola forms in their evolutionary family, because Alola forms are typed differently and essentially different pokemon
# - Different forms of Silvally, since they are differently typed
# - pokemon with "-o", because that's just the name of an evolutionary family of pokemon, not an alternative form
# - Necrozma alternative forms, because they have type, stat and tier differences
# - Galar forms of Meowth, Rapidash, Slowbro, Farfetch'd, Weezing, Mr. Mime, Articuno, Zapdos, Moltres, Slowking, Corsola, Linoone, Darmanitan, Yamask, Stunfisk, and all other Galar forms in their evolutionary family, beucase Galar forms are typed differently and different, similarly to Alola forms
# - Indeedee F and M, because they are different genders with different stats and type, similar to Nidoran and Meowstic
# - Zamazenta-Crowned, because it's an alternative form of Zamazenta with different stats
# - Urshifu forms, because they have different type, moves and competitive tiering
# - Calyrex forms, because they have different types and abilities
#
# By contrast, which alternative forms of pokemon are either purely appearance oriented (and thus essentially the same pokemon) or unfair for some reason, and thus must be removed?:
# - Basculin forms, because they are mostly appearance, they have an ability difference but it isn't used competitively
# - Keldeo-Resolute, which is purely an appearance change which happens when it knows a move
# - Genesect forms, because alternative forms are almost never used competitively and even if they are, they mostly just change the type of move named technoblast, and since this move is in the learnset this feature of genesect will be indirectly accounted for by my model
# - Pikachu alternative forms, because they are purely appearance
# - Magearna-original, because it's purely appearance
# - Toxtricity low-key, which has a difference in moves and ability but the difference isn't used competitively and otherwise it's just appearance
# - Sinistea and Polteageist antique, since the antique form only affects appearance
# - Zacian Crowned, because this form of Zacian was deemed too powerful even for the highest competitive tier, Uber, so it was banned
# - Zarude Dada, because it's purely an appearance difference from Zarude
#
# Let's make the necessary removals below and add them to pokemon_removed_df:

# %%
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Basculin-Blue-Striped'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Basculin-Blue-Striped']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Keldeo-Resolute'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Keldeo-Resolute']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Genesect-Douse'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Genesect-Douse']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Genesect-Shock'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Genesect-Shock']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Genesect-Burn'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Genesect-Burn']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Genesect-Chill'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Genesect-Chill']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Original'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Original']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Hoenn'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Hoenn']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Sinnoh'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Sinnoh']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Unova'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Unova']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Kalos'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Kalos']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Alola'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Alola']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-Partner'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-Partner']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Pikachu-World'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Pikachu-World']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Magearna-Original'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Magearna-Original']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Toxtricity-Low-Key'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Toxtricity-Low-Key']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Sinistea-Antique'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Sinistea-Antique']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Polteageist-Antique'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Polteageist-Antique']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Zacian-Crowned'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Zacian-Crowned']
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['name'] == 'Zarude-Dada'])
pokemon_df = pokemon_df.loc[pokemon_df['name'] != 'Zarude-Dada']

pokemon_removed_df.shape
# Out:
# (124, 14)

# %% [markdown]
# With that difficult and research-intensive task taken care of, we can switch to cleaning the "formats" column, which contains our target variable as a list with single entry.  We should check precisely what data type have, since it's unsupported by pandas_profiling and may merely resemble a list.

# %%
for i, l in enumerate(pokemon_df["formats"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'list'>
# list 1 is <class 'list'>
# list 2 is <class 'list'>
# list 3 is <class 'list'>
# list 4 is <class 'list'>
# list 5 is <class 'list'>
# list 6 is <class 'list'>
# list 7 is <class 'list'>
# list 8 is <class 'list'>
# list 9 is <class 'list'>
# list 10 is <class 'list'>
# list 11 is <class 'list'>
# list 12 is <class 'list'>
# list 13 is <class 'list'>
# list 14 is <class 'list'>
# list 15 is <class 'list'>
# list 16 is <class 'list'>
# list 17 is <class 'list'>
# list 18 is <class 'list'>
# list 19 is <class 'list'>
# list 20 is <class 'list'>
# list 21 is <class 'list'>
# list 22 is <class 'list'>
# list 23 is <class 'list'>
# list 24 is <class 'list'>
# list 25 is <class 'list'>
# list 26 is <class 'list'>
# list 27 is <class 'list'>
# list 28 is <class 'list'>
# list 29 is <class 'list'>
# list 30 is <class 'list'>
# list 31 is <class 'list'>
# list 32 is <class 'list'>
# list 33 is <class 'list'>
# list 34 is <class 'list'>
# list 35 is <class 'list'>
# list 36 is <class 'list'>
# list 37 is <class 'list'>
# list 38 is <class 'list'>
# list 39 is <class 'list'>
# list 40 is <class 'list'>
# list 41 is <class 'list'>
# list 42 is <class 'list'>
# list 43 is <class 'list'>
# list 44 is <class 'list'>
# list 45 is <class 'list'>
# list 46 is <class 'list'>
# list 47 is <class 'list'>
# list 48 is <class 'list'>
# list 49 is <class 'list'>
# list 50 is <class 'list'>
# list 51 is <class 'list'>
# list 52 is <class 'list'>
# list 53 is <class 'list'>
# list 54 is <class 'list'>
# list 55 is <class 'list'>
# list 56 is <class 'list'>
# list 57 is <class 'list'>
# list 58 is <class 'list'>
# list 59 is <class 'list'>
# list 60 is <class 'list'>
# list 61 is <class 'list'>
# list 62 is <class 'list'>
# list 63 is <class 'list'>
# list 64 is <class 'list'>
# list 65 is <class 'list'>
# list 66 is <class 'list'>
# list 67 is <class 'list'>
# list 68 is <class 'list'>
# list 69 is <class 'list'>
# list 70 is <class 'list'>
# list 71 is <class 'list'>
# list 72 is <class 'list'>
# list 73 is <class 'list'>
# list 74 is <class 'list'>
# list 75 is <class 'list'>
# list 76 is <class 'list'>
# list 77 is <class 'list'>
# list 78 is <class 'list'>
# list 79 is <class 'list'>
# list 80 is <class 'list'>
# list 81 is <class 'list'>
# list 82 is <class 'list'>
# list 83 is <class 'list'>
# list 84 is <class 'list'>
# list 85 is <class 'list'>
# list 86 is <class 'list'>
# list 87 is <class 'list'>
# list 88 is <class 'list'>
# list 89 is <class 'list'>
# list 90 is <class 'list'>
# list 91 is <class 'list'>
# list 92 is <class 'list'>
# list 93 is <class 'list'>
# list 94 is <class 'list'>
# list 95 is <class 'list'>
# list 96 is <class 'list'>
# list 97 is <class 'list'>
# list 98 is <class 'list'>
# list 99 is <class 'list'>
# list 100 is <class 'list'>
# list 101 is <class 'list'>
# list 102 is <class 'list'>
# list 103 is <class 'list'>
# list 104 is <class 'list'>
# list 105 is <class 'list'>
# list 106 is <class 'list'>
# list 107 is <class 'list'>
# list 108 is <class 'list'>
# list 109 is <class 'list'>
# list 110 is <class 'list'>
# list 111 is <class 'list'>
# list 112 is <class 'list'>
# list 113 is <class 'list'>
# list 114 is <class 'list'>
# list 115 is <class 'list'>
# list 116 is <class 'list'>
# list 117 is <class 'list'>
# list 118 is <class 'list'>
# list 119 is <class 'list'>
# list 120 is <class 'list'>
# list 121 is <class 'list'>
# list 122 is <class 'list'>
# list 123 is <class 'list'>
# list 124 is <class 'list'>
# list 125 is <class 'list'>
# list 126 is <class 'list'>
# list 127 is <class 'list'>
# list 128 is <class 'list'>
# list 129 is <class 'list'>
# list 130 is <class 'list'>
# list 131 is <class 'list'>
# list 132 is <class 'list'>
# list 133 is <class 'list'>
# list 134 is <class 'list'>
# list 135 is <class 'list'>
# list 136 is <class 'list'>
# list 137 is <class 'list'>
# list 138 is <class 'list'>
# list 139 is <class 'list'>
# list 140 is <class 'list'>
# list 141 is <class 'list'>
# list 142 is <class 'list'>
# list 143 is <class 'list'>
# list 144 is <class 'list'>
# list 145 is <class 'list'>
# list 146 is <class 'list'>
# list 147 is <class 'list'>
# list 148 is <class 'list'>
# list 149 is <class 'list'>
# list 150 is <class 'list'>
# list 151 is <class 'list'>
# list 152 is <class 'list'>
# list 153 is <class 'list'>
# list 154 is <class 'list'>
# list 155 is <class 'list'>
# list 156 is <class 'list'>
# list 157 is <class 'list'>
# list 158 is <class 'list'>
# list 159 is <class 'list'>
# list 160 is <class 'list'>
# list 161 is <class 'list'>
# list 162 is <class 'list'>
# list 163 is <class 'list'>
# list 164 is <class 'list'>
# list 165 is <class 'list'>
# list 166 is <class 'list'>
# list 167 is <class 'list'>
# list 168 is <class 'list'>
# list 169 is <class 'list'>
# list 170 is <class 'list'>
# list 171 is <class 'list'>
# list 172 is <class 'list'>
# list 173 is <class 'list'>
# list 174 is <class 'list'>
# list 175 is <class 'list'>
# list 176 is <class 'list'>
# list 177 is <class 'list'>
# list 178 is <class 'list'>
# list 179 is <class 'list'>
# list 180 is <class 'list'>
# list 181 is <class 'list'>
# list 182 is <class 'list'>
# list 183 is <class 'list'>
# list 184 is <class 'list'>
# list 185 is <class 'list'>
# list 186 is <class 'list'>
# list 187 is <class 'list'>
# list 188 is <class 'list'>
# list 189 is <class 'list'>
# list 190 is <class 'list'>
# list 191 is <class 'list'>
# list 192 is <class 'list'>
# list 193 is <class 'list'>
# list 194 is <class 'list'>
# list 195 is <class 'list'>
# list 196 is <class 'list'>
# list 197 is <class 'list'>
# list 198 is <class 'list'>
# list 199 is <class 'list'>
# list 200 is <class 'list'>
# list 201 is <class 'list'>
# list 202 is <class 'list'>
# list 203 is <class 'list'>
# list 204 is <class 'list'>
# list 205 is <class 'list'>
# list 206 is <class 'list'>
# list 207 is <class 'list'>
# list 208 is <class 'list'>
# list 209 is <class 'list'>
# list 210 is <class 'list'>
# list 211 is <class 'list'>
# list 212 is <class 'list'>
# list 213 is <class 'list'>
# list 214 is <class 'list'>
# list 215 is <class 'list'>
# list 216 is <class 'list'>
# list 217 is <class 'list'>
# list 218 is <class 'list'>
# list 219 is <class 'list'>
# list 220 is <class 'list'>
# list 221 is <class 'list'>
# list 222 is <class 'list'>
# list 223 is <class 'list'>
# list 224 is <class 'list'>
# list 225 is <class 'list'>
# list 226 is <class 'list'>
# list 227 is <class 'list'>
# list 228 is <class 'list'>
# list 229 is <class 'list'>
# list 230 is <class 'list'>
# list 231 is <class 'list'>
# list 232 is <class 'list'>
# list 233 is <class 'list'>
# list 234 is <class 'list'>
# list 235 is <class 'list'>
# list 236 is <class 'list'>
# list 237 is <class 'list'>
# list 238 is <class 'list'>
# list 239 is <class 'list'>
# list 240 is <class 'list'>
# list 241 is <class 'list'>
# list 242 is <class 'list'>
# list 243 is <class 'list'>
# list 244 is <class 'list'>
# list 245 is <class 'list'>
# list 246 is <class 'list'>
# list 247 is <class 'list'>
# list 248 is <class 'list'>
# list 249 is <class 'list'>
# list 250 is <class 'list'>
# list 251 is <class 'list'>
# list 252 is <class 'list'>
# list 253 is <class 'list'>
# list 254 is <class 'list'>
# list 255 is <class 'list'>
# list 256 is <class 'list'>
# list 257 is <class 'list'>
# list 258 is <class 'list'>
# list 259 is <class 'list'>
# list 260 is <class 'list'>
# list 261 is <class 'list'>
# list 262 is <class 'list'>
# list 263 is <class 'list'>
# list 264 is <class 'list'>
# list 265 is <class 'list'>
# list 266 is <class 'list'>
# list 267 is <class 'list'>
# list 268 is <class 'list'>
# list 269 is <class 'list'>
# list 270 is <class 'list'>
# list 271 is <class 'list'>
# list 272 is <class 'list'>
# list 273 is <class 'list'>
# list 274 is <class 'list'>
# list 275 is <class 'list'>
# list 276 is <class 'list'>
# list 277 is <class 'list'>
# list 278 is <class 'list'>
# list 279 is <class 'list'>
# list 280 is <class 'list'>
# list 281 is <class 'list'>
# list 282 is <class 'list'>
# list 283 is <class 'list'>
# list 284 is <class 'list'>
# list 285 is <class 'list'>
# list 286 is <class 'list'>
# list 287 is <class 'list'>
# list 288 is <class 'list'>
# list 289 is <class 'list'>
# list 290 is <class 'list'>
# list 291 is <class 'list'>
# list 292 is <class 'list'>
# list 293 is <class 'list'>
# list 294 is <class 'list'>
# list 295 is <class 'list'>
# list 296 is <class 'list'>
# list 297 is <class 'list'>
# list 298 is <class 'list'>
# list 299 is <class 'list'>
# list 300 is <class 'list'>
# list 301 is <class 'list'>
# list 302 is <class 'list'>
# list 303 is <class 'list'>
# list 304 is <class 'list'>
# list 305 is <class 'list'>
# list 306 is <class 'list'>
# list 307 is <class 'list'>
# list 308 is <class 'list'>
# list 309 is <class 'list'>
# list 310 is <class 'list'>
# list 311 is <class 'list'>
# list 312 is <class 'list'>
# list 313 is <class 'list'>
# list 314 is <class 'list'>
# list 315 is <class 'list'>
# list 316 is <class 'list'>
# list 317 is <class 'list'>
# list 318 is <class 'list'>
# list 319 is <class 'list'>
# list 320 is <class 'list'>
# list 321 is <class 'list'>
# list 322 is <class 'list'>
# list 323 is <class 'list'>
# list 324 is <class 'list'>
# list 325 is <class 'list'>
# list 326 is <class 'list'>
# list 327 is <class 'list'>
# list 328 is <class 'list'>
# list 329 is <class 'list'>
# list 330 is <class 'list'>
# list 331 is <class 'list'>
# list 332 is <class 'list'>
# list 333 is <class 'list'>
# list 334 is <class 'list'>
# list 335 is <class 'list'>
# list 336 is <class 'list'>
# list 337 is <class 'list'>
# list 338 is <class 'list'>
# list 339 is <class 'list'>
# list 340 is <class 'list'>
# list 341 is <class 'list'>
# list 342 is <class 'list'>
# list 343 is <class 'list'>
# list 344 is <class 'list'>
# list 345 is <class 'list'>
# list 346 is <class 'list'>
# list 347 is <class 'list'>
# list 348 is <class 'list'>
# list 349 is <class 'list'>
# list 350 is <class 'list'>
# list 351 is <class 'list'>
# list 352 is <class 'list'>
# list 353 is <class 'list'>
# list 354 is <class 'list'>
# list 355 is <class 'list'>
# list 356 is <class 'list'>
# list 357 is <class 'list'>
# list 358 is <class 'list'>
# list 359 is <class 'list'>
# list 360 is <class 'list'>
# list 361 is <class 'list'>
# list 362 is <class 'list'>
# list 363 is <class 'list'>
# list 364 is <class 'list'>
# list 365 is <class 'list'>
# list 366 is <class 'list'>
# list 367 is <class 'list'>
# list 368 is <class 'list'>
# list 369 is <class 'list'>
# list 370 is <class 'list'>
# list 371 is <class 'list'>
# list 372 is <class 'list'>
# list 373 is <class 'list'>
# list 374 is <class 'list'>
# list 375 is <class 'list'>
# list 376 is <class 'list'>
# list 377 is <class 'list'>
# list 378 is <class 'list'>
# list 379 is <class 'list'>
# list 380 is <class 'list'>
# list 381 is <class 'list'>
# list 382 is <class 'list'>
# list 383 is <class 'list'>
# list 384 is <class 'list'>
# list 385 is <class 'list'>
# list 386 is <class 'list'>
# list 387 is <class 'list'>
# list 388 is <class 'list'>
# list 389 is <class 'list'>
# list 390 is <class 'list'>
# list 391 is <class 'list'>
# list 392 is <class 'list'>
# list 393 is <class 'list'>
# list 394 is <class 'list'>
# list 395 is <class 'list'>
# list 396 is <class 'list'>
# list 397 is <class 'list'>
# list 398 is <class 'list'>
# list 399 is <class 'list'>
# list 400 is <class 'list'>
# list 401 is <class 'list'>
# list 402 is <class 'list'>
# list 403 is <class 'list'>
# list 404 is <class 'list'>
# list 405 is <class 'list'>
# list 406 is <class 'list'>
# list 407 is <class 'list'>
# list 408 is <class 'list'>
# list 409 is <class 'list'>
# list 410 is <class 'list'>
# list 411 is <class 'list'>
# list 412 is <class 'list'>
# list 413 is <class 'list'>
# list 414 is <class 'list'>
# list 415 is <class 'list'>
# list 416 is <class 'list'>
# list 417 is <class 'list'>
# list 418 is <class 'list'>
# list 419 is <class 'list'>
# list 420 is <class 'list'>
# list 421 is <class 'list'>
# list 422 is <class 'list'>
# list 423 is <class 'list'>
# list 424 is <class 'list'>
# list 425 is <class 'list'>
# list 426 is <class 'list'>
# list 427 is <class 'list'>
# list 428 is <class 'list'>
# list 429 is <class 'list'>
# list 430 is <class 'list'>
# list 431 is <class 'list'>
# list 432 is <class 'list'>
# list 433 is <class 'list'>
# list 434 is <class 'list'>
# list 435 is <class 'list'>
# list 436 is <class 'list'>
# list 437 is <class 'list'>
# list 438 is <class 'list'>
# list 439 is <class 'list'>
# list 440 is <class 'list'>
# list 441 is <class 'list'>
# list 442 is <class 'list'>
# list 443 is <class 'list'>
# list 444 is <class 'list'>
# list 445 is <class 'list'>
# list 446 is <class 'list'>
# list 447 is <class 'list'>
# list 448 is <class 'list'>
# list 449 is <class 'list'>
# list 450 is <class 'list'>
# list 451 is <class 'list'>
# list 452 is <class 'list'>
# list 453 is <class 'list'>
# list 454 is <class 'list'>
# list 455 is <class 'list'>
# list 456 is <class 'list'>
# list 457 is <class 'list'>
# list 458 is <class 'list'>
# list 459 is <class 'list'>
# list 460 is <class 'list'>
# list 461 is <class 'list'>
# list 462 is <class 'list'>
# list 463 is <class 'list'>
# list 464 is <class 'list'>
# list 465 is <class 'list'>
# list 466 is <class 'list'>
# list 467 is <class 'list'>
# list 468 is <class 'list'>
# list 469 is <class 'list'>
# list 470 is <class 'list'>
# list 471 is <class 'list'>
# list 472 is <class 'list'>
# list 473 is <class 'list'>
# list 474 is <class 'list'>
# list 475 is <class 'list'>
# list 476 is <class 'list'>
# list 477 is <class 'list'>
# list 478 is <class 'list'>
# list 479 is <class 'list'>
# list 480 is <class 'list'>
# list 481 is <class 'list'>
# list 482 is <class 'list'>
# list 483 is <class 'list'>
# list 484 is <class 'list'>
# list 485 is <class 'list'>
# list 486 is <class 'list'>
# list 487 is <class 'list'>
# list 488 is <class 'list'>
# list 489 is <class 'list'>
# list 490 is <class 'list'>
# list 491 is <class 'list'>
# list 492 is <class 'list'>
# list 493 is <class 'list'>
# list 494 is <class 'list'>
# list 495 is <class 'list'>
# list 496 is <class 'list'>
# list 497 is <class 'list'>
# list 498 is <class 'list'>
# list 499 is <class 'list'>
# list 500 is <class 'list'>
# list 501 is <class 'list'>
# list 502 is <class 'list'>
# list 503 is <class 'list'>
# list 504 is <class 'list'>
# list 505 is <class 'list'>
# list 506 is <class 'list'>
# list 507 is <class 'list'>
# list 508 is <class 'list'>
# list 509 is <class 'list'>
# list 510 is <class 'list'>
# list 511 is <class 'list'>
# list 512 is <class 'list'>
# list 513 is <class 'list'>
# list 514 is <class 'list'>
# list 515 is <class 'list'>
# list 516 is <class 'list'>
# list 517 is <class 'list'>
# list 518 is <class 'list'>
# list 519 is <class 'list'>
# list 520 is <class 'list'>
# list 521 is <class 'list'>
# list 522 is <class 'list'>
# list 523 is <class 'list'>
# list 524 is <class 'list'>
# list 525 is <class 'list'>
# list 526 is <class 'list'>
# list 527 is <class 'list'>
# list 528 is <class 'list'>
# list 529 is <class 'list'>
# list 530 is <class 'list'>
# list 531 is <class 'list'>
# list 532 is <class 'list'>
# list 533 is <class 'list'>
# list 534 is <class 'list'>
# list 535 is <class 'list'>
# list 536 is <class 'list'>
# list 537 is <class 'list'>
# list 538 is <class 'list'>
# list 539 is <class 'list'>
# list 540 is <class 'list'>
# list 541 is <class 'list'>
# list 542 is <class 'list'>
# list 543 is <class 'list'>
# list 544 is <class 'list'>
# list 545 is <class 'list'>
# list 546 is <class 'list'>
# list 547 is <class 'list'>
# list 548 is <class 'list'>
# list 549 is <class 'list'>
# list 550 is <class 'list'>
# list 551 is <class 'list'>
# list 552 is <class 'list'>
# list 553 is <class 'list'>
# list 554 is <class 'list'>
# list 555 is <class 'list'>
# list 556 is <class 'list'>
# list 557 is <class 'list'>
# list 558 is <class 'list'>
# list 559 is <class 'list'>
# list 560 is <class 'list'>
# list 561 is <class 'list'>
# list 562 is <class 'list'>
# list 563 is <class 'list'>
# list 564 is <class 'list'>
# list 565 is <class 'list'>
# list 566 is <class 'list'>
# list 567 is <class 'list'>
# list 568 is <class 'list'>
# list 569 is <class 'list'>
# list 570 is <class 'list'>
# list 571 is <class 'list'>
# list 572 is <class 'list'>
# list 573 is <class 'list'>
# list 574 is <class 'list'>
# list 575 is <class 'list'>
# list 576 is <class 'list'>
# list 577 is <class 'list'>
# list 578 is <class 'list'>
# list 579 is <class 'list'>
# list 580 is <class 'list'>
# list 581 is <class 'list'>
# list 582 is <class 'list'>
# list 583 is <class 'list'>
# list 584 is <class 'list'>
# list 585 is <class 'list'>
# list 586 is <class 'list'>
# list 587 is <class 'list'>
# list 588 is <class 'list'>
# list 589 is <class 'list'>
# list 590 is <class 'list'>
# list 591 is <class 'list'>
# list 592 is <class 'list'>
# list 593 is <class 'list'>
# list 594 is <class 'list'>
# list 595 is <class 'list'>
# list 596 is <class 'list'>
# list 597 is <class 'list'>
# list 598 is <class 'list'>
# list 599 is <class 'list'>
# list 600 is <class 'list'>
# list 601 is <class 'list'>
# list 602 is <class 'list'>
# list 603 is <class 'list'>
# list 604 is <class 'list'>
# list 605 is <class 'list'>
# list 606 is <class 'list'>
# list 607 is <class 'list'>
# list 608 is <class 'list'>
# list 609 is <class 'list'>
# list 610 is <class 'list'>
# list 611 is <class 'list'>
# list 612 is <class 'list'>
# list 613 is <class 'list'>
# list 614 is <class 'list'>
# list 615 is <class 'list'>
# list 616 is <class 'list'>
# list 617 is <class 'list'>
# list 618 is <class 'list'>
# list 619 is <class 'list'>
# list 620 is <class 'list'>
# list 621 is <class 'list'>
# list 622 is <class 'list'>
# list 623 is <class 'list'>
# list 624 is <class 'list'>
# list 625 is <class 'list'>
# list 626 is <class 'list'>
# list 627 is <class 'list'>
# list 628 is <class 'list'>
# list 629 is <class 'list'>
# list 630 is <class 'list'>
# list 631 is <class 'list'>
# list 632 is <class 'list'>
# list 633 is <class 'list'>
# list 634 is <class 'list'>
# list 635 is <class 'list'>
# list 636 is <class 'list'>
# list 637 is <class 'list'>
# list 638 is <class 'list'>
# list 639 is <class 'list'>
# list 640 is <class 'list'>
# list 641 is <class 'list'>
# list 642 is <class 'list'>
# list 643 is <class 'list'>
# list 644 is <class 'list'>
# list 645 is <class 'list'>
# list 646 is <class 'list'>
# list 647 is <class 'list'>
# list 648 is <class 'list'>
# list 649 is <class 'list'>
# list 650 is <class 'list'>
# list 651 is <class 'list'>
# list 652 is <class 'list'>
# list 653 is <class 'list'>
# list 654 is <class 'list'>
# list 655 is <class 'list'>
# list 656 is <class 'list'>
# list 657 is <class 'list'>
# list 658 is <class 'list'>
# list 659 is <class 'list'>
# list 660 is <class 'list'>
# list 661 is <class 'list'>
# list 662 is <class 'list'>
# list 663 is <class 'list'>
# list 664 is <class 'list'>
# list 665 is <class 'list'>
# list 666 is <class 'list'>
# list 667 is <class 'list'>
# list 668 is <class 'list'>
# list 669 is <class 'list'>
# list 670 is <class 'list'>
# list 671 is <class 'list'>
# list 672 is <class 'list'>
# list 673 is <class 'list'>
# list 674 is <class 'list'>
# list 675 is <class 'list'>
# list 676 is <class 'list'>
# list 677 is <class 'list'>
# list 678 is <class 'list'>
# list 679 is <class 'list'>
# list 680 is <class 'list'>
# list 681 is <class 'list'>
# list 682 is <class 'list'>
# list 683 is <class 'list'>
# list 684 is <class 'list'>
# list 685 is <class 'list'>
# list 686 is <class 'list'>
# list 687 is <class 'list'>
# list 688 is <class 'list'>
# list 689 is <class 'list'>
# list 690 is <class 'list'>
# list 691 is <class 'list'>
# list 692 is <class 'list'>
# list 693 is <class 'list'>
# list 694 is <class 'list'>
# list 695 is <class 'list'>
# list 696 is <class 'list'>
# list 697 is <class 'list'>
# list 698 is <class 'list'>
# list 699 is <class 'list'>
# list 700 is <class 'list'>
# list 701 is <class 'list'>
# list 702 is <class 'list'>
# list 703 is <class 'list'>
# list 704 is <class 'list'>
# list 705 is <class 'list'>
# list 706 is <class 'list'>
# list 707 is <class 'list'>
# list 708 is <class 'list'>
# list 709 is <class 'list'>
# list 710 is <class 'list'>
# list 711 is <class 'list'>
# list 712 is <class 'list'>
# list 713 is <class 'list'>
# list 714 is <class 'list'>
# list 715 is <class 'list'>
# list 716 is <class 'list'>
# list 717 is <class 'list'>
# list 718 is <class 'list'>
# list 719 is <class 'list'>
# list 720 is <class 'list'>
# list 721 is <class 'list'>
# list 722 is <class 'list'>
# list 723 is <class 'list'>
# list 724 is <class 'list'>
# list 725 is <class 'list'>
# list 726 is <class 'list'>
# list 727 is <class 'list'>
# list 728 is <class 'list'>
# list 729 is <class 'list'>
# list 730 is <class 'list'>
# list 731 is <class 'list'>
# list 732 is <class 'list'>
# list 733 is <class 'list'>
# list 734 is <class 'list'>
# list 735 is <class 'list'>
# list 736 is <class 'list'>
# list 737 is <class 'list'>
# list 738 is <class 'list'>
# list 739 is <class 'list'>
# list 740 is <class 'list'>
# list 741 is <class 'list'>
# list 742 is <class 'list'>
# list 743 is <class 'list'>
# list 744 is <class 'list'>
# list 745 is <class 'list'>
# list 746 is <class 'list'>
# list 747 is <class 'list'>
# list 748 is <class 'list'>
# list 749 is <class 'list'>
# list 750 is <class 'list'>
# list 751 is <class 'list'>
# list 752 is <class 'list'>
# list 753 is <class 'list'>
# list 754 is <class 'list'>
# list 755 is <class 'list'>
# list 756 is <class 'list'>
# list 757 is <class 'list'>
# list 758 is <class 'list'>
# list 759 is <class 'list'>
# list 760 is <class 'list'>
# list 761 is <class 'list'>
# list 762 is <class 'list'>
# list 763 is <class 'list'>
# list 764 is <class 'list'>
# list 765 is <class 'list'>
# list 766 is <class 'list'>
# list 767 is <class 'list'>
# list 768 is <class 'list'>
# list 769 is <class 'list'>
# list 770 is <class 'list'>
# list 771 is <class 'list'>
# list 772 is <class 'list'>
# list 773 is <class 'list'>
# list 774 is <class 'list'>
# list 775 is <class 'list'>
# list 776 is <class 'list'>
# list 777 is <class 'list'>
# list 778 is <class 'list'>
# list 779 is <class 'list'>
# list 780 is <class 'list'>
# list 781 is <class 'list'>
# list 782 is <class 'list'>
# list 783 is <class 'list'>
# list 784 is <class 'list'>
# list 785 is <class 'list'>
# list 786 is <class 'list'>
# list 787 is <class 'list'>
# list 788 is <class 'list'>
# list 789 is <class 'list'>
# list 790 is <class 'list'>
# list 791 is <class 'list'>
# list 792 is <class 'list'>
# list 793 is <class 'list'>
# list 794 is <class 'list'>
# list 795 is <class 'list'>
# list 796 is <class 'list'>
# list 797 is <class 'list'>
# list 798 is <class 'list'>
# list 799 is <class 'list'>
# list 800 is <class 'list'>
# list 801 is <class 'list'>
# list 802 is <class 'list'>
# list 803 is <class 'list'>
# list 804 is <class 'list'>
# list 805 is <class 'list'>
# list 806 is <class 'list'>
# list 807 is <class 'list'>
# list 808 is <class 'list'>
# list 809 is <class 'list'>
# list 810 is <class 'list'>
# list 811 is <class 'list'>
# list 812 is <class 'list'>
# list 813 is <class 'list'>
# list 814 is <class 'list'>
# list 815 is <class 'list'>
# list 816 is <class 'list'>
# list 817 is <class 'list'>
# list 818 is <class 'list'>
# list 819 is <class 'list'>
# list 820 is <class 'list'>
# list 821 is <class 'list'>
# list 822 is <class 'list'>
# list 823 is <class 'list'>
# list 824 is <class 'list'>
# list 825 is <class 'list'>
# list 826 is <class 'list'>
# list 827 is <class 'list'>
# list 828 is <class 'list'>
# list 829 is <class 'list'>
# list 830 is <class 'list'>
# list 831 is <class 'list'>
# list 832 is <class 'list'>
# list 833 is <class 'list'>
# list 834 is <class 'list'>
# list 835 is <class 'list'>
# list 836 is <class 'list'>
# list 837 is <class 'list'>
# list 838 is <class 'list'>
# list 839 is <class 'list'>
# list 840 is <class 'list'>
# list 841 is <class 'list'>
# list 842 is <class 'list'>
# list 843 is <class 'list'>
# list 844 is <class 'list'>
# list 845 is <class 'list'>
# list 846 is <class 'list'>
# list 847 is <class 'list'>
# list 848 is <class 'list'>
# list 849 is <class 'list'>
# list 850 is <class 'list'>
# list 851 is <class 'list'>
# list 852 is <class 'list'>
# list 853 is <class 'list'>
# list 854 is <class 'list'>
# list 855 is <class 'list'>
# list 856 is <class 'list'>
# list 857 is <class 'list'>
# list 858 is <class 'list'>
# list 859 is <class 'list'>
# list 860 is <class 'list'>
# list 861 is <class 'list'>
# list 862 is <class 'list'>
# list 863 is <class 'list'>
# list 864 is <class 'list'>
# list 865 is <class 'list'>
# list 866 is <class 'list'>
# list 867 is <class 'list'>
# list 868 is <class 'list'>
# list 869 is <class 'list'>
# list 870 is <class 'list'>
# list 871 is <class 'list'>
# list 872 is <class 'list'>
# list 873 is <class 'list'>
# list 874 is <class 'list'>
# list 875 is <class 'list'>
# list 876 is <class 'list'>
# list 877 is <class 'list'>
# list 878 is <class 'list'>
# list 879 is <class 'list'>
# list 880 is <class 'list'>
# list 881 is <class 'list'>
# list 882 is <class 'list'>
# list 883 is <class 'list'>
# list 884 is <class 'list'>
# list 885 is <class 'list'>
# list 886 is <class 'list'>
# list 887 is <class 'list'>
# list 888 is <class 'list'>
# list 889 is <class 'list'>
# list 890 is <class 'list'>
# list 891 is <class 'list'>
# list 892 is <class 'list'>
# list 893 is <class 'list'>
# list 894 is <class 'list'>
# list 895 is <class 'list'>
# list 896 is <class 'list'>
# list 897 is <class 'list'>
# list 898 is <class 'list'>
# list 899 is <class 'list'>
# list 900 is <class 'list'>
# list 901 is <class 'list'>
# list 902 is <class 'list'>
# list 903 is <class 'list'>
# list 904 is <class 'list'>
# list 905 is <class 'list'>
# list 906 is <class 'list'>
# list 907 is <class 'list'>
# list 908 is <class 'list'>
# list 909 is <class 'list'>
# list 910 is <class 'list'>
# list 911 is <class 'list'>
# list 912 is <class 'list'>
# list 913 is <class 'list'>
# list 914 is <class 'list'>
# list 915 is <class 'list'>
# list 916 is <class 'list'>
# list 917 is <class 'list'>
# list 918 is <class 'list'>
# list 919 is <class 'list'>
# list 920 is <class 'list'>
# list 921 is <class 'list'>
# list 922 is <class 'list'>
# list 923 is <class 'list'>
# list 924 is <class 'list'>
# list 925 is <class 'list'>
# list 926 is <class 'list'>
# list 927 is <class 'list'>
# list 928 is <class 'list'>
# list 929 is <class 'list'>
# list 930 is <class 'list'>
# list 931 is <class 'list'>
# list 932 is <class 'list'>
# list 933 is <class 'list'>
# list 934 is <class 'list'>
# list 935 is <class 'list'>
# list 936 is <class 'list'>
# list 937 is <class 'list'>
# list 938 is <class 'list'>
# list 939 is <class 'list'>
# list 940 is <class 'list'>
# list 941 is <class 'list'>
# list 942 is <class 'list'>
# list 943 is <class 'list'>
# list 944 is <class 'list'>
# list 945 is <class 'list'>
# list 946 is <class 'list'>
# list 947 is <class 'list'>
# list 948 is <class 'list'>
# list 949 is <class 'list'>
# list 950 is <class 'list'>
# list 951 is <class 'list'>
# list 952 is <class 'list'>
# list 953 is <class 'list'>
# list 954 is <class 'list'>
# list 955 is <class 'list'>
# list 956 is <class 'list'>
# list 957 is <class 'list'>
# list 958 is <class 'list'>
# list 959 is <class 'list'>
# list 960 is <class 'list'>
# list 961 is <class 'list'>
# list 962 is <class 'list'>
# list 963 is <class 'list'>
# list 964 is <class 'list'>
# list 965 is <class 'list'>
# list 966 is <class 'list'>
# list 967 is <class 'list'>
# list 968 is <class 'list'>
# list 969 is <class 'list'>
# list 970 is <class 'list'>
# list 971 is <class 'list'>
# list 972 is <class 'list'>
# list 973 is <class 'list'>
# list 974 is <class 'list'>
# list 975 is <class 'list'>
# list 976 is <class 'list'>
# list 977 is <class 'list'>
# list 978 is <class 'list'>
# list 979 is <class 'list'>
# list 980 is <class 'list'>
# list 981 is <class 'list'>
# list 982 is <class 'list'>
# list 983 is <class 'list'>
# list 984 is <class 'list'>
# list 985 is <class 'list'>
# list 986 is <class 'list'>
# list 987 is <class 'list'>
# list 988 is <class 'list'>
# list 989 is <class 'list'>
# list 990 is <class 'list'>
# list 991 is <class 'list'>
# list 992 is <class 'list'>
# list 993 is <class 'list'>
# list 994 is <class 'list'>
# list 995 is <class 'list'>
# list 996 is <class 'list'>
# list 997 is <class 'list'>
# list 998 is <class 'list'>
# list 999 is <class 'list'>
# list 1000 is <class 'list'>
# list 1001 is <class 'list'>
# list 1002 is <class 'list'>
# list 1003 is <class 'list'>
# list 1004 is <class 'list'>
# list 1005 is <class 'list'>
# list 1006 is <class 'list'>
# list 1007 is <class 'list'>
# list 1008 is <class 'list'>
# list 1009 is <class 'list'>
# list 1010 is <class 'list'>
# list 1011 is <class 'list'>
# list 1012 is <class 'list'>
# list 1013 is <class 'list'>
# list 1014 is <class 'list'>
# list 1015 is <class 'list'>
# list 1016 is <class 'list'>
# list 1017 is <class 'list'>
# list 1018 is <class 'list'>
# list 1019 is <class 'list'>
# list 1020 is <class 'list'>
# list 1021 is <class 'list'>
# list 1022 is <class 'list'>
# list 1023 is <class 'list'>
# list 1024 is <class 'list'>
# list 1025 is <class 'list'>
# list 1026 is <class 'list'>
# list 1027 is <class 'list'>
# list 1028 is <class 'list'>
# list 1029 is <class 'list'>
# list 1030 is <class 'list'>
# list 1031 is <class 'list'>
# list 1032 is <class 'list'>
# list 1033 is <class 'list'>
# list 1034 is <class 'list'>
# list 1035 is <class 'list'>
# list 1036 is <class 'list'>
# list 1037 is <class 'list'>
# list 1038 is <class 'list'>
# list 1039 is <class 'list'>
# list 1040 is <class 'list'>
# list 1041 is <class 'list'>
# list 1042 is <class 'list'>
# list 1043 is <class 'list'>
# list 1044 is <class 'list'>
# list 1045 is <class 'list'>
# list 1046 is <class 'list'>
# list 1047 is <class 'list'>
# list 1048 is <class 'list'>
# list 1049 is <class 'list'>
# list 1050 is <class 'list'>
# list 1051 is <class 'list'>
# list 1052 is <class 'list'>
# list 1053 is <class 'list'>
# list 1054 is <class 'list'>
# list 1055 is <class 'list'>
# list 1056 is <class 'list'>
# list 1057 is <class 'list'>
# list 1058 is <class 'list'>
# list 1059 is <class 'list'>
# list 1060 is <class 'list'>
# list 1061 is <class 'list'>
# list 1062 is <class 'list'>
# list 1063 is <class 'list'>
# list 1064 is <class 'list'>
# list 1065 is <class 'list'>
# list 1066 is <class 'list'>
# list 1067 is <class 'list'>
# list 1068 is <class 'list'>
# list 1069 is <class 'list'>
# list 1070 is <class 'list'>
# list 1071 is <class 'list'>
# list 1072 is <class 'list'>
# list 1073 is <class 'list'>
# list 1074 is <class 'list'>
# list 1075 is <class 'list'>
# list 1076 is <class 'list'>
# list 1077 is <class 'list'>
# list 1078 is <class 'list'>
# list 1079 is <class 'list'>
# list 1080 is <class 'list'>
# list 1081 is <class 'list'>

# %% [markdown]
# They are actually in list format, so we can simply apply the pandas "series" function to this column to make the values strings which can be processed instead of inconvenient lists.

# %%
pokemon_formats = pokemon_df['formats'].apply(pd.Series)
pokemon_formats
# Out:
#          0
# 0       LC
# 1      NFE
# 2     RUBL
# 3       LC
# 4      NFE
# ...    ...
# 1097   NaN
# 1098   CAP
# 1099   NaN
# 1100   CAP
# 1101   CAP
#
# [1082 rows x 1 columns]

# %%
pokemon_df['formats'] = pokemon_formats.values
pokemon_df
# Out:
#             name   hp  atk  def  spa  spd  spe  weight  height  \
# 0      Bulbasaur   45   49   49   65   65   45     6.9     0.7
# 1        Ivysaur   60   62   63   80   80   60    13.0     1.0
# 2       Venusaur   80   82   83  100  100   80   100.0     2.0
# 3     Charmander   39   52   43   60   50   65     8.5     0.6
# 4     Charmeleon   58   64   58   80   65   80    19.0     1.1
# ...          ...  ...  ...  ...  ...  ...  ...     ...     ...
# 1097      Solotl   68   48   34   72   24   84    11.8     0.6
# 1098   Astrolotl  108  108   74   92   64  114    50.0     1.9
# 1099    Miasmite   40   85   60   52   52   44    10.1     0.6
# 1100     Miasmaw   85  135   60  115   85   92    57.0     1.2
# 1101    Chromera   85   85  115  115  100  100   215.0     2.5
#
#                 types                                        abilities  \
# 0     [Grass, Poison]                          [Chlorophyll, Overgrow]
# 1     [Grass, Poison]                          [Chlorophyll, Overgrow]
# 2     [Grass, Poison]                          [Chlorophyll, Overgrow]
# 3              [Fire]                             [Blaze, Solar Power]
# 4              [Fire]                             [Blaze, Solar Power]
# ...               ...                                              ...
# 1097   [Fire, Dragon]            [Magician, Regenerator, Vital Spirit]
# 1098   [Fire, Dragon]            [Magician, Regenerator, Vital Spirit]
# 1099    [Bug, Dragon]  [Compound Eyes, Hyper Cutter, Neutralizing Gas]
# 1100    [Bug, Dragon]  [Compound Eyes, Hyper Cutter, Neutralizing Gas]
# 1101   [Dark, Poison]                                   [Color Change]
#
#      formats isNonstandard                                                oob
# 0         LC      Standard  {'dex_number': 1, 'evos': ['Ivysaur'], 'alts':...
# 1        NFE      Standard  {'dex_number': 2, 'evos': ['Venusaur'], 'alts'...
# 2       RUBL      Standard  {'dex_number': 3, 'evos': [], 'alts': ['Venusa...
# 3         LC      Standard  {'dex_number': 4, 'evos': ['Charmeleon'], 'alt...
# 4        NFE      Standard  {'dex_number': 5, 'evos': ['Charizard'], 'alts...
# ...      ...           ...                                                ...
# 1097     NaN           CAP  {'dex_number': -56, 'evos': ['Astrolotl'], 'al...
# 1098     CAP           CAP  {'dex_number': -57, 'evos': [], 'alts': [], 'g...
# 1099     NaN           CAP  {'dex_number': -58, 'evos': ['Miasmaw'], 'alts...
# 1100     CAP           CAP  {'dex_number': -59, 'evos': [], 'alts': [], 'g...
# 1101     CAP           CAP  {'dex_number': -60, 'evos': [], 'alts': [], 'g...
#
# [1082 rows x 14 columns]

# %% [markdown]
# We should check the unique values of this formats column to make sure they are what we are looking for.

# %%
pokemon_df['formats'].unique()
# Out:
# array(['LC', 'NFE', 'RUBL', 'PU', 'NU', 'Untiered', 'National Dex', 'UU',
#        'OU', 'UUBL', 'PUBL', 'RU', 'Uber', 'NUBL', 'CAP', nan, 'AG'],
#       dtype=object)

# %% [markdown]
# There are several formats here which are incorrect:
#
# 1. AG: this is due to Zacian, who is listed as AG format, even though it's really the alternative form Zacian Crowned which is AG (and has been removed). Zacian is actually an Uber, so his corresponding "formats" value will be switched to Uber and this should remove AG from the set of possible values.
#
# 2. National Dex: This is a real format for pokemon not obtainable in generation 8 by standard means, and it doesn't contain any real strategies and in many cases even movesets.  Since it doesn't fit within the ranking we're trying to predict either, we're going to have to remove all pokemon with this format (though maybe we can examine what tier they'd end up in later for fun).
#
# 3. CAP: This is the Create-A-Pokemon format, which contains pokemon which were created and are not real.  These also need to be removed, but also might be fun to examine later.
#
# 4. nan, which is a null value that likely indicates an error of some sort.
#
# First of all, we need to know what the nan values indicate:

# %%
pokemon_df.loc[pokemon_df['formats'].isna()]
# Out:
#             name  hp  atk  def  spa  spd  spe  weight  height  \
# 532       Syclar  40   76   45   74   39   91     4.0    0.20
# 533      Embirch  60   40   55   65   40   60    15.0    0.60
# 534      Flarelm  90   50   95   75   70   40    73.0    1.40
# 535       Breezi  50   46   69   60   50   75     0.6    0.40
# 536       Rebble  45   25   65   75   55   80     7.0    0.30
# 537      Tactite  70   40   65  100   65   95    16.0    0.60
# 538    Privatyke  65   75   65   40   60   45    35.0    1.00
# 539      Voodoll  55   40   55   75   50   70    25.0    1.00
# 710    Scratchet  55   85   80   20   70   40    20.0    0.50
# 712    Necturine  49   55   60   50   75   51     1.8    0.30
# 714        Cupra  50   60   49   67   30   44     4.8    0.50
# 715      Argalis  60   90   89   87   40   54   341.4    1.30
# 716     Brattler  80   70   40   20   90   30    11.5    1.80
# 717       Cawdet  35   72   85   40   55   88    25.0    0.76
# 803   Volkritter  60   30   50   80   60   70    15.0    0.30
# 805     Snugglow  40   37   79   91   68   70     6.0    1.20
# 807      Floatoy  48   70   40   70   30   77     1.9    0.80
# 808     Caimanoe  73   85   65   80   40   87    72.5    1.40
# 810      Pluffle  74   38   51   65   78   49     1.8    0.80
# 826      Justyke  72   70   56   83   68   30    36.5    0.40
# 966       Mumbao  55   30   64   87   73   66   250.0    1.00
# 968     Fawnifer  49   61   42   52   40   76     6.9    0.70
# 969    Electrelk  59   81   67   57   55  101    41.5    1.40
# 971     Smogecko  48   66   43   58   48   56     8.5    0.50
# 972     Smoguana  68   86   53   68   68   76    22.2    1.50
# 974    Swirlpool  61   49   70   50   62   28     7.0    0.50
# 975    Coribalis  76   69   90   65   77   43    24.5    1.40
# 1097      Solotl  68   48   34   72   24   84    11.8    0.60
# 1099    Miasmite  40   85   60   52   52   44    10.1    0.60
#
#                    types                                        abilities  \
# 532           [Ice, Bug]            [Compound Eyes, Ice Body, Snow Cloak]
# 533        [Fire, Grass]              [Chlorophyll, Leaf Guard, Reckless]
# 534        [Fire, Grass]           [Battle Armor, Rock Head, White Smoke]
# 535     [Poison, Flying]                     [Frisk, Own Tempo, Unburden]
# 536               [Rock]                   [Levitate, Sniper, Solid Rock]
# 537               [Rock]                   [Levitate, Sniper, Technician]
# 538    [Water, Fighting]                            [Technician, Unaware]
# 539       [Normal, Dark]        [Cursed Body, Lightning Rod, Volt Absorb]
# 710   [Normal, Fighting]               [Prankster, Scrappy, Vital Spirit]
# 712       [Grass, Ghost]                        [Anticipation, Telepathy]
# 714       [Bug, Psychic]             [Keen Eye, Magic Guard, Shield Dust]
# 715       [Bug, Psychic]             [Compound Eyes, Overcoat, Shed Skin]
# 716        [Dark, Grass]                  [Harvest, Infiltrator, Rattled]
# 717      [Steel, Flying]               [Big Pecks, Keen Eye, Volt Absorb]
# 803        [Water, Fire]             [Anticipation, Infiltrator, Unnerve]
# 805   [Electric, Poison]           [Storm Drain, Telepathy, Vital Spirit]
# 807              [Water]              [Heatproof, Swift Swim, Water Veil]
# 808       [Water, Steel]             [Heatproof, Light Metal, Water Veil]
# 810              [Fairy]         [Aroma Veil, Friend Guard, Natural Cure]
# 826      [Steel, Ground]                  [Justified, Levitate, Stalwart]
# 966       [Grass, Fairy]                   [Overcoat, Solar Power, Trace]
# 968              [Grass]                        [Lightning Rod, Overgrow]
# 969    [Grass, Electric]                            [Galvanize, Overgrow]
# 971               [Fire]                              [Blaze, Technician]
# 972       [Fire, Ground]                              [Blaze, Technician]
# 974              [Water]                           [Poison Heal, Torrent]
# 975         [Water, Bug]                           [Poison Heal, Torrent]
# 1097      [Fire, Dragon]            [Magician, Regenerator, Vital Spirit]
# 1099       [Bug, Dragon]  [Compound Eyes, Hyper Cutter, Neutralizing Gas]
#
#      formats isNonstandard                                                oob
# 532      NaN           CAP  {'dex_number': -1, 'evos': ['Syclant'], 'alts'...
# 533      NaN           CAP  {'dex_number': -4, 'evos': ['Flarelm'], 'alts'...
# 534      NaN           CAP  {'dex_number': -5, 'evos': ['Pyroak'], 'alts':...
# 535      NaN           CAP  {'dex_number': -7, 'evos': ['Fidgit'], 'alts':...
# 536      NaN           CAP  {'dex_number': -9, 'evos': ['Tactite'], 'alts'...
# 537      NaN           CAP  {'dex_number': -10, 'evos': ['Stratagem'], 'al...
# 538      NaN           CAP  {'dex_number': -12, 'evos': ['Arghonaut'], 'al...
# 539      NaN           CAP  {'dex_number': -18, 'evos': ['Voodoom'], 'alts...
# 710      NaN           CAP  {'dex_number': -20, 'evos': ['Tomohawk'], 'alt...
# 712      NaN           CAP  {'dex_number': -22, 'evos': ['Necturna'], 'alt...
# 714      NaN           CAP  {'dex_number': -25, 'evos': ['Argalis'], 'alts...
# 715      NaN           CAP  {'dex_number': -26, 'evos': ['Aurumoth'], 'alt...
# 716      NaN           CAP  {'dex_number': -28, 'evos': ['Malaconda'], 'al...
# 717      NaN           CAP  {'dex_number': -30, 'evos': ['Cawmodore'], 'al...
# 803      NaN           CAP  {'dex_number': -32, 'evos': ['Volkraken'], 'al...
# 805      NaN           CAP  {'dex_number': -34, 'evos': ['Plasmanta'], 'al...
# 807      NaN           CAP  {'dex_number': -36, 'evos': ['Caimanoe'], 'alt...
# 808      NaN           CAP  {'dex_number': -37, 'evos': ['Naviathan'], 'al...
# 810      NaN           CAP  {'dex_number': -40, 'evos': ['Kerfluffle'], 'a...
# 826      NaN           CAP  {'dex_number': -54, 'evos': ['Equilibra'], 'al...
# 966      NaN           CAP  {'dex_number': -43, 'evos': ['Jumbao'], 'alts'...
# 968      NaN           CAP  {'dex_number': -45, 'evos': ['Electrelk'], 'al...
# 969      NaN           CAP  {'dex_number': -46, 'evos': ['Caribolt'], 'alt...
# 971      NaN           CAP  {'dex_number': -48, 'evos': ['Smoguana'], 'alt...
# 972      NaN           CAP  {'dex_number': -49, 'evos': ['Smokomodo'], 'al...
# 974      NaN           CAP  {'dex_number': -51, 'evos': ['Coribalis'], 'al...
# 975      NaN           CAP  {'dex_number': -52, 'evos': ['Snaelstrom'], 'a...
# 1097     NaN           CAP  {'dex_number': -56, 'evos': ['Astrolotl'], 'al...
# 1099     NaN           CAP  {'dex_number': -58, 'evos': ['Miasmaw'], 'alts...

# %% [markdown]
# They are always paired with the isNonstandard column having a value of CAP, so these are almost certainly created pokemon which aren't even used in the CAP format.  They will also be removed, so let's removed everything we've set out to below:

# %%
#fixing AG
pokemon_df.loc[pokemon_df['name'] == 'Zacian', 'formats'] = 'Uber'

#fixing National Dex
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['isNonstandard'] == 'NatDex'])
pokemon_df = pokemon_df.loc[pokemon_df['isNonstandard'] != 'NatDex']

#fixing CAP and nan values
pokemon_removed_df = pokemon_removed_df.append(pokemon_df.loc[pokemon_df['isNonstandard'] == 'CAP'])
pokemon_df = pokemon_df.loc[pokemon_df['isNonstandard'] != 'CAP']

pokemon_df
# Out:
#                 name   hp  atk  def  spa  spd  spe  weight  height  \
# 0          Bulbasaur   45   49   49   65   65   45     6.9     0.7
# 1            Ivysaur   60   62   63   80   80   60    13.0     1.0
# 2           Venusaur   80   82   83  100  100   80   100.0     2.0
# 3         Charmander   39   52   43   60   50   65     8.5     0.6
# 4         Charmeleon   58   64   58   80   65   80    19.0     1.1
# ...              ...  ...  ...  ...  ...  ...  ...     ...     ...
# 1092       Glastrier  100  145  130   65  110   30   800.0     2.2
# 1093       Spectrier  100   65   60  145   80  130    44.5     2.0
# 1094         Calyrex  100   80   80   80   80   80     7.7     1.1
# 1095     Calyrex-Ice  100  165  150   85  130   50   809.1     2.4
# 1096  Calyrex-Shadow  100   85   80  165  100  150    53.6     2.4
#
#                  types                abilities   formats isNonstandard  \
# 0      [Grass, Poison]  [Chlorophyll, Overgrow]        LC      Standard
# 1      [Grass, Poison]  [Chlorophyll, Overgrow]       NFE      Standard
# 2      [Grass, Poison]  [Chlorophyll, Overgrow]      RUBL      Standard
# 3               [Fire]     [Blaze, Solar Power]        LC      Standard
# 4               [Fire]     [Blaze, Solar Power]       NFE      Standard
# ...                ...                      ...       ...           ...
# 1092             [Ice]         [Chilling Neigh]        NU      Standard
# 1093           [Ghost]             [Grim Neigh]      Uber      Standard
# 1094  [Psychic, Grass]                [Unnerve]  Untiered      Standard
# 1095    [Psychic, Ice]     [As One (Glastrier)]      Uber      Standard
# 1096  [Psychic, Ghost]     [As One (Spectrier)]      Uber      Standard
#
#                                                     oob
# 0     {'dex_number': 1, 'evos': ['Ivysaur'], 'alts':...
# 1     {'dex_number': 2, 'evos': ['Venusaur'], 'alts'...
# 2     {'dex_number': 3, 'evos': [], 'alts': ['Venusa...
# 3     {'dex_number': 4, 'evos': ['Charmeleon'], 'alt...
# 4     {'dex_number': 5, 'evos': ['Charizard'], 'alts...
# ...                                                 ...
# 1092  {'dex_number': 896, 'evos': [], 'alts': [], 'g...
# 1093  {'dex_number': 897, 'evos': [], 'alts': [], 'g...
# 1094  {'dex_number': 898, 'evos': [], 'alts': [], 'g...
# 1095  {'dex_number': 898, 'evos': [], 'alts': [], 'g...
# 1096  {'dex_number': 898, 'evos': [], 'alts': [], 'g...
#
# [739 rows x 14 columns]

# %% [markdown]
# That looks correct.  Let's just do a few final steps: check whether there are no more undesirable formats, and place the pokemon names as the index of the Dataframe.  This index of pokemon names will serve as the key linking all of our different dataframes and dictionaries together by the end of this Data Wrangling step.

# %%
pokemon_df['formats'].unique()
# Out:
# array(['LC', 'NFE', 'RUBL', 'PU', 'NU', 'Untiered', 'UU', 'OU', 'UUBL',
#        'PUBL', 'RU', 'Uber', 'NUBL'], dtype=object)

# %% [markdown]
# That seems completely fixed.

# %%
pokemon_df.set_index('name', inplace=True)

#And we'll generate one final profile report to make sure there isn't anything else to pay attention to.
profile_report = pokemon_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/28 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# It looks good in general, but there are still the unsupported columns and isNonstandard which is a completely uniform column (with the single value "Standard"). isNonstandard no longer contains any information and should be removed.
#
# Let's come back to cleaning all of these columns when we get what we need out of types, abilities, and oob, since those unsupported values contain lots of information so we should store in another way that will allow us to access it more effectively.

# %% [markdown]
# <a id='pokemon_types_df'></a>
# ### pokemon_types_df

# %% [markdown]
# We need to go back to pokedex_dict, and make another dataframe, similar to what we did for pokemon_df.  However, this time we will use a different section of the JSON file (which is best observed through jsonviewer).

# %%
types_df = pd.DataFrame(pokedex_dict['injectRpcs'][1][1]['types'])
types_df
# Out:
#         name                                     atk_effectives  \
# 0        Bug  [[Bug, 1], [Dark, 2], [Dragon, 1], [Electric, ...
# 1       Dark  [[Bug, 1], [Dark, 0.5], [Dragon, 1], [Electric...
# 2     Dragon  [[Bug, 1], [Dark, 1], [Dragon, 2], [Electric, ...
# 3   Electric  [[Bug, 1], [Dark, 1], [Dragon, 0.5], [Electric...
# 4      Fairy  [[Bug, 1], [Dark, 2], [Dragon, 2], [Electric, ...
# 5   Fighting  [[Bug, 0.5], [Dark, 2], [Dragon, 1], [Electric...
# 6       Fire  [[Bug, 2], [Dark, 1], [Dragon, 0.5], [Electric...
# 7     Flying  [[Bug, 2], [Dark, 1], [Dragon, 1], [Electric, ...
# 8      Ghost  [[Bug, 1], [Dark, 0.5], [Dragon, 1], [Electric...
# 9      Grass  [[Bug, 0.5], [Dark, 1], [Dragon, 0.5], [Electr...
# 10    Ground  [[Bug, 0.5], [Dark, 1], [Dragon, 1], [Electric...
# 11       Ice  [[Bug, 1], [Dark, 1], [Dragon, 2], [Electric, ...
# 12    Normal  [[Bug, 1], [Dark, 1], [Dragon, 1], [Electric, ...
# 13    Poison  [[Bug, 1], [Dark, 1], [Dragon, 1], [Electric, ...
# 14   Psychic  [[Bug, 1], [Dark, 0], [Dragon, 1], [Electric, ...
# 15      Rock  [[Bug, 2], [Dark, 1], [Dragon, 1], [Electric, ...
# 16     Steel  [[Bug, 1], [Dark, 1], [Dragon, 1], [Electric, ...
# 17     Water  [[Bug, 1], [Dark, 1], [Dragon, 0.5], [Electric...
#
#                            genfamily  \
# 0   [RB, GS, RS, DP, BW, XY, SM, SS]
# 1       [GS, RS, DP, BW, XY, SM, SS]
# 2   [RB, GS, RS, DP, BW, XY, SM, SS]
# 3   [RB, GS, RS, DP, BW, XY, SM, SS]
# 4                       [XY, SM, SS]
# 5   [RB, GS, RS, DP, BW, XY, SM, SS]
# 6   [RB, GS, RS, DP, BW, XY, SM, SS]
# 7   [RB, GS, RS, DP, BW, XY, SM, SS]
# 8   [RB, GS, RS, DP, BW, XY, SM, SS]
# 9   [RB, GS, RS, DP, BW, XY, SM, SS]
# 10  [RB, GS, RS, DP, BW, XY, SM, SS]
# 11  [RB, GS, RS, DP, BW, XY, SM, SS]
# 12  [RB, GS, RS, DP, BW, XY, SM, SS]
# 13  [RB, GS, RS, DP, BW, XY, SM, SS]
# 14  [RB, GS, RS, DP, BW, XY, SM, SS]
# 15  [RB, GS, RS, DP, BW, XY, SM, SS]
# 16      [GS, RS, DP, BW, XY, SM, SS]
# 17  [RB, GS, RS, DP, BW, XY, SM, SS]
#
#                                           description
# 0
# 1   Pokemon of this type are immune to Status move...
# 2
# 3       Pokemon of this type cannot become paralyzed.
# 4
# 5
# 6          Pokemon of this type cannot become burned.
# 7   Pokemon of this type are airborne and lose the...
# 8   Pokemon of this type cannot be prevented from ...
# 9   Pokemon of this type cannot become affected by...
# 10  Pokemon of this type are immune to damage from...
# 11  Pokemon of this type cannot become frozen and ...
# 12
# 13  Pokemon of this type cannot become poisoned, e...
# 14
# 15  Pokemon of this type are immune to damage from...
# 16  Pokemon of this type cannot become poisoned, e...
# 17   Freeze-Dry is super effective against this type.

# %% [markdown]
# For our purposes, we really only need the types.  Genfamilies, attack effectiveness, and descriptions always come with the type anyways and aren't being directly analyzed in the machine learning task.  Also, we want to link our types dataframe with our pokemon dataframe by using the same index, so let's initialize a new dataframe to hold the types of each pokemon in a one-hot encoded fashion (which is most convenient for machine learning).

# %%
pokemon_types_df = pd.DataFrame(0, index=pokemon_df.index, columns=types_df['name'].rename(''))
pokemon_types_df
# Out:
#                 Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  Flying  \
# name
# Bulbasaur         0     0       0         0      0         0     0       0
# Ivysaur           0     0       0         0      0         0     0       0
# Venusaur          0     0       0         0      0         0     0       0
# Charmander        0     0       0         0      0         0     0       0
# Charmeleon        0     0       0         0      0         0     0       0
# ...             ...   ...     ...       ...    ...       ...   ...     ...
# Glastrier         0     0       0         0      0         0     0       0
# Spectrier         0     0       0         0      0         0     0       0
# Calyrex           0     0       0         0      0         0     0       0
# Calyrex-Ice       0     0       0         0      0         0     0       0
# Calyrex-Shadow    0     0       0         0      0         0     0       0
#
#                 Ghost  Grass  Ground  Ice  Normal  Poison  Psychic  Rock  \
# name
# Bulbasaur           0      0       0    0       0       0        0     0
# Ivysaur             0      0       0    0       0       0        0     0
# Venusaur            0      0       0    0       0       0        0     0
# Charmander          0      0       0    0       0       0        0     0
# Charmeleon          0      0       0    0       0       0        0     0
# ...               ...    ...     ...  ...     ...     ...      ...   ...
# Glastrier           0      0       0    0       0       0        0     0
# Spectrier           0      0       0    0       0       0        0     0
# Calyrex             0      0       0    0       0       0        0     0
# Calyrex-Ice         0      0       0    0       0       0        0     0
# Calyrex-Shadow      0      0       0    0       0       0        0     0
#
#                 Steel  Water
# name
# Bulbasaur           0      0
# Ivysaur             0      0
# Venusaur            0      0
# Charmander          0      0
# Charmeleon          0      0
# ...               ...    ...
# Glastrier           0      0
# Spectrier           0      0
# Calyrex             0      0
# Calyrex-Ice         0      0
# Calyrex-Shadow      0      0
#
# [739 rows x 18 columns]

# %% [markdown]
# Now we need to check the unsupported data type from pokemon_df in the types column, which is where we'll get our values for this new dataframe from:

# %%
for i, l in enumerate(pokemon_df["types"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'list'>
# list 1 is <class 'list'>
# list 2 is <class 'list'>
# list 3 is <class 'list'>
# list 4 is <class 'list'>
# list 5 is <class 'list'>
# list 6 is <class 'list'>
# list 7 is <class 'list'>
# list 8 is <class 'list'>
# list 9 is <class 'list'>
# list 10 is <class 'list'>
# list 11 is <class 'list'>
# list 12 is <class 'list'>
# list 13 is <class 'list'>
# list 14 is <class 'list'>
# list 15 is <class 'list'>
# list 16 is <class 'list'>
# list 17 is <class 'list'>
# list 18 is <class 'list'>
# list 19 is <class 'list'>
# list 20 is <class 'list'>
# list 21 is <class 'list'>
# list 22 is <class 'list'>
# list 23 is <class 'list'>
# list 24 is <class 'list'>
# list 25 is <class 'list'>
# list 26 is <class 'list'>
# list 27 is <class 'list'>
# list 28 is <class 'list'>
# list 29 is <class 'list'>
# list 30 is <class 'list'>
# list 31 is <class 'list'>
# list 32 is <class 'list'>
# list 33 is <class 'list'>
# list 34 is <class 'list'>
# list 35 is <class 'list'>
# list 36 is <class 'list'>
# list 37 is <class 'list'>
# list 38 is <class 'list'>
# list 39 is <class 'list'>
# list 40 is <class 'list'>
# list 41 is <class 'list'>
# list 42 is <class 'list'>
# list 43 is <class 'list'>
# list 44 is <class 'list'>
# list 45 is <class 'list'>
# list 46 is <class 'list'>
# list 47 is <class 'list'>
# list 48 is <class 'list'>
# list 49 is <class 'list'>
# list 50 is <class 'list'>
# list 51 is <class 'list'>
# list 52 is <class 'list'>
# list 53 is <class 'list'>
# list 54 is <class 'list'>
# list 55 is <class 'list'>
# list 56 is <class 'list'>
# list 57 is <class 'list'>
# list 58 is <class 'list'>
# list 59 is <class 'list'>
# list 60 is <class 'list'>
# list 61 is <class 'list'>
# list 62 is <class 'list'>
# list 63 is <class 'list'>
# list 64 is <class 'list'>
# list 65 is <class 'list'>
# list 66 is <class 'list'>
# list 67 is <class 'list'>
# list 68 is <class 'list'>
# list 69 is <class 'list'>
# list 70 is <class 'list'>
# list 71 is <class 'list'>
# list 72 is <class 'list'>
# list 73 is <class 'list'>
# list 74 is <class 'list'>
# list 75 is <class 'list'>
# list 76 is <class 'list'>
# list 77 is <class 'list'>
# list 78 is <class 'list'>
# list 79 is <class 'list'>
# list 80 is <class 'list'>
# list 81 is <class 'list'>
# list 82 is <class 'list'>
# list 83 is <class 'list'>
# list 84 is <class 'list'>
# list 85 is <class 'list'>
# list 86 is <class 'list'>
# list 87 is <class 'list'>
# list 88 is <class 'list'>
# list 89 is <class 'list'>
# list 90 is <class 'list'>
# list 91 is <class 'list'>
# list 92 is <class 'list'>
# list 93 is <class 'list'>
# list 94 is <class 'list'>
# list 95 is <class 'list'>
# list 96 is <class 'list'>
# list 97 is <class 'list'>
# list 98 is <class 'list'>
# list 99 is <class 'list'>
# list 100 is <class 'list'>
# list 101 is <class 'list'>
# list 102 is <class 'list'>
# list 103 is <class 'list'>
# list 104 is <class 'list'>
# list 105 is <class 'list'>
# list 106 is <class 'list'>
# list 107 is <class 'list'>
# list 108 is <class 'list'>
# list 109 is <class 'list'>
# list 110 is <class 'list'>
# list 111 is <class 'list'>
# list 112 is <class 'list'>
# list 113 is <class 'list'>
# list 114 is <class 'list'>
# list 115 is <class 'list'>
# list 116 is <class 'list'>
# list 117 is <class 'list'>
# list 118 is <class 'list'>
# list 119 is <class 'list'>
# list 120 is <class 'list'>
# list 121 is <class 'list'>
# list 122 is <class 'list'>
# list 123 is <class 'list'>
# list 124 is <class 'list'>
# list 125 is <class 'list'>
# list 126 is <class 'list'>
# list 127 is <class 'list'>
# list 128 is <class 'list'>
# list 129 is <class 'list'>
# list 130 is <class 'list'>
# list 131 is <class 'list'>
# list 132 is <class 'list'>
# list 133 is <class 'list'>
# list 134 is <class 'list'>
# list 135 is <class 'list'>
# list 136 is <class 'list'>
# list 137 is <class 'list'>
# list 138 is <class 'list'>
# list 139 is <class 'list'>
# list 140 is <class 'list'>
# list 141 is <class 'list'>
# list 142 is <class 'list'>
# list 143 is <class 'list'>
# list 144 is <class 'list'>
# list 145 is <class 'list'>
# list 146 is <class 'list'>
# list 147 is <class 'list'>
# list 148 is <class 'list'>
# list 149 is <class 'list'>
# list 150 is <class 'list'>
# list 151 is <class 'list'>
# list 152 is <class 'list'>
# list 153 is <class 'list'>
# list 154 is <class 'list'>
# list 155 is <class 'list'>
# list 156 is <class 'list'>
# list 157 is <class 'list'>
# list 158 is <class 'list'>
# list 159 is <class 'list'>
# list 160 is <class 'list'>
# list 161 is <class 'list'>
# list 162 is <class 'list'>
# list 163 is <class 'list'>
# list 164 is <class 'list'>
# list 165 is <class 'list'>
# list 166 is <class 'list'>
# list 167 is <class 'list'>
# list 168 is <class 'list'>
# list 169 is <class 'list'>
# list 170 is <class 'list'>
# list 171 is <class 'list'>
# list 172 is <class 'list'>
# list 173 is <class 'list'>
# list 174 is <class 'list'>
# list 175 is <class 'list'>
# list 176 is <class 'list'>
# list 177 is <class 'list'>
# list 178 is <class 'list'>
# list 179 is <class 'list'>
# list 180 is <class 'list'>
# list 181 is <class 'list'>
# list 182 is <class 'list'>
# list 183 is <class 'list'>
# list 184 is <class 'list'>
# list 185 is <class 'list'>
# list 186 is <class 'list'>
# list 187 is <class 'list'>
# list 188 is <class 'list'>
# list 189 is <class 'list'>
# list 190 is <class 'list'>
# list 191 is <class 'list'>
# list 192 is <class 'list'>
# list 193 is <class 'list'>
# list 194 is <class 'list'>
# list 195 is <class 'list'>
# list 196 is <class 'list'>
# list 197 is <class 'list'>
# list 198 is <class 'list'>
# list 199 is <class 'list'>
# list 200 is <class 'list'>
# list 201 is <class 'list'>
# list 202 is <class 'list'>
# list 203 is <class 'list'>
# list 204 is <class 'list'>
# list 205 is <class 'list'>
# list 206 is <class 'list'>
# list 207 is <class 'list'>
# list 208 is <class 'list'>
# list 209 is <class 'list'>
# list 210 is <class 'list'>
# list 211 is <class 'list'>
# list 212 is <class 'list'>
# list 213 is <class 'list'>
# list 214 is <class 'list'>
# list 215 is <class 'list'>
# list 216 is <class 'list'>
# list 217 is <class 'list'>
# list 218 is <class 'list'>
# list 219 is <class 'list'>
# list 220 is <class 'list'>
# list 221 is <class 'list'>
# list 222 is <class 'list'>
# list 223 is <class 'list'>
# list 224 is <class 'list'>
# list 225 is <class 'list'>
# list 226 is <class 'list'>
# list 227 is <class 'list'>
# list 228 is <class 'list'>
# list 229 is <class 'list'>
# list 230 is <class 'list'>
# list 231 is <class 'list'>
# list 232 is <class 'list'>
# list 233 is <class 'list'>
# list 234 is <class 'list'>
# list 235 is <class 'list'>
# list 236 is <class 'list'>
# list 237 is <class 'list'>
# list 238 is <class 'list'>
# list 239 is <class 'list'>
# list 240 is <class 'list'>
# list 241 is <class 'list'>
# list 242 is <class 'list'>
# list 243 is <class 'list'>
# list 244 is <class 'list'>
# list 245 is <class 'list'>
# list 246 is <class 'list'>
# list 247 is <class 'list'>
# list 248 is <class 'list'>
# list 249 is <class 'list'>
# list 250 is <class 'list'>
# list 251 is <class 'list'>
# list 252 is <class 'list'>
# list 253 is <class 'list'>
# list 254 is <class 'list'>
# list 255 is <class 'list'>
# list 256 is <class 'list'>
# list 257 is <class 'list'>
# list 258 is <class 'list'>
# list 259 is <class 'list'>
# list 260 is <class 'list'>
# list 261 is <class 'list'>
# list 262 is <class 'list'>
# list 263 is <class 'list'>
# list 264 is <class 'list'>
# list 265 is <class 'list'>
# list 266 is <class 'list'>
# list 267 is <class 'list'>
# list 268 is <class 'list'>
# list 269 is <class 'list'>
# list 270 is <class 'list'>
# list 271 is <class 'list'>
# list 272 is <class 'list'>
# list 273 is <class 'list'>
# list 274 is <class 'list'>
# list 275 is <class 'list'>
# list 276 is <class 'list'>
# list 277 is <class 'list'>
# list 278 is <class 'list'>
# list 279 is <class 'list'>
# list 280 is <class 'list'>
# list 281 is <class 'list'>
# list 282 is <class 'list'>
# list 283 is <class 'list'>
# list 284 is <class 'list'>
# list 285 is <class 'list'>
# list 286 is <class 'list'>
# list 287 is <class 'list'>
# list 288 is <class 'list'>
# list 289 is <class 'list'>
# list 290 is <class 'list'>
# list 291 is <class 'list'>
# list 292 is <class 'list'>
# list 293 is <class 'list'>
# list 294 is <class 'list'>
# list 295 is <class 'list'>
# list 296 is <class 'list'>
# list 297 is <class 'list'>
# list 298 is <class 'list'>
# list 299 is <class 'list'>
# list 300 is <class 'list'>
# list 301 is <class 'list'>
# list 302 is <class 'list'>
# list 303 is <class 'list'>
# list 304 is <class 'list'>
# list 305 is <class 'list'>
# list 306 is <class 'list'>
# list 307 is <class 'list'>
# list 308 is <class 'list'>
# list 309 is <class 'list'>
# list 310 is <class 'list'>
# list 311 is <class 'list'>
# list 312 is <class 'list'>
# list 313 is <class 'list'>
# list 314 is <class 'list'>
# list 315 is <class 'list'>
# list 316 is <class 'list'>
# list 317 is <class 'list'>
# list 318 is <class 'list'>
# list 319 is <class 'list'>
# list 320 is <class 'list'>
# list 321 is <class 'list'>
# list 322 is <class 'list'>
# list 323 is <class 'list'>
# list 324 is <class 'list'>
# list 325 is <class 'list'>
# list 326 is <class 'list'>
# list 327 is <class 'list'>
# list 328 is <class 'list'>
# list 329 is <class 'list'>
# list 330 is <class 'list'>
# list 331 is <class 'list'>
# list 332 is <class 'list'>
# list 333 is <class 'list'>
# list 334 is <class 'list'>
# list 335 is <class 'list'>
# list 336 is <class 'list'>
# list 337 is <class 'list'>
# list 338 is <class 'list'>
# list 339 is <class 'list'>
# list 340 is <class 'list'>
# list 341 is <class 'list'>
# list 342 is <class 'list'>
# list 343 is <class 'list'>
# list 344 is <class 'list'>
# list 345 is <class 'list'>
# list 346 is <class 'list'>
# list 347 is <class 'list'>
# list 348 is <class 'list'>
# list 349 is <class 'list'>
# list 350 is <class 'list'>
# list 351 is <class 'list'>
# list 352 is <class 'list'>
# list 353 is <class 'list'>
# list 354 is <class 'list'>
# list 355 is <class 'list'>
# list 356 is <class 'list'>
# list 357 is <class 'list'>
# list 358 is <class 'list'>
# list 359 is <class 'list'>
# list 360 is <class 'list'>
# list 361 is <class 'list'>
# list 362 is <class 'list'>
# list 363 is <class 'list'>
# list 364 is <class 'list'>
# list 365 is <class 'list'>
# list 366 is <class 'list'>
# list 367 is <class 'list'>
# list 368 is <class 'list'>
# list 369 is <class 'list'>
# list 370 is <class 'list'>
# list 371 is <class 'list'>
# list 372 is <class 'list'>
# list 373 is <class 'list'>
# list 374 is <class 'list'>
# list 375 is <class 'list'>
# list 376 is <class 'list'>
# list 377 is <class 'list'>
# list 378 is <class 'list'>
# list 379 is <class 'list'>
# list 380 is <class 'list'>
# list 381 is <class 'list'>
# list 382 is <class 'list'>
# list 383 is <class 'list'>
# list 384 is <class 'list'>
# list 385 is <class 'list'>
# list 386 is <class 'list'>
# list 387 is <class 'list'>
# list 388 is <class 'list'>
# list 389 is <class 'list'>
# list 390 is <class 'list'>
# list 391 is <class 'list'>
# list 392 is <class 'list'>
# list 393 is <class 'list'>
# list 394 is <class 'list'>
# list 395 is <class 'list'>
# list 396 is <class 'list'>
# list 397 is <class 'list'>
# list 398 is <class 'list'>
# list 399 is <class 'list'>
# list 400 is <class 'list'>
# list 401 is <class 'list'>
# list 402 is <class 'list'>
# list 403 is <class 'list'>
# list 404 is <class 'list'>
# list 405 is <class 'list'>
# list 406 is <class 'list'>
# list 407 is <class 'list'>
# list 408 is <class 'list'>
# list 409 is <class 'list'>
# list 410 is <class 'list'>
# list 411 is <class 'list'>
# list 412 is <class 'list'>
# list 413 is <class 'list'>
# list 414 is <class 'list'>
# list 415 is <class 'list'>
# list 416 is <class 'list'>
# list 417 is <class 'list'>
# list 418 is <class 'list'>
# list 419 is <class 'list'>
# list 420 is <class 'list'>
# list 421 is <class 'list'>
# list 422 is <class 'list'>
# list 423 is <class 'list'>
# list 424 is <class 'list'>
# list 425 is <class 'list'>
# list 426 is <class 'list'>
# list 427 is <class 'list'>
# list 428 is <class 'list'>
# list 429 is <class 'list'>
# list 430 is <class 'list'>
# list 431 is <class 'list'>
# list 432 is <class 'list'>
# list 433 is <class 'list'>
# list 434 is <class 'list'>
# list 435 is <class 'list'>
# list 436 is <class 'list'>
# list 437 is <class 'list'>
# list 438 is <class 'list'>
# list 439 is <class 'list'>
# list 440 is <class 'list'>
# list 441 is <class 'list'>
# list 442 is <class 'list'>
# list 443 is <class 'list'>
# list 444 is <class 'list'>
# list 445 is <class 'list'>
# list 446 is <class 'list'>
# list 447 is <class 'list'>
# list 448 is <class 'list'>
# list 449 is <class 'list'>
# list 450 is <class 'list'>
# list 451 is <class 'list'>
# list 452 is <class 'list'>
# list 453 is <class 'list'>
# list 454 is <class 'list'>
# list 455 is <class 'list'>
# list 456 is <class 'list'>
# list 457 is <class 'list'>
# list 458 is <class 'list'>
# list 459 is <class 'list'>
# list 460 is <class 'list'>
# list 461 is <class 'list'>
# list 462 is <class 'list'>
# list 463 is <class 'list'>
# list 464 is <class 'list'>
# list 465 is <class 'list'>
# list 466 is <class 'list'>
# list 467 is <class 'list'>
# list 468 is <class 'list'>
# list 469 is <class 'list'>
# list 470 is <class 'list'>
# list 471 is <class 'list'>
# list 472 is <class 'list'>
# list 473 is <class 'list'>
# list 474 is <class 'list'>
# list 475 is <class 'list'>
# list 476 is <class 'list'>
# list 477 is <class 'list'>
# list 478 is <class 'list'>
# list 479 is <class 'list'>
# list 480 is <class 'list'>
# list 481 is <class 'list'>
# list 482 is <class 'list'>
# list 483 is <class 'list'>
# list 484 is <class 'list'>
# list 485 is <class 'list'>
# list 486 is <class 'list'>
# list 487 is <class 'list'>
# list 488 is <class 'list'>
# list 489 is <class 'list'>
# list 490 is <class 'list'>
# list 491 is <class 'list'>
# list 492 is <class 'list'>
# list 493 is <class 'list'>
# list 494 is <class 'list'>
# list 495 is <class 'list'>
# list 496 is <class 'list'>
# list 497 is <class 'list'>
# list 498 is <class 'list'>
# list 499 is <class 'list'>
# list 500 is <class 'list'>
# list 501 is <class 'list'>
# list 502 is <class 'list'>
# list 503 is <class 'list'>
# list 504 is <class 'list'>
# list 505 is <class 'list'>
# list 506 is <class 'list'>
# list 507 is <class 'list'>
# list 508 is <class 'list'>
# list 509 is <class 'list'>
# list 510 is <class 'list'>
# list 511 is <class 'list'>
# list 512 is <class 'list'>
# list 513 is <class 'list'>
# list 514 is <class 'list'>
# list 515 is <class 'list'>
# list 516 is <class 'list'>
# list 517 is <class 'list'>
# list 518 is <class 'list'>
# list 519 is <class 'list'>
# list 520 is <class 'list'>
# list 521 is <class 'list'>
# list 522 is <class 'list'>
# list 523 is <class 'list'>
# list 524 is <class 'list'>
# list 525 is <class 'list'>
# list 526 is <class 'list'>
# list 527 is <class 'list'>
# list 528 is <class 'list'>
# list 529 is <class 'list'>
# list 530 is <class 'list'>
# list 531 is <class 'list'>
# list 532 is <class 'list'>
# list 533 is <class 'list'>
# list 534 is <class 'list'>
# list 535 is <class 'list'>
# list 536 is <class 'list'>
# list 537 is <class 'list'>
# list 538 is <class 'list'>
# list 539 is <class 'list'>
# list 540 is <class 'list'>
# list 541 is <class 'list'>
# list 542 is <class 'list'>
# list 543 is <class 'list'>
# list 544 is <class 'list'>
# list 545 is <class 'list'>
# list 546 is <class 'list'>
# list 547 is <class 'list'>
# list 548 is <class 'list'>
# list 549 is <class 'list'>
# list 550 is <class 'list'>
# list 551 is <class 'list'>
# list 552 is <class 'list'>
# list 553 is <class 'list'>
# list 554 is <class 'list'>
# list 555 is <class 'list'>
# list 556 is <class 'list'>
# list 557 is <class 'list'>
# list 558 is <class 'list'>
# list 559 is <class 'list'>
# list 560 is <class 'list'>
# list 561 is <class 'list'>
# list 562 is <class 'list'>
# list 563 is <class 'list'>
# list 564 is <class 'list'>
# list 565 is <class 'list'>
# list 566 is <class 'list'>
# list 567 is <class 'list'>
# list 568 is <class 'list'>
# list 569 is <class 'list'>
# list 570 is <class 'list'>
# list 571 is <class 'list'>
# list 572 is <class 'list'>
# list 573 is <class 'list'>
# list 574 is <class 'list'>
# list 575 is <class 'list'>
# list 576 is <class 'list'>
# list 577 is <class 'list'>
# list 578 is <class 'list'>
# list 579 is <class 'list'>
# list 580 is <class 'list'>
# list 581 is <class 'list'>
# list 582 is <class 'list'>
# list 583 is <class 'list'>
# list 584 is <class 'list'>
# list 585 is <class 'list'>
# list 586 is <class 'list'>
# list 587 is <class 'list'>
# list 588 is <class 'list'>
# list 589 is <class 'list'>
# list 590 is <class 'list'>
# list 591 is <class 'list'>
# list 592 is <class 'list'>
# list 593 is <class 'list'>
# list 594 is <class 'list'>
# list 595 is <class 'list'>
# list 596 is <class 'list'>
# list 597 is <class 'list'>
# list 598 is <class 'list'>
# list 599 is <class 'list'>
# list 600 is <class 'list'>
# list 601 is <class 'list'>
# list 602 is <class 'list'>
# list 603 is <class 'list'>
# list 604 is <class 'list'>
# list 605 is <class 'list'>
# list 606 is <class 'list'>
# list 607 is <class 'list'>
# list 608 is <class 'list'>
# list 609 is <class 'list'>
# list 610 is <class 'list'>
# list 611 is <class 'list'>
# list 612 is <class 'list'>
# list 613 is <class 'list'>
# list 614 is <class 'list'>
# list 615 is <class 'list'>
# list 616 is <class 'list'>
# list 617 is <class 'list'>
# list 618 is <class 'list'>
# list 619 is <class 'list'>
# list 620 is <class 'list'>
# list 621 is <class 'list'>
# list 622 is <class 'list'>
# list 623 is <class 'list'>
# list 624 is <class 'list'>
# list 625 is <class 'list'>
# list 626 is <class 'list'>
# list 627 is <class 'list'>
# list 628 is <class 'list'>
# list 629 is <class 'list'>
# list 630 is <class 'list'>
# list 631 is <class 'list'>
# list 632 is <class 'list'>
# list 633 is <class 'list'>
# list 634 is <class 'list'>
# list 635 is <class 'list'>
# list 636 is <class 'list'>
# list 637 is <class 'list'>
# list 638 is <class 'list'>
# list 639 is <class 'list'>
# list 640 is <class 'list'>
# list 641 is <class 'list'>
# list 642 is <class 'list'>
# list 643 is <class 'list'>
# list 644 is <class 'list'>
# list 645 is <class 'list'>
# list 646 is <class 'list'>
# list 647 is <class 'list'>
# list 648 is <class 'list'>
# list 649 is <class 'list'>
# list 650 is <class 'list'>
# list 651 is <class 'list'>
# list 652 is <class 'list'>
# list 653 is <class 'list'>
# list 654 is <class 'list'>
# list 655 is <class 'list'>
# list 656 is <class 'list'>
# list 657 is <class 'list'>
# list 658 is <class 'list'>
# list 659 is <class 'list'>
# list 660 is <class 'list'>
# list 661 is <class 'list'>
# list 662 is <class 'list'>
# list 663 is <class 'list'>
# list 664 is <class 'list'>
# list 665 is <class 'list'>
# list 666 is <class 'list'>
# list 667 is <class 'list'>
# list 668 is <class 'list'>
# list 669 is <class 'list'>
# list 670 is <class 'list'>
# list 671 is <class 'list'>
# list 672 is <class 'list'>
# list 673 is <class 'list'>
# list 674 is <class 'list'>
# list 675 is <class 'list'>
# list 676 is <class 'list'>
# list 677 is <class 'list'>
# list 678 is <class 'list'>
# list 679 is <class 'list'>
# list 680 is <class 'list'>
# list 681 is <class 'list'>
# list 682 is <class 'list'>
# list 683 is <class 'list'>
# list 684 is <class 'list'>
# list 685 is <class 'list'>
# list 686 is <class 'list'>
# list 687 is <class 'list'>
# list 688 is <class 'list'>
# list 689 is <class 'list'>
# list 690 is <class 'list'>
# list 691 is <class 'list'>
# list 692 is <class 'list'>
# list 693 is <class 'list'>
# list 694 is <class 'list'>
# list 695 is <class 'list'>
# list 696 is <class 'list'>
# list 697 is <class 'list'>
# list 698 is <class 'list'>
# list 699 is <class 'list'>
# list 700 is <class 'list'>
# list 701 is <class 'list'>
# list 702 is <class 'list'>
# list 703 is <class 'list'>
# list 704 is <class 'list'>
# list 705 is <class 'list'>
# list 706 is <class 'list'>
# list 707 is <class 'list'>
# list 708 is <class 'list'>
# list 709 is <class 'list'>
# list 710 is <class 'list'>
# list 711 is <class 'list'>
# list 712 is <class 'list'>
# list 713 is <class 'list'>
# list 714 is <class 'list'>
# list 715 is <class 'list'>
# list 716 is <class 'list'>
# list 717 is <class 'list'>
# list 718 is <class 'list'>
# list 719 is <class 'list'>
# list 720 is <class 'list'>
# list 721 is <class 'list'>
# list 722 is <class 'list'>
# list 723 is <class 'list'>
# list 724 is <class 'list'>
# list 725 is <class 'list'>
# list 726 is <class 'list'>
# list 727 is <class 'list'>
# list 728 is <class 'list'>
# list 729 is <class 'list'>
# list 730 is <class 'list'>
# list 731 is <class 'list'>
# list 732 is <class 'list'>
# list 733 is <class 'list'>
# list 734 is <class 'list'>
# list 735 is <class 'list'>
# list 736 is <class 'list'>
# list 737 is <class 'list'>
# list 738 is <class 'list'>

# %% [markdown]
# Since they're lists, we can handle them the same way we did the formats column:

# %%
pokemon_types = pokemon_df['types'].apply(pd.Series)
pokemon_types
# Out:
#                       0       1
# name
# Bulbasaur         Grass  Poison
# Ivysaur           Grass  Poison
# Venusaur          Grass  Poison
# Charmander         Fire     NaN
# Charmeleon         Fire     NaN
# ...                 ...     ...
# Glastrier           Ice     NaN
# Spectrier         Ghost     NaN
# Calyrex         Psychic   Grass
# Calyrex-Ice     Psychic     Ice
# Calyrex-Shadow  Psychic   Ghost
#
# [739 rows x 2 columns]

# %%
pokemon_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       739 non-null    object
#  1   1       396 non-null    object
# dtypes: object(2)
# memory usage: 17.3+ KB

# %% [markdown]
# This is a slightly more complicated result than formats because we have two columns from this application of pd.Series, and not only that, but the second column contains many null values.  This is acceptable though, since some pokemon have only 1 type and some have 2 types, but it can only be one of those two options.  And it looks like all pokemon have at least one type (since there are 739 rows and each of them is filled from the first column), so there is no problem.
#
# Now we will iterate through pokemon_types to fill in values of "1" in our one-hot encoded pokemon_types_df for each type that a pokemon has:

# %%
for index, row in pokemon_types.iterrows():
    pokemon_types_df.loc[index, row[0]] = 1
    if row.isna().sum() == 0:
        pokemon_types_df.loc[index, row[1]] = 1

pokemon_types_df
# Out:
#                 Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  Flying  \
# name
# Bulbasaur         0     0       0         0      0         0     0       0
# Ivysaur           0     0       0         0      0         0     0       0
# Venusaur          0     0       0         0      0         0     0       0
# Charmander        0     0       0         0      0         0     1       0
# Charmeleon        0     0       0         0      0         0     1       0
# ...             ...   ...     ...       ...    ...       ...   ...     ...
# Glastrier         0     0       0         0      0         0     0       0
# Spectrier         0     0       0         0      0         0     0       0
# Calyrex           0     0       0         0      0         0     0       0
# Calyrex-Ice       0     0       0         0      0         0     0       0
# Calyrex-Shadow    0     0       0         0      0         0     0       0
#
#                 Ghost  Grass  Ground  Ice  Normal  Poison  Psychic  Rock  \
# name
# Bulbasaur           0      1       0    0       0       1        0     0
# Ivysaur             0      1       0    0       0       1        0     0
# Venusaur            0      1       0    0       0       1        0     0
# Charmander          0      0       0    0       0       0        0     0
# Charmeleon          0      0       0    0       0       0        0     0
# ...               ...    ...     ...  ...     ...     ...      ...   ...
# Glastrier           0      0       0    1       0       0        0     0
# Spectrier           1      0       0    0       0       0        0     0
# Calyrex             0      1       0    0       0       0        1     0
# Calyrex-Ice         0      0       0    1       0       0        1     0
# Calyrex-Shadow      1      0       0    0       0       0        1     0
#
#                 Steel  Water
# name
# Bulbasaur           0      0
# Ivysaur             0      0
# Venusaur            0      0
# Charmander          0      0
# Charmeleon          0      0
# ...               ...    ...
# Glastrier           0      0
# Spectrier           0      0
# Calyrex             0      0
# Calyrex-Ice         0      0
# Calyrex-Shadow      0      0
#
# [739 rows x 18 columns]

# %%
pokemon_types_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Bug       739 non-null    int64
#  1   Dark      739 non-null    int64
#  2   Dragon    739 non-null    int64
#  3   Electric  739 non-null    int64
#  4   Fairy     739 non-null    int64
#  5   Fighting  739 non-null    int64
#  6   Fire      739 non-null    int64
#  7   Flying    739 non-null    int64
#  8   Ghost     739 non-null    int64
#  9   Grass     739 non-null    int64
#  10  Ground    739 non-null    int64
#  11  Ice       739 non-null    int64
#  12  Normal    739 non-null    int64
#  13  Poison    739 non-null    int64
#  14  Psychic   739 non-null    int64
#  15  Rock      739 non-null    int64
#  16  Steel     739 non-null    int64
#  17  Water     739 non-null    int64
# dtypes: int64(18)
# memory usage: 125.9+ KB

# %%
pokemon_types_df.apply(sum, axis=1).value_counts()
# Out:
# 2    396
# 1    343
# dtype: int64

# %% [markdown]
# It seems to have worked with no problems and it looks like there is a correct amount of pokemon with 2 types (said to be 396 before) and a correct amount with 1 type and no values out of that range.  Let's just make a pandas profile to make sure there are no more non-obvious issues:

# %%
profile_report = pokemon_types_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()

# %% [markdown]
# There are no problems at all, so let's move on to our dataframe for abilities!

# %% [markdown]
# <a id='pokemon_abilities_df'></a>
# ### pokemon_abilities_df

# %% [markdown]
# Once again, we are making another dataframe, this time using another different section of the JSON file (which is best observed through jsonviewer).

# %%
abilities_df = pd.DataFrame(pokedex_dict['injectRpcs'][1][1]['abilities'])
abilities_df
# Out:
#                  name                                        description  \
# 0          Cute Charm  30% chance of infatuating Pokemon of the oppos...
# 1        Effect Spore  30% chance of poison/paralysis/sleep on others...
# 2          Flame Body  30% chance a Pokemon making contact with this ...
# 3          Flash Fire  This Pokemon's Fire attacks do 1.5x damage if ...
# 4          Intimidate  On switch-in, this Pokemon lowers the Attack o...
# ..                ...                                                ...
# 265      Steam Engine  This Pokemon's Speed is raised by 6 stages aft...
# 266     Steely Spirit  This Pokemon and its allies' Steel-type moves ...
# 267        Transistor  This Pokemon's attacking stat is multiplied by...
# 268       Unseen Fist          All contact moves hit through protection.
# 269  Wandering Spirit  Pokemon making contact with this Pokemon have ...
#
#     isNonstandard                 genfamily
# 0        Standard  [RS, DP, BW, XY, SM, SS]
# 1        Standard  [RS, DP, BW, XY, SM, SS]
# 2        Standard  [RS, DP, BW, XY, SM, SS]
# 3        Standard  [RS, DP, BW, XY, SM, SS]
# 4        Standard  [RS, DP, BW, XY, SM, SS]
# ..            ...                       ...
# 265      Standard                      [SS]
# 266      Standard                      [SS]
# 267      Standard                      [SS]
# 268      Standard                      [SS]
# 269      Standard                      [SS]
#
# [270 rows x 4 columns]

# %% [markdown]
# We've seen the isNonstandard column before, so we should explore it and see what values it has (since we likely only want the Standard abilities).

# %%
abilities_df['isNonstandard'].unique()
# Out:
# array(['Standard', 'CAP'], dtype=object)

# %% [markdown]
# Indeed, we should remove any CAP abilities since those are only for created pokemon which are not usable in the standard format (which contextualizes this project).  Basically, since CAP pokemon are removed, there is no reason to keep any CAP abilities).

# %%
abilities_df = abilities_df.loc[abilities_df['isNonstandard'] != 'CAP']
abilities_df
# Out:
#                  name                                        description  \
# 0          Cute Charm  30% chance of infatuating Pokemon of the oppos...
# 1        Effect Spore  30% chance of poison/paralysis/sleep on others...
# 2          Flame Body  30% chance a Pokemon making contact with this ...
# 3          Flash Fire  This Pokemon's Fire attacks do 1.5x damage if ...
# 4          Intimidate  On switch-in, this Pokemon lowers the Attack o...
# ..                ...                                                ...
# 265      Steam Engine  This Pokemon's Speed is raised by 6 stages aft...
# 266     Steely Spirit  This Pokemon and its allies' Steel-type moves ...
# 267        Transistor  This Pokemon's attacking stat is multiplied by...
# 268       Unseen Fist          All contact moves hit through protection.
# 269  Wandering Spirit  Pokemon making contact with this Pokemon have ...
#
#     isNonstandard                 genfamily
# 0        Standard  [RS, DP, BW, XY, SM, SS]
# 1        Standard  [RS, DP, BW, XY, SM, SS]
# 2        Standard  [RS, DP, BW, XY, SM, SS]
# 3        Standard  [RS, DP, BW, XY, SM, SS]
# 4        Standard  [RS, DP, BW, XY, SM, SS]
# ..            ...                       ...
# 265      Standard                      [SS]
# 266      Standard                      [SS]
# 267      Standard                      [SS]
# 268      Standard                      [SS]
# 269      Standard                      [SS]
#
# [267 rows x 4 columns]

# %% [markdown]
# Some final touches:
#
# 1. We should set the ability names as the index, since the current index is uninformative.
#
# 2. We can remove the isNonstandard and genfamily columns are they provide no relevant information to competitive aspect of pokemon, but we should keep the descriptions as they might be useful to EDA later (there are so many abilities that I will likely have to bucket them, and having descriptions may make it easier to do that).

# %%
abilities_df.set_index('name', inplace=True)
abilities_df = abilities_df.drop(columns=['isNonstandard', 'genfamily'])
abilities_df
# Out:
#                                                         description
# name
# Cute Charm        30% chance of infatuating Pokemon of the oppos...
# Effect Spore      30% chance of poison/paralysis/sleep on others...
# Flame Body        30% chance a Pokemon making contact with this ...
# Flash Fire        This Pokemon's Fire attacks do 1.5x damage if ...
# Intimidate        On switch-in, this Pokemon lowers the Attack o...
# ...                                                             ...
# Steam Engine      This Pokemon's Speed is raised by 6 stages aft...
# Steely Spirit     This Pokemon and its allies' Steel-type moves ...
# Transistor        This Pokemon's attacking stat is multiplied by...
# Unseen Fist               All contact moves hit through protection.
# Wandering Spirit  Pokemon making contact with this Pokemon have ...
#
# [267 rows x 1 columns]

# %% [markdown]
# We also need to initialize the dataframe that's going to hold our one-hot encoded abilities, and like last time we will use the pokemon_df index to sync the dataframes together.

# %%
pokemon_abilities_df = pd.DataFrame(0, index=pokemon_df.index, columns=abilities_df.index.rename(''))
pokemon_abilities_df
# Out:
#                 Cute Charm  Effect Spore  Flame Body  Flash Fire  Intimidate  \
# name
# Bulbasaur                0             0           0           0           0
# Ivysaur                  0             0           0           0           0
# Venusaur                 0             0           0           0           0
# Charmander               0             0           0           0           0
# Charmeleon               0             0           0           0           0
# ...                    ...           ...         ...         ...         ...
# Glastrier                0             0           0           0           0
# Spectrier                0             0           0           0           0
# Calyrex                  0             0           0           0           0
# Calyrex-Ice              0             0           0           0           0
# Calyrex-Shadow           0             0           0           0           0
#
#                 Lightning Rod  Minus  Plus  Poison Point  Pressure  ...  \
# name                                                                ...
# Bulbasaur                   0      0     0             0         0  ...
# Ivysaur                     0      0     0             0         0  ...
# Venusaur                    0      0     0             0         0  ...
# Charmander                  0      0     0             0         0  ...
# Charmeleon                  0      0     0             0         0  ...
# ...                       ...    ...   ...           ...       ...  ...
# Glastrier                   0      0     0             0         0  ...
# Spectrier                   0      0     0             0         0  ...
# Calyrex                     0      0     0             0         0  ...
# Calyrex-Ice                 0      0     0             0         0  ...
# Calyrex-Shadow              0      0     0             0         0  ...
#
#                 Quick Draw  Ripen  Sand Spit  Screen Cleaner  Stalwart  \
# name
# Bulbasaur                0      0          0               0         0
# Ivysaur                  0      0          0               0         0
# Venusaur                 0      0          0               0         0
# Charmander               0      0          0               0         0
# Charmeleon               0      0          0               0         0
# ...                    ...    ...        ...             ...       ...
# Glastrier                0      0          0               0         0
# Spectrier                0      0          0               0         0
# Calyrex                  0      0          0               0         0
# Calyrex-Ice              0      0          0               0         0
# Calyrex-Shadow           0      0          0               0         0
#
#                 Steam Engine  Steely Spirit  Transistor  Unseen Fist  \
# name
# Bulbasaur                  0              0           0            0
# Ivysaur                    0              0           0            0
# Venusaur                   0              0           0            0
# Charmander                 0              0           0            0
# Charmeleon                 0              0           0            0
# ...                      ...            ...         ...          ...
# Glastrier                  0              0           0            0
# Spectrier                  0              0           0            0
# Calyrex                    0              0           0            0
# Calyrex-Ice                0              0           0            0
# Calyrex-Shadow             0              0           0            0
#
#                 Wandering Spirit
# name
# Bulbasaur                      0
# Ivysaur                        0
# Venusaur                       0
# Charmander                     0
# Charmeleon                     0
# ...                          ...
# Glastrier                      0
# Spectrier                      0
# Calyrex                        0
# Calyrex-Ice                    0
# Calyrex-Shadow                 0
#
# [739 rows x 267 columns]

# %% [markdown]
# As before, we need to check the data types of the abilities column of pokemon_df, to understand what transformation we need to apply to it before using it to fill pokemon_abilities_df.

# %%
for i, l in enumerate(pokemon_df["abilities"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'list'>
# list 1 is <class 'list'>
# list 2 is <class 'list'>
# list 3 is <class 'list'>
# list 4 is <class 'list'>
# list 5 is <class 'list'>
# list 6 is <class 'list'>
# list 7 is <class 'list'>
# list 8 is <class 'list'>
# list 9 is <class 'list'>
# list 10 is <class 'list'>
# list 11 is <class 'list'>
# list 12 is <class 'list'>
# list 13 is <class 'list'>
# list 14 is <class 'list'>
# list 15 is <class 'list'>
# list 16 is <class 'list'>
# list 17 is <class 'list'>
# list 18 is <class 'list'>
# list 19 is <class 'list'>
# list 20 is <class 'list'>
# list 21 is <class 'list'>
# list 22 is <class 'list'>
# list 23 is <class 'list'>
# list 24 is <class 'list'>
# list 25 is <class 'list'>
# list 26 is <class 'list'>
# list 27 is <class 'list'>
# list 28 is <class 'list'>
# list 29 is <class 'list'>
# list 30 is <class 'list'>
# list 31 is <class 'list'>
# list 32 is <class 'list'>
# list 33 is <class 'list'>
# list 34 is <class 'list'>
# list 35 is <class 'list'>
# list 36 is <class 'list'>
# list 37 is <class 'list'>
# list 38 is <class 'list'>
# list 39 is <class 'list'>
# list 40 is <class 'list'>
# list 41 is <class 'list'>
# list 42 is <class 'list'>
# list 43 is <class 'list'>
# list 44 is <class 'list'>
# list 45 is <class 'list'>
# list 46 is <class 'list'>
# list 47 is <class 'list'>
# list 48 is <class 'list'>
# list 49 is <class 'list'>
# list 50 is <class 'list'>
# list 51 is <class 'list'>
# list 52 is <class 'list'>
# list 53 is <class 'list'>
# list 54 is <class 'list'>
# list 55 is <class 'list'>
# list 56 is <class 'list'>
# list 57 is <class 'list'>
# list 58 is <class 'list'>
# list 59 is <class 'list'>
# list 60 is <class 'list'>
# list 61 is <class 'list'>
# list 62 is <class 'list'>
# list 63 is <class 'list'>
# list 64 is <class 'list'>
# list 65 is <class 'list'>
# list 66 is <class 'list'>
# list 67 is <class 'list'>
# list 68 is <class 'list'>
# list 69 is <class 'list'>
# list 70 is <class 'list'>
# list 71 is <class 'list'>
# list 72 is <class 'list'>
# list 73 is <class 'list'>
# list 74 is <class 'list'>
# list 75 is <class 'list'>
# list 76 is <class 'list'>
# list 77 is <class 'list'>
# list 78 is <class 'list'>
# list 79 is <class 'list'>
# list 80 is <class 'list'>
# list 81 is <class 'list'>
# list 82 is <class 'list'>
# list 83 is <class 'list'>
# list 84 is <class 'list'>
# list 85 is <class 'list'>
# list 86 is <class 'list'>
# list 87 is <class 'list'>
# list 88 is <class 'list'>
# list 89 is <class 'list'>
# list 90 is <class 'list'>
# list 91 is <class 'list'>
# list 92 is <class 'list'>
# list 93 is <class 'list'>
# list 94 is <class 'list'>
# list 95 is <class 'list'>
# list 96 is <class 'list'>
# list 97 is <class 'list'>
# list 98 is <class 'list'>
# list 99 is <class 'list'>
# list 100 is <class 'list'>
# list 101 is <class 'list'>
# list 102 is <class 'list'>
# list 103 is <class 'list'>
# list 104 is <class 'list'>
# list 105 is <class 'list'>
# list 106 is <class 'list'>
# list 107 is <class 'list'>
# list 108 is <class 'list'>
# list 109 is <class 'list'>
# list 110 is <class 'list'>
# list 111 is <class 'list'>
# list 112 is <class 'list'>
# list 113 is <class 'list'>
# list 114 is <class 'list'>
# list 115 is <class 'list'>
# list 116 is <class 'list'>
# list 117 is <class 'list'>
# list 118 is <class 'list'>
# list 119 is <class 'list'>
# list 120 is <class 'list'>
# list 121 is <class 'list'>
# list 122 is <class 'list'>
# list 123 is <class 'list'>
# list 124 is <class 'list'>
# list 125 is <class 'list'>
# list 126 is <class 'list'>
# list 127 is <class 'list'>
# list 128 is <class 'list'>
# list 129 is <class 'list'>
# list 130 is <class 'list'>
# list 131 is <class 'list'>
# list 132 is <class 'list'>
# list 133 is <class 'list'>
# list 134 is <class 'list'>
# list 135 is <class 'list'>
# list 136 is <class 'list'>
# list 137 is <class 'list'>
# list 138 is <class 'list'>
# list 139 is <class 'list'>
# list 140 is <class 'list'>
# list 141 is <class 'list'>
# list 142 is <class 'list'>
# list 143 is <class 'list'>
# list 144 is <class 'list'>
# list 145 is <class 'list'>
# list 146 is <class 'list'>
# list 147 is <class 'list'>
# list 148 is <class 'list'>
# list 149 is <class 'list'>
# list 150 is <class 'list'>
# list 151 is <class 'list'>
# list 152 is <class 'list'>
# list 153 is <class 'list'>
# list 154 is <class 'list'>
# list 155 is <class 'list'>
# list 156 is <class 'list'>
# list 157 is <class 'list'>
# list 158 is <class 'list'>
# list 159 is <class 'list'>
# list 160 is <class 'list'>
# list 161 is <class 'list'>
# list 162 is <class 'list'>
# list 163 is <class 'list'>
# list 164 is <class 'list'>
# list 165 is <class 'list'>
# list 166 is <class 'list'>
# list 167 is <class 'list'>
# list 168 is <class 'list'>
# list 169 is <class 'list'>
# list 170 is <class 'list'>
# list 171 is <class 'list'>
# list 172 is <class 'list'>
# list 173 is <class 'list'>
# list 174 is <class 'list'>
# list 175 is <class 'list'>
# list 176 is <class 'list'>
# list 177 is <class 'list'>
# list 178 is <class 'list'>
# list 179 is <class 'list'>
# list 180 is <class 'list'>
# list 181 is <class 'list'>
# list 182 is <class 'list'>
# list 183 is <class 'list'>
# list 184 is <class 'list'>
# list 185 is <class 'list'>
# list 186 is <class 'list'>
# list 187 is <class 'list'>
# list 188 is <class 'list'>
# list 189 is <class 'list'>
# list 190 is <class 'list'>
# list 191 is <class 'list'>
# list 192 is <class 'list'>
# list 193 is <class 'list'>
# list 194 is <class 'list'>
# list 195 is <class 'list'>
# list 196 is <class 'list'>
# list 197 is <class 'list'>
# list 198 is <class 'list'>
# list 199 is <class 'list'>
# list 200 is <class 'list'>
# list 201 is <class 'list'>
# list 202 is <class 'list'>
# list 203 is <class 'list'>
# list 204 is <class 'list'>
# list 205 is <class 'list'>
# list 206 is <class 'list'>
# list 207 is <class 'list'>
# list 208 is <class 'list'>
# list 209 is <class 'list'>
# list 210 is <class 'list'>
# list 211 is <class 'list'>
# list 212 is <class 'list'>
# list 213 is <class 'list'>
# list 214 is <class 'list'>
# list 215 is <class 'list'>
# list 216 is <class 'list'>
# list 217 is <class 'list'>
# list 218 is <class 'list'>
# list 219 is <class 'list'>
# list 220 is <class 'list'>
# list 221 is <class 'list'>
# list 222 is <class 'list'>
# list 223 is <class 'list'>
# list 224 is <class 'list'>
# list 225 is <class 'list'>
# list 226 is <class 'list'>
# list 227 is <class 'list'>
# list 228 is <class 'list'>
# list 229 is <class 'list'>
# list 230 is <class 'list'>
# list 231 is <class 'list'>
# list 232 is <class 'list'>
# list 233 is <class 'list'>
# list 234 is <class 'list'>
# list 235 is <class 'list'>
# list 236 is <class 'list'>
# list 237 is <class 'list'>
# list 238 is <class 'list'>
# list 239 is <class 'list'>
# list 240 is <class 'list'>
# list 241 is <class 'list'>
# list 242 is <class 'list'>
# list 243 is <class 'list'>
# list 244 is <class 'list'>
# list 245 is <class 'list'>
# list 246 is <class 'list'>
# list 247 is <class 'list'>
# list 248 is <class 'list'>
# list 249 is <class 'list'>
# list 250 is <class 'list'>
# list 251 is <class 'list'>
# list 252 is <class 'list'>
# list 253 is <class 'list'>
# list 254 is <class 'list'>
# list 255 is <class 'list'>
# list 256 is <class 'list'>
# list 257 is <class 'list'>
# list 258 is <class 'list'>
# list 259 is <class 'list'>
# list 260 is <class 'list'>
# list 261 is <class 'list'>
# list 262 is <class 'list'>
# list 263 is <class 'list'>
# list 264 is <class 'list'>
# list 265 is <class 'list'>
# list 266 is <class 'list'>
# list 267 is <class 'list'>
# list 268 is <class 'list'>
# list 269 is <class 'list'>
# list 270 is <class 'list'>
# list 271 is <class 'list'>
# list 272 is <class 'list'>
# list 273 is <class 'list'>
# list 274 is <class 'list'>
# list 275 is <class 'list'>
# list 276 is <class 'list'>
# list 277 is <class 'list'>
# list 278 is <class 'list'>
# list 279 is <class 'list'>
# list 280 is <class 'list'>
# list 281 is <class 'list'>
# list 282 is <class 'list'>
# list 283 is <class 'list'>
# list 284 is <class 'list'>
# list 285 is <class 'list'>
# list 286 is <class 'list'>
# list 287 is <class 'list'>
# list 288 is <class 'list'>
# list 289 is <class 'list'>
# list 290 is <class 'list'>
# list 291 is <class 'list'>
# list 292 is <class 'list'>
# list 293 is <class 'list'>
# list 294 is <class 'list'>
# list 295 is <class 'list'>
# list 296 is <class 'list'>
# list 297 is <class 'list'>
# list 298 is <class 'list'>
# list 299 is <class 'list'>
# list 300 is <class 'list'>
# list 301 is <class 'list'>
# list 302 is <class 'list'>
# list 303 is <class 'list'>
# list 304 is <class 'list'>
# list 305 is <class 'list'>
# list 306 is <class 'list'>
# list 307 is <class 'list'>
# list 308 is <class 'list'>
# list 309 is <class 'list'>
# list 310 is <class 'list'>
# list 311 is <class 'list'>
# list 312 is <class 'list'>
# list 313 is <class 'list'>
# list 314 is <class 'list'>
# list 315 is <class 'list'>
# list 316 is <class 'list'>
# list 317 is <class 'list'>
# list 318 is <class 'list'>
# list 319 is <class 'list'>
# list 320 is <class 'list'>
# list 321 is <class 'list'>
# list 322 is <class 'list'>
# list 323 is <class 'list'>
# list 324 is <class 'list'>
# list 325 is <class 'list'>
# list 326 is <class 'list'>
# list 327 is <class 'list'>
# list 328 is <class 'list'>
# list 329 is <class 'list'>
# list 330 is <class 'list'>
# list 331 is <class 'list'>
# list 332 is <class 'list'>
# list 333 is <class 'list'>
# list 334 is <class 'list'>
# list 335 is <class 'list'>
# list 336 is <class 'list'>
# list 337 is <class 'list'>
# list 338 is <class 'list'>
# list 339 is <class 'list'>
# list 340 is <class 'list'>
# list 341 is <class 'list'>
# list 342 is <class 'list'>
# list 343 is <class 'list'>
# list 344 is <class 'list'>
# list 345 is <class 'list'>
# list 346 is <class 'list'>
# list 347 is <class 'list'>
# list 348 is <class 'list'>
# list 349 is <class 'list'>
# list 350 is <class 'list'>
# list 351 is <class 'list'>
# list 352 is <class 'list'>
# list 353 is <class 'list'>
# list 354 is <class 'list'>
# list 355 is <class 'list'>
# list 356 is <class 'list'>
# list 357 is <class 'list'>
# list 358 is <class 'list'>
# list 359 is <class 'list'>
# list 360 is <class 'list'>
# list 361 is <class 'list'>
# list 362 is <class 'list'>
# list 363 is <class 'list'>
# list 364 is <class 'list'>
# list 365 is <class 'list'>
# list 366 is <class 'list'>
# list 367 is <class 'list'>
# list 368 is <class 'list'>
# list 369 is <class 'list'>
# list 370 is <class 'list'>
# list 371 is <class 'list'>
# list 372 is <class 'list'>
# list 373 is <class 'list'>
# list 374 is <class 'list'>
# list 375 is <class 'list'>
# list 376 is <class 'list'>
# list 377 is <class 'list'>
# list 378 is <class 'list'>
# list 379 is <class 'list'>
# list 380 is <class 'list'>
# list 381 is <class 'list'>
# list 382 is <class 'list'>
# list 383 is <class 'list'>
# list 384 is <class 'list'>
# list 385 is <class 'list'>
# list 386 is <class 'list'>
# list 387 is <class 'list'>
# list 388 is <class 'list'>
# list 389 is <class 'list'>
# list 390 is <class 'list'>
# list 391 is <class 'list'>
# list 392 is <class 'list'>
# list 393 is <class 'list'>
# list 394 is <class 'list'>
# list 395 is <class 'list'>
# list 396 is <class 'list'>
# list 397 is <class 'list'>
# list 398 is <class 'list'>
# list 399 is <class 'list'>
# list 400 is <class 'list'>
# list 401 is <class 'list'>
# list 402 is <class 'list'>
# list 403 is <class 'list'>
# list 404 is <class 'list'>
# list 405 is <class 'list'>
# list 406 is <class 'list'>
# list 407 is <class 'list'>
# list 408 is <class 'list'>
# list 409 is <class 'list'>
# list 410 is <class 'list'>
# list 411 is <class 'list'>
# list 412 is <class 'list'>
# list 413 is <class 'list'>
# list 414 is <class 'list'>
# list 415 is <class 'list'>
# list 416 is <class 'list'>
# list 417 is <class 'list'>
# list 418 is <class 'list'>
# list 419 is <class 'list'>
# list 420 is <class 'list'>
# list 421 is <class 'list'>
# list 422 is <class 'list'>
# list 423 is <class 'list'>
# list 424 is <class 'list'>
# list 425 is <class 'list'>
# list 426 is <class 'list'>
# list 427 is <class 'list'>
# list 428 is <class 'list'>
# list 429 is <class 'list'>
# list 430 is <class 'list'>
# list 431 is <class 'list'>
# list 432 is <class 'list'>
# list 433 is <class 'list'>
# list 434 is <class 'list'>
# list 435 is <class 'list'>
# list 436 is <class 'list'>
# list 437 is <class 'list'>
# list 438 is <class 'list'>
# list 439 is <class 'list'>
# list 440 is <class 'list'>
# list 441 is <class 'list'>
# list 442 is <class 'list'>
# list 443 is <class 'list'>
# list 444 is <class 'list'>
# list 445 is <class 'list'>
# list 446 is <class 'list'>
# list 447 is <class 'list'>
# list 448 is <class 'list'>
# list 449 is <class 'list'>
# list 450 is <class 'list'>
# list 451 is <class 'list'>
# list 452 is <class 'list'>
# list 453 is <class 'list'>
# list 454 is <class 'list'>
# list 455 is <class 'list'>
# list 456 is <class 'list'>
# list 457 is <class 'list'>
# list 458 is <class 'list'>
# list 459 is <class 'list'>
# list 460 is <class 'list'>
# list 461 is <class 'list'>
# list 462 is <class 'list'>
# list 463 is <class 'list'>
# list 464 is <class 'list'>
# list 465 is <class 'list'>
# list 466 is <class 'list'>
# list 467 is <class 'list'>
# list 468 is <class 'list'>
# list 469 is <class 'list'>
# list 470 is <class 'list'>
# list 471 is <class 'list'>
# list 472 is <class 'list'>
# list 473 is <class 'list'>
# list 474 is <class 'list'>
# list 475 is <class 'list'>
# list 476 is <class 'list'>
# list 477 is <class 'list'>
# list 478 is <class 'list'>
# list 479 is <class 'list'>
# list 480 is <class 'list'>
# list 481 is <class 'list'>
# list 482 is <class 'list'>
# list 483 is <class 'list'>
# list 484 is <class 'list'>
# list 485 is <class 'list'>
# list 486 is <class 'list'>
# list 487 is <class 'list'>
# list 488 is <class 'list'>
# list 489 is <class 'list'>
# list 490 is <class 'list'>
# list 491 is <class 'list'>
# list 492 is <class 'list'>
# list 493 is <class 'list'>
# list 494 is <class 'list'>
# list 495 is <class 'list'>
# list 496 is <class 'list'>
# list 497 is <class 'list'>
# list 498 is <class 'list'>
# list 499 is <class 'list'>
# list 500 is <class 'list'>
# list 501 is <class 'list'>
# list 502 is <class 'list'>
# list 503 is <class 'list'>
# list 504 is <class 'list'>
# list 505 is <class 'list'>
# list 506 is <class 'list'>
# list 507 is <class 'list'>
# list 508 is <class 'list'>
# list 509 is <class 'list'>
# list 510 is <class 'list'>
# list 511 is <class 'list'>
# list 512 is <class 'list'>
# list 513 is <class 'list'>
# list 514 is <class 'list'>
# list 515 is <class 'list'>
# list 516 is <class 'list'>
# list 517 is <class 'list'>
# list 518 is <class 'list'>
# list 519 is <class 'list'>
# list 520 is <class 'list'>
# list 521 is <class 'list'>
# list 522 is <class 'list'>
# list 523 is <class 'list'>
# list 524 is <class 'list'>
# list 525 is <class 'list'>
# list 526 is <class 'list'>
# list 527 is <class 'list'>
# list 528 is <class 'list'>
# list 529 is <class 'list'>
# list 530 is <class 'list'>
# list 531 is <class 'list'>
# list 532 is <class 'list'>
# list 533 is <class 'list'>
# list 534 is <class 'list'>
# list 535 is <class 'list'>
# list 536 is <class 'list'>
# list 537 is <class 'list'>
# list 538 is <class 'list'>
# list 539 is <class 'list'>
# list 540 is <class 'list'>
# list 541 is <class 'list'>
# list 542 is <class 'list'>
# list 543 is <class 'list'>
# list 544 is <class 'list'>
# list 545 is <class 'list'>
# list 546 is <class 'list'>
# list 547 is <class 'list'>
# list 548 is <class 'list'>
# list 549 is <class 'list'>
# list 550 is <class 'list'>
# list 551 is <class 'list'>
# list 552 is <class 'list'>
# list 553 is <class 'list'>
# list 554 is <class 'list'>
# list 555 is <class 'list'>
# list 556 is <class 'list'>
# list 557 is <class 'list'>
# list 558 is <class 'list'>
# list 559 is <class 'list'>
# list 560 is <class 'list'>
# list 561 is <class 'list'>
# list 562 is <class 'list'>
# list 563 is <class 'list'>
# list 564 is <class 'list'>
# list 565 is <class 'list'>
# list 566 is <class 'list'>
# list 567 is <class 'list'>
# list 568 is <class 'list'>
# list 569 is <class 'list'>
# list 570 is <class 'list'>
# list 571 is <class 'list'>
# list 572 is <class 'list'>
# list 573 is <class 'list'>
# list 574 is <class 'list'>
# list 575 is <class 'list'>
# list 576 is <class 'list'>
# list 577 is <class 'list'>
# list 578 is <class 'list'>
# list 579 is <class 'list'>
# list 580 is <class 'list'>
# list 581 is <class 'list'>
# list 582 is <class 'list'>
# list 583 is <class 'list'>
# list 584 is <class 'list'>
# list 585 is <class 'list'>
# list 586 is <class 'list'>
# list 587 is <class 'list'>
# list 588 is <class 'list'>
# list 589 is <class 'list'>
# list 590 is <class 'list'>
# list 591 is <class 'list'>
# list 592 is <class 'list'>
# list 593 is <class 'list'>
# list 594 is <class 'list'>
# list 595 is <class 'list'>
# list 596 is <class 'list'>
# list 597 is <class 'list'>
# list 598 is <class 'list'>
# list 599 is <class 'list'>
# list 600 is <class 'list'>
# list 601 is <class 'list'>
# list 602 is <class 'list'>
# list 603 is <class 'list'>
# list 604 is <class 'list'>
# list 605 is <class 'list'>
# list 606 is <class 'list'>
# list 607 is <class 'list'>
# list 608 is <class 'list'>
# list 609 is <class 'list'>
# list 610 is <class 'list'>
# list 611 is <class 'list'>
# list 612 is <class 'list'>
# list 613 is <class 'list'>
# list 614 is <class 'list'>
# list 615 is <class 'list'>
# list 616 is <class 'list'>
# list 617 is <class 'list'>
# list 618 is <class 'list'>
# list 619 is <class 'list'>
# list 620 is <class 'list'>
# list 621 is <class 'list'>
# list 622 is <class 'list'>
# list 623 is <class 'list'>
# list 624 is <class 'list'>
# list 625 is <class 'list'>
# list 626 is <class 'list'>
# list 627 is <class 'list'>
# list 628 is <class 'list'>
# list 629 is <class 'list'>
# list 630 is <class 'list'>
# list 631 is <class 'list'>
# list 632 is <class 'list'>
# list 633 is <class 'list'>
# list 634 is <class 'list'>
# list 635 is <class 'list'>
# list 636 is <class 'list'>
# list 637 is <class 'list'>
# list 638 is <class 'list'>
# list 639 is <class 'list'>
# list 640 is <class 'list'>
# list 641 is <class 'list'>
# list 642 is <class 'list'>
# list 643 is <class 'list'>
# list 644 is <class 'list'>
# list 645 is <class 'list'>
# list 646 is <class 'list'>
# list 647 is <class 'list'>
# list 648 is <class 'list'>
# list 649 is <class 'list'>
# list 650 is <class 'list'>
# list 651 is <class 'list'>
# list 652 is <class 'list'>
# list 653 is <class 'list'>
# list 654 is <class 'list'>
# list 655 is <class 'list'>
# list 656 is <class 'list'>
# list 657 is <class 'list'>
# list 658 is <class 'list'>
# list 659 is <class 'list'>
# list 660 is <class 'list'>
# list 661 is <class 'list'>
# list 662 is <class 'list'>
# list 663 is <class 'list'>
# list 664 is <class 'list'>
# list 665 is <class 'list'>
# list 666 is <class 'list'>
# list 667 is <class 'list'>
# list 668 is <class 'list'>
# list 669 is <class 'list'>
# list 670 is <class 'list'>
# list 671 is <class 'list'>
# list 672 is <class 'list'>
# list 673 is <class 'list'>
# list 674 is <class 'list'>
# list 675 is <class 'list'>
# list 676 is <class 'list'>
# list 677 is <class 'list'>
# list 678 is <class 'list'>
# list 679 is <class 'list'>
# list 680 is <class 'list'>
# list 681 is <class 'list'>
# list 682 is <class 'list'>
# list 683 is <class 'list'>
# list 684 is <class 'list'>
# list 685 is <class 'list'>
# list 686 is <class 'list'>
# list 687 is <class 'list'>
# list 688 is <class 'list'>
# list 689 is <class 'list'>
# list 690 is <class 'list'>
# list 691 is <class 'list'>
# list 692 is <class 'list'>
# list 693 is <class 'list'>
# list 694 is <class 'list'>
# list 695 is <class 'list'>
# list 696 is <class 'list'>
# list 697 is <class 'list'>
# list 698 is <class 'list'>
# list 699 is <class 'list'>
# list 700 is <class 'list'>
# list 701 is <class 'list'>
# list 702 is <class 'list'>
# list 703 is <class 'list'>
# list 704 is <class 'list'>
# list 705 is <class 'list'>
# list 706 is <class 'list'>
# list 707 is <class 'list'>
# list 708 is <class 'list'>
# list 709 is <class 'list'>
# list 710 is <class 'list'>
# list 711 is <class 'list'>
# list 712 is <class 'list'>
# list 713 is <class 'list'>
# list 714 is <class 'list'>
# list 715 is <class 'list'>
# list 716 is <class 'list'>
# list 717 is <class 'list'>
# list 718 is <class 'list'>
# list 719 is <class 'list'>
# list 720 is <class 'list'>
# list 721 is <class 'list'>
# list 722 is <class 'list'>
# list 723 is <class 'list'>
# list 724 is <class 'list'>
# list 725 is <class 'list'>
# list 726 is <class 'list'>
# list 727 is <class 'list'>
# list 728 is <class 'list'>
# list 729 is <class 'list'>
# list 730 is <class 'list'>
# list 731 is <class 'list'>
# list 732 is <class 'list'>
# list 733 is <class 'list'>
# list 734 is <class 'list'>
# list 735 is <class 'list'>
# list 736 is <class 'list'>
# list 737 is <class 'list'>
# list 738 is <class 'list'>

# %% [markdown]
# They're lists, so like last time we just need to apply pd.Series.

# %%
pokemon_abilities = pokemon_df['abilities'].apply(pd.Series)
pokemon_abilities
# Out:
#                                  0            1    2    3
# name
# Bulbasaur              Chlorophyll     Overgrow  NaN  NaN
# Ivysaur                Chlorophyll     Overgrow  NaN  NaN
# Venusaur               Chlorophyll     Overgrow  NaN  NaN
# Charmander                   Blaze  Solar Power  NaN  NaN
# Charmeleon                   Blaze  Solar Power  NaN  NaN
# ...                            ...          ...  ...  ...
# Glastrier           Chilling Neigh          NaN  NaN  NaN
# Spectrier               Grim Neigh          NaN  NaN  NaN
# Calyrex                    Unnerve          NaN  NaN  NaN
# Calyrex-Ice     As One (Glastrier)          NaN  NaN  NaN
# Calyrex-Shadow  As One (Spectrier)          NaN  NaN  NaN
#
# [739 rows x 4 columns]

# %% [markdown]
# This is slightly more complicated still, because pokemon can have anymore from one to four possible abilities.  However, four is very rare; how many pokemon have four?

# %%
pokemon_abilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       739 non-null    object
#  1   1       593 non-null    object
#  2   2       395 non-null    object
#  3   3       1 non-null      object
# dtypes: object(4)
# memory usage: 45.0+ KB

# %% [markdown]
# Just one!  And which pokemon is that?

# %%
pokemon_df.loc[pokemon_abilities.loc[:, 3].notna()]
# Out:
#           hp  atk  def  spa  spd  spe  weight  height   types  \
# name
# Rockruff  45   65   40   30   40   60     9.2     0.5  [Rock]
#
#                                                abilities formats  \
# name
# Rockruff  [Keen Eye, Own Tempo, Steadfast, Vital Spirit]      LC
#
#          isNonstandard                                                oob
# name
# Rockruff      Standard  {'dex_number': 744, 'evos': ['Lycanroc', 'Lyca...

# %% [markdown]
# Checking it in the reference material on Smogon, it seems that Rockruff really has 4 possible abilities so there is no mistake.
#
# Since there are up to 4 possible abilities for each pokemon, our code for filling pokemon_abilities_df will have to be slightly more complicated than the code for pokemon_types_df, but not intractably so.

# %%
for index, row in pokemon_abilities.iterrows():
    pokemon_abilities_df.loc[index, row[0]] = 1
    if row.isna().sum() < 3:
        pokemon_abilities_df.loc[index, row[1]] = 1
    if row.isna().sum() < 2:
        pokemon_abilities_df.loc[index, row[2]] = 1
    if row.isna().sum() < 1:
        pokemon_abilities_df.loc[index, row[3]] = 1

pokemon_abilities_df
# Out:
#                 Cute Charm  Effect Spore  Flame Body  Flash Fire  Intimidate  \
# name
# Bulbasaur                0             0           0           0           0
# Ivysaur                  0             0           0           0           0
# Venusaur                 0             0           0           0           0
# Charmander               0             0           0           0           0
# Charmeleon               0             0           0           0           0
# ...                    ...           ...         ...         ...         ...
# Glastrier                0             0           0           0           0
# Spectrier                0             0           0           0           0
# Calyrex                  0             0           0           0           0
# Calyrex-Ice              0             0           0           0           0
# Calyrex-Shadow           0             0           0           0           0
#
#                 Lightning Rod  Minus  Plus  Poison Point  Pressure  ...  \
# name                                                                ...
# Bulbasaur                   0      0     0             0         0  ...
# Ivysaur                     0      0     0             0         0  ...
# Venusaur                    0      0     0             0         0  ...
# Charmander                  0      0     0             0         0  ...
# Charmeleon                  0      0     0             0         0  ...
# ...                       ...    ...   ...           ...       ...  ...
# Glastrier                   0      0     0             0         0  ...
# Spectrier                   0      0     0             0         0  ...
# Calyrex                     0      0     0             0         0  ...
# Calyrex-Ice                 0      0     0             0         0  ...
# Calyrex-Shadow              0      0     0             0         0  ...
#
#                 Quick Draw  Ripen  Sand Spit  Screen Cleaner  Stalwart  \
# name
# Bulbasaur                0      0          0               0         0
# Ivysaur                  0      0          0               0         0
# Venusaur                 0      0          0               0         0
# Charmander               0      0          0               0         0
# Charmeleon               0      0          0               0         0
# ...                    ...    ...        ...             ...       ...
# Glastrier                0      0          0               0         0
# Spectrier                0      0          0               0         0
# Calyrex                  0      0          0               0         0
# Calyrex-Ice              0      0          0               0         0
# Calyrex-Shadow           0      0          0               0         0
#
#                 Steam Engine  Steely Spirit  Transistor  Unseen Fist  \
# name
# Bulbasaur                  0              0           0            0
# Ivysaur                    0              0           0            0
# Venusaur                   0              0           0            0
# Charmander                 0              0           0            0
# Charmeleon                 0              0           0            0
# ...                      ...            ...         ...          ...
# Glastrier                  0              0           0            0
# Spectrier                  0              0           0            0
# Calyrex                    0              0           0            0
# Calyrex-Ice                0              0           0            0
# Calyrex-Shadow             0              0           0            0
#
#                 Wandering Spirit
# name
# Bulbasaur                      0
# Ivysaur                        0
# Venusaur                       0
# Charmander                     0
# Charmeleon                     0
# ...                          ...
# Glastrier                      0
# Spectrier                      0
# Calyrex                        0
# Calyrex-Ice                    0
# Calyrex-Shadow                 0
#
# [739 rows x 267 columns]

# %% [markdown]
# Let's do some sanity checks to make sure this worked out properly:

# %%
pokemon_abilities_df.loc['Rockruff'].sum()
# Out:
# 4

# %%
pokemon_abilities_df.loc['Bulbasaur'].sum()
# Out:
# 2

# %%
pokemon_abilities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Columns: 267 entries, Cute Charm to Wandering Spirit
# dtypes: int64(267)
# memory usage: 1.5+ MB

# %% [markdown]
# It's interesting that our dataframe consists of integer instead of boolean values.  I'm not sure which is better for machine learning, but it is something we can consider later.  Pandas profiling seems to interpret them as booleans, in any case.
#
# We should check that we have the correct number of abilities in each row:

# %%
pokemon_abilities_df.apply(sum, axis=1).value_counts()
# Out:
# 3    394
# 2    198
# 1    146
# 4      1
# dtype: int64

# %% [markdown]
# 394 is correct for "3 abilities", because there were 395 values in the 3rd ability column and only Rockruff has 4, which takes one away from rows which sum to exactly 3 (since 395 are "at least" 3).
#
# Basically the calculation was 395 - 1 = 394
#
# Likewise:
# 593 - 395 = 198, so 198 is correct for "2 abilities"
# 793 - 593 = 146, so 146 is correct for "1 ability"
#
# We know 1 is correct is "4 abilities" (Rockruff), thus our database is officially validated at the basic level.  Let's see if a pandas profile report picks up anything less obvious.

# %%
profile_report = pokemon_abilities_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/282 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# Upon examination, all the columns with constant values of zero seem to occur only in "National Dex" pokemon, which were removed from pokemon_df and thus of course these abilities never had a single "1" selected within the set of pokemon I'm using.  These abilities need to be removed, but since I'm saving National Dex pokemon, I might as well save these abilities aside as well.

# %%
abilities_removed_df = pokemon_abilities_df.loc[:, pokemon_abilities_df.sum(axis=0) == 0].columns
abilities_removed_df
# Out:
# Index(['Color Change', 'Forecast', 'Magma Armor', 'Pure Power', 'Bad Dreams',
#        'Normalize', 'Multitype', 'Poison Heal', 'Toxic Boost', 'Aerilate',
#        'Parental Bond', 'Delta Stream', 'Desolate Land', 'Grass Pelt',
#        'Primordial Sea', 'Protean', 'Battle Bond', 'Comatose', 'Dancer',
#        'Dazzling', 'Galvanize', 'Neuroforce', 'Power of Alchemy',
#        'Shields Down'],
#       dtype='object', name='')

# %%
pokemon_abilities_df = pokemon_abilities_df.loc[:, pokemon_abilities_df.sum(axis=0) != 0].copy()
pokemon_abilities_df
# Out:
#                 Cute Charm  Effect Spore  Flame Body  Flash Fire  Intimidate  \
# name
# Bulbasaur                0             0           0           0           0
# Ivysaur                  0             0           0           0           0
# Venusaur                 0             0           0           0           0
# Charmander               0             0           0           0           0
# Charmeleon               0             0           0           0           0
# ...                    ...           ...         ...         ...         ...
# Glastrier                0             0           0           0           0
# Spectrier                0             0           0           0           0
# Calyrex                  0             0           0           0           0
# Calyrex-Ice              0             0           0           0           0
# Calyrex-Shadow           0             0           0           0           0
#
#                 Lightning Rod  Minus  Plus  Poison Point  Pressure  ...  \
# name                                                                ...
# Bulbasaur                   0      0     0             0         0  ...
# Ivysaur                     0      0     0             0         0  ...
# Venusaur                    0      0     0             0         0  ...
# Charmander                  0      0     0             0         0  ...
# Charmeleon                  0      0     0             0         0  ...
# ...                       ...    ...   ...           ...       ...  ...
# Glastrier                   0      0     0             0         0  ...
# Spectrier                   0      0     0             0         0  ...
# Calyrex                     0      0     0             0         0  ...
# Calyrex-Ice                 0      0     0             0         0  ...
# Calyrex-Shadow              0      0     0             0         0  ...
#
#                 Quick Draw  Ripen  Sand Spit  Screen Cleaner  Stalwart  \
# name
# Bulbasaur                0      0          0               0         0
# Ivysaur                  0      0          0               0         0
# Venusaur                 0      0          0               0         0
# Charmander               0      0          0               0         0
# Charmeleon               0      0          0               0         0
# ...                    ...    ...        ...             ...       ...
# Glastrier                0      0          0               0         0
# Spectrier                0      0          0               0         0
# Calyrex                  0      0          0               0         0
# Calyrex-Ice              0      0          0               0         0
# Calyrex-Shadow           0      0          0               0         0
#
#                 Steam Engine  Steely Spirit  Transistor  Unseen Fist  \
# name
# Bulbasaur                  0              0           0            0
# Ivysaur                    0              0           0            0
# Venusaur                   0              0           0            0
# Charmander                 0              0           0            0
# Charmeleon                 0              0           0            0
# ...                      ...            ...         ...          ...
# Glastrier                  0              0           0            0
# Spectrier                  0              0           0            0
# Calyrex                    0              0           0            0
# Calyrex-Ice                0              0           0            0
# Calyrex-Shadow             0              0           0            0
#
#                 Wandering Spirit
# name
# Bulbasaur                      0
# Ivysaur                        0
# Venusaur                       0
# Charmander                     0
# Charmeleon                     0
# ...                          ...
# Glastrier                      0
# Spectrier                      0
# Calyrex                        0
# Calyrex-Ice                    0
# Calyrex-Shadow                 0
#
# [739 rows x 243 columns]

# %% [markdown]
# Since 267-24=243, we removed exactly the right amount of abilities.
#
# There is just one more small matter to attend to: in my research about pokemon alternative forms, I discovered that Zygarde-10% can't use one of its abilities (Power Construct) in its format because that would transform Zygarde-10% into Zygarde-Complete, which is only admissible in the Uber format.  Therefore, for our purposes we should remove this ability from Zygarde-10%, as it isn't likely to be used in Uber (compared to regular Zygarde which is itself an Uber tier pokemon) and is used much more in lower tiers nearer to RU.

# %%
pokemon_abilities_df.loc['Zygarde-10%', 'Power Construct'] = 0
pokemon_abilities_df.loc[pokemon_abilities_df['Power Construct'] == 1, :]
# Out:
#          Cute Charm  Effect Spore  Flame Body  Flash Fire  Intimidate  \
# name
# Zygarde           0             0           0           0           0
#
#          Lightning Rod  Minus  Plus  Poison Point  Pressure  ...  Quick Draw  \
# name                                                         ...
# Zygarde              0      0     0             0         0  ...           0
#
#          Ripen  Sand Spit  Screen Cleaner  Stalwart  Steam Engine  \
# name
# Zygarde      0          0               0         0             0
#
#          Steely Spirit  Transistor  Unseen Fist  Wandering Spirit
# name
# Zygarde              0           0            0                 0
#
# [1 rows x 243 columns]

# %% [markdown]
# That seems to have worked!
#
# Now that we've finished using the types and abilities columns of pokemon_df to fill our new dataframes, we should put the finishing touches on each column of pokemon_df by removing it or suitably modifying it so that there are no more unsupported data types.
#
# Types, abilities, and isNonstandard (which literally contains no information) can just be dropped, but oob might have some potentially interesting information.

# %%
pokemon_df = pokemon_df.drop(columns=['types', 'abilities', 'isNonstandard'])
pokemon_df
# Out:
#                  hp  atk  def  spa  spd  spe  weight  height   formats  \
# name
# Bulbasaur        45   49   49   65   65   45     6.9     0.7        LC
# Ivysaur          60   62   63   80   80   60    13.0     1.0       NFE
# Venusaur         80   82   83  100  100   80   100.0     2.0      RUBL
# Charmander       39   52   43   60   50   65     8.5     0.6        LC
# Charmeleon       58   64   58   80   65   80    19.0     1.1       NFE
# ...             ...  ...  ...  ...  ...  ...     ...     ...       ...
# Glastrier       100  145  130   65  110   30   800.0     2.2        NU
# Spectrier       100   65   60  145   80  130    44.5     2.0      Uber
# Calyrex         100   80   80   80   80   80     7.7     1.1  Untiered
# Calyrex-Ice     100  165  150   85  130   50   809.1     2.4      Uber
# Calyrex-Shadow  100   85   80  165  100  150    53.6     2.4      Uber
#
#                                                               oob
# name
# Bulbasaur       {'dex_number': 1, 'evos': ['Ivysaur'], 'alts':...
# Ivysaur         {'dex_number': 2, 'evos': ['Venusaur'], 'alts'...
# Venusaur        {'dex_number': 3, 'evos': [], 'alts': ['Venusa...
# Charmander      {'dex_number': 4, 'evos': ['Charmeleon'], 'alt...
# Charmeleon      {'dex_number': 5, 'evos': ['Charizard'], 'alts...
# ...                                                           ...
# Glastrier       {'dex_number': 896, 'evos': [], 'alts': [], 'g...
# Spectrier       {'dex_number': 897, 'evos': [], 'alts': [], 'g...
# Calyrex         {'dex_number': 898, 'evos': [], 'alts': [], 'g...
# Calyrex-Ice     {'dex_number': 898, 'evos': [], 'alts': [], 'g...
# Calyrex-Shadow  {'dex_number': 898, 'evos': [], 'alts': [], 'g...
#
# [739 rows x 10 columns]

# %% [markdown]
# Examining the JSON file (in jsonviewer) that was used to make pokedex_dict, it appears that oob is mostly unimportant information for our purposes, but it may be interesting to know the generation in which pokemon were introduced (to answer questions about how powerful each generation is, whether there was "power creep", etc.).  So we can make a new column in pokemon_df that will just contain the generation in which the pokemon was introduced, and get rid of the oob column after that.

# %%
for i, l in enumerate(pokemon_df["oob"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'dict'>
# list 1 is <class 'dict'>
# list 2 is <class 'dict'>
# list 3 is <class 'dict'>
# list 4 is <class 'dict'>
# list 5 is <class 'dict'>
# list 6 is <class 'dict'>
# list 7 is <class 'dict'>
# list 8 is <class 'dict'>
# list 9 is <class 'dict'>
# list 10 is <class 'dict'>
# list 11 is <class 'dict'>
# list 12 is <class 'dict'>
# list 13 is <class 'dict'>
# list 14 is <class 'dict'>
# list 15 is <class 'dict'>
# list 16 is <class 'dict'>
# list 17 is <class 'dict'>
# list 18 is <class 'dict'>
# list 19 is <class 'dict'>
# list 20 is <class 'dict'>
# list 21 is <class 'dict'>
# list 22 is <class 'dict'>
# list 23 is <class 'dict'>
# list 24 is <class 'dict'>
# list 25 is <class 'dict'>
# list 26 is <class 'dict'>
# list 27 is <class 'dict'>
# list 28 is <class 'dict'>
# list 29 is <class 'dict'>
# list 30 is <class 'dict'>
# list 31 is <class 'dict'>
# list 32 is <class 'dict'>
# list 33 is <class 'dict'>
# list 34 is <class 'dict'>
# list 35 is <class 'dict'>
# list 36 is <class 'dict'>
# list 37 is <class 'dict'>
# list 38 is <class 'dict'>
# list 39 is <class 'dict'>
# list 40 is <class 'dict'>
# list 41 is <class 'dict'>
# list 42 is <class 'dict'>
# list 43 is <class 'dict'>
# list 44 is <class 'dict'>
# list 45 is <class 'dict'>
# list 46 is <class 'dict'>
# list 47 is <class 'dict'>
# list 48 is <class 'dict'>
# list 49 is <class 'dict'>
# list 50 is <class 'dict'>
# list 51 is <class 'dict'>
# list 52 is <class 'dict'>
# list 53 is <class 'dict'>
# list 54 is <class 'dict'>
# list 55 is <class 'dict'>
# list 56 is <class 'dict'>
# list 57 is <class 'dict'>
# list 58 is <class 'dict'>
# list 59 is <class 'dict'>
# list 60 is <class 'dict'>
# list 61 is <class 'dict'>
# list 62 is <class 'dict'>
# list 63 is <class 'dict'>
# list 64 is <class 'dict'>
# list 65 is <class 'dict'>
# list 66 is <class 'dict'>
# list 67 is <class 'dict'>
# list 68 is <class 'dict'>
# list 69 is <class 'dict'>
# list 70 is <class 'dict'>
# list 71 is <class 'dict'>
# list 72 is <class 'dict'>
# list 73 is <class 'dict'>
# list 74 is <class 'dict'>
# list 75 is <class 'dict'>
# list 76 is <class 'dict'>
# list 77 is <class 'dict'>
# list 78 is <class 'dict'>
# list 79 is <class 'dict'>
# list 80 is <class 'dict'>
# list 81 is <class 'dict'>
# list 82 is <class 'dict'>
# list 83 is <class 'dict'>
# list 84 is <class 'dict'>
# list 85 is <class 'dict'>
# list 86 is <class 'dict'>
# list 87 is <class 'dict'>
# list 88 is <class 'dict'>
# list 89 is <class 'dict'>
# list 90 is <class 'dict'>
# list 91 is <class 'dict'>
# list 92 is <class 'dict'>
# list 93 is <class 'dict'>
# list 94 is <class 'dict'>
# list 95 is <class 'dict'>
# list 96 is <class 'dict'>
# list 97 is <class 'dict'>
# list 98 is <class 'dict'>
# list 99 is <class 'dict'>
# list 100 is <class 'dict'>
# list 101 is <class 'dict'>
# list 102 is <class 'dict'>
# list 103 is <class 'dict'>
# list 104 is <class 'dict'>
# list 105 is <class 'dict'>
# list 106 is <class 'dict'>
# list 107 is <class 'dict'>
# list 108 is <class 'dict'>
# list 109 is <class 'dict'>
# list 110 is <class 'dict'>
# list 111 is <class 'dict'>
# list 112 is <class 'dict'>
# list 113 is <class 'dict'>
# list 114 is <class 'dict'>
# list 115 is <class 'dict'>
# list 116 is <class 'dict'>
# list 117 is <class 'dict'>
# list 118 is <class 'dict'>
# list 119 is <class 'dict'>
# list 120 is <class 'dict'>
# list 121 is <class 'dict'>
# list 122 is <class 'dict'>
# list 123 is <class 'dict'>
# list 124 is <class 'dict'>
# list 125 is <class 'dict'>
# list 126 is <class 'dict'>
# list 127 is <class 'dict'>
# list 128 is <class 'dict'>
# list 129 is <class 'dict'>
# list 130 is <class 'dict'>
# list 131 is <class 'dict'>
# list 132 is <class 'dict'>
# list 133 is <class 'dict'>
# list 134 is <class 'dict'>
# list 135 is <class 'dict'>
# list 136 is <class 'dict'>
# list 137 is <class 'dict'>
# list 138 is <class 'dict'>
# list 139 is <class 'dict'>
# list 140 is <class 'dict'>
# list 141 is <class 'dict'>
# list 142 is <class 'dict'>
# list 143 is <class 'dict'>
# list 144 is <class 'dict'>
# list 145 is <class 'dict'>
# list 146 is <class 'dict'>
# list 147 is <class 'dict'>
# list 148 is <class 'dict'>
# list 149 is <class 'dict'>
# list 150 is <class 'dict'>
# list 151 is <class 'dict'>
# list 152 is <class 'dict'>
# list 153 is <class 'dict'>
# list 154 is <class 'dict'>
# list 155 is <class 'dict'>
# list 156 is <class 'dict'>
# list 157 is <class 'dict'>
# list 158 is <class 'dict'>
# list 159 is <class 'dict'>
# list 160 is <class 'dict'>
# list 161 is <class 'dict'>
# list 162 is <class 'dict'>
# list 163 is <class 'dict'>
# list 164 is <class 'dict'>
# list 165 is <class 'dict'>
# list 166 is <class 'dict'>
# list 167 is <class 'dict'>
# list 168 is <class 'dict'>
# list 169 is <class 'dict'>
# list 170 is <class 'dict'>
# list 171 is <class 'dict'>
# list 172 is <class 'dict'>
# list 173 is <class 'dict'>
# list 174 is <class 'dict'>
# list 175 is <class 'dict'>
# list 176 is <class 'dict'>
# list 177 is <class 'dict'>
# list 178 is <class 'dict'>
# list 179 is <class 'dict'>
# list 180 is <class 'dict'>
# list 181 is <class 'dict'>
# list 182 is <class 'dict'>
# list 183 is <class 'dict'>
# list 184 is <class 'dict'>
# list 185 is <class 'dict'>
# list 186 is <class 'dict'>
# list 187 is <class 'dict'>
# list 188 is <class 'dict'>
# list 189 is <class 'dict'>
# list 190 is <class 'dict'>
# list 191 is <class 'dict'>
# list 192 is <class 'dict'>
# list 193 is <class 'dict'>
# list 194 is <class 'dict'>
# list 195 is <class 'dict'>
# list 196 is <class 'dict'>
# list 197 is <class 'dict'>
# list 198 is <class 'dict'>
# list 199 is <class 'dict'>
# list 200 is <class 'dict'>
# list 201 is <class 'dict'>
# list 202 is <class 'dict'>
# list 203 is <class 'dict'>
# list 204 is <class 'dict'>
# list 205 is <class 'dict'>
# list 206 is <class 'dict'>
# list 207 is <class 'dict'>
# list 208 is <class 'dict'>
# list 209 is <class 'dict'>
# list 210 is <class 'dict'>
# list 211 is <class 'dict'>
# list 212 is <class 'dict'>
# list 213 is <class 'dict'>
# list 214 is <class 'dict'>
# list 215 is <class 'dict'>
# list 216 is <class 'dict'>
# list 217 is <class 'dict'>
# list 218 is <class 'dict'>
# list 219 is <class 'dict'>
# list 220 is <class 'dict'>
# list 221 is <class 'dict'>
# list 222 is <class 'dict'>
# list 223 is <class 'dict'>
# list 224 is <class 'dict'>
# list 225 is <class 'dict'>
# list 226 is <class 'dict'>
# list 227 is <class 'dict'>
# list 228 is <class 'dict'>
# list 229 is <class 'dict'>
# list 230 is <class 'dict'>
# list 231 is <class 'dict'>
# list 232 is <class 'dict'>
# list 233 is <class 'dict'>
# list 234 is <class 'dict'>
# list 235 is <class 'dict'>
# list 236 is <class 'dict'>
# list 237 is <class 'dict'>
# list 238 is <class 'dict'>
# list 239 is <class 'dict'>
# list 240 is <class 'dict'>
# list 241 is <class 'dict'>
# list 242 is <class 'dict'>
# list 243 is <class 'dict'>
# list 244 is <class 'dict'>
# list 245 is <class 'dict'>
# list 246 is <class 'dict'>
# list 247 is <class 'dict'>
# list 248 is <class 'dict'>
# list 249 is <class 'dict'>
# list 250 is <class 'dict'>
# list 251 is <class 'dict'>
# list 252 is <class 'dict'>
# list 253 is <class 'dict'>
# list 254 is <class 'dict'>
# list 255 is <class 'dict'>
# list 256 is <class 'dict'>
# list 257 is <class 'dict'>
# list 258 is <class 'dict'>
# list 259 is <class 'dict'>
# list 260 is <class 'dict'>
# list 261 is <class 'dict'>
# list 262 is <class 'dict'>
# list 263 is <class 'dict'>
# list 264 is <class 'dict'>
# list 265 is <class 'dict'>
# list 266 is <class 'dict'>
# list 267 is <class 'dict'>
# list 268 is <class 'dict'>
# list 269 is <class 'dict'>
# list 270 is <class 'dict'>
# list 271 is <class 'dict'>
# list 272 is <class 'dict'>
# list 273 is <class 'dict'>
# list 274 is <class 'dict'>
# list 275 is <class 'dict'>
# list 276 is <class 'dict'>
# list 277 is <class 'dict'>
# list 278 is <class 'dict'>
# list 279 is <class 'dict'>
# list 280 is <class 'dict'>
# list 281 is <class 'dict'>
# list 282 is <class 'dict'>
# list 283 is <class 'dict'>
# list 284 is <class 'dict'>
# list 285 is <class 'dict'>
# list 286 is <class 'dict'>
# list 287 is <class 'dict'>
# list 288 is <class 'dict'>
# list 289 is <class 'dict'>
# list 290 is <class 'dict'>
# list 291 is <class 'dict'>
# list 292 is <class 'dict'>
# list 293 is <class 'dict'>
# list 294 is <class 'dict'>
# list 295 is <class 'dict'>
# list 296 is <class 'dict'>
# list 297 is <class 'dict'>
# list 298 is <class 'dict'>
# list 299 is <class 'dict'>
# list 300 is <class 'dict'>
# list 301 is <class 'dict'>
# list 302 is <class 'dict'>
# list 303 is <class 'dict'>
# list 304 is <class 'dict'>
# list 305 is <class 'dict'>
# list 306 is <class 'dict'>
# list 307 is <class 'dict'>
# list 308 is <class 'dict'>
# list 309 is <class 'dict'>
# list 310 is <class 'dict'>
# list 311 is <class 'dict'>
# list 312 is <class 'dict'>
# list 313 is <class 'dict'>
# list 314 is <class 'dict'>
# list 315 is <class 'dict'>
# list 316 is <class 'dict'>
# list 317 is <class 'dict'>
# list 318 is <class 'dict'>
# list 319 is <class 'dict'>
# list 320 is <class 'dict'>
# list 321 is <class 'dict'>
# list 322 is <class 'dict'>
# list 323 is <class 'dict'>
# list 324 is <class 'dict'>
# list 325 is <class 'dict'>
# list 326 is <class 'dict'>
# list 327 is <class 'dict'>
# list 328 is <class 'dict'>
# list 329 is <class 'dict'>
# list 330 is <class 'dict'>
# list 331 is <class 'dict'>
# list 332 is <class 'dict'>
# list 333 is <class 'dict'>
# list 334 is <class 'dict'>
# list 335 is <class 'dict'>
# list 336 is <class 'dict'>
# list 337 is <class 'dict'>
# list 338 is <class 'dict'>
# list 339 is <class 'dict'>
# list 340 is <class 'dict'>
# list 341 is <class 'dict'>
# list 342 is <class 'dict'>
# list 343 is <class 'dict'>
# list 344 is <class 'dict'>
# list 345 is <class 'dict'>
# list 346 is <class 'dict'>
# list 347 is <class 'dict'>
# list 348 is <class 'dict'>
# list 349 is <class 'dict'>
# list 350 is <class 'dict'>
# list 351 is <class 'dict'>
# list 352 is <class 'dict'>
# list 353 is <class 'dict'>
# list 354 is <class 'dict'>
# list 355 is <class 'dict'>
# list 356 is <class 'dict'>
# list 357 is <class 'dict'>
# list 358 is <class 'dict'>
# list 359 is <class 'dict'>
# list 360 is <class 'dict'>
# list 361 is <class 'dict'>
# list 362 is <class 'dict'>
# list 363 is <class 'dict'>
# list 364 is <class 'dict'>
# list 365 is <class 'dict'>
# list 366 is <class 'dict'>
# list 367 is <class 'dict'>
# list 368 is <class 'dict'>
# list 369 is <class 'dict'>
# list 370 is <class 'dict'>
# list 371 is <class 'dict'>
# list 372 is <class 'dict'>
# list 373 is <class 'dict'>
# list 374 is <class 'dict'>
# list 375 is <class 'dict'>
# list 376 is <class 'dict'>
# list 377 is <class 'dict'>
# list 378 is <class 'dict'>
# list 379 is <class 'dict'>
# list 380 is <class 'dict'>
# list 381 is <class 'dict'>
# list 382 is <class 'dict'>
# list 383 is <class 'dict'>
# list 384 is <class 'dict'>
# list 385 is <class 'dict'>
# list 386 is <class 'dict'>
# list 387 is <class 'dict'>
# list 388 is <class 'dict'>
# list 389 is <class 'dict'>
# list 390 is <class 'dict'>
# list 391 is <class 'dict'>
# list 392 is <class 'dict'>
# list 393 is <class 'dict'>
# list 394 is <class 'dict'>
# list 395 is <class 'dict'>
# list 396 is <class 'dict'>
# list 397 is <class 'dict'>
# list 398 is <class 'dict'>
# list 399 is <class 'dict'>
# list 400 is <class 'dict'>
# list 401 is <class 'dict'>
# list 402 is <class 'dict'>
# list 403 is <class 'dict'>
# list 404 is <class 'dict'>
# list 405 is <class 'dict'>
# list 406 is <class 'dict'>
# list 407 is <class 'dict'>
# list 408 is <class 'dict'>
# list 409 is <class 'dict'>
# list 410 is <class 'dict'>
# list 411 is <class 'dict'>
# list 412 is <class 'dict'>
# list 413 is <class 'dict'>
# list 414 is <class 'dict'>
# list 415 is <class 'dict'>
# list 416 is <class 'dict'>
# list 417 is <class 'dict'>
# list 418 is <class 'dict'>
# list 419 is <class 'dict'>
# list 420 is <class 'dict'>
# list 421 is <class 'dict'>
# list 422 is <class 'dict'>
# list 423 is <class 'dict'>
# list 424 is <class 'dict'>
# list 425 is <class 'dict'>
# list 426 is <class 'dict'>
# list 427 is <class 'dict'>
# list 428 is <class 'dict'>
# list 429 is <class 'dict'>
# list 430 is <class 'dict'>
# list 431 is <class 'dict'>
# list 432 is <class 'dict'>
# list 433 is <class 'dict'>
# list 434 is <class 'dict'>
# list 435 is <class 'dict'>
# list 436 is <class 'dict'>
# list 437 is <class 'dict'>
# list 438 is <class 'dict'>
# list 439 is <class 'dict'>
# list 440 is <class 'dict'>
# list 441 is <class 'dict'>
# list 442 is <class 'dict'>
# list 443 is <class 'dict'>
# list 444 is <class 'dict'>
# list 445 is <class 'dict'>
# list 446 is <class 'dict'>
# list 447 is <class 'dict'>
# list 448 is <class 'dict'>
# list 449 is <class 'dict'>
# list 450 is <class 'dict'>
# list 451 is <class 'dict'>
# list 452 is <class 'dict'>
# list 453 is <class 'dict'>
# list 454 is <class 'dict'>
# list 455 is <class 'dict'>
# list 456 is <class 'dict'>
# list 457 is <class 'dict'>
# list 458 is <class 'dict'>
# list 459 is <class 'dict'>
# list 460 is <class 'dict'>
# list 461 is <class 'dict'>
# list 462 is <class 'dict'>
# list 463 is <class 'dict'>
# list 464 is <class 'dict'>
# list 465 is <class 'dict'>
# list 466 is <class 'dict'>
# list 467 is <class 'dict'>
# list 468 is <class 'dict'>
# list 469 is <class 'dict'>
# list 470 is <class 'dict'>
# list 471 is <class 'dict'>
# list 472 is <class 'dict'>
# list 473 is <class 'dict'>
# list 474 is <class 'dict'>
# list 475 is <class 'dict'>
# list 476 is <class 'dict'>
# list 477 is <class 'dict'>
# list 478 is <class 'dict'>
# list 479 is <class 'dict'>
# list 480 is <class 'dict'>
# list 481 is <class 'dict'>
# list 482 is <class 'dict'>
# list 483 is <class 'dict'>
# list 484 is <class 'dict'>
# list 485 is <class 'dict'>
# list 486 is <class 'dict'>
# list 487 is <class 'dict'>
# list 488 is <class 'dict'>
# list 489 is <class 'dict'>
# list 490 is <class 'dict'>
# list 491 is <class 'dict'>
# list 492 is <class 'dict'>
# list 493 is <class 'dict'>
# list 494 is <class 'dict'>
# list 495 is <class 'dict'>
# list 496 is <class 'dict'>
# list 497 is <class 'dict'>
# list 498 is <class 'dict'>
# list 499 is <class 'dict'>
# list 500 is <class 'dict'>
# list 501 is <class 'dict'>
# list 502 is <class 'dict'>
# list 503 is <class 'dict'>
# list 504 is <class 'dict'>
# list 505 is <class 'dict'>
# list 506 is <class 'dict'>
# list 507 is <class 'dict'>
# list 508 is <class 'dict'>
# list 509 is <class 'dict'>
# list 510 is <class 'dict'>
# list 511 is <class 'dict'>
# list 512 is <class 'dict'>
# list 513 is <class 'dict'>
# list 514 is <class 'dict'>
# list 515 is <class 'dict'>
# list 516 is <class 'dict'>
# list 517 is <class 'dict'>
# list 518 is <class 'dict'>
# list 519 is <class 'dict'>
# list 520 is <class 'dict'>
# list 521 is <class 'dict'>
# list 522 is <class 'dict'>
# list 523 is <class 'dict'>
# list 524 is <class 'dict'>
# list 525 is <class 'dict'>
# list 526 is <class 'dict'>
# list 527 is <class 'dict'>
# list 528 is <class 'dict'>
# list 529 is <class 'dict'>
# list 530 is <class 'dict'>
# list 531 is <class 'dict'>
# list 532 is <class 'dict'>
# list 533 is <class 'dict'>
# list 534 is <class 'dict'>
# list 535 is <class 'dict'>
# list 536 is <class 'dict'>
# list 537 is <class 'dict'>
# list 538 is <class 'dict'>
# list 539 is <class 'dict'>
# list 540 is <class 'dict'>
# list 541 is <class 'dict'>
# list 542 is <class 'dict'>
# list 543 is <class 'dict'>
# list 544 is <class 'dict'>
# list 545 is <class 'dict'>
# list 546 is <class 'dict'>
# list 547 is <class 'dict'>
# list 548 is <class 'dict'>
# list 549 is <class 'dict'>
# list 550 is <class 'dict'>
# list 551 is <class 'dict'>
# list 552 is <class 'dict'>
# list 553 is <class 'dict'>
# list 554 is <class 'dict'>
# list 555 is <class 'dict'>
# list 556 is <class 'dict'>
# list 557 is <class 'dict'>
# list 558 is <class 'dict'>
# list 559 is <class 'dict'>
# list 560 is <class 'dict'>
# list 561 is <class 'dict'>
# list 562 is <class 'dict'>
# list 563 is <class 'dict'>
# list 564 is <class 'dict'>
# list 565 is <class 'dict'>
# list 566 is <class 'dict'>
# list 567 is <class 'dict'>
# list 568 is <class 'dict'>
# list 569 is <class 'dict'>
# list 570 is <class 'dict'>
# list 571 is <class 'dict'>
# list 572 is <class 'dict'>
# list 573 is <class 'dict'>
# list 574 is <class 'dict'>
# list 575 is <class 'dict'>
# list 576 is <class 'dict'>
# list 577 is <class 'dict'>
# list 578 is <class 'dict'>
# list 579 is <class 'dict'>
# list 580 is <class 'dict'>
# list 581 is <class 'dict'>
# list 582 is <class 'dict'>
# list 583 is <class 'dict'>
# list 584 is <class 'dict'>
# list 585 is <class 'dict'>
# list 586 is <class 'dict'>
# list 587 is <class 'dict'>
# list 588 is <class 'dict'>
# list 589 is <class 'dict'>
# list 590 is <class 'dict'>
# list 591 is <class 'dict'>
# list 592 is <class 'dict'>
# list 593 is <class 'dict'>
# list 594 is <class 'dict'>
# list 595 is <class 'dict'>
# list 596 is <class 'dict'>
# list 597 is <class 'dict'>
# list 598 is <class 'dict'>
# list 599 is <class 'dict'>
# list 600 is <class 'dict'>
# list 601 is <class 'dict'>
# list 602 is <class 'dict'>
# list 603 is <class 'dict'>
# list 604 is <class 'dict'>
# list 605 is <class 'dict'>
# list 606 is <class 'dict'>
# list 607 is <class 'dict'>
# list 608 is <class 'dict'>
# list 609 is <class 'dict'>
# list 610 is <class 'dict'>
# list 611 is <class 'dict'>
# list 612 is <class 'dict'>
# list 613 is <class 'dict'>
# list 614 is <class 'dict'>
# list 615 is <class 'dict'>
# list 616 is <class 'dict'>
# list 617 is <class 'dict'>
# list 618 is <class 'dict'>
# list 619 is <class 'dict'>
# list 620 is <class 'dict'>
# list 621 is <class 'dict'>
# list 622 is <class 'dict'>
# list 623 is <class 'dict'>
# list 624 is <class 'dict'>
# list 625 is <class 'dict'>
# list 626 is <class 'dict'>
# list 627 is <class 'dict'>
# list 628 is <class 'dict'>
# list 629 is <class 'dict'>
# list 630 is <class 'dict'>
# list 631 is <class 'dict'>
# list 632 is <class 'dict'>
# list 633 is <class 'dict'>
# list 634 is <class 'dict'>
# list 635 is <class 'dict'>
# list 636 is <class 'dict'>
# list 637 is <class 'dict'>
# list 638 is <class 'dict'>
# list 639 is <class 'dict'>
# list 640 is <class 'dict'>
# list 641 is <class 'dict'>
# list 642 is <class 'dict'>
# list 643 is <class 'dict'>
# list 644 is <class 'dict'>
# list 645 is <class 'dict'>
# list 646 is <class 'dict'>
# list 647 is <class 'dict'>
# list 648 is <class 'dict'>
# list 649 is <class 'dict'>
# list 650 is <class 'dict'>
# list 651 is <class 'dict'>
# list 652 is <class 'dict'>
# list 653 is <class 'dict'>
# list 654 is <class 'dict'>
# list 655 is <class 'dict'>
# list 656 is <class 'dict'>
# list 657 is <class 'dict'>
# list 658 is <class 'dict'>
# list 659 is <class 'dict'>
# list 660 is <class 'dict'>
# list 661 is <class 'dict'>
# list 662 is <class 'dict'>
# list 663 is <class 'dict'>
# list 664 is <class 'dict'>
# list 665 is <class 'dict'>
# list 666 is <class 'dict'>
# list 667 is <class 'dict'>
# list 668 is <class 'dict'>
# list 669 is <class 'dict'>
# list 670 is <class 'dict'>
# list 671 is <class 'dict'>
# list 672 is <class 'dict'>
# list 673 is <class 'dict'>
# list 674 is <class 'dict'>
# list 675 is <class 'dict'>
# list 676 is <class 'dict'>
# list 677 is <class 'dict'>
# list 678 is <class 'dict'>
# list 679 is <class 'dict'>
# list 680 is <class 'dict'>
# list 681 is <class 'dict'>
# list 682 is <class 'dict'>
# list 683 is <class 'dict'>
# list 684 is <class 'dict'>
# list 685 is <class 'dict'>
# list 686 is <class 'dict'>
# list 687 is <class 'dict'>
# list 688 is <class 'dict'>
# list 689 is <class 'dict'>
# list 690 is <class 'dict'>
# list 691 is <class 'dict'>
# list 692 is <class 'dict'>
# list 693 is <class 'dict'>
# list 694 is <class 'dict'>
# list 695 is <class 'dict'>
# list 696 is <class 'dict'>
# list 697 is <class 'dict'>
# list 698 is <class 'dict'>
# list 699 is <class 'dict'>
# list 700 is <class 'dict'>
# list 701 is <class 'dict'>
# list 702 is <class 'dict'>
# list 703 is <class 'dict'>
# list 704 is <class 'dict'>
# list 705 is <class 'dict'>
# list 706 is <class 'dict'>
# list 707 is <class 'dict'>
# list 708 is <class 'dict'>
# list 709 is <class 'dict'>
# list 710 is <class 'dict'>
# list 711 is <class 'dict'>
# list 712 is <class 'dict'>
# list 713 is <class 'dict'>
# list 714 is <class 'dict'>
# list 715 is <class 'dict'>
# list 716 is <class 'dict'>
# list 717 is <class 'dict'>
# list 718 is <class 'dict'>
# list 719 is <class 'dict'>
# list 720 is <class 'dict'>
# list 721 is <class 'dict'>
# list 722 is <class 'dict'>
# list 723 is <class 'dict'>
# list 724 is <class 'dict'>
# list 725 is <class 'dict'>
# list 726 is <class 'dict'>
# list 727 is <class 'dict'>
# list 728 is <class 'dict'>
# list 729 is <class 'dict'>
# list 730 is <class 'dict'>
# list 731 is <class 'dict'>
# list 732 is <class 'dict'>
# list 733 is <class 'dict'>
# list 734 is <class 'dict'>
# list 735 is <class 'dict'>
# list 736 is <class 'dict'>
# list 737 is <class 'dict'>
# list 738 is <class 'dict'>

# %% [markdown]
# The oob column consists of dictionaries, so we can access it by looking at the appropriate paths in the jsonviewer for pokedex_dict.

# %%
oob_df = pokemon_df['oob'].apply(pd.Series)
genfamily_df = oob_df['genfamily'].apply(pd.Series)
pokemon_df['generation'] = genfamily_df[0].values
pokemon_df = pokemon_df.drop(columns=['oob'])

pokemon_df
# Out:
#                  hp  atk  def  spa  spd  spe  weight  height   formats  \
# name
# Bulbasaur        45   49   49   65   65   45     6.9     0.7        LC
# Ivysaur          60   62   63   80   80   60    13.0     1.0       NFE
# Venusaur         80   82   83  100  100   80   100.0     2.0      RUBL
# Charmander       39   52   43   60   50   65     8.5     0.6        LC
# Charmeleon       58   64   58   80   65   80    19.0     1.1       NFE
# ...             ...  ...  ...  ...  ...  ...     ...     ...       ...
# Glastrier       100  145  130   65  110   30   800.0     2.2        NU
# Spectrier       100   65   60  145   80  130    44.5     2.0      Uber
# Calyrex         100   80   80   80   80   80     7.7     1.1  Untiered
# Calyrex-Ice     100  165  150   85  130   50   809.1     2.4      Uber
# Calyrex-Shadow  100   85   80  165  100  150    53.6     2.4      Uber
#
#                generation
# name
# Bulbasaur              RB
# Ivysaur                RB
# Venusaur               RB
# Charmander             RB
# Charmeleon             RB
# ...                   ...
# Glastrier              SS
# Spectrier              SS
# Calyrex                SS
# Calyrex-Ice            SS
# Calyrex-Shadow         SS
#
# [739 rows x 10 columns]

# %% [markdown]
# Looks good, let's just make a profile report to make sure there is nothing we missed.

# %%
profile_report = pokemon_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/25 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# There are no problems, so let's move on to the moves dataframe

# %% [markdown]
# <a id='moves_df'></a>
# ### moves_df

# %% [markdown]
# As usual, we need to fetch the section we need from pokedex_dict, using the jsonviewer if necessary.

# %%
moves_df = pd.DataFrame(pokedex_dict['injectRpcs'][1][1]['moves'])
moves_df
# Out:
#                 name isNonstandard      category  power  accuracy  priority  \
# 0               Acid      Standard       Special     40       100         0
# 1            Amnesia      Standard  Non-Damaging      0         0         0
# 2        Aurora Beam      Standard       Special     65       100         0
# 3               Bide        NatDex      Physical      0         0         1
# 4               Bind      Standard      Physical     15        85         0
# ..               ...           ...           ...    ...       ...       ...
# 838    Terrain Pulse      Standard       Special     50       100         0
# 839     Thunder Cage      Standard       Special     80        90         0
# 840  Thunderous Kick      Standard      Physical     90       100         0
# 841      Triple Axel      Standard      Physical     20        90         0
# 842      Wicked Blow      Standard      Physical     80       100         0
#
#      pp                                        description      type flags  \
# 0    30       10% chance to lower the foe(s) Sp. Def by 1.    Poison    []
# 1    20                    Raises the user's Sp. Def by 2.   Psychic    []
# 2    20      10% chance to lower the target's Attack by 1.       Ice    []
# 3    10      Waits 2 turns; deals double the damage taken.    Normal    []
# 4    20        Traps and damages the target for 4-5 turns.    Normal    []
# ..   ..                                                ...       ...   ...
# 838  10       User on terrain: power doubles, type varies.    Normal    []
# 839  15        Traps and damages the target for 4-5 turns.  Electric    []
# 840  10    100% chance to lower the target's Defense by 1.  Fighting    []
# 841  10  Hits 3 times. Each hit can miss, but power rises.       Ice    []
# 842   5                  Always results in a critical hit.      Dark    []
#
#                             genfamily
# 0    [RB, GS, RS, DP, BW, XY, SM, SS]
# 1    [RB, GS, RS, DP, BW, XY, SM, SS]
# 2    [RB, GS, RS, DP, BW, XY, SM, SS]
# 3    [RB, GS, RS, DP, BW, XY, SM, SS]
# 4    [RB, GS, RS, DP, BW, XY, SM, SS]
# ..                                ...
# 838                              [SS]
# 839                              [SS]
# 840                              [SS]
# 841                              [SS]
# 842                              [SS]
#
# [843 rows x 11 columns]

# %% [markdown]
# Importantly, we have another "isNonstandard" column, which tends to be very informative regarding which values I should keep and which I should get rid of.

# %%
moves_df['isNonstandard'].value_counts()
# Out:
# Standard    698
# NatDex      143
# CAP           2
# Name: isNonstandard, dtype: int64

# %% [markdown]
# According to smogon, NatDex and CAP moves can't be used in the standard format, but can only be used legally in the NatDex or CAP formats, so I can remove these moves.
#
# What is flags?  Nothing like last time?

# %%
for index, row in moves_df.iterrows():
    if row['flags'] != []:
        print(row['flags'])

# %% [markdown]
# Indeed, it's nothing.  So we're going to remove NatDex and CAP removes, and then remove the uninformative "isNonstandard", "flags", and "genfamily" columns, while setting the index to move names since that is much more informative than the current integer index.

# %%
moves_df.set_index('name', inplace=True)
moves_df = moves_df.loc[moves_df['isNonstandard'] == 'Standard']
moves_df = moves_df.drop(columns=['isNonstandard', 'flags', 'genfamily'])
moves_df
# Out:
#                      category  power  accuracy  priority  pp  \
# name
# Acid                  Special     40       100         0  30
# Amnesia          Non-Damaging      0         0         0  20
# Aurora Beam           Special     65       100         0  20
# Bind                 Physical     15        85         0  20
# Bite                 Physical     60       100         0  25
# ...                       ...    ...       ...       ...  ..
# Terrain Pulse         Special     50       100         0  10
# Thunder Cage          Special     80        90         0  15
# Thunderous Kick      Physical     90       100         0  10
# Triple Axel          Physical     20        90         0  10
# Wicked Blow          Physical     80       100         0   5
#
#                                                        description      type
# name
# Acid                  10% chance to lower the foe(s) Sp. Def by 1.    Poison
# Amnesia                            Raises the user's Sp. Def by 2.   Psychic
# Aurora Beam          10% chance to lower the target's Attack by 1.       Ice
# Bind                   Traps and damages the target for 4-5 turns.    Normal
# Bite                         30% chance to make the target flinch.      Dark
# ...                                                            ...       ...
# Terrain Pulse         User on terrain: power doubles, type varies.    Normal
# Thunder Cage           Traps and damages the target for 4-5 turns.  Electric
# Thunderous Kick    100% chance to lower the target's Defense by 1.  Fighting
# Triple Axel      Hits 3 times. Each hit can miss, but power rises.       Ice
# Wicked Blow                      Always results in a critical hit.      Dark
#
# [698 rows x 7 columns]

# %% [markdown]
# Now we can use a profile report to tell us what issues there might be:

# %%
profile_report = moves_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/22 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# Some interesting facts:
#
# 1. Move descriptions only have a cardinality of 454, which means many moves have the same description.  This is important for bucketing, but that will happen during EDA.
#
# 2. More moves have zero power (246) than are in the non-damaging category (220), so there must be some other reason for the 26 zero power moves, or some mistake.
#
# 3. Priority is an interesting concept and could also be useful for bucketing, but we will examine it later.
#
# 4. There are a lot of zero accuracy moves which should be looked into.
#
# So first, we should figure out which zero powered moves we need to examine.

# %%
damaging = moves_df.loc[moves_df['category'] != 'Non-Damaging']
zero_damaging = damaging.loc[damaging['power'] == 0]
zero_damaging
# Out:
#                   category  power  accuracy  priority  pp  \
# name
# Counter           Physical      0       100        -5  20
# Night Shade        Special      0       100         0  15
# Seismic Toss      Physical      0       100         0  20
# Super Fang        Physical      0        90         0  10
# Low Kick          Physical      0       100         0  20
# Fissure           Physical      0        30         0   5
# Guillotine        Physical      0        30         0   5
# Horn Drill        Physical      0        30         0   5
# Beat Up           Physical      0       100         0  10
# Flail             Physical      0       100         0  15
# Mirror Coat        Special      0       100        -5  20
# Reversal          Physical      0       100         0  15
# Present           Physical      0        90         0  15
# Endeavor          Physical      0       100         0   5
# Sheer Cold         Special      0        30         0   5
# Spit Up            Special      0       100         0  10
# Crush Grip        Physical      0       100         0   5
# Gyro Ball         Physical      0       100         0   5
# Grass Knot         Special      0       100         0  20
# Fling             Physical      0       100         0  10
# Metal Burst       Physical      0       100         0  10
# Electro Ball       Special      0       100         0  10
# Final Gambit       Special      0       100         0   5
# Heat Crash        Physical      0       100         0  10
# Heavy Slam        Physical      0       100         0  10
# Nature's Madness   Special      0        90         0  10
#
#                                                         description      type
# name
# Counter           If hit by physical attack, returns double damage.  Fighting
# Night Shade                  Does damage equal to the user's level.     Ghost
# Seismic Toss                 Does damage equal to the user's level.  Fighting
# Super Fang            Does damage equal to 1/2 target's current HP.    Normal
# Low Kick                         More power the heavier the target.  Fighting
# Fissure           OHKOs the target. Fails if user is a lower level.    Ground
# Guillotine        OHKOs the target. Fails if user is a lower level.    Normal
# Horn Drill        OHKOs the target. Fails if user is a lower level.    Normal
# Beat Up              All healthy allies aid in damaging the target.      Dark
# Flail                     More power the less HP the user has left.    Normal
# Mirror Coat        If hit by special attack, returns double damage.   Psychic
# Reversal                  More power the less HP the user has left.  Fighting
# Present              40, 80, 120 power, or heals target 1/4 max HP.    Normal
# Endeavor                   Lowers the target's HP to the user's HP.    Normal
# Sheer Cold        OHKOs non-Ice targets. Fails if user's lower l...       Ice
# Spit Up                     More power with more uses of Stockpile.    Normal
# Crush Grip              More power the more HP the target has left.    Normal
# Gyro Ball           More power the slower the user than the target.     Steel
# Grass Knot                       More power the heavier the target.     Grass
# Fling             Flings the user's item at the target. Power va...      Dark
# Metal Burst               If hit by an attack, returns 1.5x damage.     Steel
# Electro Ball      More power the faster the user is than the tar...  Electric
# Final Gambit       Does damage equal to the user's HP. User faints.  Fighting
# Heat Crash         More power the heavier the user than the target.      Fire
# Heavy Slam         More power the heavier the user than the target.     Steel
# Nature's Madness      Does damage equal to 1/2 target's current HP.     Fairy

# %% [markdown]
# These moves are legitimiate; they just have non-standard means of acquiring their power.  So what about zero accuracy moves?  Let's just the non-damaging one's:

# %%
non_damaging = moves_df.loc[moves_df['category'] == 'Non-Damaging']
zero_accurate_non_damaging = non_damaging.loc[non_damaging['accuracy'] == 0]
zero_accurate_non_damaging
# Out:
#                   category  power  accuracy  priority  pp  \
# name
# Amnesia       Non-Damaging      0         0         0  20
# Conversion    Non-Damaging      0         0         0  30
# Focus Energy  Non-Damaging      0         0         0  30
# Growth        Non-Damaging      0         0         0  20
# Haze          Non-Damaging      0         0         0  30
# ...                    ...    ...       ...       ...  ..
# Life Dew      Non-Damaging      0         0         0  10
# Max Guard     Non-Damaging      0         0         4  10
# No Retreat    Non-Damaging      0         0         0   5
# Stuff Cheeks  Non-Damaging      0         0         0  10
# Teatime       Non-Damaging      0         0         0  10
#
#                                                     description      type
# name
# Amnesia                         Raises the user's Sp. Def by 2.   Psychic
# Conversion         Changes user's type to match its first move.    Normal
# Focus Energy         Raises the user's critical hit ratio by 2.    Normal
# Growth         Raises user's Attack and Sp. Atk by 1; 2 in Sun.    Normal
# Haze                               Eliminates all stat changes.       Ice
# ...                                                         ...       ...
# Life Dew      Heals the user and its allies by 1/4 their max...     Water
# Max Guard     Protects user from moves &amp; Max Moves this ...    Normal
# No Retreat     Raises all stats by 1 (not acc/eva). Traps user.  Fighting
# Stuff Cheeks   Must hold Berry to use. User eats Berry, Def +2.    Normal
# Teatime                All active Pokemon consume held Berries.    Normal
#
# [154 rows x 7 columns]

# %% [markdown]
# These appear to be moves which only affect the user or its team, so accuracy just doesn't apply to them.  What about damaging moves with no accuracy?

# %%
zero_accurate_damaging = damaging.loc[damaging['accuracy'] == 0]
zero_accurate_damaging
# Out:
#                 category  power  accuracy  priority  pp  \
# name
# Struggle        Physical     50         0         0   1
# Swift            Special     60         0         0  20
# Vital Throw     Physical     70         0        -1  10
# Aerial Ace      Physical     60         0         0  20
# Magical Leaf     Special     60         0         0  20
# ...                  ...    ...       ...       ...  ..
# Max Rockfall    Physical     10         0         0  10
# Max Starfall    Physical     10         0         0  10
# Max Steelspike  Physical     10         0         0  10
# Max Strike      Physical     10         0         0  10
# Max Wyrmwind    Physical     10         0         0  10
#
#                                                    description      type
# name
# Struggle                         User loses 1/4 of its max HP.    Normal
# Swift            This move does not check accuracy. Hits foes.    Normal
# Vital Throw      This move does not check accuracy. Goes last.  Fighting
# Aerial Ace                  This move does not check accuracy.    Flying
# Magical Leaf                This move does not check accuracy.     Grass
# ...                                                        ...       ...
# Max Rockfall        Base move affects power. Starts Sandstorm.      Rock
# Max Starfall    Base move affects power. Starts Misty Terrain.     Fairy
# Max Steelspike    Base move affects power. Allies: +1 Defense.     Steel
# Max Strike            Base move affects power. Foes: -1 Speed.    Normal
# Max Wyrmwind         Base move affects power. Foes: -1 Attack.    Dragon
#
# [63 rows x 7 columns]

# %% [markdown]
# These are moves which "always hit", and things like accuracy or evasiveness don't affect (Swift is famous for that).  Probably there is no issue here, so we'll just move on.
#
# Next we need to look into the data I scraped from smogon that contains information about the learnsets of each pokemon, as well as the competitive strategies used by these pokemon in generation 8 (the names of those competitive strategies and the movesets that they use).

# %% [markdown]
# <a id='strategydex_df'></a>
# ### strategydex_df

# %%
with open("smogonpokemondata2021/smogonpokemondata2021/scraped_data/PokemonData2021.csv", encoding="utf8") as infile:
    strategydex_df = pd.read_csv(infile)

strategydex_df
# Out:
#                                             pokemonData pokemonName
# 0     {'languages': ['en', 'pt', 'es', 'fr', 'it'], ...   ninetales
# 1     {'languages': ['en'], 'learnset': ['Amnesia', ...   bulbasaur
# 2     {'languages': ['en'], 'learnset': ['Ally Switc...  wigglytuff
# 3     {'languages': ['en'], 'learnset': ['Amnesia', ...    nidorino
# 4     {'languages': ['en'], 'learnset': ['Ally Switc...  jigglypuff
# ...                                                 ...         ...
# 1096  {'languages': ['en'], 'learnset': ['Aqua Jet',...    squirtle
# 1097  {'languages': ['en'], 'learnset': ['Aqua Jet',...   wartortle
# 1098  {'languages': ['en'], 'learnset': ['Acrobatics...  charmeleon
# 1099  {'languages': ['en'], 'learnset': ['Acrobatics...  charmander
# 1100  {'languages': ['en'], 'learnset': ['Amnesia', ...     ivysaur
#
# [1101 rows x 2 columns]

# %%
strategydex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pokemonData  1101 non-null   object
#  1   pokemonName  1101 non-null   object
# dtypes: object(2)
# memory usage: 17.3+ KB

# %% [markdown]
# There appears to be no missing data, which is strange because it looked like there was in the file.  It's certainly a good thing though.  Let's check the format of the pokemonData column, which looks pretty complicated.

# %%
for i, l in enumerate(strategydex_df["pokemonData"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'str'>
# list 1 is <class 'str'>
# list 2 is <class 'str'>
# list 3 is <class 'str'>
# list 4 is <class 'str'>
# list 5 is <class 'str'>
# list 6 is <class 'str'>
# list 7 is <class 'str'>
# list 8 is <class 'str'>
# list 9 is <class 'str'>
# list 10 is <class 'str'>
# list 11 is <class 'str'>
# list 12 is <class 'str'>
# list 13 is <class 'str'>
# list 14 is <class 'str'>
# list 15 is <class 'str'>
# list 16 is <class 'str'>
# list 17 is <class 'str'>
# list 18 is <class 'str'>
# list 19 is <class 'str'>
# list 20 is <class 'str'>
# list 21 is <class 'str'>
# list 22 is <class 'str'>
# list 23 is <class 'str'>
# list 24 is <class 'str'>
# list 25 is <class 'str'>
# list 26 is <class 'str'>
# list 27 is <class 'str'>
# list 28 is <class 'str'>
# list 29 is <class 'str'>
# list 30 is <class 'str'>
# list 31 is <class 'str'>
# list 32 is <class 'str'>
# list 33 is <class 'str'>
# list 34 is <class 'str'>
# list 35 is <class 'str'>
# list 36 is <class 'str'>
# list 37 is <class 'str'>
# list 38 is <class 'str'>
# list 39 is <class 'str'>
# list 40 is <class 'str'>
# list 41 is <class 'str'>
# list 42 is <class 'str'>
# list 43 is <class 'str'>
# list 44 is <class 'str'>
# list 45 is <class 'str'>
# list 46 is <class 'str'>
# list 47 is <class 'str'>
# list 48 is <class 'str'>
# list 49 is <class 'str'>
# list 50 is <class 'str'>
# list 51 is <class 'str'>
# list 52 is <class 'str'>
# list 53 is <class 'str'>
# list 54 is <class 'str'>
# list 55 is <class 'str'>
# list 56 is <class 'str'>
# list 57 is <class 'str'>
# list 58 is <class 'str'>
# list 59 is <class 'str'>
# list 60 is <class 'str'>
# list 61 is <class 'str'>
# list 62 is <class 'str'>
# list 63 is <class 'str'>
# list 64 is <class 'str'>
# list 65 is <class 'str'>
# list 66 is <class 'str'>
# list 67 is <class 'str'>
# list 68 is <class 'str'>
# list 69 is <class 'str'>
# list 70 is <class 'str'>
# list 71 is <class 'str'>
# list 72 is <class 'str'>
# list 73 is <class 'str'>
# list 74 is <class 'str'>
# list 75 is <class 'str'>
# list 76 is <class 'str'>
# list 77 is <class 'str'>
# list 78 is <class 'str'>
# list 79 is <class 'str'>
# list 80 is <class 'str'>
# list 81 is <class 'str'>
# list 82 is <class 'str'>
# list 83 is <class 'str'>
# list 84 is <class 'str'>
# list 85 is <class 'str'>
# list 86 is <class 'str'>
# list 87 is <class 'str'>
# list 88 is <class 'str'>
# list 89 is <class 'str'>
# list 90 is <class 'str'>
# list 91 is <class 'str'>
# list 92 is <class 'str'>
# list 93 is <class 'str'>
# list 94 is <class 'str'>
# list 95 is <class 'str'>
# list 96 is <class 'str'>
# list 97 is <class 'str'>
# list 98 is <class 'str'>
# list 99 is <class 'str'>
# list 100 is <class 'str'>
# list 101 is <class 'str'>
# list 102 is <class 'str'>
# list 103 is <class 'str'>
# list 104 is <class 'str'>
# list 105 is <class 'str'>
# list 106 is <class 'str'>
# list 107 is <class 'str'>
# list 108 is <class 'str'>
# list 109 is <class 'str'>
# list 110 is <class 'str'>
# list 111 is <class 'str'>
# list 112 is <class 'str'>
# list 113 is <class 'str'>
# list 114 is <class 'str'>
# list 115 is <class 'str'>
# list 116 is <class 'str'>
# list 117 is <class 'str'>
# list 118 is <class 'str'>
# list 119 is <class 'str'>
# list 120 is <class 'str'>
# list 121 is <class 'str'>
# list 122 is <class 'str'>
# list 123 is <class 'str'>
# list 124 is <class 'str'>
# list 125 is <class 'str'>
# list 126 is <class 'str'>
# list 127 is <class 'str'>
# list 128 is <class 'str'>
# list 129 is <class 'str'>
# list 130 is <class 'str'>
# list 131 is <class 'str'>
# list 132 is <class 'str'>
# list 133 is <class 'str'>
# list 134 is <class 'str'>
# list 135 is <class 'str'>
# list 136 is <class 'str'>
# list 137 is <class 'str'>
# list 138 is <class 'str'>
# list 139 is <class 'str'>
# list 140 is <class 'str'>
# list 141 is <class 'str'>
# list 142 is <class 'str'>
# list 143 is <class 'str'>
# list 144 is <class 'str'>
# list 145 is <class 'str'>
# list 146 is <class 'str'>
# list 147 is <class 'str'>
# list 148 is <class 'str'>
# list 149 is <class 'str'>
# list 150 is <class 'str'>
# list 151 is <class 'str'>
# list 152 is <class 'str'>
# list 153 is <class 'str'>
# list 154 is <class 'str'>
# list 155 is <class 'str'>
# list 156 is <class 'str'>
# list 157 is <class 'str'>
# list 158 is <class 'str'>
# list 159 is <class 'str'>
# list 160 is <class 'str'>
# list 161 is <class 'str'>
# list 162 is <class 'str'>
# list 163 is <class 'str'>
# list 164 is <class 'str'>
# list 165 is <class 'str'>
# list 166 is <class 'str'>
# list 167 is <class 'str'>
# list 168 is <class 'str'>
# list 169 is <class 'str'>
# list 170 is <class 'str'>
# list 171 is <class 'str'>
# list 172 is <class 'str'>
# list 173 is <class 'str'>
# list 174 is <class 'str'>
# list 175 is <class 'str'>
# list 176 is <class 'str'>
# list 177 is <class 'str'>
# list 178 is <class 'str'>
# list 179 is <class 'str'>
# list 180 is <class 'str'>
# list 181 is <class 'str'>
# list 182 is <class 'str'>
# list 183 is <class 'str'>
# list 184 is <class 'str'>
# list 185 is <class 'str'>
# list 186 is <class 'str'>
# list 187 is <class 'str'>
# list 188 is <class 'str'>
# list 189 is <class 'str'>
# list 190 is <class 'str'>
# list 191 is <class 'str'>
# list 192 is <class 'str'>
# list 193 is <class 'str'>
# list 194 is <class 'str'>
# list 195 is <class 'str'>
# list 196 is <class 'str'>
# list 197 is <class 'str'>
# list 198 is <class 'str'>
# list 199 is <class 'str'>
# list 200 is <class 'str'>
# list 201 is <class 'str'>
# list 202 is <class 'str'>
# list 203 is <class 'str'>
# list 204 is <class 'str'>
# list 205 is <class 'str'>
# list 206 is <class 'str'>
# list 207 is <class 'str'>
# list 208 is <class 'str'>
# list 209 is <class 'str'>
# list 210 is <class 'str'>
# list 211 is <class 'str'>
# list 212 is <class 'str'>
# list 213 is <class 'str'>
# list 214 is <class 'str'>
# list 215 is <class 'str'>
# list 216 is <class 'str'>
# list 217 is <class 'str'>
# list 218 is <class 'str'>
# list 219 is <class 'str'>
# list 220 is <class 'str'>
# list 221 is <class 'str'>
# list 222 is <class 'str'>
# list 223 is <class 'str'>
# list 224 is <class 'str'>
# list 225 is <class 'str'>
# list 226 is <class 'str'>
# list 227 is <class 'str'>
# list 228 is <class 'str'>
# list 229 is <class 'str'>
# list 230 is <class 'str'>
# list 231 is <class 'str'>
# list 232 is <class 'str'>
# list 233 is <class 'str'>
# list 234 is <class 'str'>
# list 235 is <class 'str'>
# list 236 is <class 'str'>
# list 237 is <class 'str'>
# list 238 is <class 'str'>
# list 239 is <class 'str'>
# list 240 is <class 'str'>
# list 241 is <class 'str'>
# list 242 is <class 'str'>
# list 243 is <class 'str'>
# list 244 is <class 'str'>
# list 245 is <class 'str'>
# list 246 is <class 'str'>
# list 247 is <class 'str'>
# list 248 is <class 'str'>
# list 249 is <class 'str'>
# list 250 is <class 'str'>
# list 251 is <class 'str'>
# list 252 is <class 'str'>
# list 253 is <class 'str'>
# list 254 is <class 'str'>
# list 255 is <class 'str'>
# list 256 is <class 'str'>
# list 257 is <class 'str'>
# list 258 is <class 'str'>
# list 259 is <class 'str'>
# list 260 is <class 'str'>
# list 261 is <class 'str'>
# list 262 is <class 'str'>
# list 263 is <class 'str'>
# list 264 is <class 'str'>
# list 265 is <class 'str'>
# list 266 is <class 'str'>
# list 267 is <class 'str'>
# list 268 is <class 'str'>
# list 269 is <class 'str'>
# list 270 is <class 'str'>
# list 271 is <class 'str'>
# list 272 is <class 'str'>
# list 273 is <class 'str'>
# list 274 is <class 'str'>
# list 275 is <class 'str'>
# list 276 is <class 'str'>
# list 277 is <class 'str'>
# list 278 is <class 'str'>
# list 279 is <class 'str'>
# list 280 is <class 'str'>
# list 281 is <class 'str'>
# list 282 is <class 'str'>
# list 283 is <class 'str'>
# list 284 is <class 'str'>
# list 285 is <class 'str'>
# list 286 is <class 'str'>
# list 287 is <class 'str'>
# list 288 is <class 'str'>
# list 289 is <class 'str'>
# list 290 is <class 'str'>
# list 291 is <class 'str'>
# list 292 is <class 'str'>
# list 293 is <class 'str'>
# list 294 is <class 'str'>
# list 295 is <class 'str'>
# list 296 is <class 'str'>
# list 297 is <class 'str'>
# list 298 is <class 'str'>
# list 299 is <class 'str'>
# list 300 is <class 'str'>
# list 301 is <class 'str'>
# list 302 is <class 'str'>
# list 303 is <class 'str'>
# list 304 is <class 'str'>
# list 305 is <class 'str'>
# list 306 is <class 'str'>
# list 307 is <class 'str'>
# list 308 is <class 'str'>
# list 309 is <class 'str'>
# list 310 is <class 'str'>
# list 311 is <class 'str'>
# list 312 is <class 'str'>
# list 313 is <class 'str'>
# list 314 is <class 'str'>
# list 315 is <class 'str'>
# list 316 is <class 'str'>
# list 317 is <class 'str'>
# list 318 is <class 'str'>
# list 319 is <class 'str'>
# list 320 is <class 'str'>
# list 321 is <class 'str'>
# list 322 is <class 'str'>
# list 323 is <class 'str'>
# list 324 is <class 'str'>
# list 325 is <class 'str'>
# list 326 is <class 'str'>
# list 327 is <class 'str'>
# list 328 is <class 'str'>
# list 329 is <class 'str'>
# list 330 is <class 'str'>
# list 331 is <class 'str'>
# list 332 is <class 'str'>
# list 333 is <class 'str'>
# list 334 is <class 'str'>
# list 335 is <class 'str'>
# list 336 is <class 'str'>
# list 337 is <class 'str'>
# list 338 is <class 'str'>
# list 339 is <class 'str'>
# list 340 is <class 'str'>
# list 341 is <class 'str'>
# list 342 is <class 'str'>
# list 343 is <class 'str'>
# list 344 is <class 'str'>
# list 345 is <class 'str'>
# list 346 is <class 'str'>
# list 347 is <class 'str'>
# list 348 is <class 'str'>
# list 349 is <class 'str'>
# list 350 is <class 'str'>
# list 351 is <class 'str'>
# list 352 is <class 'str'>
# list 353 is <class 'str'>
# list 354 is <class 'str'>
# list 355 is <class 'str'>
# list 356 is <class 'str'>
# list 357 is <class 'str'>
# list 358 is <class 'str'>
# list 359 is <class 'str'>
# list 360 is <class 'str'>
# list 361 is <class 'str'>
# list 362 is <class 'str'>
# list 363 is <class 'str'>
# list 364 is <class 'str'>
# list 365 is <class 'str'>
# list 366 is <class 'str'>
# list 367 is <class 'str'>
# list 368 is <class 'str'>
# list 369 is <class 'str'>
# list 370 is <class 'str'>
# list 371 is <class 'str'>
# list 372 is <class 'str'>
# list 373 is <class 'str'>
# list 374 is <class 'str'>
# list 375 is <class 'str'>
# list 376 is <class 'str'>
# list 377 is <class 'str'>
# list 378 is <class 'str'>
# list 379 is <class 'str'>
# list 380 is <class 'str'>
# list 381 is <class 'str'>
# list 382 is <class 'str'>
# list 383 is <class 'str'>
# list 384 is <class 'str'>
# list 385 is <class 'str'>
# list 386 is <class 'str'>
# list 387 is <class 'str'>
# list 388 is <class 'str'>
# list 389 is <class 'str'>
# list 390 is <class 'str'>
# list 391 is <class 'str'>
# list 392 is <class 'str'>
# list 393 is <class 'str'>
# list 394 is <class 'str'>
# list 395 is <class 'str'>
# list 396 is <class 'str'>
# list 397 is <class 'str'>
# list 398 is <class 'str'>
# list 399 is <class 'str'>
# list 400 is <class 'str'>
# list 401 is <class 'str'>
# list 402 is <class 'str'>
# list 403 is <class 'str'>
# list 404 is <class 'str'>
# list 405 is <class 'str'>
# list 406 is <class 'str'>
# list 407 is <class 'str'>
# list 408 is <class 'str'>
# list 409 is <class 'str'>
# list 410 is <class 'str'>
# list 411 is <class 'str'>
# list 412 is <class 'str'>
# list 413 is <class 'str'>
# list 414 is <class 'str'>
# list 415 is <class 'str'>
# list 416 is <class 'str'>
# list 417 is <class 'str'>
# list 418 is <class 'str'>
# list 419 is <class 'str'>
# list 420 is <class 'str'>
# list 421 is <class 'str'>
# list 422 is <class 'str'>
# list 423 is <class 'str'>
# list 424 is <class 'str'>
# list 425 is <class 'str'>
# list 426 is <class 'str'>
# list 427 is <class 'str'>
# list 428 is <class 'str'>
# list 429 is <class 'str'>
# list 430 is <class 'str'>
# list 431 is <class 'str'>
# list 432 is <class 'str'>
# list 433 is <class 'str'>
# list 434 is <class 'str'>
# list 435 is <class 'str'>
# list 436 is <class 'str'>
# list 437 is <class 'str'>
# list 438 is <class 'str'>
# list 439 is <class 'str'>
# list 440 is <class 'str'>
# list 441 is <class 'str'>
# list 442 is <class 'str'>
# list 443 is <class 'str'>
# list 444 is <class 'str'>
# list 445 is <class 'str'>
# list 446 is <class 'str'>
# list 447 is <class 'str'>
# list 448 is <class 'str'>
# list 449 is <class 'str'>
# list 450 is <class 'str'>
# list 451 is <class 'str'>
# list 452 is <class 'str'>
# list 453 is <class 'str'>
# list 454 is <class 'str'>
# list 455 is <class 'str'>
# list 456 is <class 'str'>
# list 457 is <class 'str'>
# list 458 is <class 'str'>
# list 459 is <class 'str'>
# list 460 is <class 'str'>
# list 461 is <class 'str'>
# list 462 is <class 'str'>
# list 463 is <class 'str'>
# list 464 is <class 'str'>
# list 465 is <class 'str'>
# list 466 is <class 'str'>
# list 467 is <class 'str'>
# list 468 is <class 'str'>
# list 469 is <class 'str'>
# list 470 is <class 'str'>
# list 471 is <class 'str'>
# list 472 is <class 'str'>
# list 473 is <class 'str'>
# list 474 is <class 'str'>
# list 475 is <class 'str'>
# list 476 is <class 'str'>
# list 477 is <class 'str'>
# list 478 is <class 'str'>
# list 479 is <class 'str'>
# list 480 is <class 'str'>
# list 481 is <class 'str'>
# list 482 is <class 'str'>
# list 483 is <class 'str'>
# list 484 is <class 'str'>
# list 485 is <class 'str'>
# list 486 is <class 'str'>
# list 487 is <class 'str'>
# list 488 is <class 'str'>
# list 489 is <class 'str'>
# list 490 is <class 'str'>
# list 491 is <class 'str'>
# list 492 is <class 'str'>
# list 493 is <class 'str'>
# list 494 is <class 'str'>
# list 495 is <class 'str'>
# list 496 is <class 'str'>
# list 497 is <class 'str'>
# list 498 is <class 'str'>
# list 499 is <class 'str'>
# list 500 is <class 'str'>
# list 501 is <class 'str'>
# list 502 is <class 'str'>
# list 503 is <class 'str'>
# list 504 is <class 'str'>
# list 505 is <class 'str'>
# list 506 is <class 'str'>
# list 507 is <class 'str'>
# list 508 is <class 'str'>
# list 509 is <class 'str'>
# list 510 is <class 'str'>
# list 511 is <class 'str'>
# list 512 is <class 'str'>
# list 513 is <class 'str'>
# list 514 is <class 'str'>
# list 515 is <class 'str'>
# list 516 is <class 'str'>
# list 517 is <class 'str'>
# list 518 is <class 'str'>
# list 519 is <class 'str'>
# list 520 is <class 'str'>
# list 521 is <class 'str'>
# list 522 is <class 'str'>
# list 523 is <class 'str'>
# list 524 is <class 'str'>
# list 525 is <class 'str'>
# list 526 is <class 'str'>
# list 527 is <class 'str'>
# list 528 is <class 'str'>
# list 529 is <class 'str'>
# list 530 is <class 'str'>
# list 531 is <class 'str'>
# list 532 is <class 'str'>
# list 533 is <class 'str'>
# list 534 is <class 'str'>
# list 535 is <class 'str'>
# list 536 is <class 'str'>
# list 537 is <class 'str'>
# list 538 is <class 'str'>
# list 539 is <class 'str'>
# list 540 is <class 'str'>
# list 541 is <class 'str'>
# list 542 is <class 'str'>
# list 543 is <class 'str'>
# list 544 is <class 'str'>
# list 545 is <class 'str'>
# list 546 is <class 'str'>
# list 547 is <class 'str'>
# list 548 is <class 'str'>
# list 549 is <class 'str'>
# list 550 is <class 'str'>
# list 551 is <class 'str'>
# list 552 is <class 'str'>
# list 553 is <class 'str'>
# list 554 is <class 'str'>
# list 555 is <class 'str'>
# list 556 is <class 'str'>
# list 557 is <class 'str'>
# list 558 is <class 'str'>
# list 559 is <class 'str'>
# list 560 is <class 'str'>
# list 561 is <class 'str'>
# list 562 is <class 'str'>
# list 563 is <class 'str'>
# list 564 is <class 'str'>
# list 565 is <class 'str'>
# list 566 is <class 'str'>
# list 567 is <class 'str'>
# list 568 is <class 'str'>
# list 569 is <class 'str'>
# list 570 is <class 'str'>
# list 571 is <class 'str'>
# list 572 is <class 'str'>
# list 573 is <class 'str'>
# list 574 is <class 'str'>
# list 575 is <class 'str'>
# list 576 is <class 'str'>
# list 577 is <class 'str'>
# list 578 is <class 'str'>
# list 579 is <class 'str'>
# list 580 is <class 'str'>
# list 581 is <class 'str'>
# list 582 is <class 'str'>
# list 583 is <class 'str'>
# list 584 is <class 'str'>
# list 585 is <class 'str'>
# list 586 is <class 'str'>
# list 587 is <class 'str'>
# list 588 is <class 'str'>
# list 589 is <class 'str'>
# list 590 is <class 'str'>
# list 591 is <class 'str'>
# list 592 is <class 'str'>
# list 593 is <class 'str'>
# list 594 is <class 'str'>
# list 595 is <class 'str'>
# list 596 is <class 'str'>
# list 597 is <class 'str'>
# list 598 is <class 'str'>
# list 599 is <class 'str'>
# list 600 is <class 'str'>
# list 601 is <class 'str'>
# list 602 is <class 'str'>
# list 603 is <class 'str'>
# list 604 is <class 'str'>
# list 605 is <class 'str'>
# list 606 is <class 'str'>
# list 607 is <class 'str'>
# list 608 is <class 'str'>
# list 609 is <class 'str'>
# list 610 is <class 'str'>
# list 611 is <class 'str'>
# list 612 is <class 'str'>
# list 613 is <class 'str'>
# list 614 is <class 'str'>
# list 615 is <class 'str'>
# list 616 is <class 'str'>
# list 617 is <class 'str'>
# list 618 is <class 'str'>
# list 619 is <class 'str'>
# list 620 is <class 'str'>
# list 621 is <class 'str'>
# list 622 is <class 'str'>
# list 623 is <class 'str'>
# list 624 is <class 'str'>
# list 625 is <class 'str'>
# list 626 is <class 'str'>
# list 627 is <class 'str'>
# list 628 is <class 'str'>
# list 629 is <class 'str'>
# list 630 is <class 'str'>
# list 631 is <class 'str'>
# list 632 is <class 'str'>
# list 633 is <class 'str'>
# list 634 is <class 'str'>
# list 635 is <class 'str'>
# list 636 is <class 'str'>
# list 637 is <class 'str'>
# list 638 is <class 'str'>
# list 639 is <class 'str'>
# list 640 is <class 'str'>
# list 641 is <class 'str'>
# list 642 is <class 'str'>
# list 643 is <class 'str'>
# list 644 is <class 'str'>
# list 645 is <class 'str'>
# list 646 is <class 'str'>
# list 647 is <class 'str'>
# list 648 is <class 'str'>
# list 649 is <class 'str'>
# list 650 is <class 'str'>
# list 651 is <class 'str'>
# list 652 is <class 'str'>
# list 653 is <class 'str'>
# list 654 is <class 'str'>
# list 655 is <class 'str'>
# list 656 is <class 'str'>
# list 657 is <class 'str'>
# list 658 is <class 'str'>
# list 659 is <class 'str'>
# list 660 is <class 'str'>
# list 661 is <class 'str'>
# list 662 is <class 'str'>
# list 663 is <class 'str'>
# list 664 is <class 'str'>
# list 665 is <class 'str'>
# list 666 is <class 'str'>
# list 667 is <class 'str'>
# list 668 is <class 'str'>
# list 669 is <class 'str'>
# list 670 is <class 'str'>
# list 671 is <class 'str'>
# list 672 is <class 'str'>
# list 673 is <class 'str'>
# list 674 is <class 'str'>
# list 675 is <class 'str'>
# list 676 is <class 'str'>
# list 677 is <class 'str'>
# list 678 is <class 'str'>
# list 679 is <class 'str'>
# list 680 is <class 'str'>
# list 681 is <class 'str'>
# list 682 is <class 'str'>
# list 683 is <class 'str'>
# list 684 is <class 'str'>
# list 685 is <class 'str'>
# list 686 is <class 'str'>
# list 687 is <class 'str'>
# list 688 is <class 'str'>
# list 689 is <class 'str'>
# list 690 is <class 'str'>
# list 691 is <class 'str'>
# list 692 is <class 'str'>
# list 693 is <class 'str'>
# list 694 is <class 'str'>
# list 695 is <class 'str'>
# list 696 is <class 'str'>
# list 697 is <class 'str'>
# list 698 is <class 'str'>
# list 699 is <class 'str'>
# list 700 is <class 'str'>
# list 701 is <class 'str'>
# list 702 is <class 'str'>
# list 703 is <class 'str'>
# list 704 is <class 'str'>
# list 705 is <class 'str'>
# list 706 is <class 'str'>
# list 707 is <class 'str'>
# list 708 is <class 'str'>
# list 709 is <class 'str'>
# list 710 is <class 'str'>
# list 711 is <class 'str'>
# list 712 is <class 'str'>
# list 713 is <class 'str'>
# list 714 is <class 'str'>
# list 715 is <class 'str'>
# list 716 is <class 'str'>
# list 717 is <class 'str'>
# list 718 is <class 'str'>
# list 719 is <class 'str'>
# list 720 is <class 'str'>
# list 721 is <class 'str'>
# list 722 is <class 'str'>
# list 723 is <class 'str'>
# list 724 is <class 'str'>
# list 725 is <class 'str'>
# list 726 is <class 'str'>
# list 727 is <class 'str'>
# list 728 is <class 'str'>
# list 729 is <class 'str'>
# list 730 is <class 'str'>
# list 731 is <class 'str'>
# list 732 is <class 'str'>
# list 733 is <class 'str'>
# list 734 is <class 'str'>
# list 735 is <class 'str'>
# list 736 is <class 'str'>
# list 737 is <class 'str'>
# list 738 is <class 'str'>
# list 739 is <class 'str'>
# list 740 is <class 'str'>
# list 741 is <class 'str'>
# list 742 is <class 'str'>
# list 743 is <class 'str'>
# list 744 is <class 'str'>
# list 745 is <class 'str'>
# list 746 is <class 'str'>
# list 747 is <class 'str'>
# list 748 is <class 'str'>
# list 749 is <class 'str'>
# list 750 is <class 'str'>
# list 751 is <class 'str'>
# list 752 is <class 'str'>
# list 753 is <class 'str'>
# list 754 is <class 'str'>
# list 755 is <class 'str'>
# list 756 is <class 'str'>
# list 757 is <class 'str'>
# list 758 is <class 'str'>
# list 759 is <class 'str'>
# list 760 is <class 'str'>
# list 761 is <class 'str'>
# list 762 is <class 'str'>
# list 763 is <class 'str'>
# list 764 is <class 'str'>
# list 765 is <class 'str'>
# list 766 is <class 'str'>
# list 767 is <class 'str'>
# list 768 is <class 'str'>
# list 769 is <class 'str'>
# list 770 is <class 'str'>
# list 771 is <class 'str'>
# list 772 is <class 'str'>
# list 773 is <class 'str'>
# list 774 is <class 'str'>
# list 775 is <class 'str'>
# list 776 is <class 'str'>
# list 777 is <class 'str'>
# list 778 is <class 'str'>
# list 779 is <class 'str'>
# list 780 is <class 'str'>
# list 781 is <class 'str'>
# list 782 is <class 'str'>
# list 783 is <class 'str'>
# list 784 is <class 'str'>
# list 785 is <class 'str'>
# list 786 is <class 'str'>
# list 787 is <class 'str'>
# list 788 is <class 'str'>
# list 789 is <class 'str'>
# list 790 is <class 'str'>
# list 791 is <class 'str'>
# list 792 is <class 'str'>
# list 793 is <class 'str'>
# list 794 is <class 'str'>
# list 795 is <class 'str'>
# list 796 is <class 'str'>
# list 797 is <class 'str'>
# list 798 is <class 'str'>
# list 799 is <class 'str'>
# list 800 is <class 'str'>
# list 801 is <class 'str'>
# list 802 is <class 'str'>
# list 803 is <class 'str'>
# list 804 is <class 'str'>
# list 805 is <class 'str'>
# list 806 is <class 'str'>
# list 807 is <class 'str'>
# list 808 is <class 'str'>
# list 809 is <class 'str'>
# list 810 is <class 'str'>
# list 811 is <class 'str'>
# list 812 is <class 'str'>
# list 813 is <class 'str'>
# list 814 is <class 'str'>
# list 815 is <class 'str'>
# list 816 is <class 'str'>
# list 817 is <class 'str'>
# list 818 is <class 'str'>
# list 819 is <class 'str'>
# list 820 is <class 'str'>
# list 821 is <class 'str'>
# list 822 is <class 'str'>
# list 823 is <class 'str'>
# list 824 is <class 'str'>
# list 825 is <class 'str'>
# list 826 is <class 'str'>
# list 827 is <class 'str'>
# list 828 is <class 'str'>
# list 829 is <class 'str'>
# list 830 is <class 'str'>
# list 831 is <class 'str'>
# list 832 is <class 'str'>
# list 833 is <class 'str'>
# list 834 is <class 'str'>
# list 835 is <class 'str'>
# list 836 is <class 'str'>
# list 837 is <class 'str'>
# list 838 is <class 'str'>
# list 839 is <class 'str'>
# list 840 is <class 'str'>
# list 841 is <class 'str'>
# list 842 is <class 'str'>
# list 843 is <class 'str'>
# list 844 is <class 'str'>
# list 845 is <class 'str'>
# list 846 is <class 'str'>
# list 847 is <class 'str'>
# list 848 is <class 'str'>
# list 849 is <class 'str'>
# list 850 is <class 'str'>
# list 851 is <class 'str'>
# list 852 is <class 'str'>
# list 853 is <class 'str'>
# list 854 is <class 'str'>
# list 855 is <class 'str'>
# list 856 is <class 'str'>
# list 857 is <class 'str'>
# list 858 is <class 'str'>
# list 859 is <class 'str'>
# list 860 is <class 'str'>
# list 861 is <class 'str'>
# list 862 is <class 'str'>
# list 863 is <class 'str'>
# list 864 is <class 'str'>
# list 865 is <class 'str'>
# list 866 is <class 'str'>
# list 867 is <class 'str'>
# list 868 is <class 'str'>
# list 869 is <class 'str'>
# list 870 is <class 'str'>
# list 871 is <class 'str'>
# list 872 is <class 'str'>
# list 873 is <class 'str'>
# list 874 is <class 'str'>
# list 875 is <class 'str'>
# list 876 is <class 'str'>
# list 877 is <class 'str'>
# list 878 is <class 'str'>
# list 879 is <class 'str'>
# list 880 is <class 'str'>
# list 881 is <class 'str'>
# list 882 is <class 'str'>
# list 883 is <class 'str'>
# list 884 is <class 'str'>
# list 885 is <class 'str'>
# list 886 is <class 'str'>
# list 887 is <class 'str'>
# list 888 is <class 'str'>
# list 889 is <class 'str'>
# list 890 is <class 'str'>
# list 891 is <class 'str'>
# list 892 is <class 'str'>
# list 893 is <class 'str'>
# list 894 is <class 'str'>
# list 895 is <class 'str'>
# list 896 is <class 'str'>
# list 897 is <class 'str'>
# list 898 is <class 'str'>
# list 899 is <class 'str'>
# list 900 is <class 'str'>
# list 901 is <class 'str'>
# list 902 is <class 'str'>
# list 903 is <class 'str'>
# list 904 is <class 'str'>
# list 905 is <class 'str'>
# list 906 is <class 'str'>
# list 907 is <class 'str'>
# list 908 is <class 'str'>
# list 909 is <class 'str'>
# list 910 is <class 'str'>
# list 911 is <class 'str'>
# list 912 is <class 'str'>
# list 913 is <class 'str'>
# list 914 is <class 'str'>
# list 915 is <class 'str'>
# list 916 is <class 'str'>
# list 917 is <class 'str'>
# list 918 is <class 'str'>
# list 919 is <class 'str'>
# list 920 is <class 'str'>
# list 921 is <class 'str'>
# list 922 is <class 'str'>
# list 923 is <class 'str'>
# list 924 is <class 'str'>
# list 925 is <class 'str'>
# list 926 is <class 'str'>
# list 927 is <class 'str'>
# list 928 is <class 'str'>
# list 929 is <class 'str'>
# list 930 is <class 'str'>
# list 931 is <class 'str'>
# list 932 is <class 'str'>
# list 933 is <class 'str'>
# list 934 is <class 'str'>
# list 935 is <class 'str'>
# list 936 is <class 'str'>
# list 937 is <class 'str'>
# list 938 is <class 'str'>
# list 939 is <class 'str'>
# list 940 is <class 'str'>
# list 941 is <class 'str'>
# list 942 is <class 'str'>
# list 943 is <class 'str'>
# list 944 is <class 'str'>
# list 945 is <class 'str'>
# list 946 is <class 'str'>
# list 947 is <class 'str'>
# list 948 is <class 'str'>
# list 949 is <class 'str'>
# list 950 is <class 'str'>
# list 951 is <class 'str'>
# list 952 is <class 'str'>
# list 953 is <class 'str'>
# list 954 is <class 'str'>
# list 955 is <class 'str'>
# list 956 is <class 'str'>
# list 957 is <class 'str'>
# list 958 is <class 'str'>
# list 959 is <class 'str'>
# list 960 is <class 'str'>
# list 961 is <class 'str'>
# list 962 is <class 'str'>
# list 963 is <class 'str'>
# list 964 is <class 'str'>
# list 965 is <class 'str'>
# list 966 is <class 'str'>
# list 967 is <class 'str'>
# list 968 is <class 'str'>
# list 969 is <class 'str'>
# list 970 is <class 'str'>
# list 971 is <class 'str'>
# list 972 is <class 'str'>
# list 973 is <class 'str'>
# list 974 is <class 'str'>
# list 975 is <class 'str'>
# list 976 is <class 'str'>
# list 977 is <class 'str'>
# list 978 is <class 'str'>
# list 979 is <class 'str'>
# list 980 is <class 'str'>
# list 981 is <class 'str'>
# list 982 is <class 'str'>
# list 983 is <class 'str'>
# list 984 is <class 'str'>
# list 985 is <class 'str'>
# list 986 is <class 'str'>
# list 987 is <class 'str'>
# list 988 is <class 'str'>
# list 989 is <class 'str'>
# list 990 is <class 'str'>
# list 991 is <class 'str'>
# list 992 is <class 'str'>
# list 993 is <class 'str'>
# list 994 is <class 'str'>
# list 995 is <class 'str'>
# list 996 is <class 'str'>
# list 997 is <class 'str'>
# list 998 is <class 'str'>
# list 999 is <class 'str'>
# list 1000 is <class 'str'>
# list 1001 is <class 'str'>
# list 1002 is <class 'str'>
# list 1003 is <class 'str'>
# list 1004 is <class 'str'>
# list 1005 is <class 'str'>
# list 1006 is <class 'str'>
# list 1007 is <class 'str'>
# list 1008 is <class 'str'>
# list 1009 is <class 'str'>
# list 1010 is <class 'str'>
# list 1011 is <class 'str'>
# list 1012 is <class 'str'>
# list 1013 is <class 'str'>
# list 1014 is <class 'str'>
# list 1015 is <class 'str'>
# list 1016 is <class 'str'>
# list 1017 is <class 'str'>
# list 1018 is <class 'str'>
# list 1019 is <class 'str'>
# list 1020 is <class 'str'>
# list 1021 is <class 'str'>
# list 1022 is <class 'str'>
# list 1023 is <class 'str'>
# list 1024 is <class 'str'>
# list 1025 is <class 'str'>
# list 1026 is <class 'str'>
# list 1027 is <class 'str'>
# list 1028 is <class 'str'>
# list 1029 is <class 'str'>
# list 1030 is <class 'str'>
# list 1031 is <class 'str'>
# list 1032 is <class 'str'>
# list 1033 is <class 'str'>
# list 1034 is <class 'str'>
# list 1035 is <class 'str'>
# list 1036 is <class 'str'>
# list 1037 is <class 'str'>
# list 1038 is <class 'str'>
# list 1039 is <class 'str'>
# list 1040 is <class 'str'>
# list 1041 is <class 'str'>
# list 1042 is <class 'str'>
# list 1043 is <class 'str'>
# list 1044 is <class 'str'>
# list 1045 is <class 'str'>
# list 1046 is <class 'str'>
# list 1047 is <class 'str'>
# list 1048 is <class 'str'>
# list 1049 is <class 'str'>
# list 1050 is <class 'str'>
# list 1051 is <class 'str'>
# list 1052 is <class 'str'>
# list 1053 is <class 'str'>
# list 1054 is <class 'str'>
# list 1055 is <class 'str'>
# list 1056 is <class 'str'>
# list 1057 is <class 'str'>
# list 1058 is <class 'str'>
# list 1059 is <class 'str'>
# list 1060 is <class 'str'>
# list 1061 is <class 'str'>
# list 1062 is <class 'str'>
# list 1063 is <class 'str'>
# list 1064 is <class 'str'>
# list 1065 is <class 'str'>
# list 1066 is <class 'str'>
# list 1067 is <class 'str'>
# list 1068 is <class 'str'>
# list 1069 is <class 'str'>
# list 1070 is <class 'str'>
# list 1071 is <class 'str'>
# list 1072 is <class 'str'>
# list 1073 is <class 'str'>
# list 1074 is <class 'str'>
# list 1075 is <class 'str'>
# list 1076 is <class 'str'>
# list 1077 is <class 'str'>
# list 1078 is <class 'str'>
# list 1079 is <class 'str'>
# list 1080 is <class 'str'>
# list 1081 is <class 'str'>
# list 1082 is <class 'str'>
# list 1083 is <class 'str'>
# list 1084 is <class 'str'>
# list 1085 is <class 'str'>
# list 1086 is <class 'str'>
# list 1087 is <class 'str'>
# list 1088 is <class 'str'>
# list 1089 is <class 'str'>
# list 1090 is <class 'str'>
# list 1091 is <class 'str'>
# list 1092 is <class 'str'>
# list 1093 is <class 'str'>
# list 1094 is <class 'str'>
# list 1095 is <class 'str'>
# list 1096 is <class 'str'>
# list 1097 is <class 'str'>
# list 1098 is <class 'str'>
# list 1099 is <class 'str'>
# list 1100 is <class 'str'>

# %% [markdown]
# These are strings, and unfortunately they were extremely messy to clean up!  We need them in the form of JSON or dictionary-like structures, but this requires having the right quotation marks in the right places (" instead of ') and cleaning out many other mistakes and html code with regex's.  Putting the whole process in this notebook of the experimentation which lead me to decide what string replacements to make would be a waste of time and space, so if you are interested in that, please visit [data_wrangling_experiments](./data_wrangling_experiments.ipynb#strategydex_df_1) (go to the "strategydex_df experiments" section if it doesn't take you there directly).  For now, I'm just going to put the result of that extensive experimentation to the find the right aspects to replace of these complicated strings, and instead I'll give you my results which worked.

# %%
with open("smogonpokemondata2021/smogonpokemondata2021/scraped_data/PokemonData2021.csv", encoding="utf8") as infile:
    strategydex_df = pd.read_csv(infile)

strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('<p>.+?<\/p>', '', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('<section>.+?<\/section>', '', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('<h1>.+?<\/h1>', '', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('\\\\n', '', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace("\'", '\"')
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('King\"s', "King\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Maki\"s', "Maki\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Land\"s', "Land\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Dragon\"s', "Dragon\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Sirfetch\"d', "Sirfetch\'d")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Farfetch\"d', "Farfetch\'d")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Nature\"s', "Nature\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Forest\"s', "Forest\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('drampa\"s', "drampa\'s")
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('False', '\"\"')
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('True', '\"\"')
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('None', '\"\"')
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('\"\"\"\s', '\"', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('<ul>.+?<\/ul', '', regex=True)
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Swipe', 'False Swipe') #newline
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].str.replace('Surrender', 'False Surrender') #newline
strategydex_df['pokemonData'] = strategydex_df['pokemonData'].apply(json.loads)
for i, l in enumerate(strategydex_df["pokemonData"]):
    print("list",i,"is",type(l))
# Out:
# list 0 is <class 'dict'>
# list 1 is <class 'dict'>
# list 2 is <class 'dict'>
# list 3 is <class 'dict'>
# list 4 is <class 'dict'>
# list 5 is <class 'dict'>
# list 6 is <class 'dict'>
# list 7 is <class 'dict'>
# list 8 is <class 'dict'>
# list 9 is <class 'dict'>
# list 10 is <class 'dict'>
# list 11 is <class 'dict'>
# list 12 is <class 'dict'>
# list 13 is <class 'dict'>
# list 14 is <class 'dict'>
# list 15 is <class 'dict'>
# list 16 is <class 'dict'>
# list 17 is <class 'dict'>
# list 18 is <class 'dict'>
# list 19 is <class 'dict'>
# list 20 is <class 'dict'>
# list 21 is <class 'dict'>
# list 22 is <class 'dict'>
# list 23 is <class 'dict'>
# list 24 is <class 'dict'>
# list 25 is <class 'dict'>
# list 26 is <class 'dict'>
# list 27 is <class 'dict'>
# list 28 is <class 'dict'>
# list 29 is <class 'dict'>
# list 30 is <class 'dict'>
# list 31 is <class 'dict'>
# list 32 is <class 'dict'>
# list 33 is <class 'dict'>
# list 34 is <class 'dict'>
# list 35 is <class 'dict'>
# list 36 is <class 'dict'>
# list 37 is <class 'dict'>
# list 38 is <class 'dict'>
# list 39 is <class 'dict'>
# list 40 is <class 'dict'>
# list 41 is <class 'dict'>
# list 42 is <class 'dict'>
# list 43 is <class 'dict'>
# list 44 is <class 'dict'>
# list 45 is <class 'dict'>
# list 46 is <class 'dict'>
# list 47 is <class 'dict'>
# list 48 is <class 'dict'>
# list 49 is <class 'dict'>
# list 50 is <class 'dict'>
# list 51 is <class 'dict'>
# list 52 is <class 'dict'>
# list 53 is <class 'dict'>
# list 54 is <class 'dict'>
# list 55 is <class 'dict'>
# list 56 is <class 'dict'>
# list 57 is <class 'dict'>
# list 58 is <class 'dict'>
# list 59 is <class 'dict'>
# list 60 is <class 'dict'>
# list 61 is <class 'dict'>
# list 62 is <class 'dict'>
# list 63 is <class 'dict'>
# list 64 is <class 'dict'>
# list 65 is <class 'dict'>
# list 66 is <class 'dict'>
# list 67 is <class 'dict'>
# list 68 is <class 'dict'>
# list 69 is <class 'dict'>
# list 70 is <class 'dict'>
# list 71 is <class 'dict'>
# list 72 is <class 'dict'>
# list 73 is <class 'dict'>
# list 74 is <class 'dict'>
# list 75 is <class 'dict'>
# list 76 is <class 'dict'>
# list 77 is <class 'dict'>
# list 78 is <class 'dict'>
# list 79 is <class 'dict'>
# list 80 is <class 'dict'>
# list 81 is <class 'dict'>
# list 82 is <class 'dict'>
# list 83 is <class 'dict'>
# list 84 is <class 'dict'>
# list 85 is <class 'dict'>
# list 86 is <class 'dict'>
# list 87 is <class 'dict'>
# list 88 is <class 'dict'>
# list 89 is <class 'dict'>
# list 90 is <class 'dict'>
# list 91 is <class 'dict'>
# list 92 is <class 'dict'>
# list 93 is <class 'dict'>
# list 94 is <class 'dict'>
# list 95 is <class 'dict'>
# list 96 is <class 'dict'>
# list 97 is <class 'dict'>
# list 98 is <class 'dict'>
# list 99 is <class 'dict'>
# list 100 is <class 'dict'>
# list 101 is <class 'dict'>
# list 102 is <class 'dict'>
# list 103 is <class 'dict'>
# list 104 is <class 'dict'>
# list 105 is <class 'dict'>
# list 106 is <class 'dict'>
# list 107 is <class 'dict'>
# list 108 is <class 'dict'>
# list 109 is <class 'dict'>
# list 110 is <class 'dict'>
# list 111 is <class 'dict'>
# list 112 is <class 'dict'>
# list 113 is <class 'dict'>
# list 114 is <class 'dict'>
# list 115 is <class 'dict'>
# list 116 is <class 'dict'>
# list 117 is <class 'dict'>
# list 118 is <class 'dict'>
# list 119 is <class 'dict'>
# list 120 is <class 'dict'>
# list 121 is <class 'dict'>
# list 122 is <class 'dict'>
# list 123 is <class 'dict'>
# list 124 is <class 'dict'>
# list 125 is <class 'dict'>
# list 126 is <class 'dict'>
# list 127 is <class 'dict'>
# list 128 is <class 'dict'>
# list 129 is <class 'dict'>
# list 130 is <class 'dict'>
# list 131 is <class 'dict'>
# list 132 is <class 'dict'>
# list 133 is <class 'dict'>
# list 134 is <class 'dict'>
# list 135 is <class 'dict'>
# list 136 is <class 'dict'>
# list 137 is <class 'dict'>
# list 138 is <class 'dict'>
# list 139 is <class 'dict'>
# list 140 is <class 'dict'>
# list 141 is <class 'dict'>
# list 142 is <class 'dict'>
# list 143 is <class 'dict'>
# list 144 is <class 'dict'>
# list 145 is <class 'dict'>
# list 146 is <class 'dict'>
# list 147 is <class 'dict'>
# list 148 is <class 'dict'>
# list 149 is <class 'dict'>
# list 150 is <class 'dict'>
# list 151 is <class 'dict'>
# list 152 is <class 'dict'>
# list 153 is <class 'dict'>
# list 154 is <class 'dict'>
# list 155 is <class 'dict'>
# list 156 is <class 'dict'>
# list 157 is <class 'dict'>
# list 158 is <class 'dict'>
# list 159 is <class 'dict'>
# list 160 is <class 'dict'>
# list 161 is <class 'dict'>
# list 162 is <class 'dict'>
# list 163 is <class 'dict'>
# list 164 is <class 'dict'>
# list 165 is <class 'dict'>
# list 166 is <class 'dict'>
# list 167 is <class 'dict'>
# list 168 is <class 'dict'>
# list 169 is <class 'dict'>
# list 170 is <class 'dict'>
# list 171 is <class 'dict'>
# list 172 is <class 'dict'>
# list 173 is <class 'dict'>
# list 174 is <class 'dict'>
# list 175 is <class 'dict'>
# list 176 is <class 'dict'>
# list 177 is <class 'dict'>
# list 178 is <class 'dict'>
# list 179 is <class 'dict'>
# list 180 is <class 'dict'>
# list 181 is <class 'dict'>
# list 182 is <class 'dict'>
# list 183 is <class 'dict'>
# list 184 is <class 'dict'>
# list 185 is <class 'dict'>
# list 186 is <class 'dict'>
# list 187 is <class 'dict'>
# list 188 is <class 'dict'>
# list 189 is <class 'dict'>
# list 190 is <class 'dict'>
# list 191 is <class 'dict'>
# list 192 is <class 'dict'>
# list 193 is <class 'dict'>
# list 194 is <class 'dict'>
# list 195 is <class 'dict'>
# list 196 is <class 'dict'>
# list 197 is <class 'dict'>
# list 198 is <class 'dict'>
# list 199 is <class 'dict'>
# list 200 is <class 'dict'>
# list 201 is <class 'dict'>
# list 202 is <class 'dict'>
# list 203 is <class 'dict'>
# list 204 is <class 'dict'>
# list 205 is <class 'dict'>
# list 206 is <class 'dict'>
# list 207 is <class 'dict'>
# list 208 is <class 'dict'>
# list 209 is <class 'dict'>
# list 210 is <class 'dict'>
# list 211 is <class 'dict'>
# list 212 is <class 'dict'>
# list 213 is <class 'dict'>
# list 214 is <class 'dict'>
# list 215 is <class 'dict'>
# list 216 is <class 'dict'>
# list 217 is <class 'dict'>
# list 218 is <class 'dict'>
# list 219 is <class 'dict'>
# list 220 is <class 'dict'>
# list 221 is <class 'dict'>
# list 222 is <class 'dict'>
# list 223 is <class 'dict'>
# list 224 is <class 'dict'>
# list 225 is <class 'dict'>
# list 226 is <class 'dict'>
# list 227 is <class 'dict'>
# list 228 is <class 'dict'>
# list 229 is <class 'dict'>
# list 230 is <class 'dict'>
# list 231 is <class 'dict'>
# list 232 is <class 'dict'>
# list 233 is <class 'dict'>
# list 234 is <class 'dict'>
# list 235 is <class 'dict'>
# list 236 is <class 'dict'>
# list 237 is <class 'dict'>
# list 238 is <class 'dict'>
# list 239 is <class 'dict'>
# list 240 is <class 'dict'>
# list 241 is <class 'dict'>
# list 242 is <class 'dict'>
# list 243 is <class 'dict'>
# list 244 is <class 'dict'>
# list 245 is <class 'dict'>
# list 246 is <class 'dict'>
# list 247 is <class 'dict'>
# list 248 is <class 'dict'>
# list 249 is <class 'dict'>
# list 250 is <class 'dict'>
# list 251 is <class 'dict'>
# list 252 is <class 'dict'>
# list 253 is <class 'dict'>
# list 254 is <class 'dict'>
# list 255 is <class 'dict'>
# list 256 is <class 'dict'>
# list 257 is <class 'dict'>
# list 258 is <class 'dict'>
# list 259 is <class 'dict'>
# list 260 is <class 'dict'>
# list 261 is <class 'dict'>
# list 262 is <class 'dict'>
# list 263 is <class 'dict'>
# list 264 is <class 'dict'>
# list 265 is <class 'dict'>
# list 266 is <class 'dict'>
# list 267 is <class 'dict'>
# list 268 is <class 'dict'>
# list 269 is <class 'dict'>
# list 270 is <class 'dict'>
# list 271 is <class 'dict'>
# list 272 is <class 'dict'>
# list 273 is <class 'dict'>
# list 274 is <class 'dict'>
# list 275 is <class 'dict'>
# list 276 is <class 'dict'>
# list 277 is <class 'dict'>
# list 278 is <class 'dict'>
# list 279 is <class 'dict'>
# list 280 is <class 'dict'>
# list 281 is <class 'dict'>
# list 282 is <class 'dict'>
# list 283 is <class 'dict'>
# list 284 is <class 'dict'>
# list 285 is <class 'dict'>
# list 286 is <class 'dict'>
# list 287 is <class 'dict'>
# list 288 is <class 'dict'>
# list 289 is <class 'dict'>
# list 290 is <class 'dict'>
# list 291 is <class 'dict'>
# list 292 is <class 'dict'>
# list 293 is <class 'dict'>
# list 294 is <class 'dict'>
# list 295 is <class 'dict'>
# list 296 is <class 'dict'>
# list 297 is <class 'dict'>
# list 298 is <class 'dict'>
# list 299 is <class 'dict'>
# list 300 is <class 'dict'>
# list 301 is <class 'dict'>
# list 302 is <class 'dict'>
# list 303 is <class 'dict'>
# list 304 is <class 'dict'>
# list 305 is <class 'dict'>
# list 306 is <class 'dict'>
# list 307 is <class 'dict'>
# list 308 is <class 'dict'>
# list 309 is <class 'dict'>
# list 310 is <class 'dict'>
# list 311 is <class 'dict'>
# list 312 is <class 'dict'>
# list 313 is <class 'dict'>
# list 314 is <class 'dict'>
# list 315 is <class 'dict'>
# list 316 is <class 'dict'>
# list 317 is <class 'dict'>
# list 318 is <class 'dict'>
# list 319 is <class 'dict'>
# list 320 is <class 'dict'>
# list 321 is <class 'dict'>
# list 322 is <class 'dict'>
# list 323 is <class 'dict'>
# list 324 is <class 'dict'>
# list 325 is <class 'dict'>
# list 326 is <class 'dict'>
# list 327 is <class 'dict'>
# list 328 is <class 'dict'>
# list 329 is <class 'dict'>
# list 330 is <class 'dict'>
# list 331 is <class 'dict'>
# list 332 is <class 'dict'>
# list 333 is <class 'dict'>
# list 334 is <class 'dict'>
# list 335 is <class 'dict'>
# list 336 is <class 'dict'>
# list 337 is <class 'dict'>
# list 338 is <class 'dict'>
# list 339 is <class 'dict'>
# list 340 is <class 'dict'>
# list 341 is <class 'dict'>
# list 342 is <class 'dict'>
# list 343 is <class 'dict'>
# list 344 is <class 'dict'>
# list 345 is <class 'dict'>
# list 346 is <class 'dict'>
# list 347 is <class 'dict'>
# list 348 is <class 'dict'>
# list 349 is <class 'dict'>
# list 350 is <class 'dict'>
# list 351 is <class 'dict'>
# list 352 is <class 'dict'>
# list 353 is <class 'dict'>
# list 354 is <class 'dict'>
# list 355 is <class 'dict'>
# list 356 is <class 'dict'>
# list 357 is <class 'dict'>
# list 358 is <class 'dict'>
# list 359 is <class 'dict'>
# list 360 is <class 'dict'>
# list 361 is <class 'dict'>
# list 362 is <class 'dict'>
# list 363 is <class 'dict'>
# list 364 is <class 'dict'>
# list 365 is <class 'dict'>
# list 366 is <class 'dict'>
# list 367 is <class 'dict'>
# list 368 is <class 'dict'>
# list 369 is <class 'dict'>
# list 370 is <class 'dict'>
# list 371 is <class 'dict'>
# list 372 is <class 'dict'>
# list 373 is <class 'dict'>
# list 374 is <class 'dict'>
# list 375 is <class 'dict'>
# list 376 is <class 'dict'>
# list 377 is <class 'dict'>
# list 378 is <class 'dict'>
# list 379 is <class 'dict'>
# list 380 is <class 'dict'>
# list 381 is <class 'dict'>
# list 382 is <class 'dict'>
# list 383 is <class 'dict'>
# list 384 is <class 'dict'>
# list 385 is <class 'dict'>
# list 386 is <class 'dict'>
# list 387 is <class 'dict'>
# list 388 is <class 'dict'>
# list 389 is <class 'dict'>
# list 390 is <class 'dict'>
# list 391 is <class 'dict'>
# list 392 is <class 'dict'>
# list 393 is <class 'dict'>
# list 394 is <class 'dict'>
# list 395 is <class 'dict'>
# list 396 is <class 'dict'>
# list 397 is <class 'dict'>
# list 398 is <class 'dict'>
# list 399 is <class 'dict'>
# list 400 is <class 'dict'>
# list 401 is <class 'dict'>
# list 402 is <class 'dict'>
# list 403 is <class 'dict'>
# list 404 is <class 'dict'>
# list 405 is <class 'dict'>
# list 406 is <class 'dict'>
# list 407 is <class 'dict'>
# list 408 is <class 'dict'>
# list 409 is <class 'dict'>
# list 410 is <class 'dict'>
# list 411 is <class 'dict'>
# list 412 is <class 'dict'>
# list 413 is <class 'dict'>
# list 414 is <class 'dict'>
# list 415 is <class 'dict'>
# list 416 is <class 'dict'>
# list 417 is <class 'dict'>
# list 418 is <class 'dict'>
# list 419 is <class 'dict'>
# list 420 is <class 'dict'>
# list 421 is <class 'dict'>
# list 422 is <class 'dict'>
# list 423 is <class 'dict'>
# list 424 is <class 'dict'>
# list 425 is <class 'dict'>
# list 426 is <class 'dict'>
# list 427 is <class 'dict'>
# list 428 is <class 'dict'>
# list 429 is <class 'dict'>
# list 430 is <class 'dict'>
# list 431 is <class 'dict'>
# list 432 is <class 'dict'>
# list 433 is <class 'dict'>
# list 434 is <class 'dict'>
# list 435 is <class 'dict'>
# list 436 is <class 'dict'>
# list 437 is <class 'dict'>
# list 438 is <class 'dict'>
# list 439 is <class 'dict'>
# list 440 is <class 'dict'>
# list 441 is <class 'dict'>
# list 442 is <class 'dict'>
# list 443 is <class 'dict'>
# list 444 is <class 'dict'>
# list 445 is <class 'dict'>
# list 446 is <class 'dict'>
# list 447 is <class 'dict'>
# list 448 is <class 'dict'>
# list 449 is <class 'dict'>
# list 450 is <class 'dict'>
# list 451 is <class 'dict'>
# list 452 is <class 'dict'>
# list 453 is <class 'dict'>
# list 454 is <class 'dict'>
# list 455 is <class 'dict'>
# list 456 is <class 'dict'>
# list 457 is <class 'dict'>
# list 458 is <class 'dict'>
# list 459 is <class 'dict'>
# list 460 is <class 'dict'>
# list 461 is <class 'dict'>
# list 462 is <class 'dict'>
# list 463 is <class 'dict'>
# list 464 is <class 'dict'>
# list 465 is <class 'dict'>
# list 466 is <class 'dict'>
# list 467 is <class 'dict'>
# list 468 is <class 'dict'>
# list 469 is <class 'dict'>
# list 470 is <class 'dict'>
# list 471 is <class 'dict'>
# list 472 is <class 'dict'>
# list 473 is <class 'dict'>
# list 474 is <class 'dict'>
# list 475 is <class 'dict'>
# list 476 is <class 'dict'>
# list 477 is <class 'dict'>
# list 478 is <class 'dict'>
# list 479 is <class 'dict'>
# list 480 is <class 'dict'>
# list 481 is <class 'dict'>
# list 482 is <class 'dict'>
# list 483 is <class 'dict'>
# list 484 is <class 'dict'>
# list 485 is <class 'dict'>
# list 486 is <class 'dict'>
# list 487 is <class 'dict'>
# list 488 is <class 'dict'>
# list 489 is <class 'dict'>
# list 490 is <class 'dict'>
# list 491 is <class 'dict'>
# list 492 is <class 'dict'>
# list 493 is <class 'dict'>
# list 494 is <class 'dict'>
# list 495 is <class 'dict'>
# list 496 is <class 'dict'>
# list 497 is <class 'dict'>
# list 498 is <class 'dict'>
# list 499 is <class 'dict'>
# list 500 is <class 'dict'>
# list 501 is <class 'dict'>
# list 502 is <class 'dict'>
# list 503 is <class 'dict'>
# list 504 is <class 'dict'>
# list 505 is <class 'dict'>
# list 506 is <class 'dict'>
# list 507 is <class 'dict'>
# list 508 is <class 'dict'>
# list 509 is <class 'dict'>
# list 510 is <class 'dict'>
# list 511 is <class 'dict'>
# list 512 is <class 'dict'>
# list 513 is <class 'dict'>
# list 514 is <class 'dict'>
# list 515 is <class 'dict'>
# list 516 is <class 'dict'>
# list 517 is <class 'dict'>
# list 518 is <class 'dict'>
# list 519 is <class 'dict'>
# list 520 is <class 'dict'>
# list 521 is <class 'dict'>
# list 522 is <class 'dict'>
# list 523 is <class 'dict'>
# list 524 is <class 'dict'>
# list 525 is <class 'dict'>
# list 526 is <class 'dict'>
# list 527 is <class 'dict'>
# list 528 is <class 'dict'>
# list 529 is <class 'dict'>
# list 530 is <class 'dict'>
# list 531 is <class 'dict'>
# list 532 is <class 'dict'>
# list 533 is <class 'dict'>
# list 534 is <class 'dict'>
# list 535 is <class 'dict'>
# list 536 is <class 'dict'>
# list 537 is <class 'dict'>
# list 538 is <class 'dict'>
# list 539 is <class 'dict'>
# list 540 is <class 'dict'>
# list 541 is <class 'dict'>
# list 542 is <class 'dict'>
# list 543 is <class 'dict'>
# list 544 is <class 'dict'>
# list 545 is <class 'dict'>
# list 546 is <class 'dict'>
# list 547 is <class 'dict'>
# list 548 is <class 'dict'>
# list 549 is <class 'dict'>
# list 550 is <class 'dict'>
# list 551 is <class 'dict'>
# list 552 is <class 'dict'>
# list 553 is <class 'dict'>
# list 554 is <class 'dict'>
# list 555 is <class 'dict'>
# list 556 is <class 'dict'>
# list 557 is <class 'dict'>
# list 558 is <class 'dict'>
# list 559 is <class 'dict'>
# list 560 is <class 'dict'>
# list 561 is <class 'dict'>
# list 562 is <class 'dict'>
# list 563 is <class 'dict'>
# list 564 is <class 'dict'>
# list 565 is <class 'dict'>
# list 566 is <class 'dict'>
# list 567 is <class 'dict'>
# list 568 is <class 'dict'>
# list 569 is <class 'dict'>
# list 570 is <class 'dict'>
# list 571 is <class 'dict'>
# list 572 is <class 'dict'>
# list 573 is <class 'dict'>
# list 574 is <class 'dict'>
# list 575 is <class 'dict'>
# list 576 is <class 'dict'>
# list 577 is <class 'dict'>
# list 578 is <class 'dict'>
# list 579 is <class 'dict'>
# list 580 is <class 'dict'>
# list 581 is <class 'dict'>
# list 582 is <class 'dict'>
# list 583 is <class 'dict'>
# list 584 is <class 'dict'>
# list 585 is <class 'dict'>
# list 586 is <class 'dict'>
# list 587 is <class 'dict'>
# list 588 is <class 'dict'>
# list 589 is <class 'dict'>
# list 590 is <class 'dict'>
# list 591 is <class 'dict'>
# list 592 is <class 'dict'>
# list 593 is <class 'dict'>
# list 594 is <class 'dict'>
# list 595 is <class 'dict'>
# list 596 is <class 'dict'>
# list 597 is <class 'dict'>
# list 598 is <class 'dict'>
# list 599 is <class 'dict'>
# list 600 is <class 'dict'>
# list 601 is <class 'dict'>
# list 602 is <class 'dict'>
# list 603 is <class 'dict'>
# list 604 is <class 'dict'>
# list 605 is <class 'dict'>
# list 606 is <class 'dict'>
# list 607 is <class 'dict'>
# list 608 is <class 'dict'>
# list 609 is <class 'dict'>
# list 610 is <class 'dict'>
# list 611 is <class 'dict'>
# list 612 is <class 'dict'>
# list 613 is <class 'dict'>
# list 614 is <class 'dict'>
# list 615 is <class 'dict'>
# list 616 is <class 'dict'>
# list 617 is <class 'dict'>
# list 618 is <class 'dict'>
# list 619 is <class 'dict'>
# list 620 is <class 'dict'>
# list 621 is <class 'dict'>
# list 622 is <class 'dict'>
# list 623 is <class 'dict'>
# list 624 is <class 'dict'>
# list 625 is <class 'dict'>
# list 626 is <class 'dict'>
# list 627 is <class 'dict'>
# list 628 is <class 'dict'>
# list 629 is <class 'dict'>
# list 630 is <class 'dict'>
# list 631 is <class 'dict'>
# list 632 is <class 'dict'>
# list 633 is <class 'dict'>
# list 634 is <class 'dict'>
# list 635 is <class 'dict'>
# list 636 is <class 'dict'>
# list 637 is <class 'dict'>
# list 638 is <class 'dict'>
# list 639 is <class 'dict'>
# list 640 is <class 'dict'>
# list 641 is <class 'dict'>
# list 642 is <class 'dict'>
# list 643 is <class 'dict'>
# list 644 is <class 'dict'>
# list 645 is <class 'dict'>
# list 646 is <class 'dict'>
# list 647 is <class 'dict'>
# list 648 is <class 'dict'>
# list 649 is <class 'dict'>
# list 650 is <class 'dict'>
# list 651 is <class 'dict'>
# list 652 is <class 'dict'>
# list 653 is <class 'dict'>
# list 654 is <class 'dict'>
# list 655 is <class 'dict'>
# list 656 is <class 'dict'>
# list 657 is <class 'dict'>
# list 658 is <class 'dict'>
# list 659 is <class 'dict'>
# list 660 is <class 'dict'>
# list 661 is <class 'dict'>
# list 662 is <class 'dict'>
# list 663 is <class 'dict'>
# list 664 is <class 'dict'>
# list 665 is <class 'dict'>
# list 666 is <class 'dict'>
# list 667 is <class 'dict'>
# list 668 is <class 'dict'>
# list 669 is <class 'dict'>
# list 670 is <class 'dict'>
# list 671 is <class 'dict'>
# list 672 is <class 'dict'>
# list 673 is <class 'dict'>
# list 674 is <class 'dict'>
# list 675 is <class 'dict'>
# list 676 is <class 'dict'>
# list 677 is <class 'dict'>
# list 678 is <class 'dict'>
# list 679 is <class 'dict'>
# list 680 is <class 'dict'>
# list 681 is <class 'dict'>
# list 682 is <class 'dict'>
# list 683 is <class 'dict'>
# list 684 is <class 'dict'>
# list 685 is <class 'dict'>
# list 686 is <class 'dict'>
# list 687 is <class 'dict'>
# list 688 is <class 'dict'>
# list 689 is <class 'dict'>
# list 690 is <class 'dict'>
# list 691 is <class 'dict'>
# list 692 is <class 'dict'>
# list 693 is <class 'dict'>
# list 694 is <class 'dict'>
# list 695 is <class 'dict'>
# list 696 is <class 'dict'>
# list 697 is <class 'dict'>
# list 698 is <class 'dict'>
# list 699 is <class 'dict'>
# list 700 is <class 'dict'>
# list 701 is <class 'dict'>
# list 702 is <class 'dict'>
# list 703 is <class 'dict'>
# list 704 is <class 'dict'>
# list 705 is <class 'dict'>
# list 706 is <class 'dict'>
# list 707 is <class 'dict'>
# list 708 is <class 'dict'>
# list 709 is <class 'dict'>
# list 710 is <class 'dict'>
# list 711 is <class 'dict'>
# list 712 is <class 'dict'>
# list 713 is <class 'dict'>
# list 714 is <class 'dict'>
# list 715 is <class 'dict'>
# list 716 is <class 'dict'>
# list 717 is <class 'dict'>
# list 718 is <class 'dict'>
# list 719 is <class 'dict'>
# list 720 is <class 'dict'>
# list 721 is <class 'dict'>
# list 722 is <class 'dict'>
# list 723 is <class 'dict'>
# list 724 is <class 'dict'>
# list 725 is <class 'dict'>
# list 726 is <class 'dict'>
# list 727 is <class 'dict'>
# list 728 is <class 'dict'>
# list 729 is <class 'dict'>
# list 730 is <class 'dict'>
# list 731 is <class 'dict'>
# list 732 is <class 'dict'>
# list 733 is <class 'dict'>
# list 734 is <class 'dict'>
# list 735 is <class 'dict'>
# list 736 is <class 'dict'>
# list 737 is <class 'dict'>
# list 738 is <class 'dict'>
# list 739 is <class 'dict'>
# list 740 is <class 'dict'>
# list 741 is <class 'dict'>
# list 742 is <class 'dict'>
# list 743 is <class 'dict'>
# list 744 is <class 'dict'>
# list 745 is <class 'dict'>
# list 746 is <class 'dict'>
# list 747 is <class 'dict'>
# list 748 is <class 'dict'>
# list 749 is <class 'dict'>
# list 750 is <class 'dict'>
# list 751 is <class 'dict'>
# list 752 is <class 'dict'>
# list 753 is <class 'dict'>
# list 754 is <class 'dict'>
# list 755 is <class 'dict'>
# list 756 is <class 'dict'>
# list 757 is <class 'dict'>
# list 758 is <class 'dict'>
# list 759 is <class 'dict'>
# list 760 is <class 'dict'>
# list 761 is <class 'dict'>
# list 762 is <class 'dict'>
# list 763 is <class 'dict'>
# list 764 is <class 'dict'>
# list 765 is <class 'dict'>
# list 766 is <class 'dict'>
# list 767 is <class 'dict'>
# list 768 is <class 'dict'>
# list 769 is <class 'dict'>
# list 770 is <class 'dict'>
# list 771 is <class 'dict'>
# list 772 is <class 'dict'>
# list 773 is <class 'dict'>
# list 774 is <class 'dict'>
# list 775 is <class 'dict'>
# list 776 is <class 'dict'>
# list 777 is <class 'dict'>
# list 778 is <class 'dict'>
# list 779 is <class 'dict'>
# list 780 is <class 'dict'>
# list 781 is <class 'dict'>
# list 782 is <class 'dict'>
# list 783 is <class 'dict'>
# list 784 is <class 'dict'>
# list 785 is <class 'dict'>
# list 786 is <class 'dict'>
# list 787 is <class 'dict'>
# list 788 is <class 'dict'>
# list 789 is <class 'dict'>
# list 790 is <class 'dict'>
# list 791 is <class 'dict'>
# list 792 is <class 'dict'>
# list 793 is <class 'dict'>
# list 794 is <class 'dict'>
# list 795 is <class 'dict'>
# list 796 is <class 'dict'>
# list 797 is <class 'dict'>
# list 798 is <class 'dict'>
# list 799 is <class 'dict'>
# list 800 is <class 'dict'>
# list 801 is <class 'dict'>
# list 802 is <class 'dict'>
# list 803 is <class 'dict'>
# list 804 is <class 'dict'>
# list 805 is <class 'dict'>
# list 806 is <class 'dict'>
# list 807 is <class 'dict'>
# list 808 is <class 'dict'>
# list 809 is <class 'dict'>
# list 810 is <class 'dict'>
# list 811 is <class 'dict'>
# list 812 is <class 'dict'>
# list 813 is <class 'dict'>
# list 814 is <class 'dict'>
# list 815 is <class 'dict'>
# list 816 is <class 'dict'>
# list 817 is <class 'dict'>
# list 818 is <class 'dict'>
# list 819 is <class 'dict'>
# list 820 is <class 'dict'>
# list 821 is <class 'dict'>
# list 822 is <class 'dict'>
# list 823 is <class 'dict'>
# list 824 is <class 'dict'>
# list 825 is <class 'dict'>
# list 826 is <class 'dict'>
# list 827 is <class 'dict'>
# list 828 is <class 'dict'>
# list 829 is <class 'dict'>
# list 830 is <class 'dict'>
# list 831 is <class 'dict'>
# list 832 is <class 'dict'>
# list 833 is <class 'dict'>
# list 834 is <class 'dict'>
# list 835 is <class 'dict'>
# list 836 is <class 'dict'>
# list 837 is <class 'dict'>
# list 838 is <class 'dict'>
# list 839 is <class 'dict'>
# list 840 is <class 'dict'>
# list 841 is <class 'dict'>
# list 842 is <class 'dict'>
# list 843 is <class 'dict'>
# list 844 is <class 'dict'>
# list 845 is <class 'dict'>
# list 846 is <class 'dict'>
# list 847 is <class 'dict'>
# list 848 is <class 'dict'>
# list 849 is <class 'dict'>
# list 850 is <class 'dict'>
# list 851 is <class 'dict'>
# list 852 is <class 'dict'>
# list 853 is <class 'dict'>
# list 854 is <class 'dict'>
# list 855 is <class 'dict'>
# list 856 is <class 'dict'>
# list 857 is <class 'dict'>
# list 858 is <class 'dict'>
# list 859 is <class 'dict'>
# list 860 is <class 'dict'>
# list 861 is <class 'dict'>
# list 862 is <class 'dict'>
# list 863 is <class 'dict'>
# list 864 is <class 'dict'>
# list 865 is <class 'dict'>
# list 866 is <class 'dict'>
# list 867 is <class 'dict'>
# list 868 is <class 'dict'>
# list 869 is <class 'dict'>
# list 870 is <class 'dict'>
# list 871 is <class 'dict'>
# list 872 is <class 'dict'>
# list 873 is <class 'dict'>
# list 874 is <class 'dict'>
# list 875 is <class 'dict'>
# list 876 is <class 'dict'>
# list 877 is <class 'dict'>
# list 878 is <class 'dict'>
# list 879 is <class 'dict'>
# list 880 is <class 'dict'>
# list 881 is <class 'dict'>
# list 882 is <class 'dict'>
# list 883 is <class 'dict'>
# list 884 is <class 'dict'>
# list 885 is <class 'dict'>
# list 886 is <class 'dict'>
# list 887 is <class 'dict'>
# list 888 is <class 'dict'>
# list 889 is <class 'dict'>
# list 890 is <class 'dict'>
# list 891 is <class 'dict'>
# list 892 is <class 'dict'>
# list 893 is <class 'dict'>
# list 894 is <class 'dict'>
# list 895 is <class 'dict'>
# list 896 is <class 'dict'>
# list 897 is <class 'dict'>
# list 898 is <class 'dict'>
# list 899 is <class 'dict'>
# list 900 is <class 'dict'>
# list 901 is <class 'dict'>
# list 902 is <class 'dict'>
# list 903 is <class 'dict'>
# list 904 is <class 'dict'>
# list 905 is <class 'dict'>
# list 906 is <class 'dict'>
# list 907 is <class 'dict'>
# list 908 is <class 'dict'>
# list 909 is <class 'dict'>
# list 910 is <class 'dict'>
# list 911 is <class 'dict'>
# list 912 is <class 'dict'>
# list 913 is <class 'dict'>
# list 914 is <class 'dict'>
# list 915 is <class 'dict'>
# list 916 is <class 'dict'>
# list 917 is <class 'dict'>
# list 918 is <class 'dict'>
# list 919 is <class 'dict'>
# list 920 is <class 'dict'>
# list 921 is <class 'dict'>
# list 922 is <class 'dict'>
# list 923 is <class 'dict'>
# list 924 is <class 'dict'>
# list 925 is <class 'dict'>
# list 926 is <class 'dict'>
# list 927 is <class 'dict'>
# list 928 is <class 'dict'>
# list 929 is <class 'dict'>
# list 930 is <class 'dict'>
# list 931 is <class 'dict'>
# list 932 is <class 'dict'>
# list 933 is <class 'dict'>
# list 934 is <class 'dict'>
# list 935 is <class 'dict'>
# list 936 is <class 'dict'>
# list 937 is <class 'dict'>
# list 938 is <class 'dict'>
# list 939 is <class 'dict'>
# list 940 is <class 'dict'>
# list 941 is <class 'dict'>
# list 942 is <class 'dict'>
# list 943 is <class 'dict'>
# list 944 is <class 'dict'>
# list 945 is <class 'dict'>
# list 946 is <class 'dict'>
# list 947 is <class 'dict'>
# list 948 is <class 'dict'>
# list 949 is <class 'dict'>
# list 950 is <class 'dict'>
# list 951 is <class 'dict'>
# list 952 is <class 'dict'>
# list 953 is <class 'dict'>
# list 954 is <class 'dict'>
# list 955 is <class 'dict'>
# list 956 is <class 'dict'>
# list 957 is <class 'dict'>
# list 958 is <class 'dict'>
# list 959 is <class 'dict'>
# list 960 is <class 'dict'>
# list 961 is <class 'dict'>
# list 962 is <class 'dict'>
# list 963 is <class 'dict'>
# list 964 is <class 'dict'>
# list 965 is <class 'dict'>
# list 966 is <class 'dict'>
# list 967 is <class 'dict'>
# list 968 is <class 'dict'>
# list 969 is <class 'dict'>
# list 970 is <class 'dict'>
# list 971 is <class 'dict'>
# list 972 is <class 'dict'>
# list 973 is <class 'dict'>
# list 974 is <class 'dict'>
# list 975 is <class 'dict'>
# list 976 is <class 'dict'>
# list 977 is <class 'dict'>
# list 978 is <class 'dict'>
# list 979 is <class 'dict'>
# list 980 is <class 'dict'>
# list 981 is <class 'dict'>
# list 982 is <class 'dict'>
# list 983 is <class 'dict'>
# list 984 is <class 'dict'>
# list 985 is <class 'dict'>
# list 986 is <class 'dict'>
# list 987 is <class 'dict'>
# list 988 is <class 'dict'>
# list 989 is <class 'dict'>
# list 990 is <class 'dict'>
# list 991 is <class 'dict'>
# list 992 is <class 'dict'>
# list 993 is <class 'dict'>
# list 994 is <class 'dict'>
# list 995 is <class 'dict'>
# list 996 is <class 'dict'>
# list 997 is <class 'dict'>
# list 998 is <class 'dict'>
# list 999 is <class 'dict'>
# list 1000 is <class 'dict'>
# list 1001 is <class 'dict'>
# list 1002 is <class 'dict'>
# list 1003 is <class 'dict'>
# list 1004 is <class 'dict'>
# list 1005 is <class 'dict'>
# list 1006 is <class 'dict'>
# list 1007 is <class 'dict'>
# list 1008 is <class 'dict'>
# list 1009 is <class 'dict'>
# list 1010 is <class 'dict'>
# list 1011 is <class 'dict'>
# list 1012 is <class 'dict'>
# list 1013 is <class 'dict'>
# list 1014 is <class 'dict'>
# list 1015 is <class 'dict'>
# list 1016 is <class 'dict'>
# list 1017 is <class 'dict'>
# list 1018 is <class 'dict'>
# list 1019 is <class 'dict'>
# list 1020 is <class 'dict'>
# list 1021 is <class 'dict'>
# list 1022 is <class 'dict'>
# list 1023 is <class 'dict'>
# list 1024 is <class 'dict'>
# list 1025 is <class 'dict'>
# list 1026 is <class 'dict'>
# list 1027 is <class 'dict'>
# list 1028 is <class 'dict'>
# list 1029 is <class 'dict'>
# list 1030 is <class 'dict'>
# list 1031 is <class 'dict'>
# list 1032 is <class 'dict'>
# list 1033 is <class 'dict'>
# list 1034 is <class 'dict'>
# list 1035 is <class 'dict'>
# list 1036 is <class 'dict'>
# list 1037 is <class 'dict'>
# list 1038 is <class 'dict'>
# list 1039 is <class 'dict'>
# list 1040 is <class 'dict'>
# list 1041 is <class 'dict'>
# list 1042 is <class 'dict'>
# list 1043 is <class 'dict'>
# list 1044 is <class 'dict'>
# list 1045 is <class 'dict'>
# list 1046 is <class 'dict'>
# list 1047 is <class 'dict'>
# list 1048 is <class 'dict'>
# list 1049 is <class 'dict'>
# list 1050 is <class 'dict'>
# list 1051 is <class 'dict'>
# list 1052 is <class 'dict'>
# list 1053 is <class 'dict'>
# list 1054 is <class 'dict'>
# list 1055 is <class 'dict'>
# list 1056 is <class 'dict'>
# list 1057 is <class 'dict'>
# list 1058 is <class 'dict'>
# list 1059 is <class 'dict'>
# list 1060 is <class 'dict'>
# list 1061 is <class 'dict'>
# list 1062 is <class 'dict'>
# list 1063 is <class 'dict'>
# list 1064 is <class 'dict'>
# list 1065 is <class 'dict'>
# list 1066 is <class 'dict'>
# list 1067 is <class 'dict'>
# list 1068 is <class 'dict'>
# list 1069 is <class 'dict'>
# list 1070 is <class 'dict'>
# list 1071 is <class 'dict'>
# list 1072 is <class 'dict'>
# list 1073 is <class 'dict'>
# list 1074 is <class 'dict'>
# list 1075 is <class 'dict'>
# list 1076 is <class 'dict'>
# list 1077 is <class 'dict'>
# list 1078 is <class 'dict'>
# list 1079 is <class 'dict'>
# list 1080 is <class 'dict'>
# list 1081 is <class 'dict'>
# list 1082 is <class 'dict'>
# list 1083 is <class 'dict'>
# list 1084 is <class 'dict'>
# list 1085 is <class 'dict'>
# list 1086 is <class 'dict'>
# list 1087 is <class 'dict'>
# list 1088 is <class 'dict'>
# list 1089 is <class 'dict'>
# list 1090 is <class 'dict'>
# list 1091 is <class 'dict'>
# list 1092 is <class 'dict'>
# list 1093 is <class 'dict'>
# list 1094 is <class 'dict'>
# list 1095 is <class 'dict'>
# list 1096 is <class 'dict'>
# list 1097 is <class 'dict'>
# list 1098 is <class 'dict'>
# list 1099 is <class 'dict'>
# list 1100 is <class 'dict'>

# %% [markdown]
# <a id='pokemon_learnsets_df'></a>
# ### pokemon_learnsets_df

# %% [markdown]
# Now we want to use the information contained in pokemon_df, moves_df and strategydex_df (which contains the learnsets of each pokemon) to one-hot encode which moves each pokemon can learn (which is important for understand the competitive viability of a pokemon, as access or lack of access to certain moves can be a decisive factor in what a pokemon can do).  As usual, we'll index this dataframe with the pokemon_df index that's syncing everything, and we'll use moves_df as our columns since that's what's being one-hot encoded.

# %%
pokemon_learnsets_df = pd.DataFrame(0, index=pokemon_df.index, columns=moves_df.index.rename(''))
pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        0            0     0     0         0            0
# Ivysaur            0        0            0     0     0         0            0
# Venusaur           0        0            0     0     0         0            0
# Charmander         0        0            0     0     0         0            0
# Charmeleon         0        0            0     0     0         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         0            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         0            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Strange Steam  \
# name                                             ...
# Bulbasaur                0        0           0  ...              0
# Ivysaur                  0        0           0  ...              0
# Venusaur                 0        0           0  ...              0
# Charmander               0        0           0  ...              0
# Charmeleon               0        0           0  ...              0
# ...                    ...      ...         ...  ...            ...
# Glastrier                0        0           0  ...              0
# Spectrier                0        0           0  ...              0
# Calyrex                  0        0           0  ...              0
# Calyrex-Ice              0        0           0  ...              0
# Calyrex-Shadow           0        0           0  ...              0
#
#                 Stuff Cheeks  Surging Strikes  Tar Shot  Teatime  \
# name
# Bulbasaur                  0                0         0        0
# Ivysaur                    0                0         0        0
# Venusaur                   0                0         0        0
# Charmander                 0                0         0        0
# Charmeleon                 0                0         0        0
# ...                      ...              ...       ...      ...
# Glastrier                  0                0         0        0
# Spectrier                  0                0         0        0
# Calyrex                    0                0         0        0
# Calyrex-Ice                0                0         0        0
# Calyrex-Shadow             0                0         0        0
#
#                 Terrain Pulse  Thunder Cage  Thunderous Kick  Triple Axel  \
# name
# Bulbasaur                   0             0                0            0
# Ivysaur                     0             0                0            0
# Venusaur                    0             0                0            0
# Charmander                  0             0                0            0
# Charmeleon                  0             0                0            0
# ...                       ...           ...              ...          ...
# Glastrier                   0             0                0            0
# Spectrier                   0             0                0            0
# Calyrex                     0             0                0            0
# Calyrex-Ice                 0             0                0            0
# Calyrex-Shadow              0             0                0            0
#
#                 Wicked Blow
# name
# Bulbasaur                 0
# Ivysaur                   0
# Venusaur                  0
# Charmander                0
# Charmeleon                0
# ...                     ...
# Glastrier                 0
# Spectrier                 0
# Calyrex                   0
# Calyrex-Ice               0
# Calyrex-Shadow            0
#
# [739 rows x 698 columns]

# %% [markdown]
# After some experimentation, it turned out that the easiest way to organize the filling of the above dataframe is via a python dictionary, indexed by pokemon_df index, containing the movesets of each pokemon from strategydex_df.
#
# The string replacements were arrived at by a similar process of experimentation to those of strategydex_df (and which can be examined at [data_wrangling_experiments](./data_wrangling_experiments.ipynb#pokemon_learnsets_df_2) in the "pokemon_learnsets_df experiments" section). I'll just present the best results here.

# %%
pokemon_learnsets = {}

strategydex_experiment = strategydex_df.copy()

for pokemon in pokemon_df.index:
    pokemon = pokemon.replace("'", "").replace(" ", "-").replace(".", "").replace("-10%", "").replace(":", "")
    pokemon_learnsets[pokemon] = strategydex_experiment.loc[strategydex_experiment['pokemonName'] == pokemon.lower(), 'pokemonData'].item()['learnset']

pokemon_learnsets
# Out:
# {'Bulbasaur': ['Amnesia',
#   'Attract',
#   'Bind',
#   'Block',
#   'Body Slam',
#   'Bullet Seed',
#   'Celebrate',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Double-Edge',
#   'Double Team',
#   'Echoed Voice',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'False Swipe',
#   'Frenzy Plant',
#   'Fury Cutter',
#   'Giga Drain',
#   'Grass Knot',
#   'Grass Pledge',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growl',
#   'Growth',
#   'Headbutt',
#   'Helping Hand',
#   'Ingrain',
#   'Knock Off',
#   'Leaf Storm',
#   'Leech Seed',
#   'Light Screen',
#   'Magical Leaf',
#   'Mega Drain',
#   'Mimic',
#   'Mud-Slap',
#   'Nature Power',
#   'Outrage',
#   'Petal Dance',
#   'Poison Powder',
#   'Power Whip',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Safeguard',
#   'Seed Bomb',
#   'Skull Bash',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge',
#   'Sludge Bomb',
#   'Snore',
#   'Solar Beam',
#   'Strength',
#   'String Shot',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Tackle',
#   'Take Down',
#   'Toxic',
#   'Venoshock',
#   'Vine Whip',
#   'Weather Ball',
#   'Work Up',
#   'Worry Seed'],
#  'Ivysaur': ['Amnesia',
#   'Attract',
#   'Bind',
#   'Block',
#   'Body Slam',
#   'Bullet Seed',
#   'Celebrate',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Double-Edge',
#   'Double Team',
#   'Echoed Voice',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'False Swipe',
#   'Frenzy Plant',
#   'Fury Cutter',
#   'Giga Drain',
#   'Grass Knot',
#   'Grass Pledge',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growl',
#   'Growth',
#   'Headbutt',
#   'Helping Hand',
#   'Ingrain',
#   'Knock Off',
#   'Leaf Storm',
#   'Leech Seed',
#   'Light Screen',
#   'Magical Leaf',
#   'Mega Drain',
#   'Mimic',
#   'Mud-Slap',
#   'Nature Power',
#   'Outrage',
#   'Petal Dance',
#   'Poison Powder',
#   'Power Whip',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Safeguard',
#   'Seed Bomb',
#   'Skull Bash',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge',
#   'Sludge Bomb',
#   'Snore',
#   'Solar Beam',
#   'Strength',
#   'String Shot',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Tackle',
#   'Take Down',
#   'Toxic',
#   'Venoshock',
#   'Vine Whip',
#   'Weather Ball',
#   'Work Up',
#   'Worry Seed'],
#  'Venusaur': ['Amnesia',
#   'Attract',
#   'Bind',
#   'Block',
#   'Body Slam',
#   'Bulldoze',
#   'Bullet Seed',
#   'Celebrate',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Double-Edge',
#   'Double Team',
#   'Earth Power',
#   'Earthquake',
#   'Echoed Voice',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'False Swipe',
#   'Frenzy Plant',
#   'Fury Cutter',
#   'Giga Drain',
#   'Giga Impact',
#   'Grass Knot',
#   'Grass Pledge',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growl',
#   'Growth',
#   'Headbutt',
#   'Helping Hand',
#   'Hyper Beam',
#   'Ingrain',
#   'Knock Off',
#   'Leaf Storm',
#   'Leech Seed',
#   'Light Screen',
#   'Magical Leaf',
#   'Mega Drain',
#   'Mimic',
#   'Mud-Slap',
#   'Nature Power',
#   'Outrage',
#   'Petal Blizzard',
#   'Petal Dance',
#   'Poison Powder',
#   'Power Whip',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Rock Smash',
#   'Round',
#   'Safeguard',
#   'Seed Bomb',
#   'Skull Bash',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge',
#   'Sludge Bomb',
#   'Snore',
#   'Solar Beam',
#   'Stomping Tantrum',
#   'Strength',
#   'String Shot',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Tackle',
#   'Take Down',
#   'Terrain Pulse',
#   'Toxic',
#   'Venoshock',
#   'Vine Whip',
#   'Weather Ball',
#   'Work Up',
#   'Worry Seed'],
#  'Charmander': ['Acrobatics',
#   'Aerial Ace',
#   'Air Cutter',
#   'Ancient Power',
#   'Attract',
#   'Beat Up',
#   'Belly Drum',
#   'Bite',
#   'Blast Burn',
#   'Block',
#   'Body Slam',
#   'Brick Break',
#   'Celebrate',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Breath',
#   'Dragon Claw',
#   'Dragon Dance',
#   'Dragon Pulse',
#   'Dragon Rush',
#   'Dragon Tail',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Ember',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Blast',
#   'Fire Fang',
#   'Fire Pledge',
#   'Fire Punch',
#   'Fire Spin',
#   'Flame Charge',
#   'Flamethrower',
#   'Flare Blitz',
#   'Fling',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Growl',
#   'Headbutt',
#   'Heat Wave',
#   'Helping Hand',
#   'Hone Claws',
#   'Howl',
#   'Incinerate',
#   'Inferno',
#   'Iron Tail',
#   'Leer',
#   'Mega Kick',
#   'Mega Punch',
#   'Metal Claw',
#   'Mimic',
#   'Mud-Slap',
#   'Outrage',
#   'Overheat',
#   'Power-Up Punch',
#   'Protect',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Scary Face',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Smokescreen',
#   'Snore',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Swords Dance',
#   'Take Down',
#   'Thunder Punch',
#   'Toxic',
#   'Weather Ball',
#   'Will-O-Wisp',
#   'Wing Attack',
#   'Work Up'],
#  'Charmeleon': ['Acrobatics',
#   'Aerial Ace',
#   'Air Cutter',
#   'Ancient Power',
#   'Attract',
#   'Beat Up',
#   'Belly Drum',
#   'Bite',
#   'Blast Burn',
#   'Block',
#   'Body Slam',
#   'Brick Break',
#   'Celebrate',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Breath',
#   'Dragon Claw',
#   'Dragon Dance',
#   'Dragon Pulse',
#   'Dragon Rush',
#   'Dragon Tail',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Ember',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Blast',
#   'Fire Fang',
#   'Fire Pledge',
#   'Fire Punch',
#   'Fire Spin',
#   'Flame Charge',
#   'Flamethrower',
#   'Flare Blitz',
#   'Fling',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Growl',
#   'Headbutt',
#   'Heat Wave',
#   'Helping Hand',
#   'Hone Claws',
#   'Howl',
#   'Incinerate',
#   'Inferno',
#   'Iron Tail',
#   'Leer',
#   'Mega Kick',
#   'Mega Punch',
#   'Metal Claw',
#   'Mimic',
#   'Mud-Slap',
#   'Outrage',
#   'Overheat',
#   'Power-Up Punch',
#   'Protect',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Scary Face',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Smokescreen',
#   'Snore',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Swords Dance',
#   'Take Down',
#   'Thunder Punch',
#   'Toxic',
#   'Weather Ball',
#   'Will-O-Wisp',
#   'Wing Attack',
#   'Work Up'],
#  'Charizard': ['Acrobatics',
#   'Aerial Ace',
#   'Air Cutter',
#   'Air Slash',
#   'Ancient Power',
#   'Attract',
#   'Beat Up',
#   'Belly Drum',
#   'Bite',
#   'Blast Burn',
#   'Blaze Kick',
#   'Block',
#   'Body Slam',
#   'Breaking False Swipe',
#   'Brick Break',
#   'Brutal Swing',
#   'Bulldoze',
#   'Celebrate',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Defog',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Breath',
#   'Dragon Claw',
#   'Dragon Dance',
#   'Dragon Pulse',
#   'Dragon Rush',
#   'Dragon Tail',
#   'Dual Wingbeat',
#   'Dynamic Punch',
#   'Earthquake',
#   'Echoed Voice',
#   'Ember',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Blast',
#   'Fire Fang',
#   'Fire Pledge',
#   'Fire Punch',
#   'Fire Spin',
#   'Fissure',
#   'Flame Charge',
#   'Flamethrower',
#   'Flare Blitz',
#   'Fling',
#   'Fly',
#   'Focus Blast',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Giga Impact',
#   'Growl',
#   'Headbutt',
#   'Heat Crash',
#   'Heat Wave',
#   'Helping Hand',
#   'Hold Hands',
#   'Hone Claws',
#   'Howl',
#   'Hurricane',
#   'Hyper Beam',
#   'Incinerate',
#   'Inferno',
#   'Iron Tail',
#   'Leer',
#   'Mega Kick',
#   'Mega Punch',
#   'Metal Claw',
#   'Mimic',
#   'Mud-Slap',
#   'Mystical Fire',
#   'Outrage',
#   'Overheat',
#   'Power-Up Punch',
#   'Protect',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Roost',
#   'Round',
#   'Sandstorm',
#   'Scale Shot',
#   'Scary Face',
#   'Scorching Sands',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Smokescreen',
#   'Snore',
#   'Solar Beam',
#   'Steel Wing',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Swords Dance',
#   'Tailwind',
#   'Take Down',
#   'Thunder Punch',
#   'Toxic',
#   'Twister',
#   'Weather Ball',
#   'Will-O-Wisp',
#   'Wing Attack',
#   'Work Up'],
#  'Squirtle': ['Aqua Jet',
#   'Aqua Ring',
#   'Aqua Tail',
#   'Attract',
#   'Aura Sphere',
#   'Bite',
#   'Blizzard',
#   'Block',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bubble Beam',
#   'Celebrate',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Curse',
#   'Defense Curl',
#   'Dig',
#   'Dive',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Pulse',
#   'Dynamic Punch',
#   'Endure',
#   'Facade',
#   'Fake Out',
#   'False Swipe',
#   'Flail',
#   'Fling',
#   'Flip Turn',
#   'Focus Punch',
#   'Follow Me',
#   'Gyro Ball',
#   'Hail',
#   'Haze',
#   'Headbutt',
#   'Helping Hand',
#   'Hydro Cannon',
#   'Hydro Pump',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Iron Defense',
#   'Iron Tail',
#   'Life Dew',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mirror Coat',
#   'Mist',
#   'Muddy Water',
#   'Mud-Slap',
#   'Outrage',
#   'Power-Up Punch',
#   'Protect',
#   'Rain Dance',
#   'Rapid Spin',
#   'Reflect',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Rollout',
#   'Round',
#   'Scald',
#   'Seismic Toss',
#   'Shell Smash',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Toxic',
#   'Waterfall',
#   'Water Gun',
#   'Water Pledge',
#   'Water Pulse',
#   'Water Spout',
#   'Weather Ball',
#   'Whirlpool',
#   'Withdraw',
#   'Work Up',
#   'Yawn',
#   'Zen Headbutt'],
#  'Wartortle': ['Aqua Jet',
#   'Aqua Ring',
#   'Aqua Tail',
#   'Attract',
#   'Aura Sphere',
#   'Bite',
#   'Blizzard',
#   'Block',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bubble Beam',
#   'Celebrate',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Curse',
#   'Defense Curl',
#   'Dig',
#   'Dive',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Pulse',
#   'Dynamic Punch',
#   'Endure',
#   'Facade',
#   'Fake Out',
#   'False Swipe',
#   'Flail',
#   'Fling',
#   'Flip Turn',
#   'Focus Punch',
#   'Follow Me',
#   'Gyro Ball',
#   'Hail',
#   'Haze',
#   'Headbutt',
#   'Helping Hand',
#   'Hydro Cannon',
#   'Hydro Pump',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Iron Defense',
#   'Iron Tail',
#   'Life Dew',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mirror Coat',
#   'Mist',
#   'Muddy Water',
#   'Mud-Slap',
#   'Outrage',
#   'Power-Up Punch',
#   'Protect',
#   'Rain Dance',
#   'Rapid Spin',
#   'Reflect',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Rollout',
#   'Round',
#   'Scald',
#   'Seismic Toss',
#   'Shell Smash',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Toxic',
#   'Waterfall',
#   'Water Gun',
#   'Water Pledge',
#   'Water Pulse',
#   'Water Spout',
#   'Weather Ball',
#   'Whirlpool',
#   'Withdraw',
#   'Work Up',
#   'Yawn',
#   'Zen Headbutt'],
#  'Blastoise': ['Aqua Jet',
#   'Aqua Ring',
#   'Aqua Tail',
#   'Attract',
#   'Aura Sphere',
#   'Avalanche',
#   'Bite',
#   'Blizzard',
#   'Block',
#   'Body Press',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bubble Beam',
#   'Bulldoze',
#   'Celebrate',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Dark Pulse',
#   'Defense Curl',
#   'Dig',
#   'Dive',
#   'Double-Edge',
#   'Double Team',
#   'Dragon Pulse',
#   'Dragon Tail',
#   'Dynamic Punch',
#   'Earthquake',
#   'Endure',
#   'Facade',
#   'Fake Out',
#   'False Swipe',
#   'Fissure',
#   'Flail',
#   'Flash Cannon',
#   'Fling',
#   'Flip Turn',
#   'Focus Blast',
#   'Focus Punch',
#   'Follow Me',
#   'Giga Impact',
#   'Gyro Ball',
#   'Hail',
#   'Haze',
#   'Headbutt',
#   'Helping Hand',
#   'Hydro Cannon',
#   'Hydro Pump',
#   'Hyper Beam',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Iron Defense',
#   'Iron Tail',
#   'Life Dew',
#   'Liquidation',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mirror Coat',
#   'Mist',
#   'Muddy Water',
#   'Mud-Slap',
#   'Outrage',
#   'Power-Up Punch',
#   'Protect',
#   'Rain Dance',
#   'Rapid Spin',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Rollout',
#   'Round',
#   'Scald',
#   'Seismic Toss',
#   'Shell Smash',
#   'Skull Bash',
#   'Sleep Talk',
#   'Smack Down',
#   'Snore',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Terrain Pulse',
#   'Toxic',
#   'Waterfall',
#   'Water Gun',
#   'Water Pledge',
#   'Water Pulse',
#   'Water Spout',
#   'Weather Ball',
#   'Whirlpool',
#   'Withdraw',
#   'Work Up',
#   'Yawn',
#   'Zen Headbutt'],
#  'Caterpie': ['Bug Bite', 'Electroweb', 'Snore', 'String Shot', 'Tackle'],
#  'Metapod': ['Bug Bite',
#   'Electroweb',
#   'Harden',
#   'Iron Defense',
#   'Snore',
#   'String Shot',
#   'Tackle'],
#  'Butterfree': ['Acrobatics',
#   'Aerial Ace',
#   'Air Cutter',
#   'Air Slash',
#   'Attract',
#   'Baton Pass',
#   'Bug Bite',
#   'Bug Buzz',
#   'Confide',
#   'Confusion',
#   'Curse',
#   'Defog',
#   'Double-Edge',
#   'Double Team',
#   'Draining Kiss',
#   'Dream Eater',
#   'Dual Wingbeat',
#   'Electroweb',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'Giga Drain',
#   'Giga Impact',
#   'Gust',
#   'Harden',
#   'Headbutt',
#   'Hurricane',
#   'Hyper Beam',
#   'Infestation',
#   'Iron Defense',
#   'Mega Drain',
#   'Mimic',
#   'Morning Sun',
#   'Poison Powder',
#   'Pollen Puff',
#   'Protect',
#   'Psybeam',
#   'Psychic',
#   'Psych Up',
#   'Quiver Dance',
#   'Rage Powder',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Roost',
#   'Round',
#   'Safeguard',
#   'Shadow Ball',
#   'Skill Swap',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'String Shot',
#   'Struggle Bug',
#   'Stun Spore',
#   'Substitute',
#   'Sunny Day',
#   'Supersonic',
#   'Swagger',
#   'Sweet Scent',
#   'Swift',
#   'Tackle',
#   'Tailwind',
#   'Take Down',
#   'Teleport',
#   'Thief',
#   'Toxic',
#   'Twister',
#   'U-turn',
#   'Venoshock',
#   'Whirlwind'],
#  'Pikachu': ['Agility',
#   'Attract',
#   'Body Slam',
#   'Brick Break',
#   'Calm Mind',
#   'Celebrate',
#   'Charge',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disarming Voice',
#   'Discharge',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Draining Kiss',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Electric Terrain',
#   'Electro Ball',
#   'Electroweb',
#   'Encore',
#   'Endeavor',
#   'Endure',
#   'Extreme Speed',
#   'Facade',
#   'Fake Out',
#   'Feint',
#   'Flail',
#   'Fling',
#   'Fly',
#   'Focus Punch',
#   'Follow Me',
#   'Grass Knot',
#   'Growl',
#   'Happy Hour',
#   'Headbutt',
#   'Helping Hand',
#   'Hold Hands',
#   'Iron Tail',
#   'Knock Off',
#   'Laser Focus',
#   'Last Resort',
#   'Light Screen',
#   'Magnet Rise',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mud-Slap',
#   'Nasty Plot',
#   'Nuzzle',
#   'Pay Day',
#   'Play Nice',
#   'Play Rough',
#   'Present',
#   'Protect',
#   'Quick Attack',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Reversal',
#   'Rising Voltage',
#   'Rock Smash',
#   'Rollout',
#   'Round',
#   'Seismic Toss',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Slam',
#   'Sleep Talk',
#   'Snore',
#   'Spark',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Sweet Kiss',
#   'Sweet Scent',
#   'Swift',
#   'Tail Whip',
#   'Take Down',
#   'Teeter Dance',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Shock',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Uproar',
#   'Volt Switch',
#   'Volt Tackle',
#   'Wild Charge',
#   'Wish',
#   'Yawn',
#   'Zap Cannon'],
#  'Raichu': ['Agility',
#   'Attract',
#   'Body Slam',
#   'Brick Break',
#   'Brutal Swing',
#   'Calm Mind',
#   'Celebrate',
#   'Charge',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disarming Voice',
#   'Discharge',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Draining Kiss',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Eerie Impulse',
#   'Electric Terrain',
#   'Electro Ball',
#   'Electroweb',
#   'Encore',
#   'Endeavor',
#   'Endure',
#   'Extreme Speed',
#   'Facade',
#   'Fake Out',
#   'Feint',
#   'Flail',
#   'Fling',
#   'Fly',
#   'Focus Blast',
#   'Focus Punch',
#   'Follow Me',
#   'Giga Impact',
#   'Grass Knot',
#   'Growl',
#   'Happy Hour',
#   'Headbutt',
#   'Helping Hand',
#   'Hold Hands',
#   'Hyper Beam',
#   'Iron Tail',
#   'Knock Off',
#   'Laser Focus',
#   'Last Resort',
#   'Light Screen',
#   'Magnet Rise',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mud-Slap',
#   'Nasty Plot',
#   'Nuzzle',
#   'Pay Day',
#   'Play Nice',
#   'Play Rough',
#   'Present',
#   'Protect',
#   'Quick Attack',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Reversal',
#   'Rising Voltage',
#   'Rock Smash',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Seismic Toss',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Slam',
#   'Sleep Talk',
#   'Snore',
#   'Spark',
#   'Speed Swap',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Sweet Kiss',
#   'Sweet Scent',
#   'Swift',
#   'Tail Whip',
#   'Take Down',
#   'Teeter Dance',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Shock',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Uproar',
#   'Volt Switch',
#   'Volt Tackle',
#   'Wild Charge',
#   'Wish',
#   'Yawn',
#   'Zap Cannon'],
#  'Sandshrew': ['Aerial Ace',
#   'Agility',
#   'Amnesia',
#   'Attract',
#   'Body Slam',
#   'Brick Break',
#   'Bulldoze',
#   'Confide',
#   'Counter',
#   'Covet',
#   'Crush Claw',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dynamic Punch',
#   'Earth Power',
#   'Earthquake',
#   'Endure',
#   'Facade',
#   'Fissure',
#   'Flail',
#   'Fling',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Gyro Ball',
#   'Headbutt',
#   'Hone Claws',
#   'Iron Tail',
#   'Knock Off',
#   'Leech Life',
#   'Metal Claw',
#   'Mimic',
#   'Mud Shot',
#   'Mud-Slap',
#   'Night Slash',
#   'Poison Jab',
#   'Poison Sting',
#   'Protect',
#   'Rapid Spin',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Sand Attack',
#   'Sandstorm',
#   'Sand Tomb',
#   'Scorching Sands',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Snore',
#   'Stealth Rock',
#   'Steel Roller',
#   'Stomping Tantrum',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Super Fang',
#   'Swagger',
#   'Swift',
#   'Swords Dance',
#   'Take Down',
#   'Thief',
#   'Throat Chop',
#   'Toxic',
#   'Work Up',
#   'X-Scissor'],
#  'Sandslash': ['Aerial Ace',
#   'Agility',
#   'Amnesia',
#   'Attract',
#   'Body Slam',
#   'Brick Break',
#   'Bulldoze',
#   'Confide',
#   'Counter',
#   'Covet',
#   'Crush Claw',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Drill Run',
#   'Dynamic Punch',
#   'Earth Power',
#   'Earthquake',
#   'Endure',
#   'Facade',
#   'Fissure',
#   'Flail',
#   'Fling',
#   'Focus Blast',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Giga Impact',
#   'Gyro Ball',
#   'Headbutt',
#   'Hone Claws',
#   'Hyper Beam',
#   'Iron Tail',
#   'Knock Off',
#   'Leech Life',
#   'Metal Claw',
#   'Mimic',
#   'Mud Shot',
#   'Mud-Slap',
#   'Night Slash',
#   'Pin Missile',
#   'Poison Jab',
#   'Poison Sting',
#   'Protect',
#   'Rapid Spin',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Sand Attack',
#   'Sandstorm',
#   'Sand Tomb',
#   'Scorching Sands',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Snore',
#   'Spikes',
#   'Stealth Rock',
#   'Steel Roller',
#   'Stomping Tantrum',
#   'Stone Edge',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Super Fang',
#   'Swagger',
#   'Swift',
#   'Swords Dance',
#   'Take Down',
#   'Thief',
#   'Throat Chop',
#   'Toxic',
#   'Work Up',
#   'X-Scissor'],
#  'Nidoran-F': ['Aerial Ace',
#   'Attract',
#   'Beat Up',
#   'Bite',
#   'Blizzard',
#   'Body Slam',
#   'Charm',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Earth Power',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Flatter',
#   'Focus Energy',
#   'Fury False Swipes',
#   'Growl',
#   'Headbutt',
#   'Helping Hand',
#   'Hone Claws',
#   'Ice Beam',
#   'Iron Tail',
#   'Mimic',
#   'Mud-Slap',
#   'Poison Fang',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Protect',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Scratch',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Strength',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Toxic',
#   'Toxic Spikes',
#   'Venom Drench',
#   'Venoshock',
#   'Water Pulse'],
#  'Nidorina': ['Aerial Ace',
#   'Attract',
#   'Beat Up',
#   'Bite',
#   'Blizzard',
#   'Body Slam',
#   'Bubble Beam',
#   'Charm',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Earth Power',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Flatter',
#   'Focus Energy',
#   'Fury False Swipes',
#   'Growl',
#   'Headbutt',
#   'Helping Hand',
#   'Hone Claws',
#   'Horn Drill',
#   'Ice Beam',
#   'Iron Tail',
#   'Mimic',
#   'Mud-Slap',
#   'Poison Fang',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Protect',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Scratch',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Stomping Tantrum',
#   'Strength',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Toxic',
#   'Toxic Spikes',
#   'Venom Drench',
#   'Venoshock',
#   'Water Gun',
#   'Water Pulse'],
#  'Nidoqueen': ['Aerial Ace',
#   'Aqua Tail',
#   'Attract',
#   'Avalanche',
#   'Beat Up',
#   'Bite',
#   'Blizzard',
#   'Body Press',
#   'Body Slam',
#   'Brick Break',
#   'Bubble Beam',
#   'Bulldoze',
#   'Charm',
#   'Confide',
#   'Counter',
#   'Crunch',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Dragon Pulse',
#   'Dragon Tail',
#   'Drill Run',
#   'Dynamic Punch',
#   'Earth Power',
#   'Earthquake',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Fire Blast',
#   'Fire Punch',
#   'Fissure',
#   'Flamethrower',
#   'Flatter',
#   'Fling',
#   'Focus Blast',
#   'Focus Energy',
#   'Focus Punch',
#   'Fury Cutter',
#   'Fury False Swipes',
#   'Giga Impact',
#   'Growl',
#   'Headbutt',
#   'Helping Hand',
#   'Hex',
#   'High Horsepower',
#   'Hone Claws',
#   'Horn Drill',
#   'Hyper Beam',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Incinerate',
#   'Iron Tail',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mud Shot',
#   'Mud-Slap',
#   'Outrage',
#   'Pay Day',
#   'Poison Fang',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Power-Up Punch',
#   'Protect',
#   'Quash',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Rock Blast',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Sandstorm',
#   'Sand Tomb',
#   'Scorching Sands',
#   'Scratch',
#   'Seismic Toss',
#   'Shadow Ball',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Sludge Wave',
#   'Smack Down',
#   'Snore',
#   'Stealth Rock',
#   'Stomping Tantrum',
#   'Stone Edge',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Superpower',
#   'Supersonic',
#   'Surf',
#   'Swagger',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Throat Chop',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Torment',
#   'Toxic',
#   'Toxic Spikes',
#   'Uproar',
#   'Venom Drench',
#   'Venoshock',
#   'Water Gun',
#   'Water Pulse',
#   'Whirlpool'],
#  'Nidoran-M': ['Amnesia',
#   'Attract',
#   'Beat Up',
#   'Blizzard',
#   'Body Slam',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Drill Run',
#   'Earth Power',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Flatter',
#   'Focus Energy',
#   'Fury Attack',
#   'Headbutt',
#   'Head Smash',
#   'Helping Hand',
#   'Hone Claws',
#   'Horn Attack',
#   'Horn Drill',
#   'Ice Beam',
#   'Iron Tail',
#   'Leer',
#   'Mimic',
#   'Mud-Slap',
#   'Peck',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Protect',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Smart Strike',
#   'Snore',
#   'Strength',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Tackle',
#   'Take Down',
#   'Thief',
#   'Thrash',
#   'Thunder',
#   'Thunderbolt',
#   'Toxic',
#   'Toxic Spikes',
#   'Venom Drench',
#   'Venoshock',
#   'Water Pulse'],
#  'Nidorino': ['Amnesia',
#   'Attract',
#   'Beat Up',
#   'Blizzard',
#   'Body Slam',
#   'Bubble Beam',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Drill Run',
#   'Earth Power',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Flatter',
#   'Focus Energy',
#   'Fury Attack',
#   'Headbutt',
#   'Head Smash',
#   'Helping Hand',
#   'Hone Claws',
#   'Horn Attack',
#   'Horn Drill',
#   'Ice Beam',
#   'Iron Tail',
#   'Leer',
#   'Mimic',
#   'Mud-Slap',
#   'Peck',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Protect',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Rock Smash',
#   'Round',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Smart Strike',
#   'Snore',
#   'Stomping Tantrum',
#   'Strength',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Tackle',
#   'Take Down',
#   'Thief',
#   'Thrash',
#   'Thunder',
#   'Thunderbolt',
#   'Toxic',
#   'Toxic Spikes',
#   'Venom Drench',
#   'Venoshock',
#   'Water Gun',
#   'Water Pulse'],
#  'Nidoking': ['Amnesia',
#   'Aqua Tail',
#   'Attract',
#   'Avalanche',
#   'Beat Up',
#   'Blizzard',
#   'Body Press',
#   'Body Slam',
#   'Brick Break',
#   'Bubble Beam',
#   'Bulldoze',
#   'Confide',
#   'Confusion',
#   'Counter',
#   'Curse',
#   'Cut',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Double Team',
#   'Dragon Pulse',
#   'Dragon Tail',
#   'Drill Run',
#   'Dynamic Punch',
#   'Earth Power',
#   'Earthquake',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Fire Blast',
#   'Fire Punch',
#   'Fissure',
#   'Flamethrower',
#   'Flatter',
#   'Fling',
#   'Focus Blast',
#   'Focus Energy',
#   'Focus Punch',
#   'Fury Attack',
#   'Fury Cutter',
#   'Giga Impact',
#   'Headbutt',
#   'Head Smash',
#   'Helping Hand',
#   'Hex',
#   'High Horsepower',
#   'Hone Claws',
#   'Horn Attack',
#   'Horn Drill',
#   'Hyper Beam',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Incinerate',
#   'Iron Tail',
#   'Leer',
#   'Megahorn',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mud Shot',
#   'Mud-Slap',
#   'Outrage',
#   'Pay Day',
#   'Peck',
#   'Poison Jab',
#   'Poison Sting',
#   'Poison Tail',
#   'Power-Up Punch',
#   'Protect',
#   'Quash',
#   'Rain Dance',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Rock Blast',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Sandstorm',
#   'Sand Tomb',
#   'Scorching Sands',
#   'Seismic Toss',
#   'Shadow Ball',
#   'Shadow Claw',
#   'Shock Wave',
#   'Skull Bash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Sludge Wave',
#   'Smack Down',
#   'Smart Strike',
#   'Snore',
#   'Stealth Rock',
#   'Stomping Tantrum',
#   'Stone Edge',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Super Fang',
#   'Superpower',
#   'Supersonic',
#   'Surf',
#   'Swagger',
#   'Tackle',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Thrash',
#   'Throat Chop',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Torment',
#   'Toxic',
#   'Toxic Spikes',
#   'Uproar',
#   'Venom Drench',
#   'Venoshock',
#   'Water Gun',
#   'Water Pulse',
#   'Whirlpool'],
#  'Clefairy': ['After You',
#   'Ally Switch',
#   'Amnesia',
#   'Aromatherapy',
#   'Attract',
#   'Baton Pass',
#   'Belly Drum',
#   'Blizzard',
#   'Body Slam',
#   'Bounce',
#   'Brick Break',
#   'Bubble Beam',
#   'Calm Mind',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Copycat',
#   'Cosmic Power',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Dazzling Gleam',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disarming Voice',
#   'Double-Edge',
#   'Double Team',
#   'Draining Kiss',
#   'Drain Punch',
#   'Dream Eater',
#   'Dual Wingbeat',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Encore',
#   'Endeavor',
#   'Endure',
#   'Facade',
#   'Fake Tears',
#   'Fire Blast',
#   'Fire Punch',
#   'Flamethrower',
#   'Fling',
#   'Focus Punch',
#   'Follow Me',
#   'Grass Knot',
#   'Gravity',
#   'Growl',
#   'Headbutt',
#   'Heal Bell',
#   'Healing Wish',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hyper Voice',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Imprison',
#   'Incinerate',
#   'Iron Tail',
#   'Knock Off',
#   'Last Resort',
#   'Life Dew',
#   'Light Screen',
#   'Magical Leaf',
#   'Magic Coat',
#   'Mega Kick',
#   'Mega Punch',
#   'Meteor Beam',
#   'Meteor Mash',
#   'Metronome',
#   'Mimic',
#   'Minimize',
#   'Misty Explosion',
#   'Misty Terrain',
#   'Moonblast',
#   'Moonlight',
#   'Mud-Slap',
#   'Mystical Fire',
#   'Play Rough',
#   'Pound',
#   'Power-Up Punch',
#   'Present',
#   'Protect',
#   'Psychic',
#   'Psych Up',
#   'Psyshock',
#   'Rain Dance',
#   'Recycle',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Rock Smash',
#   'Role Play',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Seismic Toss',
#   'Shadow Ball',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Soft-Boiled',
#   'Solar Beam',
#   'Splash',
#   'Stealth Rock',
#   'Stored Power',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Kiss',
#   'Take Down',
#   'Teleport',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Tri Attack',
#   'Trick',
#   'Uproar',
#   'Water Gun',
#   'Water Pulse',
#   'Wish',
#   'Wonder Room',
#   'Work Up',
#   'Zap Cannon',
#   'Zen Headbutt'],
#  'Clefable': ['After You',
#   'Ally Switch',
#   'Amnesia',
#   'Aromatherapy',
#   'Attract',
#   'Baton Pass',
#   'Belly Drum',
#   'Blizzard',
#   'Body Slam',
#   'Bounce',
#   'Brick Break',
#   'Bubble Beam',
#   'Calm Mind',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Copycat',
#   'Cosmic Power',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Dazzling Gleam',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disarming Voice',
#   'Double-Edge',
#   'Double Team',
#   'Draining Kiss',
#   'Drain Punch',
#   'Dream Eater',
#   'Dual Wingbeat',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Encore',
#   'Endeavor',
#   'Endure',
#   'Facade',
#   'Fake Tears',
#   'Fire Blast',
#   'Fire Punch',
#   'Flamethrower',
#   'Fling',
#   'Focus Blast',
#   'Focus Punch',
#   'Follow Me',
#   'Giga Impact',
#   'Grass Knot',
#   'Gravity',
#   'Growl',
#   'Headbutt',
#   'Heal Bell',
#   'Healing Wish',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Imprison',
#   'Incinerate',
#   'Iron Tail',
#   'Knock Off',
#   'Laser Focus',
#   'Last Resort',
#   'Life Dew',
#   'Light Screen',
#   'Magical Leaf',
#   'Magic Coat',
#   'Mega Kick',
#   'Mega Punch',
#   'Meteor Beam',
#   'Meteor Mash',
#   'Metronome',
#   'Mimic',
#   'Minimize',
#   'Misty Explosion',
#   'Misty Terrain',
#   'Moonblast',
#   'Moonlight',
#   'Mud-Slap',
#   'Mystical Fire',
#   'Play Rough',
#   'Pound',
#   'Power-Up Punch',
#   'Present',
#   'Protect',
#   'Psychic',
#   'Psych Up',
#   'Psyshock',
#   'Rain Dance',
#   'Recycle',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Rock Smash',
#   'Role Play',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Seismic Toss',
#   'Shadow Ball',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Soft-Boiled',
#   'Solar Beam',
#   'Splash',
#   'Stealth Rock',
#   'Stored Power',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Kiss',
#   'Take Down',
#   'Teleport',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Tri Attack',
#   'Trick',
#   'Uproar',
#   'Water Gun',
#   'Water Pulse',
#   'Wish',
#   'Wonder Room',
#   'Work Up',
#   'Zap Cannon',
#   'Zen Headbutt'],
#  'Vulpix': ['Agility',
#   'Attract',
#   'Baby-Doll Eyes',
#   'Body Slam',
#   'Burning Jealousy',
#   'Charm',
#   'Confide',
#   'Confuse Ray',
#   'Covet',
#   'Curse',
#   'Dark Pulse',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Team',
#   'Ember',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Extrasensory',
#   'Facade',
#   'Fire Blast',
#   'Fire Spin',
#   'Flail',
#   'Flame Charge',
#   'Flamethrower',
#   'Flare Blitz',
#   'Foul Play',
#   'Grudge',
#   'Headbutt',
#   'Heat Wave',
#   'Hex',
#   'Howl',
#   'Hypnosis',
#   'Imprison',
#   'Incinerate',
#   'Inferno',
#   'Iron Tail',
#   'Memento',
#   'Mimic',
#   'Mystical Fire',
#   'Overheat',
#   'Pain Split',
#   'Payback',
#   'Power Swap',
#   'Protect',
#   'Psych Up',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Role Play',
#   'Round',
#   'Safeguard',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Spite',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Tackle',
#   'Tail Slap',
#   'Tail Whip',
#   'Take Down',
#   'Toxic',
#   'Weather Ball',
#   'Will-O-Wisp',
#   'Zen Headbutt'],
#  'Ninetales': ['Agility',
#   'Attract',
#   'Baby-Doll Eyes',
#   'Body Slam',
#   'Burning Jealousy',
#   'Calm Mind',
#   'Charm',
#   'Confide',
#   'Confuse Ray',
#   'Covet',
#   'Curse',
#   'Dark Pulse',
#   'Dig',
#   'Disable',
#   'Double-Edge',
#   'Double Team',
#   'Dream Eater',
#   'Ember',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Extrasensory',
#   'Facade',
#   'Fake Tears',
#   'Fire Blast',
#   'Fire Spin',
#   'Flail',
#   'Flame Charge',
#   'Flamethrower',
#   'Flare Blitz',
#   'Foul Play',
#   'Giga Impact',
#   'Grudge',
#   'Headbutt',
#   'Heat Wave',
#   'Hex',
#   'Howl',
#   'Hyper Beam',
#   'Hypnosis',
#   'Imprison',
#   'Incinerate',
#   'Inferno',
#   'Iron Tail',
#   'Laser Focus',
#   'Memento',
#   'Mimic',
#   'Mystical Fire',
#   'Nasty Plot',
#   'Overheat',
#   'Pain Split',
#   'Payback',
#   'Power Swap',
#   'Protect',
#   'Psych Up',
#   'Psyshock',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Roar',
#   'Role Play',
#   'Round',
#   'Safeguard',
#   'Scorching Sands',
#   'Shadow Ball',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'Spite',
#   'Stored Power',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Tackle',
#   'Tail Slap',
#   'Tail Whip',
#   'Take Down',
#   'Toxic',
#   'Weather Ball',
#   'Will-O-Wisp',
#   'Zen Headbutt'],
#  'Jigglypuff': ['Ally Switch',
#   'Attract',
#   'Baton Pass',
#   'Blizzard',
#   'Body Slam',
#   'Bounce',
#   'Brick Break',
#   'Bubble Beam',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Copycat',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Dazzling Gleam',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Disarming Voice',
#   'Double-Edge',
#   'Double Team',
#   'Draining Kiss',
#   'Drain Punch',
#   'Dream Eater',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Endeavor',
#   'Endure',
#   'Facade',
#   'Fake Tears',
#   'Fire Blast',
#   'Fire Punch',
#   'Flamethrower',
#   'Fling',
#   'Focus Punch',
#   'Grass Knot',
#   'Gravity',
#   'Gyro Ball',
#   'Headbutt',
#   'Heal Bell',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hyper Voice',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Incinerate',
#   'Knock Off',
#   'Last Resort',
#   'Light Screen',
#   'Magic Coat',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Misty Explosion',
#   'Misty Terrain',
#   'Mud-Slap',
#   'Pain Split',
#   'Perish Song',
#   'Play Nice',
#   'Play Rough',
#   'Pound',
#   'Power-Up Punch',
#   'Present',
#   'Protect',
#   'Psychic',
#   'Psych Up',
#   'Rain Dance',
#   'Recycle',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Role Play',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Screech',
#   'Seismic Toss',
#   'Self-Destruct',
#   'Shadow Ball',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'Spit Up',
#   'Stealth Rock',
#   'Steel Roller',
#   'Stockpile',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swallow',
#   'Sweet Kiss',
#   'Take Down',
#   'Teleport',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Tri Attack',
#   'Uproar',
#   'Water Gun',
#   'Water Pulse',
#   'Wild Charge',
#   'Wish',
#   'Work Up',
#   'Zap Cannon'],
#  'Wigglytuff': ['Ally Switch',
#   'Attract',
#   'Baton Pass',
#   'Blizzard',
#   'Body Slam',
#   'Bounce',
#   'Brick Break',
#   'Bubble Beam',
#   'Charge Beam',
#   'Charm',
#   'Confide',
#   'Copycat',
#   'Counter',
#   'Covet',
#   'Curse',
#   'Dazzling Gleam',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Disable',
#   'Disarming Voice',
#   'Double-Edge',
#   'Double Team',
#   'Draining Kiss',
#   'Drain Punch',
#   'Dream Eater',
#   'Dynamic Punch',
#   'Echoed Voice',
#   'Endeavor',
#   'Endure',
#   'Expanding Force',
#   'Facade',
#   'Fake Tears',
#   'Fire Blast',
#   'Fire Punch',
#   'Flamethrower',
#   'Fling',
#   'Focus Blast',
#   'Focus Punch',
#   'Giga Impact',
#   'Grass Knot',
#   'Gravity',
#   'Gyro Ball',
#   'Headbutt',
#   'Heal Bell',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Incinerate',
#   'Knock Off',
#   'Laser Focus',
#   'Last Resort',
#   'Light Screen',
#   'Magic Coat',
#   'Magic Room',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Minimize',
#   'Misty Explosion',
#   'Misty Terrain',
#   'Mud-Slap',
#   'Pain Split',
#   'Perish Song',
#   'Play Nice',
#   'Play Rough',
#   'Pound',
#   'Power-Up Punch',
#   'Present',
#   'Protect',
#   'Psychic',
#   'Psych Up',
#   'Rain Dance',
#   'Recycle',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Role Play',
#   'Rollout',
#   'Round',
#   'Safeguard',
#   'Screech',
#   'Seismic Toss',
#   'Self-Destruct',
#   'Shadow Ball',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'Spit Up',
#   'Stealth Rock',
#   'Steel Roller',
#   'Stockpile',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swallow',
#   'Sweet Kiss',
#   'Take Down',
#   'Teleport',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Punch',
#   'Thunder Wave',
#   'Tickle',
#   'Toxic',
#   'Tri Attack',
#   'Uproar',
#   'Water Gun',
#   'Water Pulse',
#   'Wild Charge',
#   'Wish',
#   'Work Up',
#   'Zap Cannon'],
#  'Zubat': ['Absorb',
#   'Acrobatics',
#   'Aerial Ace',
#   'Agility',
#   'Air Cutter',
#   'Air Slash',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Bite',
#   'Brave Bird',
#   'Confide',
#   'Confuse Ray',
#   'Crunch',
#   'Curse',
#   'Defog',
#   'Detect',
#   'Double-Edge',
#   'Double Team',
#   'Dual Wingbeat',
#   'Endure',
#   'Facade',
#   'Fly',
#   'Giga Drain',
#   'Gust',
#   'Haze',
#   'Headbutt',
#   'Heat Wave',
#   'Hypnosis',
#   'Leech Life',
#   'Mean Look',
#   'Mega Drain',
#   'Mimic',
#   'Nasty Plot',
#   'Payback',
#   'Pluck',
#   'Poison Fang',
#   'Protect',
#   'Quick Attack',
#   'Quick Guard',
#   'Rain Dance',
#   'Rest',
#   'Roost',
#   'Round',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Steel Wing',
#   'Substitute',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Swift',
#   'Tailwind',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Torment',
#   'Toxic',
#   'Twister',
#   'Uproar',
#   'U-turn',
#   'Venom Drench',
#   'Venoshock',
#   'Whirlwind',
#   'Wing Attack',
#   'Zen Headbutt'],
#  'Golbat': ['Absorb',
#   'Acrobatics',
#   'Aerial Ace',
#   'Agility',
#   'Air Cutter',
#   'Air Slash',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Bite',
#   'Brave Bird',
#   'Confide',
#   'Confuse Ray',
#   'Crunch',
#   'Curse',
#   'Defog',
#   'Detect',
#   'Double-Edge',
#   'Double Team',
#   'Dual Wingbeat',
#   'Endure',
#   'Facade',
#   'Fly',
#   'Giga Drain',
#   'Giga Impact',
#   'Gust',
#   'Haze',
#   'Headbutt',
#   'Heat Wave',
#   'Hyper Beam',
#   'Hypnosis',
#   'Leech Life',
#   'Mean Look',
#   'Mega Drain',
#   'Mimic',
#   'Nasty Plot',
#   'Payback',
#   'Pluck',
#   'Poison Fang',
#   'Protect',
#   'Quick Attack',
#   'Quick Guard',
#   'Rain Dance',
#   'Rest',
#   'Roost',
#   'Round',
#   'Screech',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Steel Wing',
#   'Substitute',
#   'Sunny Day',
#   'Super Fang',
#   'Supersonic',
#   'Swagger',
#   'Swift',
#   'Tailwind',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Torment',
#   'Toxic',
#   'Twister',
#   'Uproar',
#   'U-turn',
#   'Venom Drench',
#   'Venoshock',
#   'Whirlwind',
#   'Wing Attack',
#   'Zen Headbutt'],
#  'Oddish': ['Absorb',
#   'Acid',
#   'After You',
#   'Attract',
#   'Bullet Seed',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Dazzling Gleam',
#   'Double-Edge',
#   'Double Team',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'Flail',
#   'Gastro Acid',
#   'Giga Drain',
#   'Grass Knot',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growth',
#   'Headbutt',
#   'Infestation',
#   'Ingrain',
#   'Leech Seed',
#   'Mega Drain',
#   'Mimic',
#   'Moonblast',
#   'Moonlight',
#   'Nature Power',
#   'Petal Dance',
#   'Poison Powder',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Seed Bomb',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Solar Beam',
#   'Strength Sap',
#   'Stun Spore',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Take Down',
#   'Teeter Dance',
#   'Tickle',
#   'Toxic',
#   'Venoshock',
#   'Worry Seed'],
#  'Gloom': ['Absorb',
#   'Acid',
#   'After You',
#   'Attract',
#   'Bullet Seed',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Dazzling Gleam',
#   'Double-Edge',
#   'Double Team',
#   'Drain Punch',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'Flail',
#   'Fling',
#   'Gastro Acid',
#   'Giga Drain',
#   'Grass Knot',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growth',
#   'Headbutt',
#   'Infestation',
#   'Ingrain',
#   'Leech Seed',
#   'Mega Drain',
#   'Mimic',
#   'Moonblast',
#   'Moonlight',
#   'Nature Power',
#   'Petal Blizzard',
#   'Petal Dance',
#   'Poison Powder',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Seed Bomb',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Solar Beam',
#   'Strength Sap',
#   'Stun Spore',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Take Down',
#   'Teeter Dance',
#   'Tickle',
#   'Toxic',
#   'Venoshock',
#   'Worry Seed'],
#  'Vileplume': ['Absorb',
#   'Acid',
#   'After You',
#   'Aromatherapy',
#   'Attract',
#   'Body Slam',
#   'Bullet Seed',
#   'Charm',
#   'Confide',
#   'Corrosive Gas',
#   'Curse',
#   'Cut',
#   'Dazzling Gleam',
#   'Double-Edge',
#   'Double Team',
#   'Drain Punch',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'Flail',
#   'Fling',
#   'Gastro Acid',
#   'Giga Drain',
#   'Giga Impact',
#   'Grass Knot',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growth',
#   'Headbutt',
#   'Hyper Beam',
#   'Infestation',
#   'Ingrain',
#   'Leech Seed',
#   'Mega Drain',
#   'Mimic',
#   'Moonblast',
#   'Moonlight',
#   'Nature Power',
#   'Petal Blizzard',
#   'Petal Dance',
#   'Poison Powder',
#   'Pollen Puff',
#   'Protect',
#   'Razor Leaf',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Safeguard',
#   'Seed Bomb',
#   'Sleep Powder',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Sludge Wave',
#   'Snore',
#   'Solar Beam',
#   'Strength Sap',
#   'Stun Spore',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Sweet Scent',
#   'Swords Dance',
#   'Synthesis',
#   'Take Down',
#   'Teeter Dance',
#   'Tickle',
#   'Toxic',
#   'Venoshock',
#   'Worry Seed'],
#  'Diglett': ['Aerial Ace',
#   'Agility',
#   'Ally Switch',
#   'Ancient Power',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Beat Up',
#   'Body Slam',
#   'Bulldoze',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Earth Power',
#   'Earthquake',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Final Gambit',
#   'Fissure',
#   'Fury False Swipes',
#   'Growl',
#   'Headbutt',
#   'Hone Claws',
#   'Memento',
#   'Mimic',
#   'Mud-Slap',
#   'Protect',
#   'Rest',
#   'Reversal',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Sand Attack',
#   'Sandstorm',
#   'Scorching Sands',
#   'Scratch',
#   'Screech',
#   'Shadow Claw',
#   'Slash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Snore',
#   'Stealth Rock',
#   'Stomping Tantrum',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Swagger',
#   'Take Down',
#   'Thief',
#   'Toxic',
#   'Uproar',
#   'Work Up'],
#  'Dugtrio': ['Aerial Ace',
#   'Agility',
#   'Ally Switch',
#   'Ancient Power',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Beat Up',
#   'Body Slam',
#   'Bulldoze',
#   'Charm',
#   'Confide',
#   'Curse',
#   'Cut',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Earth Power',
#   'Earthquake',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Final Gambit',
#   'Fissure',
#   'Fury False Swipes',
#   'Giga Impact',
#   'Growl',
#   'Headbutt',
#   'High Horsepower',
#   'Hone Claws',
#   'Hyper Beam',
#   'Memento',
#   'Mimic',
#   'Mud-Slap',
#   'Night Slash',
#   'Protect',
#   'Rest',
#   'Reversal',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Sand Attack',
#   'Sandstorm',
#   'Sand Tomb',
#   'Scorching Sands',
#   'Scratch',
#   'Screech',
#   'Shadow Claw',
#   'Slash',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Sludge Wave',
#   'Snore',
#   'Stealth Rock',
#   'Stomping Tantrum',
#   'Stone Edge',
#   'Substitute',
#   'Sucker Punch',
#   'Sunny Day',
#   'Swagger',
#   'Take Down',
#   'Thief',
#   'Toxic',
#   'Tri Attack',
#   'Uproar',
#   'Work Up'],
#  'Meowth': ['Aerial Ace',
#   'Amnesia',
#   'Assurance',
#   'Attract',
#   'Bite',
#   'Body Slam',
#   'Bubble Beam',
#   'Charm',
#   'Confide',
#   'Covet',
#   'Curse',
#   'Cut',
#   'Dark Pulse',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dream Eater',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Fake Out',
#   'Feint',
#   'Flail',
#   'Foul Play',
#   'Fury False Swipes',
#   'Growl',
#   'Gunk Shot',
#   'Happy Hour',
#   'Headbutt',
#   'Hone Claws',
#   'Hyper Voice',
#   'Hypnosis',
#   'Icy Wind',
#   'Iron Tail',
#   'Knock Off',
#   'Lash Out',
#   'Last Resort',
#   'Mimic',
#   'Mud-Slap',
#   'Nasty Plot',
#   'Night Slash',
#   'Payback',
#   'Pay Day',
#   'Petal Dance',
#   'Play Rough',
#   'Protect',
#   'Psych Up',
#   'Rain Dance',
#   'Rest',
#   'Retaliate',
#   'Round',
#   'Scratch',
#   'Screech',
#   'Seed Bomb',
#   'Shadow Ball',
#   'Shadow Claw',
#   'Shock Wave',
#   'Sing',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Snore',
#   'Spite',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Throat Chop',
#   'Thunder',
#   'Thunderbolt',
#   'Torment',
#   'Toxic',
#   'Uproar',
#   'U-turn',
#   'Water Gun',
#   'Water Pulse',
#   'Work Up',
#   'Zap Cannon'],
#  'Persian': ['Aerial Ace',
#   'Amnesia',
#   'Assurance',
#   'Attract',
#   'Bite',
#   'Body Slam',
#   'Bubble Beam',
#   'Charm',
#   'Confide',
#   'Covet',
#   'Curse',
#   'Cut',
#   'Dark Pulse',
#   'Defense Curl',
#   'Detect',
#   'Dig',
#   'Double-Edge',
#   'Double Team',
#   'Dream Eater',
#   'Echoed Voice',
#   'Endure',
#   'Facade',
#   'Fake Out',
#   'Feint',
#   'Flail',
#   'Foul Play',
#   'Fury False Swipes',
#   'Giga Impact',
#   'Growl',
#   'Gunk Shot',
#   'Happy Hour',
#   'Headbutt',
#   'Hone Claws',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Hypnosis',
#   'Icy Wind',
#   'Iron Tail',
#   'Knock Off',
#   'Lash Out',
#   'Last Resort',
#   'Mimic',
#   'Mud-Slap',
#   'Nasty Plot',
#   'Night Slash',
#   'Payback',
#   'Pay Day',
#   'Petal Dance',
#   'Play Rough',
#   'Power Gem',
#   'Protect',
#   'Psych Up',
#   'Rain Dance',
#   'Rest',
#   'Retaliate',
#   'Roar',
#   'Round',
#   'Scratch',
#   'Screech',
#   'Seed Bomb',
#   'Shadow Ball',
#   'Shadow Claw',
#   'Shock Wave',
#   'Sing',
#   'Skitter Smack',
#   'Skull Bash',
#   'Slash',
#   'Sleep Talk',
#   'Snore',
#   'Spite',
#   'Substitute',
#   'Sunny Day',
#   'Swagger',
#   'Swift',
#   'Switcheroo',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thief',
#   'Throat Chop',
#   'Thunder',
#   'Thunderbolt',
#   'Torment',
#   'Toxic',
#   'Uproar',
#   'U-turn',
#   'Water Gun',
#   'Water Pulse',
#   'Work Up',
#   'Zap Cannon'],
#  'Psyduck': ['Aerial Ace',
#   'Amnesia',
#   'Aqua Tail',
#   'Attract',
#   'Blizzard',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bubble Beam',
#   'Calm Mind',
#   'Clear Smog',
#   'Confide',
#   'Confuse Ray',
#   'Confusion',
#   'Counter',
#   'Cross Chop',
#   'Curse',
#   'Dig',
#   'Disable',
#   'Dive',
#   'Double-Edge',
#   'Double Team',
#   'Dynamic Punch',
#   'Encore',
#   'Endure',
#   'Facade',
#   'Fling',
#   'Focus Punch',
#   'Fury False Swipes',
#   'Future Sight',
#   'Hail',
#   'Headbutt',
#   'Hone Claws',
#   'Hydro Pump',
#   'Hypnosis',
#   'Ice Beam',
#   'Ice Punch',
#   'Icy Wind',
#   'Iron Tail',
#   'Light Screen',
#   'Mega Kick',
#   'Mega Punch',
#   'Mimic',
#   'Mud-Slap',
#   'Pay Day',
#   'Power-Up Punch',
#   'Protect',
#   'Psybeam',
#   'Psychic',
#   'Psych Up',
#   'Psyshock',
#   'Rain Dance',
#   'Rest',
#   'Rock Smash',
#   'Role Play',
#   'Round',
#   'Scald',
#   'Scratch',
#   'Screech',
#   'Seismic Toss',
#   'Shadow Claw',
#   'Simple Beam',
#   'Skull Bash',
#   'Sleep Talk',
#   'Snore',
#   'Soak',
#   'Strength',
#   'Submission',
#   'Substitute',
#   'Surf',
#   'Swagger',
#   'Swift',
#   'Tail Whip',
#   'Take Down',
#   'Toxic',
#   'Waterfall',
#   'Water Gun',
#   'Water Pulse',
#   'Whirlpool',
#   'Wonder Room',
#   'Worry Seed',
#   'Yawn',
#   'Zen Headbutt'],
#  'Golduck': ['Aerial Ace',
#   'Amnesia',
#   'Aqua Jet',
#   'Aqua Tail',
#   'Attract',
#   'Blizzard',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bubble Beam',
# ...
#   'Metal Claw',
#   'Metal Sound',
#   'Mirror Coat',
#   'Night Slash',
#   'Outrage',
#   'Protect',
#   'Reflect',
#   'Rest',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Scary Face',
#   'Screech',
#   'Slash',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Stealth Rock',
#   'Steel Beam',
#   'Steel Roller',
#   'Stomping Tantrum',
#   'Stone Edge',
#   'Substitute',
#   'Swords Dance',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Wave'],
#  'Dreepy': ['Astonish',
#   'Attract',
#   'Baton Pass',
#   'Bite',
#   'Confuse Ray',
#   'Curse',
#   'Disable',
#   'Double Team',
#   'Draco Meteor',
#   'Dragon Tail',
#   'Endure',
#   'Facade',
#   'Grudge',
#   'Helping Hand',
#   'Infestation',
#   'Protect',
#   'Quick Attack',
#   'Rest',
#   'Round',
#   'Sleep Talk',
#   'Snore',
#   'Substitute',
#   'Sucker Punch',
#   'Swift',
#   'Thunder Wave'],
#  'Drakloak': ['Acrobatics',
#   'Agility',
#   'Ally Switch',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Baton Pass',
#   'Beat Up',
#   'Bite',
#   'Breaking False Swipe',
#   'Brine',
#   'Confuse Ray',
#   'Curse',
#   'Disable',
#   'Dive',
#   'Double-Edge',
#   'Double Hit',
#   'Double Team',
#   'Draco Meteor',
#   'Dragon Dance',
#   'Dragon Pulse',
#   'Dragon Rush',
#   'Dragon Tail',
#   'Endure',
#   'Facade',
#   'Fire Blast',
#   'Flamethrower',
#   'Grudge',
#   'Helping Hand',
#   'Hex',
#   'Hydro Pump',
#   'Infestation',
#   'Last Resort',
#   'Lock-On',
#   'Outrage',
#   'Phantom Force',
#   'Protect',
#   'Psychic Fangs',
#   'Quick Attack',
#   'Rest',
#   'Round',
#   'Scald',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Snore',
#   'Steel Wing',
#   'Substitute',
#   'Sucker Punch',
#   'Surf',
#   'Swift',
#   'Take Down',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Wave',
#   'U-turn',
#   'Will-O-Wisp'],
#  'Dragapult': ['Acrobatics',
#   'Agility',
#   'Ally Switch',
#   'Assurance',
#   'Astonish',
#   'Attract',
#   'Baton Pass',
#   'Beat Up',
#   'Bite',
#   'Body Slam',
#   'Breaking False Swipe',
#   'Brine',
#   'Confuse Ray',
#   'Curse',
#   'Disable',
#   'Dive',
#   'Double-Edge',
#   'Double Hit',
#   'Double Team',
#   'Draco Meteor',
#   'Dragon Breath',
#   'Dragon Claw',
#   'Dragon Dance',
#   'Dragon Darts',
#   'Dragon Pulse',
#   'Dragon Rush',
#   'Dragon Tail',
#   'Endure',
#   'Facade',
#   'Fire Blast',
#   'Flamethrower',
#   'Fly',
#   'Giga Impact',
#   'Grudge',
#   'Helping Hand',
#   'Hex',
#   'Hydro Pump',
#   'Hyper Beam',
#   'Infestation',
#   'Last Resort',
#   'Light Screen',
#   'Lock-On',
#   'Outrage',
#   'Phantom Force',
#   'Protect',
#   'Psychic Fangs',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Scald',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'Steel Wing',
#   'Substitute',
#   'Sucker Punch',
#   'Surf',
#   'Swift',
#   'Take Down',
#   'Thief',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Wave',
#   'Tri Attack',
#   'U-turn',
#   'Will-O-Wisp'],
#  'Zacian': ['Agility',
#   'Air Slash',
#   'Assurance',
#   'Bite',
#   'Brick Break',
#   'Brutal Swing',
#   'Close Combat',
#   'Crunch',
#   'Dig',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Fang',
#   'Focus Blast',
#   'Focus Energy',
#   'Giga Impact',
#   'Helping Hand',
#   'Howl',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Ice Fang',
#   'Imprison',
#   'Iron Head',
#   'Iron Tail',
#   'Laser Focus',
#   'Metal Claw',
#   'Moonblast',
#   'Play Rough',
#   'Protect',
#   'Psychic Fangs',
#   'Psycho Cut',
#   'Quick Attack',
#   'Quick Guard',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Round',
#   'Sacred Sword',
#   'Scary Face',
#   'Slash',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Blade',
#   'Steel Beam',
#   'Substitute',
#   'Swift',
#   'Swords Dance',
#   'Tail Slap',
#   'Thunder Fang',
#   'Wild Charge',
#   'Work Up'],
#  'Zamazenta': ['Agility',
#   'Bite',
#   'Close Combat',
#   'Coaching',
#   'Crunch',
#   'Dazzling Gleam',
#   'Dig',
#   'Endure',
#   'Facade',
#   'Fire Fang',
#   'Flash Cannon',
#   'Focus Blast',
#   'Focus Energy',
#   'Giga Impact',
#   'Guard Swap',
#   'Helping Hand',
#   'Howl',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Ice Fang',
#   'Imprison',
#   'Iron Defense',
#   'Iron Head',
#   'Iron Tail',
#   'Laser Focus',
#   'Light Screen',
#   'Metal Burst',
#   'Metal Claw',
#   'Moonblast',
#   'Payback',
#   'Play Rough',
#   'Power Swap',
#   'Protect',
#   'Psychic Fangs',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Round',
#   'Safeguard',
#   'Scary Face',
#   'Slash',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Steel Beam',
#   'Substitute',
#   'Swift',
#   'Tail Slap',
#   'Thunder Fang',
#   'Wide Guard',
#   'Wild Charge',
#   'Work Up'],
#  'Zamazenta-Crowned': ['Agility',
#   'Behemoth Bash',
#   'Bite',
#   'Close Combat',
#   'Coaching',
#   'Crunch',
#   'Dazzling Gleam',
#   'Dig',
#   'Endure',
#   'Facade',
#   'Fire Fang',
#   'Flash Cannon',
#   'Focus Blast',
#   'Focus Energy',
#   'Giga Impact',
#   'Guard Swap',
#   'Helping Hand',
#   'Howl',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Ice Fang',
#   'Imprison',
#   'Iron Defense',
#   'Iron Head',
#   'Iron Tail',
#   'Laser Focus',
#   'Light Screen',
#   'Metal Burst',
#   'Metal Claw',
#   'Moonblast',
#   'Payback',
#   'Play Rough',
#   'Power Swap',
#   'Protect',
#   'Psychic Fangs',
#   'Quick Attack',
#   'Reflect',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Round',
#   'Safeguard',
#   'Scary Face',
#   'Slash',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Steel Beam',
#   'Substitute',
#   'Swift',
#   'Tail Slap',
#   'Thunder Fang',
#   'Wide Guard',
#   'Wild Charge',
#   'Work Up'],
#  'Eternatus': ['Agility',
#   'Assurance',
#   'Brutal Swing',
#   'Confuse Ray',
#   'Cosmic Power',
#   'Cross Poison',
#   'Draco Meteor',
#   'Dragon Dance',
#   'Dragon Pulse',
#   'Dragon Tail',
#   'Dynamax Cannon',
#   'Endure',
#   'Eternabeam',
#   'Facade',
#   'Flamethrower',
#   'Flash Cannon',
#   'Fly',
#   'Giga Impact',
#   'Hyper Beam',
#   'Light Screen',
#   'Meteor Beam',
#   'Mystical Fire',
#   'Payback',
#   'Poison Jab',
#   'Poison Tail',
#   'Protect',
#   'Recover',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Scary Face',
#   'Screech',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Sludge Bomb',
#   'Sludge Wave',
#   'Snore',
#   'Solar Beam',
#   'Substitute',
#   'Toxic',
#   'Toxic Spikes',
#   'Venom Drench',
#   'Venoshock'],
#  'Kubfu': ['Acrobatics',
#   'Aerial Ace',
#   'Attract',
#   'Body Slam',
#   'Brick Break',
#   'Bulk Up',
#   'Close Combat',
#   'Coaching',
#   'Counter',
#   'Detect',
#   'Dig',
#   'Dynamic Punch',
#   'Endure',
#   'Facade',
#   'Fire Punch',
#   'Focus Energy',
#   'Focus Punch',
#   'Headbutt',
#   'Helping Hand',
#   'Ice Punch',
#   'Iron Head',
#   'Leer',
#   'Low Kick',
#   'Low Sweep',
#   'Mega Kick',
#   'Mega Punch',
#   'Protect',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Rock Smash',
#   'Round',
#   'Scary Face',
#   'Sleep Talk',
#   'Snore',
#   'Substitute',
#   'Superpower',
#   'Thunder Punch',
#   'U-turn',
#   'Work Up',
#   'Zen Headbutt'],
#  'Urshifu': ['Acrobatics',
#   'Aerial Ace',
#   'Assurance',
#   'Attract',
#   'Aura Sphere',
#   'Beat Up',
#   'Body Press',
#   'Body Slam',
#   'Brick Break',
#   'Bulk Up',
#   'Close Combat',
#   'Coaching',
#   'Counter',
#   'Crunch',
#   'Darkest Lariat',
#   'Dark Pulse',
#   'Detect',
#   'Dig',
#   'Drain Punch',
#   'Dynamic Punch',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Punch',
#   'Fling',
#   'Focus Blast',
#   'Focus Energy',
#   'Focus Punch',
#   'Foul Play',
#   'Giga Impact',
#   'Headbutt',
#   'Helping Hand',
#   'Ice Punch',
#   'Iron Defense',
#   'Iron Head',
#   'Lash Out',
#   'Leer',
#   'Low Kick',
#   'Low Sweep',
#   'Mega Kick',
#   'Mega Punch',
#   'Payback',
#   'Poison Jab',
#   'Protect',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Scary Face',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Stone Edge',
#   'Substitute',
#   'Sucker Punch',
#   'Superpower',
#   'Swift',
#   'Taunt',
#   'Throat Chop',
#   'Thunder Punch',
#   'U-turn',
#   'Wicked Blow',
#   'Work Up',
#   'Zen Headbutt'],
#  'Urshifu-Rapid-Strike': ['Acrobatics',
#   'Aerial Ace',
#   'Aqua Jet',
#   'Attract',
#   'Aura Sphere',
#   'Body Press',
#   'Body Slam',
#   'Brick Break',
#   'Brine',
#   'Bulk Up',
#   'Close Combat',
#   'Coaching',
#   'Counter',
#   'Detect',
#   'Dig',
#   'Dive',
#   'Drain Punch',
#   'Dynamic Punch',
#   'Endure',
#   'Facade',
#   'False Swipe',
#   'Fire Punch',
#   'Focus Blast',
#   'Focus Energy',
#   'Focus Punch',
#   'Giga Impact',
#   'Headbutt',
#   'Helping Hand',
#   'Ice Punch',
#   'Iron Defense',
#   'Iron Head',
#   'Leer',
#   'Liquidation',
#   'Low Kick',
#   'Low Sweep',
#   'Mega Kick',
#   'Mega Punch',
#   'Poison Jab',
#   'Protect',
#   'Rain Dance',
#   'Rest',
#   'Retaliate',
#   'Revenge',
#   'Reversal',
#   'Rock Slide',
#   'Rock Smash',
#   'Rock Tomb',
#   'Round',
#   'Scald',
#   'Scary Face',
#   'Sleep Talk',
#   'Snore',
#   'Stone Edge',
#   'Substitute',
#   'Superpower',
#   'Surging Strikes',
#   'Swift',
#   'Taunt',
#   'Thunder Punch',
#   'U-turn',
#   'Waterfall',
#   'Whirlpool',
#   'Work Up',
#   'Zen Headbutt'],
#  'Zarude': ['Acrobatics',
#   'Assurance',
#   'Bind',
#   'Bite',
#   'Body Slam',
#   'Brick Break',
#   'Brutal Swing',
#   'Bulk Up',
#   'Bullet Seed',
#   'Close Combat',
#   'Crunch',
#   'Darkest Lariat',
#   'Dark Pulse',
#   'Dig',
#   'Drain Punch',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Facade',
#   'Fling',
#   'Fury False Swipes',
#   'Giga Drain',
#   'Giga Impact',
#   'Grass Knot',
#   'Grassy Glide',
#   'Grassy Terrain',
#   'Growth',
#   'Hammer Arm',
#   'Hyper Beam',
#   'Hyper Voice',
#   'Iron Tail',
#   'Jungle Healing',
#   'Lash Out',
#   'Leer',
#   'Low Kick',
#   'Magical Leaf',
#   'Mega Kick',
#   'Mega Punch',
#   'Mud Shot',
#   'Nasty Plot',
#   'Payback',
#   'Power Whip',
#   'Protect',
#   'Rest',
#   'Revenge',
#   'Rock Slide',
#   'Rock Tomb',
#   'Round',
#   'Scary Face',
#   'Scratch',
#   'Seed Bomb',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Solar Blade',
#   'Stomping Tantrum',
#   'Substitute',
#   'Sunny Day',
#   'Superpower',
#   'Swagger',
#   'Swift',
#   'Synthesis',
#   'Taunt',
#   'Thief',
#   'Thrash',
#   'Throat Chop',
#   'U-turn',
#   'Vine Whip'],
#  'Regieleki': ['Acrobatics',
#   'Agility',
#   'Ancient Power',
#   'Assurance',
#   'Body Slam',
#   'Bounce',
#   'Eerie Impulse',
#   'Electric Terrain',
#   'Electro Ball',
#   'Electroweb',
#   'Endure',
#   'Explosion',
#   'Extreme Speed',
#   'Facade',
#   'Giga Impact',
#   'Hyper Beam',
#   'Light Screen',
#   'Lock-On',
#   'Magnet Rise',
#   'Protect',
#   'Rain Dance',
#   'Rapid Spin',
#   'Reflect',
#   'Rest',
#   'Rising Voltage',
#   'Round',
#   'Screech',
#   'Self-Destruct',
#   'Shock Wave',
#   'Sleep Talk',
#   'Snore',
#   'Substitute',
#   'Swift',
#   'Thrash',
#   'Thunder',
#   'Thunderbolt',
#   'Thunder Cage',
#   'Thunder Shock',
#   'Thunder Wave',
#   'Volt Switch',
#   'Wild Charge',
#   'Zap Cannon'],
#  'Regidrago': ['Ancient Power',
#   'Bite',
#   'Body Slam',
#   'Breaking False Swipe',
#   'Crunch',
#   'Draco Meteor',
#   'Dragon Breath',
#   'Dragon Claw',
#   'Dragon Dance',
#   'Dragon Energy',
#   'Dragon Pulse',
#   'Endure',
#   'Explosion',
#   'Facade',
#   'Fire Fang',
#   'Focus Energy',
#   'Giga Impact',
#   'Hammer Arm',
#   'Hyper Beam',
#   'Laser Focus',
#   'Light Screen',
#   'Outrage',
#   'Protect',
#   'Reflect',
#   'Rest',
#   'Reversal',
#   'Round',
#   'Scale Shot',
#   'Self-Destruct',
#   'Sleep Talk',
#   'Snore',
#   'Substitute',
#   'Thrash',
#   'Thunder Fang',
#   'Twister',
#   'Vice Grip'],
#  'Glastrier': ['Assurance',
#   'Avalanche',
#   'Blizzard',
#   'Body Press',
#   'Body Slam',
#   'Bulldoze',
#   'Close Combat',
#   'Crunch',
#   'Double-Edge',
#   'Double Kick',
#   'Endure',
#   'Facade',
#   'Giga Impact',
#   'Hail',
#   'Heavy Slam',
#   'High Horsepower',
#   'Hyper Beam',
#   'Ice Beam',
#   'Icicle Crash',
#   'Icicle Spear',
#   'Icy Wind',
#   'Iron Defense',
#   'Lash Out',
#   'Megahorn',
#   'Mist',
#   'Mud Shot',
#   'Outrage',
#   'Payback',
#   'Protect',
#   'Rest',
#   'Round',
#   'Scary Face',
#   'Sleep Talk',
#   'Smart Strike',
#   'Snarl',
#   'Snore',
#   'Stomp',
#   'Stomping Tantrum',
#   'Substitute',
#   'Superpower',
#   'Swords Dance',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thrash',
#   'Throat Chop',
#   'Torment',
#   'Uproar'],
#  'Spectrier': ['Agility',
#   'Assurance',
#   'Body Slam',
#   'Bulldoze',
#   'Calm Mind',
#   'Confuse Ray',
#   'Crunch',
#   'Dark Pulse',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Endure',
#   'Facade',
#   'Foul Play',
#   'Giga Impact',
#   'Haze',
#   'Hex',
#   'Hyper Beam',
#   'Lash Out',
#   'Mud Shot',
#   'Nasty Plot',
#   'Payback',
#   'Phantom Force',
#   'Protect',
#   'Psycho Cut',
#   'Rest',
#   'Round',
#   'Scary Face',
#   'Shadow Ball',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Stomp',
#   'Stomping Tantrum',
#   'Substitute',
#   'Swift',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thrash',
#   'Uproar',
#   'Will-O-Wisp'],
#  'Calyrex': ['Agility',
#   'Ally Switch',
#   'Aromatherapy',
#   'Baton Pass',
#   'Bullet Seed',
#   'Calm Mind',
#   'Confusion',
#   'Draining Kiss',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Expanding Force',
#   'Facade',
#   'Future Sight',
#   'Giga Drain',
#   'Giga Impact',
#   'Grass Knot',
#   'Grassy Terrain',
#   'Growth',
#   'Guard Swap',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hyper Beam',
#   'Imprison',
#   'Leaf Storm',
#   'Leech Seed',
#   'Life Dew',
#   'Light Screen',
#   'Magical Leaf',
#   'Magic Room',
#   'Mega Drain',
#   'Metronome',
#   'Pay Day',
#   'Pollen Puff',
#   'Pound',
#   'Power Swap',
#   'Protect',
#   'Psychic',
#   'Psychic Terrain',
#   'Psyshock',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Safeguard',
#   'Seed Bomb',
#   'Skill Swap',
#   'Sleep Talk',
#   'Snore',
#   'Solar Beam',
#   'Solar Blade',
#   'Speed Swap',
#   'Stored Power',
#   'Substitute',
#   'Sunny Day',
#   'Swift',
#   'Tri Attack',
#   'Trick',
#   'Trick Room',
#   'Wonder Room',
#   'Zen Headbutt'],
#  'Calyrex-Ice': ['Agility',
#   'Ally Switch',
#   'Aromatherapy',
#   'Assurance',
#   'Avalanche',
#   'Baton Pass',
#   'Blizzard',
#   'Body Press',
#   'Body Slam',
#   'Bulldoze',
#   'Bullet Seed',
#   'Calm Mind',
#   'Close Combat',
#   'Confusion',
#   'Crunch',
#   'Double-Edge',
#   'Double Kick',
#   'Draining Kiss',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Expanding Force',
#   'Facade',
#   'Future Sight',
#   'Giga Drain',
#   'Giga Impact',
#   'Glacial Lance',
#   'Grass Knot',
#   'Grassy Terrain',
#   'Growth',
#   'Guard Swap',
#   'Hail',
#   'Heal Pulse',
#   'Heavy Slam',
#   'Helping Hand',
#   'High Horsepower',
#   'Hyper Beam',
#   'Ice Beam',
#   'Icicle Crash',
#   'Icicle Spear',
#   'Icy Wind',
#   'Imprison',
#   'Iron Defense',
#   'Lash Out',
#   'Leaf Storm',
#   'Leech Seed',
#   'Life Dew',
#   'Light Screen',
#   'Magical Leaf',
#   'Magic Room',
#   'Mega Drain',
#   'Megahorn',
#   'Metronome',
#   'Mist',
#   'Mud Shot',
#   'Outrage',
#   'Payback',
#   'Pay Day',
#   'Pollen Puff',
#   'Pound',
#   'Power Swap',
#   'Protect',
#   'Psychic',
#   'Psychic Terrain',
#   'Psyshock',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Safeguard',
#   'Scary Face',
#   'Seed Bomb',
#   'Skill Swap',
#   'Sleep Talk',
#   'Smart Strike',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Solar Blade',
#   'Speed Swap',
#   'Stomp',
#   'Stomping Tantrum',
#   'Stored Power',
#   'Substitute',
#   'Sunny Day',
#   'Superpower',
#   'Swift',
#   'Swords Dance',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thrash',
#   'Throat Chop',
#   'Torment',
#   'Tri Attack',
#   'Trick',
#   'Trick Room',
#   'Uproar',
#   'Wonder Room',
#   'Zen Headbutt'],
#  'Calyrex-Shadow': ['Agility',
#   'Ally Switch',
#   'Aromatherapy',
#   'Assurance',
#   'Astral Barrage',
#   'Baton Pass',
#   'Body Slam',
#   'Bulldoze',
#   'Bullet Seed',
#   'Calm Mind',
#   'Confuse Ray',
#   'Confusion',
#   'Crunch',
#   'Dark Pulse',
#   'Disable',
#   'Double-Edge',
#   'Double Kick',
#   'Draining Kiss',
#   'Encore',
#   'Endure',
#   'Energy Ball',
#   'Expanding Force',
#   'Facade',
#   'Foul Play',
#   'Future Sight',
#   'Giga Drain',
#   'Giga Impact',
#   'Grass Knot',
#   'Grassy Terrain',
#   'Growth',
#   'Guard Swap',
#   'Haze',
#   'Heal Pulse',
#   'Helping Hand',
#   'Hex',
#   'Hyper Beam',
#   'Imprison',
#   'Lash Out',
#   'Leaf Storm',
#   'Leech Seed',
#   'Life Dew',
#   'Light Screen',
#   'Magical Leaf',
#   'Magic Room',
#   'Mega Drain',
#   'Metronome',
#   'Mud Shot',
#   'Nasty Plot',
#   'Payback',
#   'Pay Day',
#   'Phantom Force',
#   'Pollen Puff',
#   'Pound',
#   'Power Swap',
#   'Protect',
#   'Psychic',
#   'Psychic Terrain',
#   'Psycho Cut',
#   'Psyshock',
#   'Reflect',
#   'Rest',
#   'Round',
#   'Safeguard',
#   'Scary Face',
#   'Seed Bomb',
#   'Shadow Ball',
#   'Skill Swap',
#   'Sleep Talk',
#   'Snarl',
#   'Snore',
#   'Solar Beam',
#   'Solar Blade',
#   'Speed Swap',
#   'Stomp',
#   'Stomping Tantrum',
#   'Stored Power',
#   'Substitute',
#   'Sunny Day',
#   'Swift',
#   'Tackle',
#   'Tail Whip',
#   'Take Down',
#   'Taunt',
#   'Thrash',
#   'Tri Attack',
#   'Trick',
#   'Trick Room',
#   'Uproar',
#   'Will-O-Wisp',
#   'Wonder Room',
#   'Zen Headbutt']}

# %% [markdown]
# Now we can easily use this dictionary, in the same manner as we used dataframes before, to fill pokemon_learnsets_df:

# %%
for pokemon in pokemon_df.index:
    pokemon_cleaned = pokemon.replace("'", "").replace(" ", "-").replace(".", "").replace("-10%", "").replace(":", "")
    learnset = pokemon_learnsets[pokemon_cleaned]
    for move in learnset:
        pokemon_learnsets_df.loc[pokemon, move] = 1

pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        1            0     1     0         0            0
# Ivysaur            0        1            0     1     0         0            0
# Venusaur           0        1            0     1     0         0            0
# Charmander         0        0            0     0     1         0            0
# Charmeleon         0        0            0     0     1         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         1            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         1            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Surging Strikes  \
# name                                             ...
# Bulbasaur                0        0           0  ...                0
# Ivysaur                  0        0           0  ...                0
# Venusaur                 0        0           0  ...                0
# Charmander               0        1           0  ...                0
# Charmeleon               0        1           0  ...                0
# ...                    ...      ...         ...  ...              ...
# Glastrier                0        0           0  ...                0
# Spectrier                0        0           0  ...                0
# Calyrex                  0        0           0  ...                0
# Calyrex-Ice              0        0           0  ...                0
# Calyrex-Shadow           0        0           0  ...                0
#
#                 Tar Shot  Teatime  Terrain Pulse  Thunder Cage  \
# name
# Bulbasaur              0        0              0             0
# Ivysaur                0        0              0             0
# Venusaur               0        0              1             0
# Charmander             0        0              0             0
# Charmeleon             0        0              0             0
# ...                  ...      ...            ...           ...
# Glastrier              0        0              0             0
# Spectrier              0        0              0             0
# Calyrex                0        0              0             0
# Calyrex-Ice            0        0              0             0
# Calyrex-Shadow         0        0              0             0
#
#                 Thunderous Kick  Triple Axel  Wicked Blow  Fury False Swipes  \
# name
# Bulbasaur                     0            0            0                NaN
# Ivysaur                       0            0            0                NaN
# Venusaur                      0            0            0                NaN
# Charmander                    0            0            0                1.0
# Charmeleon                    0            0            0                1.0
# ...                         ...          ...          ...                ...
# Glastrier                     0            0            0                NaN
# Spectrier                     0            0            0                NaN
# Calyrex                       0            0            0                NaN
# Calyrex-Ice                   0            0            0                NaN
# Calyrex-Shadow                0            0            0                NaN
#
#                 Breaking False Swipe
# name
# Bulbasaur                        NaN
# Ivysaur                          NaN
# Venusaur                         NaN
# Charmander                       NaN
# Charmeleon                       NaN
# ...                              ...
# Glastrier                        NaN
# Spectrier                        NaN
# Calyrex                          NaN
# Calyrex-Ice                      NaN
# Calyrex-Shadow                   NaN
#
# [739 rows x 700 columns]

# %%
pokemon_learnsets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Columns: 700 entries, Acid to Breaking False Swipe
# dtypes: float64(2), int64(698)
# memory usage: 4.0+ MB

# %% [markdown]
# We need to check if there are any problematic duplicates in this data, since there are pokemon with similar forms, etc.  Though it's important to understand that some duplicates may not indicate any issue since they may belong to pokemon in the same evolutionary families.

# %%
pokemon_learnsets_df[pokemon_learnsets_df.duplicated(keep=False)].index.to_list()
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Charmander',
#  'Charmeleon',
#  'Squirtle',
#  'Wartortle',
#  'Porygon',
#  'Wobbuffet',
#  'Porygon2',
#  'Larvitar',
#  'Pupitar',
#  'Wynaut',
#  'Shinx',
#  'Luxio',
#  'Giratina',
#  'Giratina-Origin',
#  'Venipede',
#  'Whirlipede',
#  'Litwick',
#  'Lampent',
#  'Vanillite',
#  'Vanillish',
#  'Pidove',
#  'Tranquill',
#  'Solosis',
#  'Duosion',
#  'Tornadus',
#  'Tornadus-Therian',
#  'Thundurus',
#  'Thundurus-Therian',
#  'Landorus',
#  'Landorus-Therian',
#  'Zygarde',
#  'Pumpkaboo-Small',
#  'Pumpkaboo-Large',
#  'Gourgeist-Small',
#  'Gourgeist-Large',
#  'Honedge',
#  'Doublade',
#  'Pumpkaboo-Super',
#  'Gourgeist-Super',
#  'Zygarde-10%',
#  'Rowlet',
#  'Dartrix',
#  'Popplio',
#  'Brionne',
#  'Silvally',
#  'Silvally-Bug',
#  'Silvally-Dark',
#  'Silvally-Dragon',
#  'Silvally-Electric',
#  'Silvally-Fairy',
#  'Silvally-Fighting',
#  'Silvally-Fire',
#  'Silvally-Flying',
#  'Silvally-Ghost',
#  'Silvally-Grass',
#  'Silvally-Ground',
#  'Silvally-Ice',
#  'Silvally-Poison',
#  'Silvally-Psychic',
#  'Silvally-Rock',
#  'Silvally-Steel',
#  'Silvally-Water',
#  'Rookidee',
#  'Corvisquire']

# %% [markdown]
# And we need to understand the number of moves in each column so that we can see which duplicates are associated with one another.

# %%
pokemon_learnsets_df[pokemon_learnsets_df.duplicated(keep=False)].sum(axis=1).to_list()
# Out:
# [75.0,
#  75.0,
#  95.0,
#  95.0,
#  91.0,
#  91.0,
#  71.0,
#  9.0,
#  71.0,
#  66.0,
#  66.0,
#  9.0,
#  57.0,
#  57.0,
#  82.0,
#  82.0,
#  43.0,
#  43.0,
#  60.0,
#  60.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  65.0,
#  65.0,
#  67.0,
#  67.0,
#  74.0,
#  74.0,
#  63.0,
#  63.0,
#  65.0,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  52.0,
#  52.0,
#  4.0,
#  4.0,
#  65.0,
#  57.0,
#  57.0,
#  58.0,
#  58.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  43.0,
#  43.0]

# %% [markdown]
# Most of the these make total sense; they are pokemon in the same families one generation apart, so having the same moveset is reasonable in nearly all of these cases.
#
# However, forms of pumpkaboo and gourgeist having 0 (or 4) moves is not correct and needs to be fixed. Interestingly, the super versions have exactly 4 moves. Upon examination, the 4 moves pumpkaboo super and gourgeist super have actually aren't actually moves that aren't already in the standard movesets for pumpkaboo and gourgeist.
#
# All of these forms just need to get their moveset from the standard pumpkaboo and gorgeist.  Let's see how many moves pumpkaboo and gourgeist have first so we can check if we have the right amount later, and then try to make the replacement.

# %%
pokemon_learnsets_df.loc['Pumpkaboo', :].sum()
# Out:
# 66.0

# %%
pumpkaboo_learnset = pokemon_learnsets['Pumpkaboo']
for move in pumpkaboo_learnset:
    pokemon_learnsets_df.loc['Pumpkaboo-Small', move] = 1
    pokemon_learnsets_df.loc['Pumpkaboo-Large', move] = 1
    pokemon_learnsets_df.loc['Pumpkaboo-Super', move] = 1
    
pokemon_learnsets_df.loc[['Pumpkaboo', 'Pumpkaboo-Small', 'Pumpkaboo-Large', 'Pumpkaboo-Super'], :].sum(axis=1)
# Out:
# name
# Pumpkaboo          66.0
# Pumpkaboo-Small    66.0
# Pumpkaboo-Large    66.0
# Pumpkaboo-Super    66.0
# dtype: float64

# %%
pokemon_learnsets_df.loc['Gourgeist', :].sum()
# Out:
# 74.0

# %%
gourgeist_learnset = pokemon_learnsets['Gourgeist']
for move in gourgeist_learnset:
    pokemon_learnsets_df.loc['Gourgeist-Small', move] = 1
    pokemon_learnsets_df.loc['Gourgeist-Large', move] = 1
    pokemon_learnsets_df.loc['Gourgeist-Super', move] = 1

pokemon_learnsets_df.loc[['Gourgeist', 'Gourgeist-Small', 'Gourgeist-Large', 'Gourgeist-Super'], :].sum(axis=1)
# Out:
# name
# Gourgeist          74.0
# Gourgeist-Small    74.0
# Gourgeist-Large    74.0
# Gourgeist-Super    74.0
# dtype: float64

# %% [markdown]
# The last thing I want to check is a mass comparison between dictionary learnset length and learnset dataframes row-wise sums. These should be equal except in the few cases we manually changed since the dictionary was wrong in the first place.

# %%
for pokemon in pokemon_df.index:
    pokemon_cleaned = pokemon.replace("'", "").replace(" ", "-").replace(".", "").replace("-10%", "").replace(":", "")
    if len(pokemon_learnsets[pokemon_cleaned]) != pokemon_learnsets_df.loc[pokemon, :].sum():
        print(pokemon)
        print(len(pokemon_learnsets[pokemon_cleaned]))
        print(pokemon_learnsets_df.loc[pokemon, :].sum())
# Out:
# Pumpkaboo-Small
# 0
# 66.0
# Pumpkaboo-Large
# 0
# 66.0
# Gourgeist-Small
# 0
# 74.0
# Gourgeist-Large
# 0
# 74.0
# Pumpkaboo-Super
# 4
# 66.0
# Gourgeist-Super
# 4
# 74.0

# %% [markdown]
# Now we should use a profile report to make sure there aren't any more subtle issues with pokemon_learnsets_df.  This is going to take some time because there are hundreds of columns (about 5 minutes in my case).

# %%
profile_report = pokemon_learnsets_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()

# %% [markdown]
# The moves "Fury False Swipes" and "Breaking False Swipe" are mistakes and shouldn't exist; they likely are artifacts of string replacement we did earlier.  The good news is that the pokemon they have listed as "1's" likely actually have Fury Swipes or Breaking Swipe instead, since those moves are conspicuously all "0" which is not realistic.
#
# Max and G-Max moves are all zeroes and I'm not considering Dynamax in this analysis anyways, so those moves will simply be removed.

# %%
dynamax_moves = [move for move in pokemon_learnsets_df.columns.to_list() if "Max" in move]
dynamax_moves
# Out:
# ['G-Max Befuddle',
#  'G-Max Cannonade',
#  'G-Max Centiferno',
#  'G-Max Chi Strike',
#  'G-Max Cuddle',
#  'G-Max Depletion',
#  'G-Max Drum Solo',
#  'G-Max Finale',
#  'G-Max Fire Ball',
#  'G-Max Foam Burst',
#  'G-Max Gold Rush',
#  'G-Max Gravitas',
#  'G-Max Hydrosnipe',
#  'G-Max Malodor',
#  'G-Max Meltdown',
#  'G-Max One Blow',
#  'G-Max Rapid Flow',
#  'G-Max Replenish',
#  'G-Max Resonance',
#  'G-Max Sandblast',
#  'G-Max Smite',
#  'G-Max Snooze',
#  'G-Max Steelsurge',
#  'G-Max Stonesurge',
#  'G-Max Stun Shock',
#  'G-Max Sweetness',
#  'G-Max Tartness',
#  'G-Max Terror',
#  'G-Max Vine Lash',
#  'G-Max Volcalith',
#  'G-Max Volt Crash',
#  'G-Max Wildfire',
#  'G-Max Wind Rage',
#  'Max Airstream',
#  'Max Darkness',
#  'Max Flare',
#  'Max Flutterby',
#  'Max Geyser',
#  'Max Guard',
#  'Max Hailstorm',
#  'Max Knuckle',
#  'Max Lightning',
#  'Max Mindstorm',
#  'Max Ooze',
#  'Max Overgrowth',
#  'Max Phantasm',
#  'Max Quake',
#  'Max Rockfall',
#  'Max Starfall',
#  'Max Steelspike',
#  'Max Strike',
#  'Max Wyrmwind']

# %%
pokemon_learnsets_df = pokemon_learnsets_df.drop(columns=dynamax_moves)
pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        1            0     1     0         0            0
# Ivysaur            0        1            0     1     0         0            0
# Venusaur           0        1            0     1     0         0            0
# Charmander         0        0            0     0     1         0            0
# Charmeleon         0        0            0     0     1         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         1            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         1            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Surging Strikes  \
# name                                             ...
# Bulbasaur                0        0           0  ...                0
# Ivysaur                  0        0           0  ...                0
# Venusaur                 0        0           0  ...                0
# Charmander               0        1           0  ...                0
# Charmeleon               0        1           0  ...                0
# ...                    ...      ...         ...  ...              ...
# Glastrier                0        0           0  ...                0
# Spectrier                0        0           0  ...                0
# Calyrex                  0        0           0  ...                0
# Calyrex-Ice              0        0           0  ...                0
# Calyrex-Shadow           0        0           0  ...                0
#
#                 Tar Shot  Teatime  Terrain Pulse  Thunder Cage  \
# name
# Bulbasaur              0        0              0             0
# Ivysaur                0        0              0             0
# Venusaur               0        0              1             0
# Charmander             0        0              0             0
# Charmeleon             0        0              0             0
# ...                  ...      ...            ...           ...
# Glastrier              0        0              0             0
# Spectrier              0        0              0             0
# Calyrex                0        0              0             0
# Calyrex-Ice            0        0              0             0
# Calyrex-Shadow         0        0              0             0
#
#                 Thunderous Kick  Triple Axel  Wicked Blow  Fury False Swipes  \
# name
# Bulbasaur                     0            0            0                NaN
# Ivysaur                       0            0            0                NaN
# Venusaur                      0            0            0                NaN
# Charmander                    0            0            0                1.0
# Charmeleon                    0            0            0                1.0
# ...                         ...          ...          ...                ...
# Glastrier                     0            0            0                NaN
# Spectrier                     0            0            0                NaN
# Calyrex                       0            0            0                NaN
# Calyrex-Ice                   0            0            0                NaN
# Calyrex-Shadow                0            0            0                NaN
#
#                 Breaking False Swipe
# name
# Bulbasaur                        NaN
# Ivysaur                          NaN
# Venusaur                         NaN
# Charmander                       NaN
# Charmeleon                       NaN
# ...                              ...
# Glastrier                        NaN
# Spectrier                        NaN
# Calyrex                          NaN
# Calyrex-Ice                      NaN
# Calyrex-Shadow                   NaN
#
# [739 rows x 648 columns]

# %% [markdown]
# Struggle is also not a move pokemon can actually learn, so it makes sense that it turned out as all zeroes and it should be removed from the dataframe.

# %%
pokemon_learnsets_df = pokemon_learnsets_df.drop(columns='Struggle')
pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        1            0     1     0         0            0
# Ivysaur            0        1            0     1     0         0            0
# Venusaur           0        1            0     1     0         0            0
# Charmander         0        0            0     0     1         0            0
# Charmeleon         0        0            0     0     1         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         1            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         1            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Surging Strikes  \
# name                                             ...
# Bulbasaur                0        0           0  ...                0
# Ivysaur                  0        0           0  ...                0
# Venusaur                 0        0           0  ...                0
# Charmander               0        1           0  ...                0
# Charmeleon               0        1           0  ...                0
# ...                    ...      ...         ...  ...              ...
# Glastrier                0        0           0  ...                0
# Spectrier                0        0           0  ...                0
# Calyrex                  0        0           0  ...                0
# Calyrex-Ice              0        0           0  ...                0
# Calyrex-Shadow           0        0           0  ...                0
#
#                 Tar Shot  Teatime  Terrain Pulse  Thunder Cage  \
# name
# Bulbasaur              0        0              0             0
# Ivysaur                0        0              0             0
# Venusaur               0        0              1             0
# Charmander             0        0              0             0
# Charmeleon             0        0              0             0
# ...                  ...      ...            ...           ...
# Glastrier              0        0              0             0
# Spectrier              0        0              0             0
# Calyrex                0        0              0             0
# Calyrex-Ice            0        0              0             0
# Calyrex-Shadow         0        0              0             0
#
#                 Thunderous Kick  Triple Axel  Wicked Blow  Fury False Swipes  \
# name
# Bulbasaur                     0            0            0                NaN
# Ivysaur                       0            0            0                NaN
# Venusaur                      0            0            0                NaN
# Charmander                    0            0            0                1.0
# Charmeleon                    0            0            0                1.0
# ...                         ...          ...          ...                ...
# Glastrier                     0            0            0                NaN
# Spectrier                     0            0            0                NaN
# Calyrex                       0            0            0                NaN
# Calyrex-Ice                   0            0            0                NaN
# Calyrex-Shadow                0            0            0                NaN
#
#                 Breaking False Swipe
# name
# Bulbasaur                        NaN
# Ivysaur                          NaN
# Venusaur                         NaN
# Charmander                       NaN
# Charmeleon                       NaN
# ...                              ...
# Glastrier                        NaN
# Spectrier                        NaN
# Calyrex                          NaN
# Calyrex-Ice                      NaN
# Calyrex-Shadow                   NaN
#
# [739 rows x 647 columns]

# %% [markdown]
# Behomoth Blade belongs only to Zacian_Crowned, who was removed due to being overpowerd, thus we can drop the move.

# %%
pokemon_learnsets_df = pokemon_learnsets_df.drop(columns='Behemoth Blade')
pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        1            0     1     0         0            0
# Ivysaur            0        1            0     1     0         0            0
# Venusaur           0        1            0     1     0         0            0
# Charmander         0        0            0     0     1         0            0
# Charmeleon         0        0            0     0     1         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         1            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         1            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Surging Strikes  \
# name                                             ...
# Bulbasaur                0        0           0  ...                0
# Ivysaur                  0        0           0  ...                0
# Venusaur                 0        0           0  ...                0
# Charmander               0        1           0  ...                0
# Charmeleon               0        1           0  ...                0
# ...                    ...      ...         ...  ...              ...
# Glastrier                0        0           0  ...                0
# Spectrier                0        0           0  ...                0
# Calyrex                  0        0           0  ...                0
# Calyrex-Ice              0        0           0  ...                0
# Calyrex-Shadow           0        0           0  ...                0
#
#                 Tar Shot  Teatime  Terrain Pulse  Thunder Cage  \
# name
# Bulbasaur              0        0              0             0
# Ivysaur                0        0              0             0
# Venusaur               0        0              1             0
# Charmander             0        0              0             0
# Charmeleon             0        0              0             0
# ...                  ...      ...            ...           ...
# Glastrier              0        0              0             0
# Spectrier              0        0              0             0
# Calyrex                0        0              0             0
# Calyrex-Ice            0        0              0             0
# Calyrex-Shadow         0        0              0             0
#
#                 Thunderous Kick  Triple Axel  Wicked Blow  Fury False Swipes  \
# name
# Bulbasaur                     0            0            0                NaN
# Ivysaur                       0            0            0                NaN
# Venusaur                      0            0            0                NaN
# Charmander                    0            0            0                1.0
# Charmeleon                    0            0            0                1.0
# ...                         ...          ...          ...                ...
# Glastrier                     0            0            0                NaN
# Spectrier                     0            0            0                NaN
# Calyrex                       0            0            0                NaN
# Calyrex-Ice                   0            0            0                NaN
# Calyrex-Shadow                0            0            0                NaN
#
#                 Breaking False Swipe
# name
# Bulbasaur                        NaN
# Ivysaur                          NaN
# Venusaur                         NaN
# Charmander                       NaN
# Charmeleon                       NaN
# ...                              ...
# Glastrier                        NaN
# Spectrier                        NaN
# Calyrex                          NaN
# Calyrex-Ice                      NaN
# Calyrex-Shadow                   NaN
#
# [739 rows x 646 columns]

# %% [markdown]
# Now let's see who was given "Fury False Swipes".

# %%
pokemon_learnsets_df.loc[~pokemon_learnsets_df["Fury False Swipes"].isna(), ["Fury False Swipes"]].sort_index()
# Out:
#                  Fury False Swipes
# name
# Barbaracle                     1.0
# Beartic                        1.0
# Binacle                        1.0
# Charizard                      1.0
# Charmander                     1.0
# Charmeleon                     1.0
# Cubchoo                        1.0
# Diglett                        1.0
# Diglett-Alola                  1.0
# Drilbur                        1.0
# Dugtrio                        1.0
# Dugtrio-Alola                  1.0
# Excadrill                      1.0
# Golduck                        1.0
# Heatmor                        1.0
# Incineroar                     1.0
# Liepard                        1.0
# Linoone                        1.0
# Linoone-Galar                  1.0
# Litten                         1.0
# Lombre                         1.0
# Ludicolo                       1.0
# Meowth                         1.0
# Meowth-Alola                   1.0
# Meowth-Galar                   1.0
# Mienfoo                        1.0
# Mienshao                       1.0
# Nidoqueen                      1.0
# Nidoran-F                      1.0
# Nidorina                       1.0
# Nincada                        1.0
# Ninjask                        1.0
# Obstagoon                      1.0
# Perrserker                     1.0
# Persian                        1.0
# Persian-Alola                  1.0
# Psyduck                        1.0
# Purrloin                       1.0
# Sableye                        1.0
# Sandshrew                      1.0
# Sandshrew-Alola                1.0
# Sandslash                      1.0
# Sandslash-Alola                1.0
# Shedinja                       1.0
# Skuntank                       1.0
# Sneasel                        1.0
# Stunky                         1.0
# Torracat                       1.0
# Vespiquen                      1.0
# Weavile                        1.0
# Zarude                         1.0
# Zeraora                        1.0
# Zoroark                        1.0
# Zorua                          1.0

# %% [markdown]
# This is precisely the list of pokemon with Fury Swipes.

# %%
pokemon_learnsets_df.loc[:, 'Fury Swipes'] = pokemon_learnsets_df.loc[:, "Fury False Swipes"].values
pokemon_learnsets_df.loc[:, 'Fury Swipes']
# Out:
# name
# Bulbasaur         NaN
# Ivysaur           NaN
# Venusaur          NaN
# Charmander        1.0
# Charmeleon        1.0
#                  ...
# Glastrier         NaN
# Spectrier         NaN
# Calyrex           NaN
# Calyrex-Ice       NaN
# Calyrex-Shadow    NaN
# Name: Fury Swipes, Length: 739, dtype: float64

# %% [markdown]
# Let's do the same thing for Breaking False Swipe.

# %%
pokemon_learnsets_df.loc[~pokemon_learnsets_df["Breaking False Swipe"].isna(), ["Breaking False Swipe"]].sort_index()
# Out:
#                      Breaking False Swipe
# name
# Altaria                               1.0
# Axew                                  1.0
# Charizard                             1.0
# Dialga                                1.0
# Dracozolt                             1.0
# Dragapult                             1.0
# Dragonair                             1.0
# Dragonite                             1.0
# Drakloak                              1.0
# Drampa                                1.0
# Dratini                               1.0
# Duraludon                             1.0
# Exeggutor-Alola                       1.0
# Flygon                                1.0
# Fraxure                               1.0
# Garchomp                              1.0
# Giratina                              1.0
# Giratina-Origin                       1.0
# Goodra                                1.0
# Haxorus                               1.0
# Heliolisk                             1.0
# Hydreigon                             1.0
# Inteleon                              1.0
# Kingdra                               1.0
# Kommo-o                               1.0
# Kyurem                                1.0
# Kyurem-Black                          1.0
# Kyurem-White                          1.0
# Latias                                1.0
# Latios                                1.0
# Mew                                   1.0
# Milotic                               1.0
# Naganadel                             1.0
# Necrozma                              1.0
# Necrozma-Dawn Wings                   1.0
# Necrozma-Dusk Mane                    1.0
# Onix                                  1.0
# Palkia                                1.0
# Rayquaza                              1.0
# Regidrago                             1.0
# Reshiram                              1.0
# Rhydon                                1.0
# Rhyperior                             1.0
# Salamence                             1.0
# Salazzle                              1.0
# Sceptile                              1.0
# Steelix                               1.0
# Tyranitar                             1.0
# Tyrantrum                             1.0
# Zekrom                                1.0
# Zygarde                               1.0
# Zygarde-10%                           1.0

# %% [markdown]
# As expected, these are exactly the pokemon that can learn Breaking Swipe

# %%
pokemon_learnsets_df.loc[:, 'Breaking Swipe'] = pokemon_learnsets_df.loc[:, "Breaking False Swipe"].values
pokemon_learnsets_df.loc[:, 'Breaking Swipe']
# Out:
# name
# Bulbasaur        NaN
# Ivysaur          NaN
# Venusaur         NaN
# Charmander       NaN
# Charmeleon       NaN
#                   ..
# Glastrier        NaN
# Spectrier        NaN
# Calyrex          NaN
# Calyrex-Ice      NaN
# Calyrex-Shadow   NaN
# Name: Breaking Swipe, Length: 739, dtype: float64

# %%
pokemon_learnsets_df = pokemon_learnsets_df.drop(columns=["Fury False Swipes", "Breaking False Swipe"])
pokemon_learnsets_df = pokemon_learnsets_df.fillna(0)
pokemon_learnsets_df
# Out:
#                 Acid  Amnesia  Aurora Beam  Bind  Bite  Blizzard  Bubble Beam  \
# name
# Bulbasaur          0        1            0     1     0         0            0
# Ivysaur            0        1            0     1     0         0            0
# Venusaur           0        1            0     1     0         0            0
# Charmander         0        0            0     0     1         0            0
# Charmeleon         0        0            0     0     1         0            0
# ...              ...      ...          ...   ...   ...       ...          ...
# Glastrier          0        0            0     0     0         1            0
# Spectrier          0        0            0     0     0         0            0
# Calyrex            0        0            0     0     0         0            0
# Calyrex-Ice        0        0            0     0     0         1            0
# Calyrex-Shadow     0        0            0     0     0         0            0
#
#                 Conversion  Counter  Crabhammer  ...  Strange Steam  \
# name                                             ...
# Bulbasaur                0        0           0  ...              0
# Ivysaur                  0        0           0  ...              0
# Venusaur                 0        0           0  ...              0
# Charmander               0        1           0  ...              0
# Charmeleon               0        1           0  ...              0
# ...                    ...      ...         ...  ...            ...
# Glastrier                0        0           0  ...              0
# Spectrier                0        0           0  ...              0
# Calyrex                  0        0           0  ...              0
# Calyrex-Ice              0        0           0  ...              0
# Calyrex-Shadow           0        0           0  ...              0
#
#                 Stuff Cheeks  Surging Strikes  Tar Shot  Teatime  \
# name
# Bulbasaur                  0                0         0        0
# Ivysaur                    0                0         0        0
# Venusaur                   0                0         0        0
# Charmander                 0                0         0        0
# Charmeleon                 0                0         0        0
# ...                      ...              ...       ...      ...
# Glastrier                  0                0         0        0
# Spectrier                  0                0         0        0
# Calyrex                    0                0         0        0
# Calyrex-Ice                0                0         0        0
# Calyrex-Shadow             0                0         0        0
#
#                 Terrain Pulse  Thunder Cage  Thunderous Kick  Triple Axel  \
# name
# Bulbasaur                   0             0                0            0
# Ivysaur                     0             0                0            0
# Venusaur                    1             0                0            0
# Charmander                  0             0                0            0
# Charmeleon                  0             0                0            0
# ...                       ...           ...              ...          ...
# Glastrier                   0             0                0            0
# Spectrier                   0             0                0            0
# Calyrex                     0             0                0            0
# Calyrex-Ice                 0             0                0            0
# Calyrex-Shadow              0             0                0            0
#
#                 Wicked Blow
# name
# Bulbasaur                 0
# Ivysaur                   0
# Venusaur                  0
# Charmander                0
# Charmeleon                0
# ...                     ...
# Glastrier                 0
# Spectrier                 0
# Calyrex                   0
# Calyrex-Ice               0
# Calyrex-Shadow            0
#
# [739 rows x 644 columns]

# %%
pokemon_learnsets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Columns: 644 entries, Acid to Wicked Blow
# dtypes: float64(2), int64(642)
# memory usage: 3.7+ MB

# %% [markdown]
# Those two newly updated moves are probably the float columns due to how pandas consider nan a float value, so let's change them all to ints just to have them as a uniform data type.

# %%
pokemon_learnsets_df = pokemon_learnsets_df.astype('int64')
pokemon_learnsets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739 entries, Bulbasaur to Calyrex-Shadow
# Columns: 644 entries, Acid to Wicked Blow
# dtypes: int64(644)
# memory usage: 3.7+ MB

# %% [markdown]
# Let's make one more profile report for the purposes of observing correlation groups, which will be useful to EDA and move bucketing later (we need to bucket moves because there are probably way too many compared to their level of importance in the anaylsis, thus it's up to us to use them to identify higher level move features).

# %%
profile_report = pokemon_learnsets_df.profile_report(html={'style': {'full_width': True}})
profile_report.to_widgets()

# %% [markdown]
# #### Correlation Groups:
# - Substitute, Rest, Endure, Protect, Sleep Talk, Round, Facade
# - Double Team, Toxic, Confide, Swagger
# - Mega Punch, Mega Kick
# - Conversion, Conversion 2
# - Spit Up, Stockpile, Swallow
# - Defend Order, Attack Order
# - Giga Impact, Hyper Beam
# - Bulldoze, Earthquake
# - Thousand Waves, Thousand Arrows, Land's Wrath, Core Enforcer
# - Prismatic Laser, Photon Geyser
# - Clangorous Soul, Clanging Scales
# - Eternabeam, Dynamax Cannon
# - Pyro Ball, Court Change
# - Rising Voltage, Volt Switch
#
# Some of these, like the first list, are moves almost all pokemon can learn, whereas some are much more particular and rare.

# %% [markdown]
# <a id='strategies_dict'></a>
# ### strategies_dict

# %% [markdown]
# For the strategies of each pokemon, I want two things:
# 1. the names of various moveset strategies (to later be able to make a set of them and find patterns in them which can help identify high level strategic features)
# 2. a list of the moves used competitively (so I can remove those which aren't competitive and see what patterns exist in the moves that are used)
#
# Actually, the best way to organize this "strategies" section of my data is probably just a dictionary. It can easily be saved as a json, it's much more flexible than a dataframe, and it's not going to be put into a dataframe either. It's not even going to be used in the machine learning phase of this project; it's just to help with EDA. So instead of strategies_df, I'm going to create strategies_dict.
#
# The method of construction of strategies_dict will likely be very similar to pokemon_learnsets, since I'm taking pokemon from the pokemon_df index and then transforming the strings of the names to be compatible with strategydex_df.
#
# One more thing I will need is a list of acceptable formats for movesets (e.g. PU, RU, etc.), since I will only be taking movesets from within that list of acceptable formats. I will add ZU as that seems like the format listed for strategies instead of "untiered".
#
# The structure:
# - dictionary with pokemon name as key, then a list of dictionaries as values which have main keys as formats
# - then within each format key, a value that's a list of moveset dictionaries with moveset name as key and list of moves as value

# %%
acceptable_formats = pokemon_df['formats'].unique().tolist()
acceptable_formats.append('ZU')
acceptable_formats
# Out:
# ['LC',
#  'NFE',
#  'RUBL',
#  'PU',
#  'NU',
#  'Untiered',
#  'UU',
#  'OU',
#  'UUBL',
#  'PUBL',
#  'RU',
#  'Uber',
#  'NUBL',
#  'ZU']

# %%
strategies_dict = {}

strategydexcopy = strategydex_df.copy()

for pokemon in pokemon_df.index:
    pokemon_access = pokemon.replace("'", "").replace(" ", "-").replace(".", "").replace("-10%", "").replace(":", "")
    dex_entry = strategydexcopy.loc[strategydexcopy['pokemonName'] == pokemon_access.lower(), 'pokemonData'].item()
    format_list = []
    for competitive_format in dex_entry['strategies']:
        format_dict = {}
        current_format = competitive_format['format']
        if current_format in acceptable_formats:
            moveset_list = []
            for moveset in competitive_format['movesets']:
                moveset_dict = {}
                moveset_name = moveset['name']
                move_list = []
                for move in moveset['moveslots']:
                    for entry in move:
                        move_list.append(entry['move'])
                moveset_dict[moveset_name] = move_list
                moveset_list.append(moveset_dict)
            format_dict[current_format] = moveset_list
            format_list.append(format_dict)
    strategies_dict[pokemon] = format_list

strategies_dict
# Out:
# {'Bulbasaur': [],
#  'Ivysaur': [{'NFE': [{'Sun Sweeper': ['Growth',
#       'Solar Beam',
#       'Giga Drain',
#       'Weather Ball',
#       'Sludge Bomb',
#       'Sleep Powder',
#       'Synthesis']}]},
#   {'ZU': [{'Sun Sweeper': ['Growth',
#       'Solar Beam',
#       'Sludge Bomb',
#       'Weather Ball']}]}],
#  'Venusaur': [{'OU': [{'Chlorophyll Sweeper': ['Growth',
#       'Giga Drain',
#       'Weather Ball',
#       'Sludge Bomb',
#       'Solar Beam']}]},
#   {'UU': [{'Chlorophyll Sweeper': ['Growth',
#       'Giga Drain',
#       'Weather Ball',
#       'Sludge Bomb',
#       'Earth Power']}]}],
#  'Charmander': [{'LC': [{'Choice Scarf': ['Weather Ball',
#       'Fire Blast',
#       'Overheat',
#       'Sleep Talk']}]}],
#  'Charmeleon': [{'NFE': [{'Sun Sweeper': ['Fire Blast',
#       'Weather Ball',
#       'Ancient Power',
#       'Toxic',
#       'Overheat']}]}],
#  'Charizard': [{'PU': [{'Special Attacker': ['Roost',
#       'Fire Blast',
#       'Hurricane',
#       'Focus Blast',
#       'Defog',
#       'Toxic',
#       'Focus Blast']},
#     {'Dragon Dance': ['Dragon Dance',
#       'Flare Blitz',
#       'Earthquake',
#       'Roost',
#       'Thunder Punch']}]},
#   {'OU': [{'Choice Specs': ['Weather Ball',
#       'Overheat',
#       'Focus Blast',
#       'Roost',
#       'Flamethrower']}]},
#   {'NU': [{'Offensive': ['Flamethrower',
#       'Defog',
#       'Roost',
#       'Hurricane',
#       'Toxic']}]}],
#  'Squirtle': [],
#  'Wartortle': [{'NFE': [{'Shell Smash Sweeper': ['Shell Smash',
#       'Hydro Pump',
#       'Surf',
#       'Ice Beam',
#       'Substitute',
#       'Rapid Spin']},
#     {'Utility Pivot': ['Rapid Spin',
#       'Flip Turn',
#       'Scald',
#       'Seismic Toss',
#       'Toxic']}]}],
#  'Blastoise': [{'NU': [{'Shell Smash': ['Shell Smash',
#       'Surf',
#       'Ice Beam',
#       'Dark Pulse',
#       'Substitute']}]}],
#  'Caterpie': [],
#  'Metapod': [],
#  'Butterfree': [{'ZU': [{'Quiver Dance': ['Quiver Dance',
#       'Substitute',
#       'Hurricane',
#       'Sleep Powder']}]}],
#  'Pikachu': [{'NFE': [{'Mixed Wallbreaker': ['Knock Off',
#       'Extreme Speed',
#       'Volt Switch',
#       'Thunderbolt',
#       'Surf',
#       'Grass Knot']},
#     {'FakeSpeed': ['Fake Out', 'Extreme Speed', 'Knock Off', 'Volt Switch']}]},
#   {'PU': [{'Revenge Killer': ['Fake Out',
#       'Extreme Speed',
#       'Volt Switch',
#       'Surf',
#       'Volt Tackle',
#       'Knock Off',
#       'Surf']}]}],
#  'Raichu': [{'PU': [{'Nasty Plot': ['Nasty Plot',
#       'Thunderbolt',
#       'Focus Blast',
#       'Surf',
#       'Grass Knot']},
#     {'Choice Specs': ['Thunderbolt',
#       'Focus Blast',
#       'Surf',
#       'Grass Knot',
#       'Volt Switch']}]}],
#  'Sandshrew': [],
#  'Sandslash': [{'PU': [{'Defensive': ['Stealth Rock',
#       'Spikes',
#       'Rapid Spin',
#       'Spikes',
#       'Earthquake',
#       'Knock Off',
#       'Toxic']}]}],
#  'Nidoran-F': [],
#  'Nidorina': [],
#  'Nidoqueen': [{'UU': [{'Offensive Entry Hazard Setter': ['Stealth Rock',
#       'Toxic Spikes',
#       'Earth Power',
#       'Sludge Wave',
#       'Fire Blast']}]}],
#  'Nidoran-M': [],
#  'Nidorino': [],
#  'Nidoking': [{'OU': [{'Wallbreaker': ['Sludge Wave',
#       'Earth Power',
#       'Thunderbolt',
#       'Thunder',
#       'Flamethrower',
#       'Ice Beam']}]}],
#  'Clefairy': [{'NFE': [{'Utility': ['Moonblast',
#       'Soft-Boiled',
#       'Knock Off',
#       'Thunder Wave',
#       'Stealth Rock',
#       'Flamethrower']},
#     {'WishPass': ['Moonblast', 'Wish', 'Protect', 'Moonlight', 'Teleport']}]},
#   {'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Soft-Boiled',
#       'Seismic Toss',
#       'Moonblast',
#       'Knock Off',
#       'Toxic',
#       'Thunder Wave']}]},
#   {'ZU': [{'Specially Defensive': ['Soft-Boiled',
#       'Moonblast',
#       'Seismic Toss',
#       'Knock Off',
#       'Seismic Toss',
#       'Stealth Rock',
#       'Toxic']}]}],
#  'Clefable': [{'OU': [{'Utility': ['Moonblast',
#       'Soft-Boiled',
#       'Stealth Rock',
#       'Wish',
#       'Knock Off']},
#     {'Calm Mind': ['Calm Mind',
#       'Moonblast',
#       'Soft-Boiled',
#       'Thunder',
#       'Flamethrower']}]},
#   {'Uber': [{'Stealth Rock': ['Stealth Rock',
#       'Moonblast',
#       'Soft-Boiled',
#       'Thunder Wave']}]}],
#  'Vulpix': [{'LC': [{'Choice Item': ['Weather Ball',
#       'Overheat',
#       'Energy Ball',
#       'Hypnosis',
#       'Fire Blast']}]},
#   {'NFE': [{'Sun Setter': ['Weather Ball', 'Memento', 'Encore', 'Toxic']}]}],
#  'Ninetales': [{'RU': [{'Nasty Plot': ['Nasty Plot',
#       'Fire Blast',
#       'Solar Beam',
#       'Toxic',
#       'Scorching Sands']}]},
#   {'PU': [{'Nasty Plot': ['Nasty Plot',
#       'Fire Blast',
#       'Energy Ball',
#       'Scorching Sands']}]},
#   {'ZU': [{'Nasty Plot': ['Nasty Plot',
#       'Fire Blast',
#       'Energy Ball',
#       'Scorching Sands']}]}],
#  'Jigglypuff': [],
#  'Wigglytuff': [{'PU': [{'Defensive': ['Wish',
#       'Protect',
#       'Dazzling Gleam',
#       'Flamethrower',
#       'Teleport',
#       'Stealth Rock']}]}],
#  'Zubat': [],
#  'Golbat': [{'NFE': [{'Stallbreaker': ['Super Fang',
#       'Taunt',
#       'Roost',
#       'Brave Bird']},
#     {'Defog': ['Defog', 'Roost', 'U-turn', 'Toxic', 'Brave Bird']},
#     {'Nasty Plot': ['Nasty Plot',
#       'Air Slash',
#       'Heat Wave',
#       'Roost',
#       'Giga Drain']}]}],
#  'Oddish': [{'LC': [{'Defensive': ['Giga Drain',
#       'Sludge Bomb',
#       'Sleep Powder',
#       'Strength Sap']}]}],
#  'Gloom': [{'NFE': [{'Physical Wall': ['Strength Sap',
#       'Giga Drain',
#       'Leech Seed',
#       'Sleep Powder',
#       'Sludge Bomb',
#       'Moonblast',
#       'Moonblast',
#       'Moonlight']},
#     {'Sun Sweeper': ['Growth',
#       'Solar Beam',
#       'Sludge Bomb',
#       'Strength Sap',
#       'Moonlight']}]}],
#  'Vileplume': [{'NU': [{'Defensive': ['Giga Drain',
#       'Sludge Bomb',
#       'Strength Sap',
#       'Corrosive Gas',
#       'Sleep Powder']}]},
#   {'RU': [{'Physically Defensive': ['Giga Drain',
#       'Sludge Bomb',
#       'Strength Sap',
#       'Corrosive Gas',
#       'Sleep Powder']}]}],
#  'Diglett': [{'LC': [{'Eviolite': ['Earthquake',
#       'Final Gambit',
#       'Beat Up',
#       'Earth Power',
#       'Sucker Punch',
#       'Stealth Rock']},
#     {'Life Orb': ['Earthquake',
#       'Substitute',
#       'Beat Up',
#       'Sucker Punch',
#       'Rock Slide',
#       'Sucker Punch',
#       'Memento']}]}],
#  'Dugtrio': [{'Uber': [{'Choice Scarf Trapper': ['Earthquake',
#       'Stone Edge',
#       'Stealth Rock',
#       'Shadow Claw',
#       'Memento',
#       'Shadow Claw']}]},
#   {'PU': [{'Lead': ['Stealth Rock', 'Earthquake', 'Stone Edge', 'Toxic']},
#     {'Wallbreaker': ['Earthquake',
#       'Stone Edge',
#       'Sucker Punch',
#       'Toxic',
#       'Sludge Wave']}]}],
#  'Meowth': [{'LC': [{'All out Attacker': ['Fake Out',
#       'Feint',
#       'Water Pulse',
#       'Double-Edge']}]}],
#  'Persian': [{'PU': [{'Revenge Killer': ['Fake Out',
#       'Double-Edge',
#       'Knock Off',
#       'U-turn']}]}],
#  'Psyduck': [],
#  'Golduck': [{'PU': [{'Choice Scarf': ['Hydro Pump',
#       'Ice Beam',
#       'Psychic',
#       'Focus Blast',
#       'Flip Turn']},
#     {'Choice Specs': ['Hydro Pump',
#       'Ice Beam',
#       'Psychic',
#       'Focus Blast',
#       'Flip Turn']},
#     {'Rain Dance': ['Rain Dance',
#       'Hydro Pump',
#       'Ice Beam',
#       'Psychic',
#       'Focus Blast']}]}],
#  'Growlithe': [],
#  'Arcanine': [{'NU': [{'Defensive Pivot': ['Flamethrower',
#       'Morning Sun',
#       'Teleport',
#       'Toxic']}]}],
#  'Poliwag': [],
#  'Poliwhirl': [],
#  'Poliwrath': [{'PU': [{'Choice Band': ['Waterfall',
#       'Close Combat',
#       'Ice Punch',
#       'Earthquake']},
#     {'Choice Scarf': ['Waterfall', 'Close Combat', 'Ice Punch', 'Earthquake']},
#     {'Mixed Attacker': ['Close Combat',
#       'Liquidation',
#       'Ice Beam',
#       'Earth Power']},
#     {'RestTalk': ['Scald',
#       'Drain Punch',
#       'Circle Throw',
#       'Rest',
#       'Sleep Talk']}]},
#   {'ZU': [{'RestTalk': ['Rest', 'Sleep Talk', 'Scald', 'Circle Throw']},
#     {'Choice Scarf': ['Close Combat',
#       'Liquidation',
#       'Earthquake',
#       'Throat Chop',
#       'Toxic']},
#     {'Bulk Up': ['Substitute',
#       'Bulk Up',
#       'Drain Punch',
#       'Liquidation',
#       'Toxic']}]}],
#  'Abra': [{'LC': [{'Focus Sash': ['Psychic',
#       'Counter',
#       'Dazzling Gleam',
#       'Protect']},
#     {'Life Orb': ['Psychic',
#       'Dazzling Gleam',
#       'Fire Punch',
#       'Protect',
#       'Substitute']}]}],
#  'Kadabra': [{'NFE': [{'Life Orb': ['Psychic',
#       'Dazzling Gleam',
#       'Shadow Ball',
#       'Encore',
#       'Knock Off']},
#     {'Focus Sash': ['Psychic',
#       'Dazzling Gleam',
#       'Shadow Ball',
#       'Encore',
#       'Counter']}]},
#   {'PU': [{'Revenge Killer': ['Psychic',
#       'Dazzling Gleam',
#       'Shadow Ball',
#       'Thunder Wave',
#       'Counter',
#       'Thunder Wave']},
#     {'Life Orb Attacker': ['Psychic',
#       'Dazzling Gleam',
#       'Shadow Ball',
#       'Encore',
#       'Substitute',
#       'Calm Mind',
#       'Knock Off']}]}],
#  'Alakazam': [{'OU': [{'Nasty Plot': ['Nasty Plot',
#       'Psychic',
#       'Focus Blast',
#       'Recover',
#       'Dazzling Gleam']}]}],
#  'Machop': [],
#  'Machoke': [{'NFE': [{'Physically Defensive': ['Dynamic Punch',
#       'Knock Off',
#       'Rest',
#       'Sleep Talk']},
#     {'Bulky Attacker': ['Close Combat',
#       'Knock Off',
#       'Bullet Punch',
#       'Earthquake',
#       'Heavy Slam']},
#     {'Flame Orb': ['Close Combat',
#       'Knock Off',
#       'Bullet Punch',
#       'Facade',
#       'Heavy Slam']}]}],
#  'Machamp': [{'NU': [{'Guts Wallbreaker': ['Close Combat',
#       'Knock Off',
#       'Facade',
#       'Bullet Punch',
#       'Heavy Slam']}]}],
#  'Tentacool': [{'LC': [{'Defensive Utility': ['Rapid Spin',
#       'Scald',
#       'Sludge Bomb',
#       'Knock Off',
#       'Toxic Spikes']}]}],
#  'Tentacruel': [{'UU': [{'Defensive Spinner': ['Scald',
#       'Sludge Bomb',
#       'Knock Off',
#       'Haze',
#       'Rapid Spin']}]},
#   {'Uber': [{'Defensive': ['Rapid Spin',
#       'Knock Off',
#       'Scald',
#       'Rest',
#       'Toxic']}]}],
#  'Ponyta': [{'LC': [{'Eviolite': ['Flare Blitz',
#       'High Horsepower',
#       'Flame Charge',
#       'Wild Charge',
#       'Will-O-Wisp',
#       'Morning Sun']},
#     {'Berry Juice': ['Flare Blitz',
#       'Flame Charge',
#       'High Horsepower',
#       'Wild Charge',
#       'Will-O-Wisp']}]}],
#  'Rapidash': [{'PU': [{'Offensive Utility': ['Flare Blitz',
#       'High Horsepower',
#       'Toxic',
#       'Will-O-Wisp',
#       'Morning Sun']},
#     {'Swords Dance': ['Swords Dance',
#       'Flare Blitz',
#       'Wild Charge',
#       'High Horsepower',
#       'Morning Sun']}]},
#   {'ZU': [{'Utility': ['Flare Blitz',
#       'High Horsepower',
#       'Toxic',
#       'Will-O-Wisp',
#       'Morning Sun']},
#     {'Swords Dance': ['Swords Dance',
#       'Flare Blitz',
#       'High Horsepower',
#       'Morning Sun',
#       'Wild Charge']}]}],
#  'Slowpoke': [{'LC': [{'Bulky Pivot': ['Scald',
#       'Future Sight',
#       'Psychic',
#       'Teleport',
#       'Slack Off']}]},
#   {'NFE': [{'Physical Wall': ['Teleport',
#       'Scald',
#       'Future Sight',
#       'Toxic',
#       'Thunder Wave',
#       'Yawn',
#       'Slack Off']}]}],
#  'Slowbro': [{'OU': [{'Defensive Pivot': ['Scald',
#       'Ice Beam',
#       'Slack Off',
#       'Future Sight',
#       'Teleport']}]}],
#  'Magnemite': [{'LC': [{'SturdyJuice': ['Volt Switch',
#       'Flash Cannon',
#       'Recycle',
#       'Endure']},
#     {'Choice Scarf': ['Volt Switch',
#       'Thunderbolt',
#       'Flash Cannon',
#       'Steel Beam']}]}],
#  'Magneton': [{'RU': [{'Choice Scarf': ['Thunderbolt',
#       'Volt Switch',
#       'Flash Cannon',
#       'Toxic',
#       'Steel Beam']}]},
#   {'PU': [{'Choice Specs': ['Thunderbolt',
#       'Volt Switch',
#       'Flash Cannon',
#       'Tri Attack',
#       'Teleport',
#       'Steel Beam']},
#     {'Revenge Killer': ['Thunderbolt',
#       'Volt Switch',
#       'Flash Cannon',
#       'Thunder Wave',
#       'Toxic',
#       'Steel Beam']}]}],
#  "Farfetch'd": [],
#  'Shellder': [{'LC': [{'Shell Smash': ['Shell Smash',
#       'Icicle Spear',
#       'Rock Blast',
#       'Liquidation',
#       'Ice Shard']}]}],
#  'Cloyster': [{'RU': [{'Shell Smash Sweeper': ['Shell Smash',
#       'Icicle Spear',
#       'Rock Blast',
#       'Hydro Pump']}]},
#   {'Uber': [{'Shell Smash Lead': ['Spikes',
#       'Shell Smash',
#       'Icicle Spear',
#       'Rapid Spin']}]},
#   {'OU': [{'Shell Smash': ['Shell Smash',
#       'Icicle Spear',
#       'Rock Blast',
#       'Ice Shard']}]}],
#  'Gastly': [{'NFE': [{'Special Wallbreaker': ['Shadow Ball',
#       'Sludge Bomb',
#       'Dazzling Gleam',
#       'Trick',
#       'Destiny Bond']}]}],
#  'Haunter': [{'PU': [{'Substitute Attacker': ['Shadow Ball',
#       'Sludge Bomb',
#       'Substitute',
#       'Pain Split',
#       'Disable',
#       'Will-O-Wisp']},
#     {'Choice Scarf': ['Shadow Ball',
#       'Sludge Bomb',
#       'Destiny Bond',
#       'Trick']}]}],
#  'Gengar': [{'OU': [{'Substitute': ['Substitute',
#       'Nasty Plot',
#       'Shadow Ball',
#       'Focus Blast',
#       'Dazzling Gleam']}]}],
#  'Onix': [{'LC': [{'Weak Armor': ['Earthquake',
#       'High Horsepower',
#       'Rock Blast',
#       'Stealth Rock',
#       'Explosion']},
#     {'Sturdy': ['Earthquake',
#       'High Horsepower',
#       'Rock Blast',
#       'Stealth Rock',
#       'Explosion',
#       'Endure',
#       'Taunt']},
#     {'Rock Head': ['Head Smash',
#       'Earthquake',
#       'Stealth Rock',
#       'Explosion',
#       'Body Press',
#       'Dragon Dance',
#       'Explosion',
#       'Body Press']}]}],
#  'Krabby': [{'LC': [{'Wallbreaker': ['Liquidation',
#       'Knock Off',
#       'Superpower',
#       'Body Slam',
#       'Agility']}]}],
#  'Kingler': [],
#  'Exeggcute': [],
#  'Exeggutor': [{'ZU': [{'Choice Specs': ['Leaf Storm',
#       'Psychic',
#       'Giga Drain',
#       'Teleport',
#       'Ancient Power']},
#     {'Sunny Day': ['Sunny Day', 'Psychic', 'Solar Beam', 'Sleep Powder']}]}],
#  'Cubone': [],
#  'Marowak': [{'PU': [{'Wallbreaker': ['Substitute',
#       'Stealth Rock',
#       'Swords Dance',
#       'Earthquake',
#       'Bonemerang',
#       'Knock Off',
#       'Fire Punch']}]}],
#  'Hitmonlee': [{'PU': [{'Terrain Sweeper': ['Bulk Up',
#       'Close Combat',
#       'Knock Off',
#       'Stone Edge',
#       'Poison Jab']}]},
#   {'NU': [{'Terrain Sweeper': ['Bulk Up',
#       'Close Combat',
#       'Knock Off',
#       'Stone Edge',
#       'Poison Jab']}]}],
#  'Hitmonchan': [{'PU': [{'Assault Vest': ['Rapid Spin',
#       'Drain Punch',
#       'Throat Chop',
#       'Mach Punch']},
#     {'Offensive': ['Drain Punch',
#       'Throat Chop',
#       'Thunder Punch',
#       'Rapid Spin',
#       'Mach Punch']}]}],
#  'Lickitung': [{'LC': [{'Defensive': ['Wish',
#       'Protect',
#       'Body Slam',
#       'Knock Off']}]}],
#  'Koffing': [{'LC': [{'Offensive': ['Sludge Bomb',
#       'Will-O-Wisp',
#       'Fire Blast',
#       'Thunderbolt']}]},
#   {'NFE': [{'Physically Defensive': ['Toxic Spikes',
#       'Sludge Bomb',
#       'Pain Split',
#       'Will-O-Wisp',
#       'Thief',
#       'Corrosive Gas']}]}],
#  'Weezing': [{'PU': [{'Defensive Utility': ['Sludge Bomb',
#       'Will-O-Wisp',
#       'Toxic Spikes',
#       'Taunt',
#       'Pain Split',
#       'Taunt',
#       'Flamethrower']}]},
#   {'NU': [{'Physically Defensive': ['Sludge Bomb',
#       'Will-O-Wisp',
#       'Taunt',
#       'Toxic Spikes',
#       'Pain Split']}]}],
#  'Rhyhorn': [],
#  'Rhydon': [{'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Earthquake',
#       'Stone Edge',
#       'Swords Dance',
#       'Heat Crash']},
#     {'Choice Band': ['Earthquake',
#       'Stone Edge',
#       'Heat Crash',
#       'Megahorn',
#       'Stealth Rock']}]},
#   {'ZU': [{'Stealth Rock': ['Stealth Rock',
#       'Earthquake',
#       'Stone Edge',
#       'Roar',
#       'Body Press',
#       'Toxic']},
#     {'Double Dance': ['Swords Dance',
#       'Rock Polish',
#       'Earthquake',
#       'Stone Edge']}]}],
#  'Chansey': [{'UU': [{'Defensive': ['Seismic Toss',
#       'Toxic',
#       'Thunder Wave',
#       'Soft-Boiled',
#       'Stealth Rock',
#       'Teleport']}]}],
#  'Tangela': [{'NFE': [{'Physically Defensive': ['Giga Drain',
#       'Leaf Storm',
#       'Knock Off',
#       'Toxic',
#       'Sludge Bomb',
#       'Synthesis',
#       'Leech Seed']},
#     {'Chlorophyll Sweeper': ['Growth',
#       'Giga Drain',
#       'Solar Beam',
#       'Sludge Bomb',
#       'Knock Off',
#       'Synthesis']},
#     {'Offensive': ['Leaf Storm',
#       'Giga Drain',
#       'Sludge Bomb',
#       'Knock Off',
#       'Sleep Powder',
#       'Stun Spore']}]},
#   {'RU': [{'Wall': ['Giga Drain',
#       'Knock Off',
#       'Sludge Bomb',
#       'Synthesis',
#       'Leech Seed']}]},
#   {'PU': [{'Defensive': ['Giga Drain',
#       'Knock Off',
#       'Leech Seed',
#       'Synthesis',
#       'Toxic',
#       'Sleep Powder']}]},
#   {'ZU': [{'Physical Wall': ['Giga Drain',
#       'Leaf Storm',
#       'Knock Off',
#       'Sleep Powder',
#       'Toxic',
#       'Sludge Bomb',
#       'Synthesis',
#       'Leech Seed']}]}],
#  'Kangaskhan': [{'PU': [{'Offensive': ['Fake Out',
#       'Double-Edge',
#       'Earthquake',
#       'Sucker Punch']},
#     {'Defensive': ['Wish', 'Protect', 'Body Slam', 'Seismic Toss', 'Toxic']},
#     {'Choice Band': ['Double-Edge',
#       'Fire Punch',
#       'Earthquake',
#       'Sucker Punch',
#       'Fake Out']}]},
#   {'ZU': [{'Priority Attacker': ['Fake Out',
#       'Double-Edge',
#       'Sucker Punch',
#       'Earthquake']}]}],
#  'Horsea': [],
#  'Seadra': [{'NFE': [{'Choice Specs': ['Surf',
#       'Scald',
#       'Hydro Pump',
#       'Ice Beam',
#       'Flip Turn']}]}],
#  'Goldeen': [],
#  'Seaking': [{'PU': [{'Choice Band': ['Waterfall',
#       'Knock Off',
#       'Megahorn',
#       'Flip Turn']}]}],
#  'Staryu': [{'LC': [{'Offensive': ['Hydro Pump',
#       'Thunderbolt',
#       'Psychic',
#       'Rapid Spin',
#       'Ice Beam']},
#     {'Defensive': ['Scald', 'Thunderbolt', 'Recover', 'Rapid Spin']},
#     {'Life Orb': ['Hydro Pump', 'Psychic', 'Thunderbolt', 'Ice Beam']}]}],
#  'Starmie': [{'NU': [{'Wallbreaker': ['Hydro Pump',
#       'Thunderbolt',
#       'Ice Beam',
#       'Psyshock',
#       'Recover',
#       'Rapid Spin']}]},
#   {'UU': [{'Offensive': ['Hydro Pump',
#       'Thunderbolt',
#       'Ice Beam',
#       'Psyshock',
#       'Recover',
#       'Psyshock']}]},
#   {'RU': [{'Wallbreaker': ['Surf',
#       'Hydro Pump',
#       'Ice Beam',
#       'Grass Knot',
#       'Thunderbolt',
#       'Psyshock',
#       'Recover']},
#     {'Rapid Spin': ['Rapid Spin',
#       'Scald',
#       'Psyshock',
#       'Grass Knot',
#       'Ice Beam',
#       'Recover']}]}],
#  'Mr. Mime': [{'PU': [{'Choice Scarf': ['Psychic',
#       'Dazzling Gleam',
#       'Trick',
#       'Healing Wish']}]}],
#  'Scyther': [{'PU': [{'Offensive Pivot': ['Swords Dance',
#       'U-turn',
#       'Dual Wingbeat',
#       'Knock Off',
#       'Roost']}]}],
#  'Jynx': [{'PU': [{'Nasty Plot': ['Nasty Plot',
#       'Lovely Kiss',
#       'Ice Beam',
#       'Psyshock',
#       'Focus Blast']},
#     {'Choice Scarf': ['Ice Beam', 'Psychic', 'Focus Blast', 'Trick']},
#     {'Choice Specs': ['Ice Beam',
#       'Psyshock',
#       'Psychic',
#       'Focus Blast',
#       'Trick']}]}],
#  'Electabuzz': [{'NFE': [{'Offensive Pivot': ['Thunderbolt',
#       'Volt Switch',
#       'Psychic',
#       'Focus Blast',
#       'Toxic',
#       'Taunt']},
#     {'Choice Specs': ['Thunderbolt',
#       'Volt Switch',
#       'Psychic',
#       'Focus Blast',
#       'Toxic',
#       'Teleport']}]}],
#  'Magmar': [{'NFE': [{'Choice Specs': ['Lava Plume',
#       'Scorching Sands',
#       'Fire Blast',
#       'Psychic',
#       'Focus Blast',
#       'Teleport']},
#     {'Stallbreaker': ['Lava Plume',
#       'Scorching Sands',
#       'Taunt',
#       'Fire Blast',
#       'Psychic']}]}],
#  'Pinsir': [{'PU': [{'Swords Dance': ['Swords Dance',
#       'X-Scissor',
#       'Earthquake',
#       'Stone Edge']},
#     {'Choice Scarf': ['X-Scissor', 'Earthquake', 'Stone Edge', 'Knock Off']},
#     {'Stealth Rock': ['Stealth Rock',
#       'X-Scissor',
#       'Earthquake',
#       'Stone Edge']}]}],
#  'Tauros': [{'NU': [{'All-out Attacker': ['Body Slam',
#       'Close Combat',
#       'Throat Chop',
#       'Iron Head']}]},
#   {'RU': [{'All-out Attacker': ['Body Slam',
#       'Close Combat',
#       'Throat Chop',
#       'Rock Slide']}]}],
#  'Magikarp': [],
#  'Gyarados': [{'UU': [{'Dragon Dance Sweeper': ['Dragon Dance',
#       'Waterfall',
#       'Ice Fang',
#       'Bounce',
#       'Power Whip']}]}],
#  'Lapras': [{'PU': [{'RestTalk': ['Freeze-Dry', 'Surf', 'Rest', 'Sleep Talk']},
#     {'Choice Specs': ['Hydro Pump',
#       'Freeze-Dry',
#       'Ice Beam',
#       'Thunderbolt',
#       'Surf']}]}],
#  'Ditto': [{'Uber': [{'Ditto (Copycat)': ['Transform']}]},
#   {'OU': [{'Imposter': ['Transform']}]},
#   {'UU': [{'Imposter': ['Transform']}]},
#   {'RU': [{'Revenge Killer': ['Transform']}]}],
#  'Eevee': [],
#  'Vaporeon': [{'NU': [{'Defensive': ['Scald',
#       'Wish',
#       'Protect',
#       'Heal Bell',
#       'Toxic',
#       'Flip Turn']}]}],
#  'Jolteon': [{'PU': [{'Utility': ['Thunderbolt',
#       'Volt Switch',
#       'Shadow Ball',
#       'Toxic',
#       'Yawn',
#       'Heal Bell']}]}],
#  'Flareon': [{'PU': [{'Specially Defensive': ['Wish',
#       'Protect',
#       'Flare Blitz',
#       'Lava Plume',
#       'Toxic']},
#     {'Offensive': ['Flare Blitz', 'Facade', 'Superpower', 'Quick Attack']}]}],
#  'Porygon': [{'LC': [{'Download': ['Tri Attack',
#       'Psychic',
#       'Ice Beam',
#       'Agility']},
#     {'Trace': ['Tri Attack',
#       'Ice Beam',
#       'Psychic',
#       'Recover',
#       'Thunder Wave',
#       'Teleport']}]},
#   {'NFE': [{'Choice Specs': ['Tri Attack',
#       'Ice Beam',
#       'Thunderbolt',
#       'Psychic',
#       'Trick']},
#     {'Specially Defensive Pivot': ['Shadow Ball',
#       'Tri Attack',
#       'Psychic',
#       'Recover',
#       'Teleport']}]}],
#  'Omanyte': [{'LC': [{'Shell Smash': ['Shell Smash',
#       'Hydro Pump',
#       'Surf',
#       'Ice Beam',
#       'Earth Power']},
#     {'Support': ['Spikes',
#       'Hydro Pump',
#       'Scald',
#       'Knock Off',
#       'Stealth Rock']}]}],
#  'Omastar': [{'RU': [{'Setup Sweeper': ['Shell Smash',
#       'Meteor Beam',
#       'Surf',
#       'Hydro Pump',
#       'Ice Beam']}]},
#   {'NU': [{'Shell Smash': ['Shell Smash', 'Meteor Beam', 'Surf', 'Ice Beam']},
#     {'Lead': ['Stealth Rock', 'Spikes', 'Scald', 'Shell Smash']}]}],
#  'Kabuto': [{'LC': [{'Support': ['Rapid Spin',
#       'Stealth Rock',
#       'Knock Off',
#       'Rock Slide',
#       'Waterfall']}]}],
#  'Kabutops': [{'RU': [{'Rain Sweeper': ['Swords Dance',
#       'Liquidation',
#       'Waterfall',
#       'Stone Edge',
#       'Flip Turn',
#       'Aqua Jet']}]}],
#  'Aerodactyl': [{'NU': [{'Choice Band': ['Stone Edge',
#       'Dual Wingbeat',
#       'Earthquake',
#       'Crunch']}]},
#   {'Uber': [{'Stealth Rocks Lead': ['Stealth Rock',
#       'Rock Tomb',
#       'Taunt',
#       'Tailwind',
#       'Defog']}]},
#   {'RU': [{'Dragon Dance': ['Dragon Dance',
#       'Stone Edge',
#       'Dual Wingbeat',
#       'Earthquake']},
#     {'3 Attacks + Roost': ['Stone Edge',
#       'Earthquake',
#       'Dual Wingbeat',
#       'Roost']}]}],
#  'Snorlax': [{'RU': [{'Curselax': ['Curse',
#       'Body Slam',
#       'Earthquake',
#       'Rest']}]}],
#  'Articuno': [{'ZU': [{'Specially Defensive': ['Roost',
#       'Defog',
#       'Brave Bird',
#       'Freeze-Dry',
#       'U-turn',
#       'Toxic',
#       'Freeze-Dry']},
#     {'SubRoost': ['Substitute', 'Roost', 'Toxic', 'Freeze-Dry']},
#     {'Roost + 3 Attacks': ['Roost', 'Hurricane', 'Freeze-Dry', 'U-turn']}]}],
#  'Zapdos': [{'OU': [{'Utility': ['Discharge',
#       'Volt Switch',
#       'Hurricane',
#       'Heat Wave',
#       'Roost',
#       'Defog']},
#     {'Offensive Rain Sweeper': ['Thunder',
#       'Hurricane',
#       'Weather Ball',
#       'Roost']}]}],
#  'Moltres': [{'UU': [{'Offensive': ['Flamethrower',
#       'Hurricane',
#       'U-turn',
#       'Defog',
#       'Roost']},
#     {'SubToxic': ['Substitute', 'Mystical Fire', 'Roost', 'Toxic']}]},
#   {'OU': [{'Substitute': ['Substitute',
#       'Flamethrower',
#       'Hurricane',
#       'Roost']}]}],
#  'Dratini': [],
#  'Dragonair': [],
#  'Dragonite': [{'OU': [{'Offensive Dragon Dance': ['Dragon Dance',
#       'Dual Wingbeat',
#       'Earthquake',
#       'Roost',
#       'Extreme Speed']},
#     {'Defensive Dragon Dance': ['Dragon Dance',
#       'Dual Wingbeat',
#       'Heal Bell',
#       'Roost']},
#     {'Utility': ['Ice Beam', 'Earthquake', 'Roost', 'Heal Bell', 'Defog']}]}],
#  'Mewtwo': [{'Uber': [{'Nasty Plot': ['Psystrike',
#       'Nasty Plot',
#       'Ice Beam',
#       'Focus Blast',
#       'Fire Blast']}]}],
#  'Mew': [{'UU': [{'Utility': ['Psychic',
#       'Ice Beam',
#       'Will-O-Wisp',
#       'Knock Off',
#       'Flamethrower',
#       'Spikes',
#       'Soft-Boiled']},
#     {'Nasty Plot': ['Nasty Plot',
#       'Psychic',
#       'Psyshock',
#       'Flamethrower',
#       'Giga Drain',
#       'Vacuum Wave']},
#     {'Suicide Lead': ['Spikes', 'Stealth Rock', 'Taunt', 'Explosion']},
#     {'Cosmic Power': ['Cosmic Power', 'Stored Power', 'Body Press', 'Rest']}]},
#   {'Uber': [{'Lead': ['Stealth Rock', 'Spikes', 'Taunt', 'Misty Explosion']}]},
#   {'OU': [{'Suicide Lead': ['Stealth Rock',
#       'Spikes',
#       'Taunt',
#       'Flare Blitz']}]}],
#  'Igglybuff': [],
#  'Togepi': [],
#  'Togetic': [{'NFE': [{'Defog': ['Defog',
#       'Roost',
#       'Dazzling Gleam',
#       'Flamethrower',
#       'Toxic']},
#     {'Nasty Plot': ['Nasty Plot',
#       'Dazzling Gleam',
#       'Flamethrower',
#       'Psyshock',
#       'Roost']}]},
#   {'PU': [{'Defog': ['Defog',
#       'Roost',
#       'Dazzling Gleam',
#       'Thunder Wave',
#       'Flamethrower',
#       'Heal Bell']}]}],
#  'Cleffa': [],
#  'Bellossom': [{'PU': [{'Bulky Quiver Dance': ['Quiver Dance',
#       'Strength Sap',
#       'Giga Drain',
#       'Moonblast']}]}],
#  'Marill': [],
#  'Azumarill': [{'UU': [{'Choice Band': ['Aqua Jet',
#       'Play Rough',
#       'Liquidation',
#       'Knock Off',
#       'Ice Punch']},
#     {'Belly Drum': ['Belly Drum', 'Aqua Jet', 'Play Rough', 'Knock Off']}]},
#   {'OU': [{'Belly Drum': ['Belly Drum',
#       'Play Rough',
#       'Aqua Jet',
#       'Knock Off']}]}],
#  'Tyrogue': [],
#  'Hitmontop': [{'PU': [{'Offensive': ['Mach Punch',
#       'Triple Axel',
#       'Thief',
#       'Stone Edge',
#       'Fake Out',
#       'Rapid Spin']}]}],
#  'Noctowl': [],
#  'Qwilfish': [{'PU': [{'Spikes': ['Spikes',
#       'Taunt',
#       'Waterfall',
#       'Thunder Wave',
#       'Poison Jab',
#       'Destiny Bond']},
#     {'Rain Sweeper': ['Swords Dance',
#       'Waterfall',
#       'Poison Jab',
#       'Aqua Jet']}]},
#   {'ZU': [{'Defensive Spikes': ['Spikes',
#       'Toxic Spikes',
#       'Taunt',
#       'Thunder Wave',
#       'Liquidation',
#       'Scald',
#       'Pain Split']}]}],
#  'Corsola': [],
#  'Mantine': [{'NU': [{'Utility': ['Scald',
#       'Defog',
#       'Roost',
#       'Air Slash',
#       'Haze']}]},
#   {'UU': [{'Defensive': ['Scald', 'Toxic', 'Haze', 'Defog', 'Roost']}]}],
#  'Raikou': [{'RU': [{'Offensive Pivot': ['Volt Switch',
#       'Thunderbolt',
#       'Aura Sphere',
#       'Toxic',
#       'Scald']},
#     {'Calm Mind': ['Calm Mind',
#       'Thunderbolt',
#       'Aura Sphere',
#       'Scald',
#       'Substitute']}]},
#   {'UU': [{'Offensive Pivot': ['Thunderbolt',
#       'Volt Switch',
#       'Aura Sphere',
#       'Scald',
#       'Toxic']}]}],
#  'Entei': [{'UU': [{'Choice Band': ['Sacred Fire',
#       'Extreme Speed',
#       'Stone Edge',
#       'Flare Blitz',
#       'Toxic']}]},
#   {'RU': [{'Choice Band': ['Sacred Fire',
#       'Extreme Speed',
#       'Stone Edge',
#       'Flare Blitz',
#       'Stomping Tantrum']}]}],
#  'Suicune': [{'RU': [{'Substitute + Calm Mind': ['Substitute',
#       'Calm Mind',
#       'Scald',
#       'Protect',
#       'Ice Beam',
#       'Roar']},
#     {'RestTalk': ['Rest', 'Sleep Talk', 'Roar', 'Scald', 'Calm Mind']}]},
#   {'OU': [{'VinCune': ['Scald', 'Substitute', 'Calm Mind', 'Protect']}]},
#   {'UU': [{'Crocune': ['Calm Mind', 'Scald', 'Rest', 'Sleep Talk']}]}],
#  'Hoothoot': [],
#  'Crobat': [{'RU': [{'Pivot': ['Brave Bird',
#       'Roost',
#       'U-turn',
#       'Defog',
#       'Taunt']}]}],
#  'Chinchou': [{'LC': [{'Offensive Pivot': ['Volt Switch',
#       'Ice Beam',
#       'Thunderbolt',
#       'Scald']}]}],
#  'Lanturn': [{'PU': [{'Bulky Pivot': ['Scald',
#       'Volt Switch',
#       'Toxic',
#       'Heal Bell',
#       'Protect',
#       'Heal Bell']},
#     {'Assault Vest': ['Scald',
#       'Volt Switch',
#       'Ice Beam',
#       'Discharge',
#       'Dazzling Gleam',
#       'Psybeam']}]}],
#  'Pichu': [],
#  'Natu': [{'LC': [{'Screens': ['Reflect',
#       'Light Screen',
#       'Teleport',
#       'Thunder Wave']},
#     {'Offensive': ['Psychic', 'Heat Wave', 'Dazzling Gleam', 'Giga Drain']}]},
#   {'NFE': [{'Teleport': ['Teleport',
#       'Roost',
#       'Toxic',
#       'Psychic',
#       'Night Shade']}]}],
#  'Xatu': [{'PU': [{'Cosmic Power': ['Cosmic Power',
#       'Roost',
#       'Stored Power',
#       'Dazzling Gleam']}]},
#   {'Uber': [{'Magic Bounce': ['Roost',
#       'Thunder Wave',
#       'Toxic',
#       'Teleport',
#       'Night Shade']}]},
#   {'OU': [{'Magic Bounce': ['Psychic', 'Roost', 'Teleport', 'Heat Wave']}]},
#   {'RU': [{'Magic Bounce': ['Roost',
#       'Heat Wave',
#       'Grass Knot',
#       'Teleport',
#       'U-turn']}]},
#   {'NU': [{'Pivot': ['Psychic',
#       'Future Sight',
#       'Night Shade',
#       'Heat Wave',
#       'Roost',
#       'Teleport',
#       'U-turn']},
#     {'Dual Screens': ['Reflect',
#       'Light Screen',
#       'Teleport',
#       'Thunder Wave',
#       'Roost']}]}],
#  'Sudowoodo': [],
#  'Politoed': [{'UU': [{'Rain Setter': ['Scald',
#       'Toxic',
#       'Encore',
#       'Rest',
#       'Ice Beam']}]},
#   {'RU': [{'Rain Setter': ['Scald',
#       'Encore',
#       'Toxic',
#       'Hypnosis',
#       'Ice Beam',
#       'Perish Song',
#       'Rest']}]}],
#  'Wooper': [],
#  'Quagsire': [{'UU': [{'Unaware Wall': ['Scald',
#       'Earthquake',
#       'Haze',
#       'Recover']}]},
#   {'OU': [{'Unaware': ['Scald', 'Earthquake', 'Recover', 'Toxic']}]}],
#  'Espeon': [{'NU': [{'Dual Screens': ['Reflect',
#       'Light Screen',
#       'Dazzling Gleam',
#       'Yawn']}]}],
#  'Umbreon': [{'RU': [{'Cleric': ['Wish',
#       'Protect',
#       'Heal Bell',
#       'Foul Play']}]},
#   {'UU': [{'Defensive': ['Foul Play', 'Wish', 'Protect', 'Toxic']}]}],
#  'Slowking': [{'OU': [{'Specially Defensive Pivot': ['Scald',
#       'Future Sight',
#       'Slack Off',
#       'Teleport']}]}],
#  'Wobbuffet': [],
#  'Dunsparce': [],
#  'Steelix': [{'RU': [{'Defensive': ['Stealth Rock',
#       'Earthquake',
#       'Heavy Slam',
#       'Toxic']}]}],
#  'Scizor': [{'UU': [{'Swords Dance + Roost': ['Swords Dance',
#       'Bullet Punch',
#       'Knock Off',
#       'U-turn',
#       'Roost']},
#     {'Choice Band': ['Bullet Punch', 'U-turn', 'Knock Off', 'Dual Wingbeat']},
#     {'Offensive Swords Dance': ['Swords Dance',
#       'Bullet Punch',
#       'Knock Off',
#       'Bug Bite',
#       'Quick Attack']}]},
#   {'OU': [{'Specially Defensive': ['Bullet Punch',
#       'U-turn',
#       'Swords Dance',
#       'Roost',
#       'Knock Off',
#       'Swords Dance']},
#     {'Offensive Swords Dance': ['Swords Dance',
#       'Bullet Punch',
#       'Knock Off',
#       'Superpower',
#       'Sand Tomb',
#       'Psycho Cut']}]}],
#  'Shuckle': [{'Uber': [{'Sticky Web Setter': ['Sticky Web',
#       'Stealth Rock',
#       'Final Gambit',
#       'Encore',
#       'Toxic']}]},
#   {'UU': [{'Lead': ['Sticky Web',
#       'Stealth Rock',
#       'Encore',
#       'Knock Off',
#       'Toxic']}]},
#   {'PU': [{'Lead': ['Sticky Web', 'Stealth Rock', 'Toxic', 'Encore']}]}],
#  'Heracross': [{'RU': [{'Guts Wallbreaker': ['Close Combat',
#       'Facade',
#       'Knock Off',
#       'Megahorn',
#       'Swords Dance']},
#     {'Choice Scarf': ['Close Combat',
#       'Megahorn',
#       'Spikes',
#       'Knock Off',
#       'Stone Edge']}]}],
#  'Sneasel': [{'NU': [{'Choice Band': ['Knock Off',
#       'Icicle Crash',
#       'Low Kick',
#       'Ice Shard']},
#     {'Swords Dance': ['Swords Dance',
#       'Icicle Crash',
#       'Knock Off',
#       'Ice Shard']}]},
#   {'PU': [{'Swords Dance': ['Swords Dance',
#       'Knock Off',
#       'Triple Axel',
#       'Ice Shard']},
#     {'Choice Band': ['Knock Off', 'Triple Axel', 'Ice Shard', 'Low Kick']}]}],
#  'Swinub': [],
#  'Piloswine': [{'NFE': [{'Stealth Rock': ['Stealth Rock',
#       'High Horsepower',
#       'Earthquake',
#       'Icicle Crash',
#       'Icicle Spear',
#       'Ice Shard']},
#     {'Choice Band': ['Earthquake',
#       'High Horsepower',
#       'Icicle Crash',
#       'Ice Shard',
#       'Superpower']}]},
#   {'ZU': [{'Stealth Rock': ['Stealth Rock',
#       'Earthquake',
#       'Icicle Crash',
#       'Ice Shard']}]}],
#  'Remoraid': [],
#  'Octillery': [],
#  'Delibird': [],
#  'Skarmory': [{'OU': [{'Defensive Spikes': ['Body Press',
#       'Spikes',
#       'Iron Defense',
#       'Toxic',
#       'Roost']}]},
#   {'Uber': [{'Defensive Spikes': ['Roost',
#       'Spikes',
#       'Whirlwind',
#       'Toxic',
#       'Body Press']}]}],
#  'Kingdra': [{'OU': [{'Choice Specs': ['Hydro Pump',
#       'Draco Meteor',
#       'Hurricane',
#       'Surf',
#       'Flip Turn']}]},
#   {'UU': [{'Swift Swim Sweeper': ['Hydro Pump',
#       'Draco Meteor',
#       'Hurricane',
#       'Surf',
#       'Flip Turn']}]},
#   {'RU': [{'Rain Sweeper': ['Surf',
#       'Draco Meteor',
#       'Hurricane',
#       'Hydro Pump',
#       'Flip Turn']}]},
#   {'NU': [{'CritDra': ['Focus Energy', 'Draco Meteor', 'Surf', 'Agility']}]}],
#  'Porygon2': [{'RU': [{'Specially Defensive': ['Teleport',
#       'Recover',
#       'Ice Beam',
#       'Tri Attack',
#       'Toxic']}]},
#   {'Uber': [{'Defensive': ['Recover', 'Foul Play', 'Ice Beam', 'Teleport']}]}],
#  'Smoochum': [],
#  'Elekid': [{'LC': [{'Offensive': ['Volt Switch',
#       'Thunderbolt',
#       'Psychic',
#       'Ice Punch',
#       'Brick Break']}]}],
#  'Magby': [{'LC': [{'Belly Drum': ['Belly Drum',
#       'Fire Punch',
#       'Mach Punch',
#       'Thunder Punch']}]}],
#  'Miltank': [{'PU': [{'Defensive': ['Stealth Rock',
#       'Milk Drink',
#       'Toxic',
#       'Seismic Toss',
#       'Body Slam']},
#     {'Offensive': ['Stealth Rock', 'Body Slam', 'Hammer Arm', 'Milk Drink']}]},
#   {'ZU': [{'Special Wall': ['Milk Drink',
#       'Toxic',
#       'Thunder Wave',
#       'Seismic Toss',
#       'Body Slam',
#       'Heal Bell',
#       'Stealth Rock']},
#     {'Mixed Wall': ['Stealth Rock',
#       'Heal Bell',
#       'Seismic Toss',
#       'Milk Drink',
#       'Toxic',
#       'Thunder Wave']}]}],
#  'Blissey': [{'OU': [{'Defensive': ['Seismic Toss',
#       'Soft-Boiled',
#       'Thunder Wave',
#       'Toxic',
#       'Teleport']}]},
#   {'Uber': [{'Defensive': ['Soft-Boiled',
#       'Seismic Toss',
#       'Shadow Ball',
#       'Teleport',
#       'Thunder Wave',
#       'Stealth Rock',
#       'Confide',
#       'Aromatherapy',
#       'Wish']}]}],
#  'Larvitar': [],
#  'Pupitar': [],
#  'Tyranitar': [{'OU': [{'Specially Defensive': ['Stealth Rock',
#       'Rock Blast',
#       'Earthquake',
#       'Thunder Wave',
#       'Toxic']},
#     {'Choice Band': ['Stone Edge',
#       'Crunch',
#       'Fire Punch',
#       'Ice Punch',
#       'Heavy Slam']}]},
#   {'Uber': [{'Specially Defensive': ['Stealth Rock',
#       'Foul Play',
#       'Rock Blast',
#       'Snarl',
#       'Foul Play',
#       'Thunder Wave',
#       'Rest']}]}],
#  'Lugia': [{'Uber': [{'Defensive': ['Roost',
#       'Ice Beam',
#       'Whirlwind',
#       'Toxic',
#       'Thunder Wave']}]}],
#  'Ho-Oh': [{'Uber': [{'Defensive': ['Sacred Fire',
#       'Defog',
#       'Toxic',
#       'Thunder Wave',
#       'Whirlwind',
#       'Brave Bird']},
#     {'Choice Band': ['Sacred Fire',
#       'Brave Bird',
#       'Earthquake',
#       'Defog',
#       'Whirlwind',
#       'Flare Blitz',
#       'Toxic']}]}],
#  'Celebi': [{'NU': [{'Nasty Plot': ['Nasty Plot',
#       'Psychic',
#       'Aura Sphere',
#       'Recover',
#       'Giga Drain']}]},
#   {'RU': [{'Utility': ['Thunder Wave',
#       'U-turn',
#       'Recover',
#       'Psychic',
#       'Grass Knot']},
#     {'Choice Scarf': ['Leaf Storm', 'Psychic', 'Trick', 'U-turn']}]}],
#  'Milotic': [{'RU': [{'Defensive': ['Scald',
#       'Recover',
#       'Flip Turn',
#       'Ice Beam',
#       'Toxic',
#       'Haze']}]},
#   {'UU': [{'Defensive Pivot': ['Scald',
#       'Flip Turn',
#       'Toxic',
#       'Ice Beam',
#       'Recover']}]}],
#  'Treecko': [{'LC': [{'Sweeper': ['Swords Dance',
#       'Bullet Seed',
#       'Drain Punch',
#       'Acrobatics',
#       'Rock Slide']}]}],
#  'Grovyle': [{'NFE': [{'Unburden Sweeper': ['Swords Dance',
#       'Acrobatics',
#       'Leaf Blade',
#       'Substitute',
#       'Drain Punch']}]}],
#  'Sceptile': [],
#  'Torchic': [],
#  'Combusken': [{'NFE': [{'Specially Offensive': ['Flamethrower',
#       'Protect',
#       'Toxic',
#       'Substitute',
#       'Focus Blast']},
#     {'Swords Dance': ['Swords Dance',
#       'Protect',
#       'Flare Blitz',
#       'Brick Break',
#       'Thunder Punch']}]}],
#  'Blaziken': [{'OU': [{'Swords Dance': ['Swords Dance',
#       'Flare Blitz',
#       'Close Combat',
#       'Thunder Punch',
#       'Earthquake']},
#     {'Choice Band': ['Flare Blitz', 'Close Combat', 'Knock Off', 'U-turn']}]}],
#  'Mudkip': [],
#  'Marshtomp': [{'NFE': [{'Special Wall': ['Scald',
#       'Earthquake',
#       'Toxic',
#       'Yawn',
#       'Stealth Rock']}]}],
#  'Swampert': [{'OU': [{'Stealth Rock Pivot': ['Stealth Rock',
#       'Flip Turn',
#       'Earthquake',
#       'Toxic',
#       'Yawn',
#       'Rest',
#       'Protect']}]}],
#  'Ralts': [],
#  'Kirlia': [],
#  'Gardevoir': [{'RU': [{'Choice Specs': ['Moonblast',
#       'Psychic',
#       'Focus Blast',
#       'Shadow Ball']},
#     {'Choice Scarf': ['Moonblast', 'Psychic', 'Trick', 'Healing Wish']}]},
#   {'UU': [{'Offensive': ['Psyshock',
#       'Psychic',
#       'Moonblast',
#       'Mystical Fire',
#       'Taunt',
#       'Thunder Wave']}]}],
#  'Exploud': [{'NU': [{'DAT LOUD': ['Boomburst',
#       'Overheat',
#       'Focus Blast',
#       'Surf']}]}],
#  'Azurill': [],
#  'Mawile': [],
#  'Feebas': [],
#  'Duskull': [],
#  'Dusclops': [{'NFE': [{'Bulky Attacker': ['Poltergeist',
#       'Shadow Sneak',
#       'Power-Up Punch',
#       'Will-O-Wisp']}]}],
#  'Regirock': [{'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Rock Blast',
#       'Stone Edge',
#       'Body Press',
#       'Toxic',
#       'Thunder Wave']}]}],
#  'Regice': [{'PU': [{'Rock Polish': ['Rock Polish',
#       'Ice Beam',
#       'Thunderbolt',
#       'Focus Blast']},
#     {'RestTalk': ['Rest', 'Sleep Talk', 'Ice Beam', 'Thunderbolt']}]}],
#  'Registeel': [{'RU': [{'Specially Defensive': ['Stealth Rock',
#       'Toxic',
#       'Seismic Toss',
#       'Body Press',
#       'Heavy Slam',
#       'Protect']}]}],
#  'Wingull': [{'LC': [{'Life Orb': ['Hurricane',
#       'Scald',
#       'Substitute',
#       'Air Slash',
#       'U-turn']}]}],
#  'Pelipper': [{'OU': [{'Defensive': ['Scald',
#       'Hurricane',
#       'Roost',
#       'U-turn',
#       'Defog']},
#     {'Choice Specs': ['Weather Ball', 'Hurricane', 'Scald', 'U-turn']}]}],
#  'Torkoal': [{'OU': [{'Support': ['Lava Plume',
#       'Rest',
#       'Rapid Spin',
#       'Sleep Talk',
#       'Stealth Rock',
#       'Toxic']}]},
#   {'UU': [{'Sun Setter': ['Stealth Rock',
#       'Lava Plume',
#       'Rapid Spin',
#       'Toxic',
#       'Yawn']}]},
#   {'RU': [{'Sun Support': ['Stealth Rock',
#       'Lava Plume',
#       'Yawn',
#       'Toxic',
#       'Body Press']}]}],
#  'Lunatone': [],
#  'Solrock': [{'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Morning Sun',
#       'Will-O-Wisp',
#       'Rock Slide',
#       'Zen Headbutt']}]}],
#  'Trapinch': [{'LC': [{'Trapper': ['Earthquake',
#       'Giga Drain',
#       'First Impression',
#       'Superpower',
#       'Feint']}]}],
#  'Vibrava': [],
#  'Flygon': [{'NU': [{'Choice Scarf': ['Earthquake',
#       'Outrage',
#       'U-turn',
#       'Dragon Claw',
#       'Defog',
#       'Stone Edge']},
#     {'Utility': ['Earthquake', 'Roost', 'U-turn', 'Toxic', 'Defog']}]},
#   {'RU': [{'Choice Scarf': ['Earthquake',
#       'U-turn',
#       'Stone Edge',
#       'Outrage',
#       'Outrage',
#       'Toxic',
#       'Defog']}]}],
#  'Zigzagoon': [{'LC': [{'Belly Drum': ['Belly Drum',
#       'Extreme Speed',
#       'Seed Bomb',
#       'Thief',
#       'Protect']}]}],
#  'Linoone': [{'RU': [{'Belly Drum': ['Belly Drum',
#       'Extreme Speed',
#       'Stomping Tantrum',
#       'Seed Bomb',
#       'Throat Chop']}]}],
#  'Lotad': [],
#  'Lombre': [],
#  'Ludicolo': [{'PU': [{'Rain Sweeper': ['Rain Dance',
#       'Hydro Pump',
#       'Giga Drain',
#       'Ice Beam']}]},
#   {'ZU': [{'Rain Sweeper': ['Hydro Pump',
#       'Giga Drain',
#       'Ice Beam',
#       'Rain Dance']}]}],
#  'Seedot': [],
#  'Nuzleaf': [],
#  'Shiftry': [{'RU': [{'Sun Sweeper': ['Growth',
#       'Solar Blade',
#       'Leaf Blade',
#       'Knock Off',
#       'Low Kick',
#       'Heat Wave']}]},
#   {'ZU': [{'Mixed Attacker': ['Knock Off',
#       'Sucker Punch',
#       'Leaf Storm',
#       'Swords Dance',
#       'Defog']},
#     {'Sun Sweeper': ['Swords Dance',
#       'Growth',
#       'Solar Blade',
#       'Knock Off',
#       'Sucker Punch',
#       'Heat Wave']}]}],
#  'Nincada': [],
#  'Ninjask': [{'NU': [{'Swords Dance': ['Acrobatics',
#       'U-turn',
#       'Protect',
#       'Swords Dance']}]},
#   {'RU': [{'Offensive Pivot': ['U-turn',
#       'Dual Wingbeat',
#       'Swords Dance',
#       'Protect']}]}],
#  'Shedinja': [{'Uber': [{'Wonder Guard': ['Shadow Sneak',
#       'Protect',
#       'Toxic',
#       'Swords Dance',
#       'Will-O-Wisp',
#       'Poltergeist']}]}],
#  'Whismur': [],
#  'Loudred': [],
#  'Sableye': [{'PU': [{'Defensive': ['Knock Off',
#       'Foul Play',
#       'Recover',
#       'Will-O-Wisp',
#       'Encore',
#       'Taunt']}]}],
#  'Aron': [],
#  'Lairon': [{'NFE': [{'Choice Band': ['Head Smash',
#       'Heavy Slam',
#       'Superpower',
#       'Stealth Rock',
#       'Double-Edge']}]}],
#  'Aggron': [],
#  'Electrike': [],
#  'Manectric': [{'PU': [{'Choice Scarf': ['Thunderbolt',
#       'Volt Switch',
#       'Overheat',
#       'Flamethrower',
#       'Switcheroo']},
#     {'Choice Specs': ['Thunderbolt',
#       'Volt Switch',
#       'Overheat',
#       'Flamethrower',
#       'Switcheroo',
#       'Hyper Voice']},
#     {'Toxic + Protect': ['Thunderbolt',
#       'Volt Switch',
#       'Toxic',
#       'Flamethrower',
#       'Protect']}]},
#   {'ZU': [{'Choice Scarf': ['Thunderbolt',
#       'Volt Switch',
#       'Overheat',
#       'Switcheroo']},
#     {'Choice Specs': ['Thunderbolt',
#       'Volt Switch',
#       'Overheat',
#       'Flamethrower',
#       'Switcheroo']}]}],
#  'Roselia': [{'NFE': [{'Offensive Spikes': ['Spikes',
#       'Leaf Storm',
#       'Sludge Bomb',
#       'Sleep Powder',
#       'Extrasensory']},
#     {'Specially Defensive': ['Spikes',
#       'Sludge Bomb',
#       'Giga Drain',
#       'Synthesis']},
#     {'Choice Specs': ['Leaf Storm',
#       'Sludge Bomb',
#       'Giga Drain',
#       'Shadow Ball',
#       'Extrasensory']}]},
#   {'PU': [{'Offensive': ['Toxic Spikes',
#       'Spikes',
#       'Leaf Storm',
#       'Sludge Bomb',
#       'Synthesis',
#       'Sleep Powder']},
#     {'Defensive': ['Toxic Spikes',
#       'Spikes',
#       'Giga Drain',
#       'Sludge Bomb',
#       'Synthesis']}]}],
#  'Carvanha': [{'LC': [{'Cleaner': ['Liquidation',
#       'Crunch',
#       'Psychic Fangs',
#       'Flip Turn',
#       'Protect',
#       'Aqua Jet']},
#     {'Special Attacker': ['Hydro Pump',
#       'Dark Pulse',
#       'Ice Beam',
#       'Protect']}]}],
#  'Sharpedo': [{'RU': [{'Physical Cleaner': ['Waterfall',
#       'Crunch',
#       'Close Combat',
#       'Protect']},
#     {'Specially Biased Mixed Cleaner': ['Hydro Pump',
#       'Dark Pulse',
#       'Close Combat',
#       'Protect']}]}],
#  'Wailmer': [],
#  'Wailord': [],
#  'Swablu': [],
#  'Altaria': [{'PU': [{'Defog': ['Defog',
#       'Roost',
#       'Hurricane',
#       'Flamethrower',
#       'Toxic',
#       'Flamethrower',
#       'Fire Spin']}]},
#   {'ZU': [{'Physical Wall': ['Roost',
#       'Defog',
#       'Hurricane',
#       'Earthquake',
#       'Toxic',
#       'Dual Wingbeat']}]}],
#  'Barboach': [],
#  'Whiscash': [],
#  'Corphish': [{'LC': [{'Wallbreaker': ['Crabhammer',
#       'Aqua Jet',
#       'Knock Off',
#       'Superpower',
#       'Swords Dance',
#       'Dragon Dance',
#       'Superpower']}]}],
#  'Crawdaunt': [{'UU': [{'Swords Dance': ['Swords Dance',
#       'Crabhammer',
#       'Knock Off',
#       'Aqua Jet']},
#     {'All-out Attacker': ['Crabhammer',
#       'Knock Off',
#       'Aqua Jet',
#       'Close Combat']}]},
#   {'OU': [{'Swords Dance': ['Swords Dance',
#       'Crabhammer',
#       'Knock Off',
#       'Aqua Jet']}]}],
#  'Baltoy': [],
#  'Claydol': [{'PU': [{'Defensive': ['Stealth Rock',
#       'Rapid Spin',
#       'Toxic',
#       'Psychic',
#       'Scorching Sands',
#       'Teleport',
#       'Protect']}]}],
#  'Lileep': [],
#  'Cradily': [{'PU': [{'Defensive': ['Stealth Rock',
#       'Recover',
#       'Toxic',
#       'Giga Drain']}]}],
#  'Anorith': [],
#  'Armaldo': [{'PU': [{'Utility': ['Rapid Spin',
#       'Stone Edge',
#       'Knock Off',
#       'Earthquake',
#       'X-Scissor']},
#     {'Swift Swim': ['Swords Dance',
#       'Stone Edge',
#       'Earthquake',
#       'X-Scissor',
#       'Aqua Jet']}]}],
#  'Absol': [{'PU': [{'Choice Band': ['Knock Off',
#       'Sucker Punch',
#       'Close Combat',
#       'Iron Tail',
#       'Psycho Cut']},
#     {'Swords Dance': ['Swords Dance',
#       'Knock Off',
#       'Sucker Punch',
#       'Iron Tail',
#       'Play Rough',
#       'Close Combat']}]}],
#  'Wynaut': [{'LC': [{'Trapper': ['Counter',
#       'Mirror Coat',
#       'Encore',
#       'Destiny Bond']}]}],
#  'Snorunt': [],
#  'Glalie': [],
#  'Spheal': [],
#  'Sealeo': [],
#  'Walrein': [{'PU': [{'Swords Dance': ['Swords Dance',
#       'Waterfall',
#       'Icicle Spear',
#       'Earthquake']}]}],
#  'Relicanth': [{'PU': [{'Choice Band': ['Head Smash',
#       'Waterfall',
#       'Earthquake',
#       'Zen Headbutt']}]}],
#  'Bagon': [],
#  'Shelgon': [],
#  'Salamence': [{'UU': [{'Special Attacker': ['Hurricane',
#       'Defog',
#       'Draco Meteor',
#       'Defog',
#       'Flamethrower',
#       'Roost']},
#     {'Dragon Dance': ['Dragon Dance',
#       'Outrage',
#       'Dual Wingbeat',
#       'Earthquake',
#       'Fire Blast']},
#     {'Defensive': ['Hurricane',
#       'Air Slash',
#       'Flamethrower',
#       'Defog',
#       'Toxic',
#       'Roost']}]}],
#  'Beldum': [],
#  'Metang': [{'NFE': [{'Stealth Rock': ['Stealth Rock',
#       'Meteor Mash',
#       'Toxic',
#       'Bullet Punch',
#       'Earthquake']}]},
#   {'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Meteor Mash',
#       'Earthquake',
#       'Toxic',
#       'Bullet Punch']}]}],
#  'Metagross': [{'RU': [{'Stealth Rock': ['Stealth Rock',
#       'Meteor Mash',
#       'Earthquake',
#       'Toxic']},
#     {'Choice Band': ['Meteor Mash',
#       'Earthquake',
#       'Bullet Punch',
#       'Zen Headbutt',
#       'Explosion']},
#     {'Choice Scarf': ['Meteor Mash',
#       'Earthquake',
#       'Ice Punch',
#       'Rock Slide',
#       'Trick']}]}],
#  'Latias': [],
#  'Latios': [{'OU': [{'Choice Specs': ['Draco Meteor',
#       'Psychic',
#       'Trick',
#       'Mystical Fire',
#       'Aura Sphere']},
#     {'Life Orb': ['Draco Meteor',
#       'Psychic',
#       'Roost',
#       'Mystical Fire',
#       'Aura Sphere']},
#     {'Choice Scarf': ['Draco Meteor',
#       'Psychic',
#       'Trick',
#       'Mystical Fire',
#       'Aura Sphere']}]}],
#  'Kyogre': [{'Uber': [{'Choice Specs': ['Water Spout',
#       'Origin Pulse',
#       'Ice Beam',
#       'Thunder']},
#     {'Choice Scarf': ['Water Spout', 'Origin Pulse', 'Ice Beam', 'Thunder']},
#     {'Bulky Calm Mind': ['Scald', 'Calm Mind', 'Ice Beam', 'Rest']}]}],
#  'Groudon': [{'Uber': [{'Double Dance': ['Swords Dance',
#       'Rock Polish',
#       'Precipice Blades',
#       'Stone Edge']},
#     {'Defensive Support': ['Stealth Rock',
#       'Thunder Wave',
#       'Rest',
#       'Roar',
#       'Toxic',
#       'Precipice Blades',
#       'Stone Edge']},
#     {'Bulky Swords Dance': ['Swords Dance',
#       'Thunder Wave',
#       'Precipice Blades',
#       'Stone Edge',
#       'Rock Slide']}]}],
#  'Rayquaza': [{'Uber': [{'Dragon Dance': ['Dragon Ascent',
#       'V-create',
#       'Dragon Dance',
#       'Extreme Speed',
#       'Draco Meteor',
#       'Outrage']},
#     {'Swords Dance': ['Dragon Ascent',
#       'V-create',
#       'Swords Dance',
#       'Extreme Speed',
#       'Scale Shot']},
#     {'Choice Band': ['Dragon Ascent',
#       'V-create',
#       'Dragon Claw',
#       'Outrage',
#       'Extreme Speed']}]}],
#  'Jirachi': [{'UU': [{'Choice Scarf': ['Iron Head',
#       'U-turn',
#       'Fire Punch',
#       'Ice Punch',
#       'Healing Wish']},
#     {'Stealth Rock': ['Iron Head',
#       'U-turn',
#       'Stealth Rock',
#       'Wish',
#       'Healing Wish',
#       'Thunder Wave']},
#     {'SubToxic': ['Iron Head', 'Fire Punch', 'Toxic', 'Substitute']}]},
#   {'OU': [{'Specially Defensive': ['Wish',
#       'Iron Head',
#       'Body Slam',
#       'Protect',
#       'U-turn']},
#     {'Choice Scarf': ['Iron Head',
#       'U-turn',
#       'Trick',
#       'Wish',
#       'Healing Wish']}]}],
#  'Rotom-Heat': [{'UU': [{'Pivot': ['Volt Switch',
#       'Overheat',
#       'Toxic',
#       'Defog',
#       'Pain Split']},
#     {'Nasty Plot': ['Nasty Plot',
#       'Discharge',
#       'Overheat',
#       'Pain Split',
#       'Toxic']}]},
#   {'OU': [{'Nasty Plot': ['Nasty Plot',
#       'Discharge',
#       'Overheat',
#       'Pain Split',
#       'Toxic']},
# ...
#       'U-turn']}]}],
#  'Skwovet': [],
#  'Greedent': [],
#  'Rookidee': [],
#  'Corvisquire': [],
#  'Corviknight': [{'OU': [{'Defog': ['Body Press',
#       'U-turn',
#       'Brave Bird',
#       'Defog',
#       'Roost']}]},
#   {'Uber': [{'Physically Defensive': ['Body Press',
#       'U-turn',
#       'Iron Defense',
#       'Defog',
#       'Roost']}]}],
#  'Blipbug': [],
#  'Dottler': [],
#  'Orbeetle': [],
#  'Nickit': [],
#  'Thievul': [{'ZU': [{'Choice Specs': ['Dark Pulse',
#       'Psychic',
#       'Parting Shot',
#       'Burning Jealousy',
#       'Knock Off']},
#     {'Grassy Terrain Sweeper': ['Nasty Plot',
#       'Dark Pulse',
#       'Psychic',
#       'Grass Knot',
#       'Burning Jealousy']}]}],
#  'Gossifleur': [],
#  'Eldegoss': [],
#  'Wooloo': [],
#  'Dubwool': [{'PU': [{'Cotton Guard': ['Cotton Guard',
#       'Body Press',
#       'Rest',
#       'Sleep Talk',
#       'Payback']}]}],
#  'Chewtle': [],
#  'Drednaw': [{'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Liquidation',
#       'Stone Edge',
#       'Head Smash',
#       'Earthquake']},
#     {'Rain Dance': ['Rain Dance',
#       'Liquidation',
#       'Stone Edge',
#       'Earthquake',
#       'Swords Dance']},
#     {'Swords Dance': ['Swords Dance',
#       'Liquidation',
#       'Stone Edge',
#       'Earthquake']},
#     {'Choice Scarf': ['Liquidation',
#       'Stone Edge',
#       'Earthquake',
#       'Rock Blast']}]}],
#  'Yamper': [],
#  'Boltund': [{'PU': [{'Wallbreaker': ['Thunder Fang',
#       'Fire Fang',
#       'Play Rough',
#       'Psychic Fangs',
#       'Volt Switch']},
#     {'Choice Scarf': ['Thunder Fang',
#       'Fire Fang',
#       'Play Rough',
#       'Volt Switch']}]}],
#  'Rolycoly': [],
#  'Carkol': [{'NFE': [{'Specially Defensive Spinner': ['Rapid Spin',
#       'Heat Crash',
#       'Rock Blast',
#       'Spikes',
#       'Stealth Rock',
#       'Will-O-Wisp']}]}],
#  'Coalossal': [{'ZU': [{'Specially Defensive': ['Spikes',
#       'Stealth Rock',
#       'Rapid Spin',
#       'Stealth Rock',
#       'Rock Blast',
#       'Flamethrower']}]}],
#  'Applin': [],
#  'Flapple': [{'ZU': [{'Wallbreaker': ['Grav Apple',
#       'Draco Meteor',
#       'Outrage',
#       'Sucker Punch',
#       'Grassy Glide',
#       'U-turn']}]}],
#  'Appletun': [{'PU': [{'Choice Specs': ['Draco Meteor',
#       'Apple Acid',
#       'Dragon Pulse',
#       'Giga Drain']},
#     {'Tank': ['Draco Meteor',
#       'Apple Acid',
#       'Recover',
#       'Body Press',
#       'Leech Seed']},
#     {'Physically Defensive': ['Recover',
#       'Apple Acid',
#       'Dragon Pulse',
#       'Leech Seed',
#       'Body Press']}]}],
#  'Silicobra': [],
#  'Sandaconda': [{'PU': [{'Stealth Rock': ['Stealth Rock',
#       'Earthquake',
#       'Glare',
#       'Rest']}]}],
#  'Cramorant': [{'ZU': [{'Defog': ['Defog', 'Roost', 'Surf', 'Brave Bird']}]}],
#  'Arrokuda': [{'LC': [{'All-out Attacker': ['Liquidation',
#       'Close Combat',
#       'Psychic Fangs',
#       'Drill Run',
#       'Aqua Jet']}]}],
#  'Barraskewda': [{'OU': [{'Choice Band': ['Liquidation',
#       'Close Combat',
#       'Flip Turn',
#       'Aqua Jet',
#       'Psychic Fangs']}]}],
#  'Toxel': [],
#  'Toxtricity': [{'RU': [{'Choice Specs': ['Boomburst',
#       'Overdrive',
#       'Volt Switch',
#       'Sludge Bomb',
#       'Snarl']}]},
#   {'OU': [{'Shift Gear': ['Shift Gear',
#       'Boomburst',
#       'Overdrive',
#       'Drain Punch']}]},
#   {'UU': [{'Choice Specs': ['Overdrive',
#       'Sludge Wave',
#       'Boomburst',
#       'Volt Switch']},
#     {'Shift Gear': ['Overdrive', 'Sludge Wave', 'Boomburst', 'Shift Gear']}]}],
#  'Sizzlipede': [],
#  'Centiskorch': [{'NU': [{'All-out Attacker': ['Fire Lash',
#       'Leech Life',
#       'Knock Off',
#       'Power Whip']}]},
#   {'PU': [{'Wallbreaker': ['Fire Lash',
#       'Leech Life',
#       'Power Whip',
#       'Knock Off']}]},
#   {'ZU': [{'Wallbreaker': ['Fire Lash',
#       'Knock Off',
#       'Power Whip',
#       'Leech Life',
#       'Coil']}]}],
#  'Clobbopus': [],
#  'Grapploct': [{'PU': [{'Bulk Up': ['Bulk Up',
#       'Drain Punch',
#       'Brutal Swing',
#       'Sucker Punch']}]}],
#  'Sinistea': [],
#  'Polteageist': [{'UU': [{'Shell Smash': ['Shell Smash',
#       'Shadow Ball',
#       'Stored Power',
#       'Giga Drain']}]},
#   {'RU': [{'Shell Smash': ['Shell Smash',
#       'Strength Sap',
#       'Shadow Ball',
#       'Giga Drain']}]}],
#  'Hatenna': [],
#  'Hattrem': [{'NFE': [{'Support': ['Psychic',
#       'Giga Drain',
#       'Mystical Fire',
#       'Healing Wish']},
#     {'Choice Specs': ['Psychic',
#       'Mystical Fire',
#       'Dazzling Gleam',
#       'Healing Wish']}]},
#   {'PU': [{'Defensive': ['Psychic',
#       'Mystical Fire',
#       'Giga Drain',
#       'Nuzzle',
#       'Healing Wish',
#       'Calm Mind']}]},
#   {'ZU': [{'Magic Bounce': ['Psychic',
#       'Mystical Fire',
#       'Rest',
#       'Sleep Talk']}]}],
#  'Hatterene': [{'UU': [{'Calm Mind': ['Calm Mind',
#       'Draining Kiss',
#       'Psyshock',
#       'Psychic',
#       'Mystical Fire']}]},
#   {'OU': [{'Calm Mind': ['Calm Mind',
#       'Psyshock',
#       'Draining Kiss',
#       'Mystical Fire']}]}],
#  'Impidimp': [],
#  'Morgrem': [{'NFE': [{'Screens': ['Light Screen',
#       'Reflect',
#       'Thunder Wave',
#       'Taunt',
#       'Dazzling Gleam']},
#     {'Nasty Plot': ['Nasty Plot',
#       'Dazzling Gleam',
#       'Dark Pulse',
#       'Sucker Punch',
#       'Burning Jealousy']}]}],
#  'Grimmsnarl': [{'Uber': [{'Dual Screens': ['Play Rough',
#       'Light Screen',
#       'Reflect',
#       'Taunt']}]},
#   {'OU': [{'Dual Screens': ['Reflect',
#       'Light Screen',
#       'Taunt',
#       'Spirit Break']}]}],
#  'Obstagoon': [{'RU': [{'Guts Wallbreaker': ['Facade',
#       'Knock Off',
#       'Close Combat',
#       'Switcheroo',
#       'Obstruct']}]},
#   {'OU': [{'Guts': ['Facade', 'Knock Off', 'Close Combat', 'Switcheroo']}]},
#   {'UU': [{'Guts': ['Facade', 'Knock Off', 'Rest', 'Sleep Talk']}]}],
#  'Perrserker': [{'PU': [{'Choice Band': ['Iron Head',
#       'Close Combat',
#       'Seed Bomb',
#       'U-turn']},
#     {'Assault Vest': ['Iron Head', 'Close Combat', 'Seed Bomb', 'U-turn']}]}],
#  'Cursola': [{'PU': [{'Weak Armor Breaker': ['Shadow Ball',
#       'Meteor Beam',
#       'Burning Jealousy',
#       'Endure']},
#     {'Choice Specs': ['Shadow Ball',
#       'Ice Beam',
#       'Hydro Pump',
#       'Burning Jealousy']}]}],
#  "Sirfetch'd": [{'NU': [{'Wallbreaker': ['Close Combat',
#       'Knock Off',
#       'First Impression',
#       'Brave Bird',
#       'Poison Jab']}]}],
#  'Mr. Rime': [{'PU': [{'Rapid Spin': ['Rapid Spin',
#       'Ice Beam',
#       'Freeze-Dry',
#       'Psychic',
#       'Healing Wish',
#       'Focus Blast']},
#     {'Choice Specs': ['Ice Beam',
#       'Psychic',
#       'Psyshock',
#       'Focus Blast',
#       'Shadow Ball']},
#     {'Specially Defensive': ['Slack Off',
#       'Rapid Spin',
#       'Freeze-Dry',
#       'Ice Beam',
#       'Toxic',
#       'Focus Blast']}]}],
#  'Runerigus': [{'PU': [{'Defensive': ['Stealth Rock',
#       'Earthquake',
#       'Body Press',
#       'Will-O-Wisp',
#       'Toxic Spikes',
#       'Poltergeist',
#       'Rest']},
#     {'Bulky Setup Sweeper': ['Iron Defense',
#       'Amnesia',
#       'Rest',
#       'Body Press']}]}],
#  'Milcery': [],
#  'Alcremie': [{'PU': [{'Offensive': ['Dazzling Gleam',
#       'Mystical Fire',
#       'Recover',
#       'Calm Mind',
#       'Aromatherapy']},
#     {'Bulky Booster': ['Acid Armor',
#       'Calm Mind',
#       'Rest',
#       'Stored Power',
#       'Dazzling Gleam']},
#     {'Three Attacks': ['Dazzling Gleam',
#       'Mystical Fire',
#       'Psychic',
#       'Recover']}]},
#   {'ZU': [{'Defensive Calm Mind + Recover': ['Calm Mind',
#       'Recover',
#       'Dazzling Gleam',
#       'Mystical Fire',
#       'Aromatherapy']},
#     {'Double Dance': ['Calm Mind', 'Acid Armor', 'Stored Power', 'Rest']},
#     {'Offensive': ['Dazzling Gleam',
#       'Mystical Fire',
#       'Psychic',
#       'Calm Mind',
#       'Recover']}]}],
#  'Falinks': [{'PU': [{'All-Out Attacker': ['Close Combat',
#       'First Impression',
#       'Throat Chop',
#       'Zen Headbutt',
#       'Poison Jab']},
#     {'Swords Dance': ['Swords Dance',
#       'Close Combat',
#       'Throat Chop',
#       'Zen Headbutt']},
#     {'No Retreat': ['No Retreat',
#       'Close Combat',
#       'Throat Chop',
#       'Zen Headbutt',
#       'Poison Jab']}]}],
#  'Pincurchin': [{'NU': [{'Terrain Setter': ['Rising Voltage',
#       'Scald',
#       'Recover',
#       'Spikes']}]},
#   {'PU': [{'Terrain Setter': ['Rising Voltage',
#       'Spikes',
#       'Toxic Spikes',
#       'Recover',
#       'Memento',
#       'Scald']},
#     {'Defensive': ['Discharge', 'Scald', 'Spikes', 'Toxic Spikes', 'Recover']},
#     {'Choice Specs': ['Rising Voltage',
#       'Scald',
#       'Hydro Pump',
#       'Thunderbolt',
#       'Toxic Spikes']}]}],
#  'Snom': [],
#  'Frosmoth': [{'PU': [{'Quiver Dance': ['Quiver Dance',
#       'Ice Beam',
#       'Bug Buzz',
#       'Giga Drain',
#       'Hurricane']}]},
#   {'ZU': [{'Quiver Dance': ['Quiver Dance',
#       'Ice Beam',
#       'Giga Drain',
#       'Substitute',
#       'Hurricane']}]}],
#  'Stonjourner': [{'PU': [{'Choice Scarf': ['Stone Edge',
#       'Heat Crash',
#       'Earthquake',
#       'Self-Destruct',
#       'Stealth Rock',
#       'Heavy Slam']},
#     {'Choice Band': ['Stone Edge',
#       'Heat Crash',
#       'Earthquake',
#       'Rock Slide',
#       'Self-Destruct']},
#     {'Stealth Rock / Rock Polish': ['Stealth Rock',
#       'Rock Polish',
#       'Stone Edge',
#       'Heat Crash',
#       'Earthquake']}]}],
#  'Eiscue': [{'PU': [{'Belly Drum': ['Belly Drum',
#       'Icicle Crash',
#       'Reversal',
#       'Zen Headbutt',
#       'Substitute']}]}],
#  'Indeedee': [{'RU': [{'Choice Specs': ['Expanding Force',
#       'Mystical Fire',
#       'Dazzling Gleam',
#       'Hyper Voice']},
#     {'Choice Scarf': ['Expanding Force',
#       'Dazzling Gleam',
#       'Mystical Fire',
#       'Trick']}]}],
#  'Indeedee-F': [{'UU': [{'Terrain Supporter': ['Expanding Force',
#       'Hyper Voice',
#       'Dazzling Gleam',
#       'Mystical Fire',
#       'Healing Wish']}]},
#   {'NU': [{'Choice Specs': ['Expanding Force',
#       'Mystical Fire',
#       'Dazzling Gleam',
#       'Trick']},
#     {'Choice Scarf': ['Expanding Force',
#       'Mystical Fire',
#       'Dazzling Gleam',
#       'Healing Wish',
#       'Trick']}]}],
#  'Morpeko': [{'PU': [{'Offensive Support': ['Aura Wheel',
#       'Parting Shot',
#       'Super Fang',
#       'Protect',
#       'Rapid Spin',
#       'Taunt']},
#     {'Wallbreaker': ['Aura Wheel',
#       'Crunch',
#       'Psychic Fangs',
#       'Seed Bomb',
#       'Parting Shot']},
#     {'Offensive Substitute': ['Substitute',
#       'Aura Wheel',
#       'Parting Shot',
#       'Protect',
#       'Super Fang']}]},
#   {'ZU': [{'Offensive Utility': ['Aura Wheel',
#       'Rapid Spin',
#       'Protect',
#       'Parting Shot']},
#     {'Choice Band': ['Aura Wheel', 'Crunch', 'Seed Bomb', 'Parting Shot']}]}],
#  'Cufant': [{'LC': [{'Bulky Attacker': ['Iron Head',
#       'Play Rough',
#       'Power Whip',
#       'High Horsepower',
#       'Superpower',
#       'Stealth Rock']}]}],
#  'Copperajah': [{'NU': [{'Stealth Rock': ['Stealth Rock',
#       'Heavy Slam',
#       'Power Whip',
#       'Heat Crash']},
#     {'Assault Vest': ['Heavy Slam',
#       'Power Whip',
#       'Stone Edge',
#       'Superpower',
#       'Heat Crash']}]}],
#  'Dracozolt': [{'OU': [{'Substitute + Fire Spin': ['Bolt Beak',
#       'Draco Meteor',
#       'Substitute',
#       'Fire Spin']},
#     {'Life Orb': ['Bolt Beak', 'Draco Meteor', 'Earthquake', 'Fire Blast']}]}],
#  'Arctozolt': [{'NU': [{'Offensive': ['Bolt Beak',
#       'Blizzard',
#       'Icicle Spear',
#       'Hail',
#       'Substitute']}]},
#   {'RU': [{'Hail Wallbreaker': ['Bolt Beak',
#       'Hydro Pump',
#       'Freeze-Dry',
#       'Blizzard']}]}],
#  'Dracovish': [{'Uber': [{'Choice Attacker': ['Fishious Rend',
#       'Outrage',
#       'Psychic Fangs',
#       'Crunch']}]}],
#  'Arctovish': [{'RU': [{'Hail Wallbreaker': ['Fishious Rend',
#       'Freeze-Dry',
#       'Icicle Crash',
#       'Stone Edge',
#       'Protect']}]}],
#  'Duraludon': [],
#  'Dreepy': [],
#  'Drakloak': [{'NFE': [{'Fast Utility': ['Will-O-Wisp',
#       'Thunder Wave',
#       'Hex',
#       'Fire Blast',
#       'Draco Meteor',
#       'U-turn']},
#     {'Choice Specs': ['Draco Meteor',
#       'Shadow Ball',
#       'Fire Blast',
#       'U-turn']}]}],
#  'Dragapult': [{'OU': [{'Choice Specs': ['Shadow Ball',
#       'Draco Meteor',
#       'U-turn',
#       'Hydro Pump']},
#     {'Offensive Pivot': ['Hex',
#       'Draco Meteor',
#       'U-turn',
#       'Thunder Wave',
#       'Will-O-Wisp']}]}],
#  'Zacian': [{'Uber': [{'Choice Band': ['Play Rough',
#       'Close Combat',
#       'Wild Charge',
#       'Crunch',
#       'Psychic Fangs']},
#     {'Swords Dance': ['Play Rough',
#       'Close Combat',
#       'Wild Charge',
#       'Swords Dance']}]}],
#  'Zamazenta': [{'Uber': [{'Choice Band': ['Close Combat',
#       'Crunch',
#       'Psychic Fangs',
#       'Wild Charge']}]}],
#  'Zamazenta-Crowned': [{'Uber': [{'Howl': ['Howl',
#       'Behemoth Bash',
#       'Close Combat',
#       'Wild Charge']}]}],
#  'Eternatus': [{'Uber': [{'Specially Defensive': ['Dynamax Cannon',
#       'Dragon Tail',
#       'Recover',
#       'Flamethrower',
#       'Mystical Fire',
#       'Toxic',
#       'Toxic Spikes']},
#     {'Offensive': ['Dynamax Cannon',
#       'Recover',
#       'Flamethrower',
#       'Sludge Bomb',
#       'Meteor Beam']}]}],
#  'Kubfu': [],
#  'Urshifu': [{'Uber': [{'Choice Band': ['Wicked Blow',
#       'Close Combat',
#       'U-turn',
#       'Sucker Punch']},
#     {'Bulk Up': ['Wicked Blow', 'Close Combat', 'Sucker Punch', 'Bulk Up']},
#     {'Choice Scarf': ['Wicked Blow',
#       'Close Combat',
#       'U-turn',
#       'Stone Edge']}]}],
#  'Urshifu-Rapid-Strike': [{'OU': [{'Choice Band': ['Surging Strikes',
#       'Close Combat',
#       'Aqua Jet',
#       'U-turn']}]}],
#  'Zarude': [{'RU': [{'Jungle Healing Pivot': ['Jungle Healing',
#       'Power Whip',
#       'Darkest Lariat',
#       'U-turn']},
#     {'Choice Scarf': ['Power Whip',
#       'Darkest Lariat',
#       'Close Combat',
#       'Rock Slide',
#       'U-turn']}]},
#   {'Uber': [{'Defensive': ['Bulk Up',
#       'Power Whip',
#       'Darkest Lariat',
#       'Jungle Healing']}]},
#   {'OU': [{'Bulk Up': ['Bulk Up',
#       'Jungle Healing',
#       'Power Whip',
#       'Darkest Lariat',
#       'Crunch']}]},
#   {'UU': [{'Heavy-Duty Boots': ['Power Whip',
#       'Darkest Lariat',
#       'U-turn',
#       'Jungle Healing']},
#     {'Choice Scarf': ['Power Whip',
#       'Darkest Lariat',
#       'Jungle Healing',
#       'Rock Slide',
#       'U-turn']}]}],
#  'Regieleki': [{'OU': [{'Screens Lead': ['Reflect',
#       'Light Screen',
#       'Rapid Spin',
#       'Explosion']}]},
#   {'Uber': [{'Offensive Hazard Control': ['Wild Charge',
#       'Rapid Spin',
#       'Explosion',
#       'Assurance']},
#     {'Electric Terrain Abuser': ['Rising Voltage',
#       'Thunder',
#       'Explosion',
#       'Rapid Spin',
#       'Volt Switch']}]}],
#  'Regidrago': [{'RU': [{'Dragon Dance': ['Dragon Dance',
#       'Outrage',
#       'Scale Shot',
#       'Thunder Fang',
#       'Substitute']},
#     {'Choice Band': ['Outrage',
#       'Scale Shot',
#       'Hammer Arm',
#       'Thunder Fang']}]}],
#  'Glastrier': [{'RU': [{'Tank': ['Swords Dance',
#       'Icicle Crash',
#       'High Horsepower',
#       'Close Combat',
#       'Substitute',
#       'Close Combat']}]}],
#  'Spectrier': [{'Uber': [{'Substitute': ['Substitute',
#       'Hex',
#       'Shadow Ball',
#       'Nasty Plot',
#       'Will-O-Wisp',
#       'Disable']}]}],
#  'Calyrex': [{'PU': [{'Choice Specs': ['Leaf Storm',
#       'Psychic',
#       'Pollen Puff',
#       'Trick']}]}],
#  'Calyrex-Ice': [{'Uber': [{'Choice Band': ['Glacial Lance',
#       'High Horsepower',
#       'Trick',
#       'Icicle Spear',
#       'Aromatherapy']},
#     {'Substitute Attacker': ['Glacial Lance',
#       'Body Press',
#       'Substitute',
#       'Iron Defense']},
#     {'Trick Room': ['Glacial Lance',
#       'High Horsepower',
#       'Swords Dance',
#       'Trick Room']}]}],
#  'Calyrex-Shadow': [{'Uber': [{'Choice Specs': ['Astral Barrage',
#       'Psyshock',
#       'Trick',
#       'Aromatherapy',
#       'Draining Kiss',
#       'Grass Knot']},
#     {'Choice Scarf': ['Astral Barrage', 'Psyshock', 'Trick', 'Aromatherapy']},
#     {'Substitute + Leech Seed': ['Astral Barrage',
#       'Substitute',
#       'Leech Seed',
#       'Nasty Plot',
#       'Taunt']},
#     {'Nasty Plot': ['Astral Barrage',
#       'Nasty Plot',
#       'Psyshock',
#       'Draining Kiss']}]}]}

# %% [markdown]
# <a id='Saving Our Data'></a>
# ### Saving Our Data

# %% [markdown]
# Let's go over the items that need to be saved:
# - pokemon_df
# - pokemon_removed_df
# - pokemon_types_df
# - pokemon_abilities_df
# - abilities_removed_df
# - moves_df
# - pokemon_learnsets_df
# - strategies_dict
#
# The dataframe files will be stored in the csv format, which seems standard.  The dictionary will be stored as a JSON, which also seems standard.

# %%
pokemon_df.to_csv('./data/pokemon_df.csv')
pokemon_removed_df.to_csv('./data/pokemon_removed_df.csv')
pokemon_types_df.to_csv('./data/pokemon_types_df.csv')
pokemon_abilities_df.to_csv('./data/pokemon_abilities_df.csv')
abilities_removed_df.to_series().to_csv('./data/abilities_removed_df.csv')
moves_df.to_csv('./data/moves_df.csv')
pokemon_learnsets_df.to_csv('./data/pokemon_learnsets_df.csv')

# %% [markdown]
# abilities_removed_df had to be converted to a series because it was only a pandas index object, which has no to_csv method.
#
# Now we have to save the strategies_dict as a json.

# %%
with open('./data/strategies_dict.json', 'w') as outfile:
    json.dump(strategies_dict, outfile)
